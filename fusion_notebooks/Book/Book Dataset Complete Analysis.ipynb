# %%
import os
import sys
import time
import numpy as np
import matplotlib.pyplot as plt
module_path = os.path.abspath(os.path.join('../../fusion'))
sys.path.append(module_path)

from preprocessing_datasets.preprocessing_utilities import ValueUtils
from preprocessing_datasets import load_dataset
from embedding_algorithms import sentence_embedding, set_embedding_model
from dimensionality_reduction_algorithms import dimension_reduction_algorithms
from cluster_algorithms import cluster_algorithm

from helper import load_by_index, get_author_candidates, getFinalAuthors, launchWithoutReductionFusion
from plot_tools import plotChart, plotCluster
from evaluation import *

# %%
key_values = {
    'model_type':'bilstm',
    'char_level':False,
    'model_version': 2,
    'rnn_dim':1024,
    'verbose':1,
    'attributes_list': ['author'],
    'embedding_type': 'inferSent',
    'dataset': 'clean_book',
    'cluster_method': 'hierarchy',
    'num_clusters_rate': 0.1,
    'block_length_thresold': 0.2,
    'acceptance_diff': 0,
    'block_weight': 2,
}

# %%
dataset_name, table_group_by_isbn, isbn_list, true_authors = load_dataset(key_values)
# Out:
# dataset: clean_book
# Loading time is: 2.7775821685791016

# %%
set_embedding_model(key_values)
# Out:
# Vocab size : 2196017
# model_version: 2
# rnn_dim: 1024
# model_type: bilstm
# char_level: False
# Setup time is: 270.20252323150635

# %%
start_time = time.time()
finalAuthors, trueAuthors = launchWithoutReductionFusion(table_group_by_isbn, isbn_list, true_authors, key_values)
print("Total time is: {0}".format(time.time() - start_time))
# Out:
# ISBN: 0007197160
# true author: Marren Peter
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.7847087383270264
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.04017305374145508
# Discarted candidate: [{'conservation officer': 2, 'former scientist': 2}, {'marren naturalist peter': 2}]
# Possible candidate: [{'marren peter': 19}]
# lengthNecessary: 5.0
# [{'marren peter': 19}]
# acceptance_diff 0
# ['marren peter'] VS true_author: ['marren peter']
# ISBN: 0029011086
# true author: Averill James R.,Nunley Elma P.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06728696823120117
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0026459693908691406
# Discarted candidate: [{'elma nunley p': 4}, {'averill': 1, 'james r': 1}]
# Possible candidate: [{'averill james r': 21}]
# lengthNecessary: 5.4
# [{'averill james r': 21}]
# acceptance_diff 0
# ['averill james r'] VS true_author: ['averill james r', 'elma nunley p']
# ISBN: 0046500022
# true author: Zimmerman Mark
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04298710823059082
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009739398956298828
# Discarted candidate: []
# Possible candidate: [{'m zimmerman': 1, 'mark zimmerman': 2, 'mark zimmermann': 4, 'zimmerman': 1}]
# lengthNecessary: 1.6
# [{'m zimmerman': 1, 'mark zimmerman': 2, 'mark zimmermann': 4, 'zimmerman': 1}]
# acceptance_diff 0
# ['mark zimmermann'] VS true_author: ['mark zimmerman']
# ISBN: 0060473738
# true author: Zinn Maxine Baca,Eitzen Stanley D.,Wells Barbara
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08790302276611328
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0020499229431152344
# Discarted candidate: [{'baca': 1, 'baca d eitzen': 1, 'd eitzen': 1}]
# Possible candidate: [{'baca maxine zinn': 9, 'maxine stanley zinn': 1, 'maxine zinn': 1}, {'d eitzen stanley': 8, 'stanley': 1}]
# lengthNecessary: 4.6000000000000005
# [{'baca maxine zinn': 9, 'maxine stanley zinn': 1, 'maxine zinn': 1}, {'d eitzen stanley': 8, 'stanley': 1}]
# acceptance_diff 0
# ['baca maxine zinn', 'd eitzen stanley'] VS true_author: ['baca maxine zinn', 'd eitzen stanley', 'barbara wells']
# ISBN: 0060621036
# true author: Dycus Jim,Dycus Barbara
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.030688047409057617
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0013260841369628906
# Discarted candidate: [{'barbara dycus': 1}]
# Possible candidate: [{'dycus jim': 10}]
# lengthNecessary: 2.2
# [{'dycus jim': 10}]
# acceptance_diff 0
# ['dycus jim'] VS true_author: ['dycus jim', 'barbara dycus']
# ISBN: 0060884614
# true author: Winchester Simon
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1103968620300293
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 6
# Blocking time is: 0.005820035934448242
# Discarted candidate: [{'author': 3}, {'historian simon winchester': 2}, {'historian simon winchester': 1}, {'simon winchester': 1}, {'simon winchester': 1}]
# Possible candidate: [{'simon winchester': 52}]
# lengthNecessary: 12.0
# [{'simon winchester': 52}]
# acceptance_diff 0
# ['simon winchester'] VS true_author: ['simon winchester']
# ISBN: 0061684384
# true author: Von Kat D.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.20251917839050293
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.01561594009399414
# Discarted candidate: [{'nikki sixx': 2}, {'aa vv': 1}, {'foreword nikki sixx': 1}, {'d kat': 1}, {'varios': 1}, {'kat vond': 1}, {'collectif': 1}, {'kat vond': 1}, {'kat vond': 1}]
# Possible candidate: [{'d kat von': 104}]
# lengthNecessary: 22.8
# [{'d kat von': 104}]
# acceptance_diff 0
# ['d kat von'] VS true_author: ['d kat von']
# ISBN: 0071471723
# true author: O'Kelly Eugene
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1578989028930664
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.011104106903076172
# Discarted candidate: [{"gene o'kelly": 11}, {"eugene o'kelly": 2}, {'andrew postman': 2}, {'eugene kelly o': 1}, {"gene o'kelly": 1}, {'andrew postman': 1}, {"gene o'kelly": 1}, {'andrew postman': 1}]
# Possible candidate: [{"eugene o'kelly": 40, 'eugene okelly': 2}, {'andrew postman': 33}]
# lengthNecessary: 19.0
# [{"eugene o'kelly": 40, 'eugene okelly': 2}, {'andrew postman': 33}]
# acceptance_diff 0
# ["eugene o'kelly", 'andrew postman'] VS true_author: ["eugene o'kelly"]
# ISBN: 0073123137
# true author: Spiceland,Sepe,Tomassini
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07592105865478516
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.003503084182739258
# Discarted candidate: [{'spiceland': 1, 'tomassini': 2}]
# Possible candidate: [{'f james sepe': 11, 'sepe spiceland': 2}, {'david j spiceland': 12}, {'a lawrence tomassini': 11}]
# lengthNecessary: 7.800000000000001
# [{'f james sepe': 11, 'sepe spiceland': 2}, {'david j spiceland': 12}, {'a lawrence tomassini': 11}]
# acceptance_diff 0
# ['f james sepe', 'david j spiceland', 'a lawrence tomassini'] VS true_author: ['sepe spiceland', 'tomassini']
# ISBN: 0091827884
# true author: Gray Rose,Roger Ruth
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06695294380187988
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.001990079879760742
# Discarted candidate: [{'gray rogers rose ruth': 4}]
# Possible candidate: [{'rogers ruth': 13}, {'gray': 1, 'gray rose': 12}]
# lengthNecessary: 6.0
# [{'rogers ruth': 13}, {'gray': 1, 'gray rose': 12}]
# acceptance_diff 0
# ['rogers ruth', 'gray rose'] VS true_author: ['gray rose', 'roger ruth']
# ISBN: 009190062X
# true author: Brundle Martin,Hamilton Maurice
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.13521575927734375
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 9
# Blocking time is: 0.009406805038452148
# Discarted candidate: [{'brundle martin': 1}, {'brundle martin': 1}, {'hamilton maurice': 1}, {'brundle martin': 1}, {'brundle martin': 1}, {'hamilton maurice': 1}, {'brundle martin': 1}]
# Possible candidate: [{'brundle martin': 43}, {'hamilton maurice': 31}]
# lengthNecessary: 16.2
# [{'brundle martin': 43}, {'hamilton maurice': 31}]
# acceptance_diff 0
# ['brundle martin', 'hamilton maurice'] VS true_author: ['brundle martin', 'hamilton maurice']
# ISBN: 0133651142
# true author: Abraham George
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04962873458862305
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009889602661132812
# Discarted candidate: []
# Possible candidate: [{'abraham george': 7, 'abraham katy': 2, 'katy': 1}]
# lengthNecessary: 2.0
# [{'abraham george': 7, 'abraham katy': 2, 'katy': 1}]
# acceptance_diff 0
# ['abraham george'] VS true_author: ['abraham george']
# ISBN: 0155463071
# true author: Sommerfeld  Ray M.,Anderson Hershel M.,Brock Horace R.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04289889335632324
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.001531839370727539
# Discarted candidate: []
# Possible candidate: [{'anderson hershel m': 1, 'brock horace r': 1, 'm ray sommerfeld': 3}]
# lengthNecessary: 1.0
# [{'anderson hershel m': 1, 'brock horace r': 1, 'm ray sommerfeld': 3}]
# acceptance_diff 0
# ['m ray sommerfeld'] VS true_author: ['m ray sommerfeld', 'anderson hershel m', 'brock horace r']
# ISBN: 0198549822
# true author: Majerus Michael E. N.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06032276153564453
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0016529560089111328
# Discarted candidate: []
# Possible candidate: [{'e m majerus n': 2, 'e majerus michael n': 12}, {'majerus michael': 4}]
# lengthNecessary: 3.6
# [{'e m majerus n': 2, 'e majerus michael n': 12}, {'majerus michael': 4}]
# acceptance_diff 0
# ['e majerus michael n'] VS true_author: ['e majerus michael n']
# ISBN: 0230116450
# true author: Bernd Schmitt,Van Zutphen Glenn
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09162306785583496
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 6
# Blocking time is: 0.004332780838012695
# Discarted candidate: [{'george witte': 1, 'glenn': 3}, {'van zutphen': 3}, {'schmitt': 3}, {'bernd': 3}]
# Possible candidate: [{'bernd schmitt': 25}, {'glenn van zutphen': 19}]
# lengthNecessary: 11.4
# [{'bernd schmitt': 25}, {'glenn van zutphen': 19}]
# acceptance_diff 0
# ['bernd schmitt', 'glenn van zutphen'] VS true_author: ['bernd schmitt', 'glenn van zutphen']
# ISBN: 0241113873
# true author: Critchley Julian
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03892207145690918
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0014612674713134766
# Discarted candidate: [{'colin wheeler': 1}]
# Possible candidate: [{'critchley': 1, 'critchley julian': 17}]
# lengthNecessary: 3.8000000000000003
# [{'critchley': 1, 'critchley julian': 17}]
# acceptance_diff 0
# ['critchley julian'] VS true_author: ['critchley julian']
# ISBN: 0252005503
# true author: Osgood Charles E.,May William H.,Miron Murray S.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05661797523498535
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0013492107391357422
# Discarted candidate: []
# Possible candidate: [{'charles e osgood': 5, 'miron': 1, 'miron murray s': 4}, {'author': 2, 'h may william': 5}]
# lengthNecessary: 3.4000000000000004
# [{'charles e osgood': 5, 'miron': 1, 'miron murray s': 4}, {'author': 2, 'h may william': 5}]
# acceptance_diff 0
# ['charles e osgood', 'h may william'] VS true_author: ['charles e osgood', 'h may william', 'miron murray s']
# ISBN: 0262680718
# true author: Rosenbloom Paul S.,Laird John E.,Newell Allen
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0369112491607666
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.001657247543334961
# Discarted candidate: []
# Possible candidate: [{'allen newell': 1, 'e john laird': 1, 'paul rosenbloom s': 3}]
# lengthNecessary: 1.0
# [{'allen newell': 1, 'e john laird': 1, 'paul rosenbloom s': 3}]
# acceptance_diff 0
# ['paul rosenbloom s'] VS true_author: ['paul rosenbloom s', 'e john laird', 'allen newell']
# ISBN: 027363027X
# true author: Black Andrew,Wright Philip,Bachman John E.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.2895677089691162
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 9
# Blocking time is: 0.013953924179077148
# Discarted candidate: [{'andrew black': 15}, {'backman e john': 1, 'black davies john': 1, 'davies john': 6}, {'maskall mike': 7}, {'andrew black dr': 5, 'black dr': 1}, {'davies dr john': 5}, {'andrew': 1, 'andrew b': 1, 'andrew philip': 1, 'wright': 1}, {'price waterhouse': 1}]
# Possible candidate: [{'philip wright': 20, 'phillip wright': 5}, {'bachman e john': 18, 'bachman john': 1}]
# lengthNecessary: 18.0
# [{'philip wright': 20, 'phillip wright': 5}, {'bachman e john': 18, 'bachman john': 1}]
# acceptance_diff 0
# ['philip wright', 'bachman e john'] VS true_author: ['andrew black', 'philip wright', 'bachman e john']
# ISBN: 0300057385
# true author: Pointon  Marcia
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04290509223937988
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0011518001556396484
# Discarted candidate: [{'marcia pointon r': 1}]
# Possible candidate: [{'marcia pointon': 12}]
# lengthNecessary: 2.6
# [{'marcia pointon': 12}]
# acceptance_diff 0
# ['marcia pointon'] VS true_author: ['marcia pointon']
# ISBN: 0307264653
# true author: Updike John
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.19161510467529297
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.016817331314086914
# Discarted candidate: [{'john uipdike': 1}, {'joihn updike': 1}, {'***pulitzer author john prize updike': 1}, {'john professor updike': 1}, {'john professor updike': 1}, {'professor': 1}, {'john updike': 1}, {'john updike': 1}, {'john updike': 1}]
# Possible candidate: [{'john updike': 113}]
# lengthNecessary: 24.400000000000002
# [{'john updike': 113}]
# acceptance_diff 0
# ['john updike'] VS true_author: ['john updike']
# ISBN: 0312862830
# true author: Cochran Molly,Murphy Warren
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1759328842163086
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.01592278480529785
# Discarted candidate: [{'cochran': 1}, {'murphy warren': 1}, {'murphy warren': 1}, {'murphy warren': 1}, {'murphy warren': 1}, {'murphy warren': 1}, {'cochran molly': 1}, {'murphy warren': 1}]
# Possible candidate: [{'cochran molly': 55}, {'murphy warren': 47}]
# lengthNecessary: 22.0
# [{'cochran molly': 55}, {'murphy warren': 47}]
# acceptance_diff 0
# ['cochran molly', 'murphy warren'] VS true_author: ['cochran molly', 'murphy warren']
# ISBN: 0316027677
# true author: McCracken Elizabeth
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03709983825683594
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0006930828094482422
# Discarted candidate: []
# Possible candidate: [{'elisabeth mccracken': 1, 'elizabeth mccracken': 1}]
# lengthNecessary: 0.4
# [{'elisabeth mccracken': 1, 'elizabeth mccracken': 1}]
# acceptance_diff 0
# ['elisabeth mccracken'] VS true_author: ['elizabeth mccracken']
# ISBN: 0345245660
# true author: Deweese Jean
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.032681941986083984
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0010290145874023438
# Discarted candidate: [{'ballantine books': 1}]
# Possible candidate: [{'deweese jean': 10}]
# lengthNecessary: 2.2
# [{'deweese jean': 10}]
# acceptance_diff 0
# ['deweese jean'] VS true_author: ['deweese jean']
# ISBN: 0345307704
# true author: Simak Clifford D.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06280374526977539
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.0027642250061035156
# Discarted candidate: [{'clifford simak': 5}, {'d': 1}, {'clifford simak': 1}]
# Possible candidate: [{'clifford d simak': 32}]
# lengthNecessary: 7.800000000000001
# [{'clifford d simak': 32}]
# acceptance_diff 0
# ['clifford d simak'] VS true_author: ['clifford d simak']
# ISBN: 0361004591
# true author: Blyton Enid
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04607701301574707
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0016219615936279297
# Discarted candidate: [{'beek illus': 1}, {'blyton enid': 1}]
# Possible candidate: [{'blyton enid': 20}]
# lengthNecessary: 4.4
# [{'blyton enid': 20}]
# acceptance_diff 0
# ['blyton enid'] VS true_author: ['blyton enid']
# ISBN: 0374514127
# true author: Avedon Richard
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05807328224182129
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0018157958984375
# Discarted candidate: [{'noonday press': 1}]
# Possible candidate: [{'avedon richard': 18}, {'essay harold rosenberg': 1, 'harold rosenberg': 7}]
# lengthNecessary: 5.4
# [{'avedon richard': 18}, {'essay harold rosenberg': 1, 'harold rosenberg': 7}]
# acceptance_diff 0
# ['avedon richard', 'harold rosenberg'] VS true_author: ['avedon richard']
# ISBN: 0375406301
# true author: Updike John
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0883328914642334
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 6
# Blocking time is: 0.004220247268676758
# Discarted candidate: [{'john upkike': 1}, {'john updike': 1}, {'john updike': 1}, {'john updike': 1}, {'john updike': 1}]
# Possible candidate: [{'john updike': 49}]
# lengthNecessary: 10.8
# [{'john updike': 49}]
# acceptance_diff 0
# ['john updike'] VS true_author: ['john updike']
# ISBN: 0380758083
# true author: Feather Jane
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07153511047363281
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.0027132034301757812
# Discarted candidate: [{'feather j': 1}, {'feather jane': 1}, {'feather jane': 1}]
# Possible candidate: [{'feather jane': 35}]
# lengthNecessary: 7.6000000000000005
# [{'feather jane': 35}]
# acceptance_diff 0
# ['feather jane'] VS true_author: ['feather jane']
# ISBN: 0393241645
# true author: Aldersey-Williams Hugh
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0656270980834961
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.0029268264770507812
# Discarted candidate: [{'willia': 1}, {'aldersey-williams h': 1}, {'aldersey hugh williams': 1}]
# Possible candidate: [{'aldersey-willia hugh': 3, 'aldersey-williams hugh': 32, 'alderseyand hugh': 1}]
# lengthNecessary: 7.800000000000001
# [{'aldersey-willia hugh': 3, 'aldersey-williams hugh': 32, 'alderseyand hugh': 1}]
# acceptance_diff 0
# ['aldersey-williams hugh'] VS true_author: ['aldersey-williams hugh']
# ISBN: 039475994X
# true author: Thomsen Moritz
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04504799842834473
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0012180805206298828
# Discarted candidate: [{'maurice thompson': 1}]
# Possible candidate: [{'moritz thomsen': 16}]
# lengthNecessary: 3.4000000000000004
# [{'moritz thomsen': 16}]
# acceptance_diff 0
# ['moritz thomsen'] VS true_author: ['moritz thomsen']
# ISBN: 0439436559
# true author: Nix Garth
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09244275093078613
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 6
# Blocking time is: 0.004684925079345703
# Discarted candidate: [{'garth nix': 2}, {'garth nix': 1}, {'garth nix': 1}, {'garth nix': 1}, {'garth nix': 1}]
# Possible candidate: [{'garth nix': 45}]
# lengthNecessary: 10.200000000000001
# [{'garth nix': 45}]
# acceptance_diff 0
# ['garth nix'] VS true_author: ['garth nix']
# ISBN: 0439670195
# true author: Kerr P. B.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.24574589729309082
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.023624897003173828
# Discarted candidate: [{'kerr philip': 18}, {'aka': 1, 'of': 1, 'the': 1}, {'b': 2}, {'b ker p': 1}, {'lamp': 1}, {'septet': 1}, {'novel': 1}, {'debut': 1}, {'children': 1}]
# Possible candidate: [{'b kerr p': 99, 'kerr p': 1}]
# lengthNecessary: 25.8
# [{'b kerr p': 99, 'kerr p': 1}]
# acceptance_diff 0
# ['b kerr p'] VS true_author: ['b kerr p']
# ISBN: 0471247642
# true author: Hamilton William Peter
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0778188705444336
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.002187967300415039
# Discarted candidate: [{'books marketplace': 4}, {'books marketplace staff': 1}, {'e hamilton': 1}]
# Possible candidate: [{'hamilton peter william': 28}]
# lengthNecessary: 6.800000000000001
# [{'hamilton peter william': 28}]
# acceptance_diff 0
# ['hamilton peter william'] VS true_author: ['hamilton peter william']
# ISBN: 0471387401
# true author: Blocker Linda,Hill Julia
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.16217684745788574
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 7
# Blocking time is: 0.005446195602416992
# Discarted candidate: [{'hill julia': 1}, {'america culinary institute of': 1}, {'blocker hill julia linda': 1}, {'culinary institute o the': 1}]
# Possible candidate: [{'blocker linda': 24}, {'hill julia': 19}, {'america culinary institute of the': 18}]
# lengthNecessary: 13.0
# [{'blocker linda': 24}, {'hill julia': 19}, {'america culinary institute of the': 18}]
# acceptance_diff 0
# ['blocker linda', 'hill julia', 'america culinary institute of the'] VS true_author: ['blocker linda', 'hill julia']
# ISBN: 0471430161
# true author: Stein Ben,DeMuth Phil
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.13315391540527344
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 9
# Blocking time is: 0.009147882461547852
# Discarted candidate: [{'ben demuth phil stein': 1}, {'de muth phil': 1}, {'d ph': 1}, {'benjamin stein': 1}, {'bill stein': 1}, {'demuth phil': 1}, {'demuth phil': 1}]
# Possible candidate: [{'ben stein': 44}, {'demuth phil': 34}]
# lengthNecessary: 17.0
# [{'ben stein': 44}, {'demuth phil': 34}]
# acceptance_diff 0
# ['ben stein', 'demuth phil'] VS true_author: ['ben stein', 'demuth phil']
# ISBN: 0471987638
# true author: Charan Ram,Tichy Noel M.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05418586730957031
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.00220489501953125
# Discarted candidate: [{'m': 1, 'noel': 1}]
# Possible candidate: [{'m noel tichy': 9, 'noel tichy': 1, 'ram tichy': 1}, {'charan': 2, 'charan ram': 8}]
# lengthNecessary: 4.6000000000000005
# [{'m noel tichy': 9, 'noel tichy': 1, 'ram tichy': 1}, {'charan': 2, 'charan ram': 8}]
# acceptance_diff 0
# ['m noel tichy', 'charan ram'] VS true_author: ['charan ram', 'm noel tichy']
# ISBN: 050034163X
# true author: Zellner Peter
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.054451942443847656
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0021729469299316406
# Discarted candidate: []
# Possible candidate: [{'aaron betsky': 3, 'etc': 1, 'etc zellner': 2, 'peter': 2, 'peter zellner': 6}, {'akira suzuki': 3, 'davina jackson': 3}]
# lengthNecessary: 4.0
# [{'aaron betsky': 3, 'etc': 1, 'etc zellner': 2, 'peter': 2, 'peter zellner': 6}, {'akira suzuki': 3, 'davina jackson': 3}]
# acceptance_diff 0
# ['peter zellner', 'akira suzuki', 'davina jackson'] VS true_author: ['peter zellner']
# ISBN: 0517588242
# true author: Tekulsky Mathew
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08633613586425781
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 7
# Blocking time is: 0.005530834197998047
# Discarted candidate: [{'matthew tekulsky': 5}, {'illus': 1}, {'claire moritz': 1}, {'clair moritz': 1}, {'mathew tekulsky': 1}, {'mathew tekulsky': 1}]
# Possible candidate: [{'mathew tekulsky': 51}]
# lengthNecessary: 12.200000000000001
# [{'mathew tekulsky': 51}]
# acceptance_diff 0
# ['mathew tekulsky'] VS true_author: ['mathew tekulsky']
# ISBN: 0520077350
# true author: Ruderman David B.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04184985160827637
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0024590492248535156
# Discarted candidate: [{'by': 1, 'db ruderman': 1}]
# Possible candidate: [{'b david ruderman': 17, 'david ruderman': 1}]
# lengthNecessary: 4.0
# [{'b david ruderman': 17, 'david ruderman': 1}]
# acceptance_diff 0
# ['b david ruderman'] VS true_author: ['b david ruderman']
# ISBN: 0521833256
# true author: Schilling Govert
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04942893981933594
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.0025031566619873047
# Discarted candidate: [{'aa vv': 1}, {'govert schilling': 1}, {'govert schilling': 1}]
# Possible candidate: [{'govert schilling': 31}]
# lengthNecessary: 6.800000000000001
# [{'govert schilling': 31}]
# acceptance_diff 0
# ['govert schilling'] VS true_author: ['govert schilling']
# ISBN: 0553292153
# true author: Toffler Alvin
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08956122398376465
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 7
# Blocking time is: 0.005688905715942383
# Discarted candidate: [{'alvin toffler': 2}, {'a toffler': 1}, {'alvin toffler': 1}, {'alvin toffler': 1}, {'alvin toffler': 1}, {'alvin toffler': 1}]
# Possible candidate: [{'alvin toffler': 60}]
# lengthNecessary: 13.4
# [{'alvin toffler': 60}]
# acceptance_diff 0
# ['alvin toffler'] VS true_author: ['alvin toffler']
# ISBN: 0582311578
# true author: Cumberland Kenneth B.,Whitelaw James S.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.036650896072387695
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009760856628417969
# Discarted candidate: []
# Possible candidate: [{'b cumberland k': 1, 'b cumberland kenneth': 2, 'j s whitelaw': 2, 'james s whitelaw': 1}]
# lengthNecessary: 1.2000000000000002
# [{'b cumberland k': 1, 'b cumberland kenneth': 2, 'j s whitelaw': 2, 'james s whitelaw': 1}]
# acceptance_diff 0
# ['b cumberland kenneth', 'j s whitelaw'] VS true_author: ['b cumberland kenneth', 'james s whitelaw']
# ISBN: 0595487785
# true author: Alverson  Dayton L.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0623927116394043
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0013201236724853516
# Discarted candidate: []
# Possible candidate: [{'alverson d dayton dr l ph': 4, 'alverson dayton dr l': 5, 'dayton dr l': 1}, {'alverson': 1, 'alverson d ph': 1, 'alverson dayton l': 4}]
# lengthNecessary: 3.2
# [{'alverson d dayton dr l ph': 4, 'alverson dayton dr l': 5, 'dayton dr l': 1}, {'alverson': 1, 'alverson d ph': 1, 'alverson dayton l': 4}]
# acceptance_diff 0
# ['alverson dayton dr l'] VS true_author: ['alverson dayton l']
# ISBN: 0670805122
# true author: Katz Donald R.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.20036983489990234
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.012533903121948242
# Discarted candidate: [{'donald katz': 18}, {'adult viking': 1}, {'adult viking': 1}, {'donald katz r': 1}, {'donald katz r': 1}, {'donald katz r': 1}, {'donald katz r': 1}, {'donald katz r': 1}, {'donald katz r': 1}]
# Possible candidate: [{'donald katz r': 76}]
# lengthNecessary: 20.400000000000002
# [{'donald katz r': 76}]
# acceptance_diff 0
# ['donald katz r'] VS true_author: ['donald katz r']
# ISBN: 0671640984
# true author: Turnbull Colin M.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.10720205307006836
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 6
# Blocking time is: 0.004992961883544922
# Discarted candidate: [{'colin turnbull': 7}, {'turnbull': 2}, {'colin m turnbull': 1}, {'colin m turnbull': 1}, {'colin m turnbull': 1}]
# Possible candidate: [{'colin m turnbull': 48}]
# lengthNecessary: 12.0
# [{'colin m turnbull': 48}]
# acceptance_diff 0
# ['colin m turnbull'] VS true_author: ['colin m turnbull']
# ISBN: 0671743058
# true author: McCammon Robert
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1139230728149414
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 7
# Blocking time is: 0.005908966064453125
# Discarted candidate: [{'mccammon robert': 2}, {'mccammon robert': 2}, {'mccammon': 1}, {'mccammon r robert': 1}, {'mccammon r robert': 1}]
# Possible candidate: [{'mccammon robert': 43}, {'mccammon r robert': 14, 'mcgammon r robert': 5}]
# lengthNecessary: 13.8
# [{'mccammon robert': 43}, {'mccammon r robert': 14, 'mcgammon r robert': 5}]
# acceptance_diff 0
# ['mccammon robert'] VS true_author: ['mccammon robert']
# ISBN: 0671787551
# true author: Friedman Michael Jan
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.19544196128845215
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.015451908111572266
# Discarted candidate: [{'friedman~dave jan michael stern': 1}, {'friedman': 1}, {'richard rohmer': 1}, {'richard rohmer': 1}, {'dave stern': 1}, {'dave stern': 1}, {'dave stern': 1}, {'dave stern': 1}]
# Possible candidate: [{'friedman jan michael': 63}, {'dave stern': 36}]
# lengthNecessary: 21.400000000000002
# [{'friedman jan michael': 63}, {'dave stern': 36}]
# acceptance_diff 0
# ['friedman jan michael', 'dave stern'] VS true_author: ['friedman jan michael']
# ISBN: 0672213230
# true author: Dember Sol
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03268289566040039
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010521411895751953
# Discarted candidate: []
# Possible candidate: [{'dember': 1, 'dember jeffrey': 1, 'dember sol': 7, 'dember steven': 1}]
# lengthNecessary: 2.0
# [{'dember': 1, 'dember jeffrey': 1, 'dember sol': 7, 'dember steven': 1}]
# acceptance_diff 0
# ['dember sol'] VS true_author: ['dember sol']
# ISBN: 0679736395
# true author: Styron William
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.11711883544921875
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.011233091354370117
# Discarted candidate: [{'styron w': 1}, {'styron willam': 1}, {'styron willam': 1}, {'styron william': 1}, {'styron william': 1}, {'styron william': 1}, {'styron william': 1}, {'styron william': 1}, {'styron william': 1}]
# Possible candidate: [{'styron william': 86}]
# lengthNecessary: 19.0
# [{'styron william': 86}]
# acceptance_diff 0
# ['styron william'] VS true_author: ['styron william']
# ISBN: 0684850052
# true author: Sgubin Marta,Nicholas Nancy
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08252406120300293
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 5
# Blocking time is: 0.0038123130798339844
# Discarted candidate: [{'nancy nicholas': 8}, {'nancy nicholas': 2}, {'nancy nichols': 1}, {'contributor-nancy nicholas': 1}]
# Possible candidate: [{'marta sgubin': 38}]
# lengthNecessary: 10.0
# [{'marta sgubin': 38}]
# acceptance_diff 0
# ['marta sgubin'] VS true_author: ['marta sgubin', 'nancy nicholas']
# ISBN: 0688086586
# true author: McGarrity Mark
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.044088125228881836
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0019490718841552734
# Discarted candidate: [{'bartholomew gill': 1}, {'mark mcgarrity': 1}]
# Possible candidate: [{'mark mccarrity': 1, 'mark mcgarrity': 26}]
# lengthNecessary: 5.800000000000001
# [{'mark mccarrity': 1, 'mark mcgarrity': 26}]
# acceptance_diff 0
# ['mark mcgarrity'] VS true_author: ['mark mcgarrity']
# ISBN: 0691027781
# true author: Beisel Nicola
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06619596481323242
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0025620460510253906
# Discarted candidate: [{'beisel': 1}]
# Possible candidate: [{'beisel kay nicola': 15}, {'beisel nicola': 11}]
# lengthNecessary: 5.4
# [{'beisel kay nicola': 15}, {'beisel nicola': 11}]
# acceptance_diff 0
# ['beisel kay nicola'] VS true_author: ['beisel nicola']
# ISBN: 0710210876
# true author: Rinpoche Tulku Thondup
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04720592498779297
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0013549327850341797
# Discarted candidate: [{'thondup': 1, 'thondup tulko': 1}]
# Possible candidate: [{'rinpoche thondup tulku': 1, 'rinpoche thundup tulku': 10}]
# lengthNecessary: 2.6
# [{'rinpoche thondup tulku': 1, 'rinpoche thundup tulku': 10}]
# acceptance_diff 0
# ['rinpoche thundup tulku'] VS true_author: ['rinpoche thondup tulku']
# ISBN: 0718208943
# true author: Borer Eva  Maria
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06526899337768555
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0015301704406738281
# Discarted candidate: [{'hilda morris': 1, 'sheila watson': 1}]
# Possible candidate: [{'borer eva m': 1, 'borer eva maria': 13}]
# lengthNecessary: 3.2
# [{'borer eva m': 1, 'borer eva maria': 13}]
# acceptance_diff 0
# ['borer eva maria'] VS true_author: ['borer eva maria']
# ISBN: 0720402042
# true author: Florin Abeles
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02933216094970703
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010509490966796875
# Discarted candidate: []
# Possible candidate: [{'abel?s f': 1, 'abeles florin': 2}]
# lengthNecessary: 0.6000000000000001
# [{'abel?s f': 1, 'abeles florin': 2}]
# acceptance_diff 0
# ['abeles florin'] VS true_author: ['abeles florin']
# ISBN: 0731805712
# true author: Cornelius Helena
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.032418012619018555
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010480880737304688
# Discarted candidate: []
# Possible candidate: [{'bates john': 1, 'cornelius helen': 4, 'cornelius helena': 1}]
# lengthNecessary: 1.2000000000000002
# [{'bates john': 1, 'cornelius helen': 4, 'cornelius helena': 1}]
# acceptance_diff 0
# ['cornelius helen'] VS true_author: ['cornelius helena']
# ISBN: 0764310372
# true author: Snyder Jeffrey B.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05158495903015137
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0013229846954345703
# Discarted candidate: [{'snyder': 1}]
# Possible candidate: [{'b jeffrey snyder': 18}]
# lengthNecessary: 3.8000000000000003
# [{'b jeffrey snyder': 18}]
# acceptance_diff 0
# ['b jeffrey snyder'] VS true_author: ['b jeffrey snyder']
# ISBN: 0764317555
# true author: Skinner Tina
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.050785064697265625
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.001983165740966797
# Discarted candidate: [{'jenna palecko schuck': 5}, {'skinner': 1}]
# Possible candidate: [{'skinner tina': 21}]
# lengthNecessary: 5.4
# [{'skinner tina': 21}]
# acceptance_diff 0
# ['skinner tina'] VS true_author: ['skinner tina']
# ISBN: 0802019862
# true author: Ross Alexander M.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0728609561920166
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.0025992393493652344
# Discarted candidate: [{'beattie william': 5}, {'beatty dr william': 1}, {'beattie w': 1}]
# Possible candidate: [{'a m ross': 1, 'alexander m ross': 22, 'alexander ross': 1}]
# lengthNecessary: 6.2
# [{'a m ross': 1, 'alexander m ross': 22, 'alexander ross': 1}]
# acceptance_diff 0
# ['alexander m ross'] VS true_author: ['alexander m ross']
# ISBN: 0802115462
# true author: Weddle David
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05199289321899414
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0015900135040283203
# Discarted candidate: [{'american heritage': 1}]
# Possible candidate: [{'david peckinpah re sam weddle': 1, 'david weddle': 16}]
# lengthNecessary: 3.6
# [{'david peckinpah re sam weddle': 1, 'david weddle': 16}]
# acceptance_diff 0
# ['david weddle'] VS true_author: ['david weddle']
# ISBN: 0805048332
# true author: Brodkey Harold
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02527618408203125
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0011761188507080078
# Discarted candidate: []
# Possible candidate: [{'brodkey harold': 2, 'bruno giuseppe': 1}]
# lengthNecessary: 0.6000000000000001
# [{'brodkey harold': 2, 'bruno giuseppe': 1}]
# acceptance_diff 0
# ['brodkey harold'] VS true_author: ['brodkey harold']
# ISBN: 0810934159
# true author: Kastner Victoria
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.10963678359985352
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 6
# Blocking time is: 0.007592916488647461
# Discarted candidate: [{'foreword george plimpton': 2, 'george plimpton': 6}, {'garagliano victoria': 7}, {'garagliano photographer-victoria': 1}, {'foreword-george plimpton': 1}, {'garagliano photography principal victoria': 1}]
# Possible candidate: [{'kastner victoria': 41}]
# lengthNecessary: 11.8
# [{'kastner victoria': 41}]
# acceptance_diff 0
# ['kastner victoria'] VS true_author: ['kastner victoria']
# ISBN: 0811809285
# true author: Slavin Sara,Petzke Karl
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0705118179321289
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.00222015380859375
# Discarted candidate: [{'karl petzke': 2}]
# Possible candidate: [{'sara slavin': 16}, {'karl petzke': 12}]
# lengthNecessary: 6.0
# [{'sara slavin': 16}, {'karl petzke': 12}]
# acceptance_diff 0
# ['sara slavin', 'karl petzke'] VS true_author: ['sara slavin', 'karl petzke']
# ISBN: 0814416012
# true author: McIntosh Perry,Luecke Richard A.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03880500793457031
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0015022754669189453
# Discarted candidate: []
# Possible candidate: [{'a luecke richard': 8}, {'mcintosh perry': 8}]
# lengthNecessary: 3.2
# [{'a luecke richard': 8}, {'mcintosh perry': 8}]
# acceptance_diff 0
# ['a luecke richard', 'mcintosh perry'] VS true_author: ['mcintosh perry', 'a luecke richard']
# ISBN: 0816638772
# true author: Tuan Yi-Fu
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06943297386169434
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 5
# Blocking time is: 0.0039501190185546875
# Discarted candidate: [{'hoelscher steven tuan': 4}, {'yi-fu': 4}, {'hoelscher steven': 2}, {'e karen till': 1}]
# Possible candidate: [{'ti-fu tuan': 1, 'tuan': 1, 'tuan yi-fu': 33}]
# lengthNecessary: 9.200000000000001
# [{'ti-fu tuan': 1, 'tuan': 1, 'tuan yi-fu': 33}]
# acceptance_diff 0
# ['tuan yi-fu'] VS true_author: ['tuan yi-fu']
# ISBN: 0865580030
# true author: Winslow Carleton M.,Frye Nickola L.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.11493182182312012
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 7
# Blocking time is: 0.0053441524505615234
# Discarted candidate: [{'carleton winslow': 3}, {'frye nickola': 2}, {'frye l nikola': 1}, {'tay': 1}]
# Possible candidate: [{'carleton jr m winslow': 1, 'carleton m winslow': 20}, {'frye l nickola': 18}, {'coffman taylor': 16}]
# lengthNecessary: 12.4
# [{'carleton jr m winslow': 1, 'carleton m winslow': 20}, {'frye l nickola': 18}, {'coffman taylor': 16}]
# acceptance_diff 0
# ['carleton m winslow', 'frye l nickola', 'coffman taylor'] VS true_author: ['carleton m winslow', 'frye l nickola']
# ISBN: 0875962343
# true author: Jacques Pepin
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.026203155517578125
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0008189678192138672
# Discarted candidate: []
# Possible candidate: [{'jacques pepin': 1, 'jacques pepins': 1}]
# lengthNecessary: 0.4
# [{'jacques pepin': 1, 'jacques pepins': 1}]
# acceptance_diff 0
# ['jacques pepin'] VS true_author: ['jacques pepin']
# ISBN: 0876050461
# true author: Hill Cherry
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06736588478088379
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.0027298927307128906
# Discarted candidate: [{'klimesh richard': 1}, {'cherry hill': 1}, {'cherry hill': 1}]
# Possible candidate: [{'cherry hill': 34}]
# lengthNecessary: 7.4
# [{'cherry hill': 34}]
# acceptance_diff 0
# ['cherry hill'] VS true_author: ['cherry hill']
# ISBN: 0905895762
# true author: Vallejo Boris
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06098008155822754
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.001730203628540039
# Discarted candidate: [{'doris': 3}]
# Possible candidate: [{'boris': 1, 'boris s vallejo': 1, 'boris vallejo': 12}, {'doris text vallejo': 1, 'doris vallejo': 8}]
# lengthNecessary: 5.2
# [{'boris': 1, 'boris s vallejo': 1, 'boris vallejo': 12}, {'doris text vallejo': 1, 'doris vallejo': 8}]
# acceptance_diff 0
# ['boris vallejo'] VS true_author: ['boris vallejo']
# ISBN: 094920658X
# true author: Morgan Sally
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06398296356201172
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.0025207996368408203
# Discarted candidate: [{'jack mcphee': 3}, {'morgan sally': 2}, {'jack mcphee': 1}]
# Possible candidate: [{'morgan sally': 29}]
# lengthNecessary: 7.0
# [{'morgan sally': 29}]
# acceptance_diff 0
# ['morgan sally'] VS true_author: ['morgan sally']
# ISBN: 0951631705
# true author: Heinimann Max,Cheetham Chris
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03803110122680664
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009667873382568359
# Discarted candidate: []
# Possible candidate: [{'ans cheetham chris heinimann max': 1, 'cheetham chris': 4, 'heinimann max': 4}]
# lengthNecessary: 1.8
# [{'ans cheetham chris heinimann max': 1, 'cheetham chris': 4, 'heinimann max': 4}]
# acceptance_diff 0
# ['cheetham chris', 'heinimann max'] VS true_author: ['heinimann max', 'cheetham chris']
# ISBN: 0967252318
# true author: Fischer M. L.
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03570103645324707
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009748935699462891
# Discarted candidate: []
# Possible candidate: [{'fischer l m': 1, 'fischer l meade': 1, 'fischer meade': 1, 'na': 1}]
# lengthNecessary: 0.8
# [{'fischer l m': 1, 'fischer l meade': 1, 'fischer meade': 1, 'na': 1}]
# acceptance_diff 0
# ['fischer l m', 'fischer meade', 'na'] VS true_author: ['fischer l m']
# ISBN: 1403934037
# true author: Wagner-Martin Linda
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04456281661987305
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.0023789405822753906
# Discarted candidate: [{'l wagner-martin': 1}, {'prof': 1}, {'linda wagner-martin': 1}]
# Possible candidate: [{'linda wagner-martin': 30}]
# lengthNecessary: 6.6000000000000005
# [{'linda wagner-martin': 30}]
# acceptance_diff 0
# ['linda wagner-martin'] VS true_author: ['linda wagner-martin']
# ISBN: 1422608875
# true author: Goldstein Moshe
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03510093688964844
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009660720825195312
# Discarted candidate: []
# Possible candidate: [{'goldshtain mosheh': 1, 'goldstein moshe': 5, 'helmowitz malky': 2}]
# lengthNecessary: 1.6
# [{'goldshtain mosheh': 1, 'goldstein moshe': 5, 'helmowitz malky': 2}]
# acceptance_diff 0
# ['goldstein moshe'] VS true_author: ['goldstein moshe']
# ISBN: 1562827928
# true author: Johnston Ollie,Thomas Frank
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05237293243408203
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0018379688262939453
# Discarted candidate: [{'johnston ollie': 1}]
# Possible candidate: [{'johnston ollie': 18}, {'frank thomas': 9}]
# lengthNecessary: 5.6000000000000005
# [{'johnston ollie': 18}, {'frank thomas': 9}]
# acceptance_diff 0
# ['johnston ollie', 'frank thomas'] VS true_author: ['johnston ollie', 'frank thomas']
# ISBN: 159558191X
# true author: Moby,Park Miyun
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06609702110290527
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 5
# Blocking time is: 0.0036590099334716797
# Discarted candidate: [{'miyun park': 7}, {'moby park': 2}, {'and miyun park': 1}, {'moby': 1}]
# Possible candidate: [{'moby': 35}]
# lengthNecessary: 9.200000000000001
# [{'moby': 35}]
# acceptance_diff 0
# ['moby'] VS true_author: ['miyun moby park']
# ISBN: 1632384183
# true author: Burt Carl
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03575706481933594
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.000988006591796875
# Discarted candidate: []
# Possible candidate: [{'burt carl': 5, 'ny press research': 1}]
# lengthNecessary: 1.2000000000000002
# [{'burt carl': 5, 'ny press research': 1}]
# acceptance_diff 0
# ['burt carl'] VS true_author: ['burt carl']
# ISBN: 186152207X
# true author: Pass Christopher,Lowes Bryan,Robinson Andrew
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06922793388366699
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0019958019256591797
# Discarted candidate: []
# Possible candidate: [{'c l pass': 6, 'chris pass': 2, 'christopher pass': 1, 'pass': 5}, {'bryan lowes': 4, 'bryan lowes pass': 1, 'byran lowes': 3}, {'andrew robinson': 6, 'christopher': 1}]
# lengthNecessary: 5.800000000000001
# [{'c l pass': 6, 'chris pass': 2, 'christopher pass': 1, 'pass': 5}, {'bryan lowes': 4, 'bryan lowes pass': 1, 'byran lowes': 3}, {'andrew robinson': 6, 'christopher': 1}]
# acceptance_diff 0
# ['c l pass', 'bryan lowes', 'andrew robinson'] VS true_author: ['christopher pass', 'bryan lowes', 'andrew robinson']
# ISBN: 1861541961
# true author: Foote Huger
# embedding_type: inferSent
# ...
# true author: Dickinson Terence
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1774272918701172
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 8
# Blocking time is: 0.007266044616699219
# Discarted candidate: [{'bianchi john': 4}, {'dickinson terrence': 4}, {'dickinson terence': 1}, {'dickinson terence': 1}, {'dickinson terence': 1}, {'dickinson terence': 1}, {'dickinson terence': 1}]
# Possible candidate: [{'dickinson terence': 60}]
# lengthNecessary: 14.600000000000001
# [{'dickinson terence': 60}]
# acceptance_diff 0
# ['dickinson terence'] VS true_author: ['dickinson terence']
# ISBN: 1400052580
# true author: De Laurentiis Giada
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.2941930294036865
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.018121957778930664
# Discarted candidate: [{'pearson victoria': 2}, {'batali mario': 2}, {'batalli mario': 2}, {'de giad laurentiis': 1}, {'de giada laurentiis w': 1}, {'batali foreword mario': 1}, {'de giada laurentiis': 1}, {'de giada laurentiis': 1}, {'de giada laurentiis': 1}]
# Possible candidate: [{'de giada laurentiis': 85}]
# lengthNecessary: 19.400000000000002
# [{'de giada laurentiis': 85}]
# acceptance_diff 0
# ['de giada laurentiis'] VS true_author: ['de giada laurentiis']
# ISBN: 1400067669
# true author: Meacham Jon
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.36292409896850586
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.017731189727783203
# Discarted candidate: [{'john meacham': 1}, {'jon michman': 1}, {'jon meachan': 1}, {'jon meacham': 1}, {'jon meacham': 1}, {'jon meacham': 1}, {'jon meacham': 1}, {'jon meacham': 1}, {'jon meacham': 1}]
# Possible candidate: [{'jon meacham': 89}]
# lengthNecessary: 19.6
# [{'jon meacham': 89}]
# acceptance_diff 0
# ['jon meacham'] VS true_author: ['jon meacham']
# ISBN: 1401303277
# true author: Albom Mitch
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.3053140640258789
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.012704849243164062
# Discarted candidate: [{'albom': 1}, {'albom mitch': 1}, {'albom mitch': 1}, {'albom mitch': 1}, {'albom mitch': 1}, {'albom mitch': 1}, {'albom mitch': 1}, {'albom mitch': 1}, {'albom mitch': 1}]
# Possible candidate: [{'albom mitch': 84}]
# lengthNecessary: 18.6
# [{'albom mitch': 84}]
# acceptance_diff 0
# ['albom mitch'] VS true_author: ['albom mitch']
# ISBN: 1401323588
# true author: Colfer Eoin
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.3491630554199219
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 9
# Blocking time is: 0.01682901382446289
# Discarted candidate: [{'colfer eoin': 2}, {'colfer eoin': 1}, {'adams douglas': 1}, {'colfer eoin': 1}, {'colfer eoin': 1}, {'colfer eoin': 1}, {'colfer eoin': 1}, {'colfer eoin': 1}]
# Possible candidate: [{'colfer eoin': 81}]
# lengthNecessary: 18.0
# [{'colfer eoin': 81}]
# acceptance_diff 0
# ['colfer eoin'] VS true_author: ['colfer eoin']
# ISBN: 141654707X
# true author: Cole Kresley
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.23734402656555176
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 8
# Blocking time is: 0.0084228515625
# Discarted candidate: [{'cole k': 1}, {'cole kresley': 1}, {'cole kresley': 1}, {'cole kresley': 1}, {'cole kresley': 1}, {'cole kresley': 1}, {'cole kresley': 1}]
# Possible candidate: [{'cole kresley': 70}]
# lengthNecessary: 15.4
# [{'cole kresley': 70}]
# acceptance_diff 0
# ['cole kresley'] VS true_author: ['cole kresley']
# ISBN: 1416571760
# true author: McCullough David
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1982121467590332
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.013894796371459961
# Discarted candidate: [{'david mccullough w': 1}, {'david mccullough': 1}, {'david mccullough': 1}, {'david mccullough': 1}, {'david mccullough': 1}, {'david mccullough': 1}, {'david mccullough': 1}, {'david mccullough': 1}, {'david mccullough': 1}]
# Possible candidate: [{'david mccullough': 100}]
# lengthNecessary: 21.8
# [{'david mccullough': 100}]
# acceptance_diff 0
# ['david mccullough'] VS true_author: ['david mccullough']
# ISBN: 1416580956
# true author: Cole Kresley
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.12192392349243164
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 8
# Blocking time is: 0.006941080093383789
# Discarted candidate: [{'cole kresley': 4}, {'cole kresley': 2}, {'hohl joan': 1}, {'hohl joan': 1}, {'cole kresley': 1}, {'cole kresley': 1}, {'cole kresley': 1}]
# Possible candidate: [{'cole kresley': 60}]
# lengthNecessary: 14.200000000000001
# [{'cole kresley': 60}]
# acceptance_diff 0
# ['cole kresley'] VS true_author: ['cole kresley']
# ISBN: 1416927832
# true author: Henry Marguerite
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.19184494018554688
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 7
# Blocking time is: 0.012560129165649414
# Discarted candidate: [{'dennis wesley': 7}, {'henry marguerite': 2}, {'dennis wesley': 1}, {'henry': 1}, {'henry marguerite': 1}, {'henry marguerite': 1}]
# Possible candidate: [{'henry marguerite': 55}]
# lengthNecessary: 13.600000000000001
# [{'henry marguerite': 55}]
# acceptance_diff 0
# ['henry marguerite'] VS true_author: ['henry marguerite']
# ISBN: 1422102505
# true author: Hamel Gary,Breen Bill
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.3317577838897705
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.021581172943115234
# Discarted candidate: [{'bill breen': 17}, {'g hamel': 3}, {'hamel': 3}, {'bill breen': 1}, {'bill breen': 1}, {'bill breen': 1}, {'bill breen': 1}, {'bill breen': 1}, {'bill breen': 1}]
# Possible candidate: [{'gary hamel': 71}]
# lengthNecessary: 20.0
# [{'gary hamel': 71}]
# acceptance_diff 0
# ['gary hamel'] VS true_author: ['gary hamel', 'bill breen']
# ISBN: 1476729085
# true author: Simsion Graeme
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.21897220611572266
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 8
# Blocking time is: 0.027601957321166992
# Discarted candidate: [{'c graeme simsion': 4}, {'graeme simsion': 1}, {'graeme simsion': 1}, {'graeme simsion': 1}, {'graeme simsion': 1}, {'graeme simsion': 1}, {'graeme simsion': 1}]
# Possible candidate: [{'graeme simsion': 69}]
# lengthNecessary: 15.8
# [{'graeme simsion': 69}]
# acceptance_diff 0
# ['graeme simsion'] VS true_author: ['graeme simsion']
# ISBN: 155661456X
# true author: Oke Janette
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.2105870246887207
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 7
# Blocking time is: 0.005685091018676758
# Discarted candidate: [{'janette oke': 2}, {'janet oke': 2}, {'janette oke': 1}, {'janette oke': 1}, {'janette oke': 1}, {'janette oke': 1}]
# Possible candidate: [{'janette oke': 58}]
# lengthNecessary: 13.200000000000001
# [{'janette oke': 58}]
# acceptance_diff 0
# ['janette oke'] VS true_author: ['janette oke']
# ISBN: 1557043167
# true author: Orman Suze
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.42061519622802734
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.02320718765258789
# Discarted candidate: [{'linda mead': 3}, {'orman suze': 2}, {'orman': 1}, {'linda mead': 1}, {'linda mead': 1}, {'linda mead': 1}, {'linda mead': 1}, {'linda mead': 1}]
# Possible candidate: [{'orman suze': 71}, {'linda mead': 52}]
# lengthNecessary: 26.8
# [{'orman suze': 71}, {'linda mead': 52}]
# acceptance_diff 0
# ['orman suze', 'linda mead'] VS true_author: ['orman suze']
# ISBN: 1560980362
# true author: Viola J. Herman,Margolis Carolyn
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.46161603927612305
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.02327871322631836
# Discarted candidate: [{'herman viola': 5}, {'h j viola': 1, 'hermán j viola': 1, 'viola': 3}, {'herman j margolis viola~carolyn': 4}, {'c margolis': 1, 'margolis': 2, 'margolis viola': 1}, {'smithsonian': 3}, {'eds': 3}, {'carolyn magolis': 1, 'j': 1}, {'institution press smithsonian': 1}]
# Possible candidate: [{'herman j viola': 58}, {'by carolyn margolis': 1, 'carolyn eds margolis': 1, 'carolyn j margolis': 3, 'carolyn margolis': 33}]
# lengthNecessary: 24.6
# [{'herman j viola': 58}, {'by carolyn margolis': 1, 'carolyn eds margolis': 1, 'carolyn j margolis': 3, 'carolyn margolis': 33}]
# acceptance_diff 0
# ['herman j viola', 'carolyn margolis'] VS true_author: ['herman j viola', 'carolyn margolis']
# ISBN: 1565124669
# true author: Hunter Tab,Muller Eddie
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.28974270820617676
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.012631893157958984
# Discarted candidate: [{'contributor-eddie muller': 1}, {'eddie mullier': 1}, {'huhter tab': 1}, {'hunter tab w': 1}, {'hunter tab': 1}, {'hunter tab': 1}, {'hunter tab': 1}, {'hunter tab': 1}]
# Possible candidate: [{'hunter tab': 65}, {'eddie muller': 28}]
# lengthNecessary: 20.200000000000003
# [{'hunter tab': 65}, {'eddie muller': 28}]
# acceptance_diff 0
# ['hunter tab', 'eddie muller'] VS true_author: ['hunter tab', 'eddie muller']
# ISBN: 1577192761
# true author: Simmons Richard
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.13794779777526855
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 8
# Blocking time is: 0.008749961853027344
# Discarted candidate: [{'david icketts': 1}, {'richard simmons': 1}, {'richard simmons': 1}, {'richard simmons': 1}, {'richard simmons': 1}, {'richard simmons': 1}, {'richard simmons': 1}]
# Possible candidate: [{'richard simmons': 67}]
# lengthNecessary: 14.8
# [{'richard simmons': 67}]
# acceptance_diff 0
# ['richard simmons'] VS true_author: ['richard simmons']
# ISBN: 159184181X
# true author: Fiorina Carly
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.10436296463012695
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 7
# Blocking time is: 0.0059511661529541016
# Discarted candidate: [{'c fiorina': 1}, {'carly fiorina': 1}, {'carly fiorina': 1}, {'carly fiorina': 1}, {'carly fiorina': 1}, {'carly fiorina': 1}]
# Possible candidate: [{'carly fiorina': 58}]
# lengthNecessary: 12.8
# [{'carly fiorina': 58}]
# acceptance_diff 0
# ['carly fiorina'] VS true_author: ['carly fiorina']
# ISBN: 1594201455
# true author: Pollan Michael
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.22307610511779785
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 9
# Blocking time is: 0.01717400550842285
# Discarted candidate: [{'pollan': 1}, {'michael pollan': 1}, {'michael pollan': 1}, {'michael pollan': 1}, {'michael pollan': 1}, {'michael pollan': 1}, {'michael pollan': 1}, {'michael pollan': 1}]
# Possible candidate: [{'michael pollan': 75}]
# lengthNecessary: 16.6
# [{'michael pollan': 75}]
# acceptance_diff 0
# ['michael pollan'] VS true_author: ['michael pollan']
# ISBN: 1594487367
# true author: Díaz Junot
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.3085312843322754
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 9
# Blocking time is: 0.013383150100708008
# Discarted candidate: [{'d?az junot': 12, 'díaz junot': 1}, {'d?az junot': 2}, {'diaz junot': 1}, {'diaz junot': 1}, {'diaz junot': 1}, {'diaz junot': 1}, {'diaz junot': 1}, {'diaz junot': 1}]
# Possible candidate: [{'diaz junot': 65}]
# lengthNecessary: 17.2
# [{'diaz junot': 65}]
# acceptance_diff 0
# ['diaz junot'] VS true_author: ['díaz junot']
# ISBN: 1595141979
# true author: Mead Richelle
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.2910041809082031
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.021804094314575195
# Discarted candidate: [{'mead': 1}, {'mead richelle': 1}, {'mead richelle': 1}, {'mead richelle': 1}, {'mead richelle': 1}, {'mead richelle': 1}, {'mead richelle': 1}, {'mead richelle': 1}, {'mead richelle': 1}]
# Possible candidate: [{'mead richelle': 97}]
# lengthNecessary: 21.200000000000003
# [{'mead richelle': 97}]
# acceptance_diff 0
# ['mead richelle'] VS true_author: ['mead richelle']
# ISBN: 1625275773
# true author: Hoffman Reid,Casnocha Ben,Yeh Chris
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.3399338722229004
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.029550790786743164
# Discarted candidate: [{'hoffman r': 3}, {'byeh c casnocha': 2}, {'hoffman': 2}, {'byeh c casnocha': 1}, {'chris yeh': 1}, {'chris yeh': 1}, {'chris yeh': 1}]
# Possible candidate: [{'hoffman reid': 56}, {'ben casnocha': 39}, {'chris yeh': 36}]
# lengthNecessary: 28.400000000000002
# [{'hoffman reid': 56}, {'ben casnocha': 39}, {'chris yeh': 36}]
# acceptance_diff 0
# ['hoffman reid', 'ben casnocha', 'chris yeh'] VS true_author: ['hoffman reid', 'ben casnocha', 'chris yeh']
# ISBN: 1856195295
# true author: King Ross
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.2710268497467041
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.0221250057220459
# Discarted candidate: [{'john lawrence': 7}, {'king ross': 1}, {'king ross': 1}, {'king ross': 1}, {'king ross': 1}, {'king ross': 1}, {'king ross': 1}, {'king ross': 1}, {'king ross': 1}]
# Possible candidate: [{'king ross': 123}]
# lengthNecessary: 27.6
# [{'king ross': 123}]
# acceptance_diff 0
# ['king ross'] VS true_author: ['king ross']
# ISBN: 1885167180
# true author: Freiberg Kevin,Freiberg Jackie
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1868751049041748
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 10
# Blocking time is: 0.019324064254760742
# Discarted candidate: [{'frieberg kevin': 2}, {'freiberg': 1}, {'freiberg jackie kevin': 1}, {'peters tom': 1}, {'freiberg jackie kevin': 1}, {'forward jackie peters tom': 1}, {'freiberg~foreword freiberg~jackie kevin peters tom': 1}, {'peters tom': 1}]
# Possible candidate: [{'freiberg kevin': 31, 'frieberg kevin': 61}, {'freiberg jackie': 30}]
# lengthNecessary: 26.200000000000003
# [{'freiberg kevin': 31, 'frieberg kevin': 61}, {'freiberg jackie': 30}]
# acceptance_diff 0
# ['frieberg kevin', 'freiberg jackie'] VS true_author: ['freiberg kevin', 'freiberg jackie']
# ISBN: 1885203292
# true author: Lewis W. Richard
# embedding_type: inferSent
# attributes_list: ['author']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.29040098190307617
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 8
# Blocking time is: 0.011083126068115234
# Discarted candidate: [{'lewis r': 7}, {'lewis richard': 3}, {'collectif': 1}, {'green': 1}, {'in shrink still wrap': 1}, {'a': 1}, {'lewis richard w': 1}]
# Possible candidate: [{'lewis richard w': 64}]
# lengthNecessary: 15.8
# [{'lewis richard w': 64}]
# acceptance_diff 0
# ['lewis richard w'] VS true_author: ['lewis richard w']
# Total time is: 169.44639897346497

# %% [markdown]
# # Old cases

# %%
getEvaluation(finalAuthors, trueAuthors, 1)
# Out:
# precision is 0.8682295877122069
# recall is 0.9597855227882037
# f1Score is 0.9117147707979626
# (0.8682295877122069, 0.9597855227882037, 0.9117147707979626)

# %%
getEvaluation(finalAuthors, trueAuthors, 1)
# Out:
# precision is 0.9014567266495287
# recall is 0.9401251117068812
# f1Score is 0.9203849518810149
# (0.9014567266495287, 0.9401251117068812, 0.9203849518810149)

# %% [markdown]
# # With multiple wins and remove similar one

# %%
# acceptance_diff = 3
getEvaluation(finalAuthors, trueAuthors, 1)
# Out:
# TP: 1058, FP: 230, FN: 61
# precision is 0.8214285714285714
# recall is 0.9454870420017873
# f1Score is 0.8791026173660157
# (0.8214285714285714, 0.9454870420017873, 0.8791026173660157)

# %%
# acceptance_diff = 2
getEvaluation(finalAuthors, trueAuthors, 1)
# Out:
# TP: 1058, FP: 230, FN: 61
# precision is 0.8214285714285714
# recall is 0.9454870420017873
# f1Score is 0.8791026173660157
# (0.8214285714285714, 0.9454870420017873, 0.8791026173660157)

# %%
# acceptance_diff = 1
getEvaluation(finalAuthors, trueAuthors, 1)
# Out:
# TP: 1058, FP: 230, FN: 61
# precision is 0.8214285714285714
# recall is 0.9454870420017873
# f1Score is 0.8791026173660157
# (0.8214285714285714, 0.9454870420017873, 0.8791026173660157)

# %%
# acceptance_diff = 0
getEvaluation(finalAuthors, trueAuthors, 1) # different because maybe multiple with same vote
# maybe more blocks same author
# Out:
# TP: 1028, FP: 140, FN: 91
# precision is 0.8801369863013698
# recall is 0.9186773905272565
# f1Score is 0.8989943156974203
# (0.8801369863013698, 0.9186773905272565, 0.8989943156974203)

# %% [markdown]
# # add blockWeight

# %%
# block_weight 2
getEvaluation(finalAuthors, trueAuthors, 1)
# Out:
# TP: 1028, FP: 140, FN: 91
# precision is 0.8801369863013698
# recall is 0.9186773905272565
# f1Score is 0.8989943156974203
# (0.8801369863013698, 0.9186773905272565, 0.8989943156974203)
