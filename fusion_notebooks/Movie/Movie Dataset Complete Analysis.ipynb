# %%
import os
import sys
import time
import numpy as np
import matplotlib.pyplot as plt
module_path = os.path.abspath(os.path.join('../../fusion'))
sys.path.append(module_path)

from preprocessing_datasets.preprocessing_utilities import ValueUtils
from preprocessing_datasets import load_dataset
from embedding_algorithms import sentence_embedding, set_embedding_model
from dimensionality_reduction_algorithms import dimension_reduction_algorithms
from cluster_algorithms import cluster_algorithm

from helper import launchWithoutReductionFusionMovie
from plot_tools import plotChart, plotCluster
from evaluation import *

# %%
key_values = {
    'model_type':'bilstm',
    'char_level':False,
    'model_version': 2,
    'rnn_dim':1024,
    'verbose':1,
    'attributes_list': ['newDirector'],
    'embedding_type': 'inferSent',
    'dataset': 'clean_movie',
    'cluster_method': 'hierarchy',
    'num_clusters_rate': 0.1,
    'block_length_thresold': 0.35,
    'acceptance_diff':2,
    'block_weight': 2,
}

# %%
dataset_name, table_group_by_movie_id, list_movie_id, true_directors = load_dataset(key_values)
# Out:
# dataset: clean_movie
# Loading time is: 0.7737767696380615

# %%
set_embedding_model(key_values)
# Out:
# Vocab size : 2196017
# model_version: 2
# rnn_dim: 1024
# model_type: bilstm
# char_level: False
# Setup time is: 182.7321581840515

# %%
start_time = time.time()
finalDirectors, trueDirectors = launchWithoutReductionFusionMovie(table_group_by_movie_id, list_movie_id, true_directors, key_values)
print("Total time is: {0}".format(time.time() - start_time))
# Out:
# movie_id: 73952
# true director: Robert Hamer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.3788938522338867
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.1254100799560547
# Discarted candidate: []
# Possible candidate: [{'chester e hal': 2, 'cyril frankel': 1, 'hamer robert': 4}]
# lengthNecessary: 2.4499999999999997
# [{'chester e hal': 2, 'cyril frankel': 1, 'hamer robert': 4}]
# acceptance_diff 2
# ['chester e hal', 'hamer robert'] VS true_author: ['hamer robert']
# movie_id: 1655
# true director: Alexandre O. Philippe
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.037998199462890625
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0011756420135498047
# Discarted candidate: []
# Possible candidate: [{'alexandre o philippe': 2, 'alexandre philippe': 1}]
# lengthNecessary: 1.0499999999999998
# [{'alexandre o philippe': 2, 'alexandre philippe': 1}]
# acceptance_diff 2
# ['alexandre o philippe'] VS true_author: ['alexandre o philippe']
# movie_id: 69693
# true director: Brad Bird
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08931303024291992
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.0029060840606689453
# Discarted candidate: [{'bird brad': 1}, {'bird brad': 1}]
# Possible candidate: [{'bird brad': 26}, {'jan pinkava': 12}]
# lengthNecessary: 12.0
# [{'bird brad': 26}, {'jan pinkava': 12}]
# acceptance_diff 2
# ['bird brad', 'jan pinkava'] VS true_author: ['bird brad']
# movie_id: 89575
# true director: Vincent Sherman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04780077934265137
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010523796081542969
# Discarted candidate: []
# Possible candidate: [{'aldrich robert': 2, 'sherman vincent': 7}]
# lengthNecessary: 3.15
# [{'aldrich robert': 2, 'sherman vincent': 7}]
# acceptance_diff 2
# ['sherman vincent'] VS true_author: ['sherman vincent']
# movie_id: 5900
# true director: Fraser C. Heston
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05137300491333008
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010750293731689453
# Discarted candidate: []
# Possible candidate: [{'c fraser heston': 2, 'clarke fraser heston': 7}]
# lengthNecessary: 3.15
# [{'c fraser heston': 2, 'clarke fraser heston': 7}]
# acceptance_diff 2
# ['clarke fraser heston'] VS true_author: ['c fraser heston']
# movie_id: 105551
# true director: John Landis;Steven Spielberg;Joe Dante;George Miller
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.16863799095153809
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 8
# Blocking time is: 0.00686192512512207
# Discarted candidate: [{'john landis': 16}, {'dante joe': 14}, {'george miller': 13}, {'john landis': 3}, {'george miller': 2}, {'dante joe': 1}, {'spielberg steven': 1}]
# Possible candidate: [{'spielberg steven': 21}]
# lengthNecessary: 20.849999999999998
# [{'spielberg steven': 21}]
# acceptance_diff 2
# ['spielberg steven'] VS true_author: ['dante joe', 'george miller', 'spielberg steven', 'john landis']
# movie_id: 61521
# true director: Godfrey Ho
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07206988334655762
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0016400814056396484
# Discarted candidate: []
# Possible candidate: [{'godfrey ho': 3, 'kim si-hyun': 1}]
# lengthNecessary: 1.4
# [{'godfrey ho': 3, 'kim si-hyun': 1}]
# acceptance_diff 2
# ['godfrey ho', 'kim si-hyun'] VS true_author: ['godfrey ho']
# movie_id: 37376
# true director: Dave Fleischer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04865694046020508
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0017478466033935547
# Discarted candidate: [{'bowsky willard': 1}]
# Possible candidate: [{'dave fleischer': 13}]
# lengthNecessary: 3.8999999999999995
# [{'dave fleischer': 13}]
# acceptance_diff 2
# ['dave fleischer'] VS true_author: ['dave fleischer']
# movie_id: 26754
# true director: Martin D'Urville
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03000020980834961
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0014319419860839844
# Discarted candidate: [{"d'urville martin": 1}]
# Possible candidate: [{"d'urville martin": 10, 'durville martin': 2}]
# lengthNecessary: 3.55
# [{"d'urville martin": 10, 'durville martin': 2}]
# acceptance_diff 2
# ["d'urville martin"] VS true_author: ["d'urville martin"]
# movie_id: 97745
# true director: Norton Virgien;Igor Kovalyov
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08670306205749512
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.0025899410247802734
# Discarted candidate: [{'norton virgien': 1}, {'igor kovalyov': 1}]
# Possible candidate: [{'norton virgien': 15}, {'igor kovalyov': 14}]
# lengthNecessary: 8.85
# [{'norton virgien': 15}, {'igor kovalyov': 14}]
# acceptance_diff 2
# ['norton virgien', 'igor kovalyov'] VS true_author: ['norton virgien', 'igor kovalyov']
# movie_id: 58040
# true director: Thomas Bezucha
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0791630744934082
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0017957687377929688
# Discarted candidate: [{'bezucha tom': 2}, {'bezucha tom': 1}]
# Possible candidate: [{'bezucha thomas': 20}]
# lengthNecessary: 7.049999999999999
# [{'bezucha thomas': 20}]
# acceptance_diff 2
# ['bezucha thomas'] VS true_author: ['bezucha thomas']
# movie_id: 11447
# true director: Michael Galinsky;Suki Hawley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03749203681945801
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0011179447174072266
# Discarted candidate: []
# Possible candidate: [{'galinsky michael': 4, 'hawley suki': 6}]
# lengthNecessary: 3.5
# [{'galinsky michael': 4, 'hawley suki': 6}]
# acceptance_diff 2
# ['galinsky michael', 'hawley suki'] VS true_author: ['galinsky michael', 'hawley suki']
# movie_id: 92995
# true director: Chatrichalerm Yukol
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.01735687255859375
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0011448860168457031
# Discarted candidate: []
# Possible candidate: [{'chatrichalerm yukoi': 2, 'chatrichalerm yukol': 2}]
# lengthNecessary: 1.4
# [{'chatrichalerm yukoi': 2, 'chatrichalerm yukol': 2}]
# acceptance_diff 2
# ['chatrichalerm yukoi'] VS true_author: ['chatrichalerm yukol']
# movie_id: 45317
# true director: Richard Talmadge;Harvey Parry
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.034648895263671875
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0014350414276123047
# Discarted candidate: []
# Possible candidate: [{'harvey parry': 3, 'richard talmadge': 1}]
# lengthNecessary: 1.4
# [{'harvey parry': 3, 'richard talmadge': 1}]
# acceptance_diff 2
# ['harvey parry', 'richard talmadge'] VS true_author: ['richard talmadge', 'harvey parry']
# movie_id: 57325
# true director: Keiichi Hara
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07990193367004395
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0020720958709716797
# Discarted candidate: [{'michael sinterniklaas': 6}, {'sheh stephanie': 6}]
# Possible candidate: [{'hara keiichi': 11}]
# lengthNecessary: 7.049999999999999
# [{'hara keiichi': 11}]
# acceptance_diff 2
# ['hara keiichi'] VS true_author: ['hara keiichi']
# movie_id: 96819
# true director: Yves Allegret
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.045989990234375
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0015368461608886719
# Discarted candidate: []
# Possible candidate: [{'allegret yves': 2, 'e portas rafael': 1}]
# lengthNecessary: 1.0499999999999998
# [{'allegret yves': 2, 'e portas rafael': 1}]
# acceptance_diff 2
# ['allegret yves', 'e portas rafael'] VS true_author: ['allegret yves']
# movie_id: 24035
# true director: William Tannen;Larry Cohen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09475588798522949
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.001226186752319336
# Discarted candidate: []
# Possible candidate: [{'cohen larry': 6, 'tannen william': 4}]
# lengthNecessary: 3.5
# [{'cohen larry': 6, 'tannen william': 4}]
# acceptance_diff 2
# ['cohen larry', 'tannen william'] VS true_author: ['cohen larry', 'tannen william']
# movie_id: 5820
# true director: Ananth Narayan Mahadevan
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.13192415237426758
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0014069080352783203
# Discarted candidate: []
# Possible candidate: [{'anant mahadevan': 1, 'ananth mahadevan narayan': 3}]
# lengthNecessary: 1.4
# [{'anant mahadevan': 1, 'ananth mahadevan narayan': 3}]
# acceptance_diff 2
# ['anant mahadevan', 'ananth mahadevan narayan'] VS true_author: ['ananth mahadevan narayan']
# movie_id: 14372
# true director: Joel Coen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.10285210609436035
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0018069744110107422
# Discarted candidate: []
# Possible candidate: [{'coen joel': 13}, {'coen ethan': 7}]
# lengthNecessary: 6.0
# [{'coen joel': 13}, {'coen ethan': 7}]
# acceptance_diff 2
# ['coen joel', 'coen ethan'] VS true_author: ['coen joel']
# movie_id: 2550
# true director: Jean-Luc Godard
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08658313751220703
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0013971328735351562
# Discarted candidate: []
# Possible candidate: [{'dziga groupe vertov': 1, 'godard jean-luc': 3}]
# lengthNecessary: 1.4
# [{'dziga groupe vertov': 1, 'godard jean-luc': 3}]
# acceptance_diff 2
# ['dziga groupe vertov', 'godard jean-luc'] VS true_author: ['godard jean-luc']
# movie_id: 8413
# true director: Adam Small;Peter Stuart
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.12103605270385742
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0015728473663330078
# Discarted candidate: []
# Possible candidate: [{'adam small': 9}, {'peter stuart': 7}]
# lengthNecessary: 4.6
# [{'adam small': 9}, {'peter stuart': 7}]
# acceptance_diff 2
# ['adam small', 'peter stuart'] VS true_author: ['adam small', 'peter stuart']
# movie_id: 93760
# true director: Caradog W. James
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03104400634765625
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010082721710205078
# Discarted candidate: []
# Possible candidate: [{'caradog james': 3, 'caradog james w': 1}]
# lengthNecessary: 1.4
# [{'caradog james': 3, 'caradog james w': 1}]
# acceptance_diff 2
# ['caradog james'] VS true_author: ['caradog james w']
# movie_id: 93024
# true director: Phil Lord;Christopher Miller
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09422111511230469
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 6
# Blocking time is: 0.0040662288665771484
# Discarted candidate: [{'christopher miller': 15}, {'chris miller': 8}, {'chris mckay': 2}, {'lord phil': 1}, {'lord phil': 1}]
# Possible candidate: [{'lord phil': 26}]
# lengthNecessary: 15.549999999999997
# [{'lord phil': 26}]
# acceptance_diff 2
# ['lord phil'] VS true_author: ['lord phil', 'christopher miller']
# movie_id: 63252
# true director: Gabriele Del Grande;Khaled Soliman Al Nassiry;Antonio Augugliaro
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05000615119934082
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.001008749008178711
# Discarted candidate: []
# Possible candidate: [{'al khaled nassiry soliman': 1, 'antonio augugliaro': 2, 'del gabriele grande': 1}]
# lengthNecessary: 1.4
# [{'al khaled nassiry soliman': 1, 'antonio augugliaro': 2, 'del gabriele grande': 1}]
# acceptance_diff 2
# ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande'] VS true_author: ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande']
# movie_id: 76340
# true director: Prince
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03969311714172363
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0015211105346679688
# Discarted candidate: []
# Possible candidate: [{'albert magnoli': 3, 'prince': 6}]
# lengthNecessary: 3.15
# [{'albert magnoli': 3, 'prince': 6}]
# acceptance_diff 2
# ['prince'] VS true_author: ['prince']
# movie_id: 21613
# true director: Andrzej Bartkowiak
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04159283638000488
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0016050338745117188
# Discarted candidate: [{'andrzek bartkowiak': 1}]
# Possible candidate: [{'andrzej bartkowiak': 19}]
# lengthNecessary: 6.0
# [{'andrzej bartkowiak': 19}]
# acceptance_diff 2
# ['andrzej bartkowiak'] VS true_author: ['andrzej bartkowiak']
# movie_id: 80167
# true director: Sandra Martin;Hugues Martin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03587913513183594
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010302066802978516
# Discarted candidate: []
# Possible candidate: [{'hugues martin': 4, 'martin sandra': 2}]
# lengthNecessary: 2.0999999999999996
# [{'hugues martin': 4, 'martin sandra': 2}]
# acceptance_diff 2
# ['hugues martin', 'martin sandra'] VS true_author: ['martin sandra', 'hugues martin']
# movie_id: 82271
# true director: Marvin J. Chomsky
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06608390808105469
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0013592243194580078
# Discarted candidate: [{'chomsky marvin': 1}]
# Possible candidate: [{'chomsky j marvin': 17}]
# lengthNecessary: 5.3
# [{'chomsky j marvin': 17}]
# acceptance_diff 2
# ['chomsky j marvin'] VS true_author: ['chomsky j marvin']
# movie_id: 7494
# true director: Tommy O'Haver
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03254890441894531
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010638236999511719
# Discarted candidate: []
# Possible candidate: [{"o'haver tommy": 7, 'ohaver tommy': 3}]
# lengthNecessary: 3.5
# [{"o'haver tommy": 7, 'ohaver tommy': 3}]
# acceptance_diff 2
# ["o'haver tommy"] VS true_author: ["o'haver tommy"]
# movie_id: 16640
# true director: Timothy Marrinan;Richard Dewey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03823113441467285
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009300708770751953
# Discarted candidate: []
# Possible candidate: [{'dewey richard': 1, 'marrinan timothy': 2}]
# lengthNecessary: 1.0499999999999998
# [{'dewey richard': 1, 'marrinan timothy': 2}]
# acceptance_diff 2
# ['dewey richard', 'marrinan timothy'] VS true_author: ['dewey richard', 'marrinan timothy']
# movie_id: 101119
# true director: Chris Hegedus;D. A. Pennebaker
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04929685592651367
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0014047622680664062
# Discarted candidate: []
# Possible candidate: [{'a d pennebaker': 9}, {'chris hegedus': 7}]
# lengthNecessary: 4.6
# [{'a d pennebaker': 9}, {'chris hegedus': 7}]
# acceptance_diff 2
# ['a d pennebaker', 'chris hegedus'] VS true_author: ['chris hegedus', 'a d pennebaker']
# movie_id: 17046
# true director: Paolo Taviani;Vittorio Taviani
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03184986114501953
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010590553283691406
# Discarted candidate: []
# Possible candidate: [{'paolo taviani': 4, 'taviani vittorio': 2}]
# lengthNecessary: 2.0999999999999996
# [{'paolo taviani': 4, 'taviani vittorio': 2}]
# acceptance_diff 2
# ['paolo taviani', 'taviani vittorio'] VS true_author: ['paolo taviani', 'taviani vittorio']
# movie_id: 80539
# true director: Karan Johar
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0447850227355957
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.001127004623413086
# Discarted candidate: [{'abhishek varman': 2}]
# Possible candidate: [{'johar karan': 10}]
# lengthNecessary: 3.1999999999999993
# [{'johar karan': 10}]
# acceptance_diff 2
# ['johar karan'] VS true_author: ['johar karan']
# movie_id: 111871
# true director: Anlo Sepulveda;Paul Collins
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03633880615234375
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010271072387695312
# Discarted candidate: []
# Possible candidate: [{'anlo sepulveda': 3, 'collins paul': 2}]
# lengthNecessary: 1.75
# [{'anlo sepulveda': 3, 'collins paul': 2}]
# acceptance_diff 2
# ['anlo sepulveda', 'collins paul'] VS true_author: ['anlo sepulveda', 'collins paul']
# movie_id: 31082
# true director: Slatan Dudow;Kurt Maetzig
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.026520967483520508
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0008461475372314453
# Discarted candidate: []
# Possible candidate: [{'dudow slatan': 2, 'groschopp richard': 1, 'kurt maetzig': 1}]
# lengthNecessary: 1.4
# [{'dudow slatan': 2, 'groschopp richard': 1, 'kurt maetzig': 1}]
# acceptance_diff 2
# ['dudow slatan', 'groschopp richard', 'kurt maetzig'] VS true_author: ['dudow slatan', 'kurt maetzig']
# movie_id: 2672
# true director: Christian Krones;Olaf S. Muller;Roland Schrotthofer;Florian Weigensamer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.056252241134643555
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010461807250976562
# Discarted candidate: []
# Possible candidate: [{'christian krones': 1, 'florian weigensamer': 2, 'muller olaf s': 1, 'roland schrotthofer': 1}]
# lengthNecessary: 1.75
# [{'christian krones': 1, 'florian weigensamer': 2, 'muller olaf s': 1, 'roland schrotthofer': 1}]
# acceptance_diff 2
# ['christian krones', 'florian weigensamer', 'muller olaf s', 'roland schrotthofer'] VS true_author: ['muller olaf s', 'roland schrotthofer', 'florian weigensamer', 'christian krones']
# movie_id: 91427
# true director: Robert Rossen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04259681701660156
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009927749633789062
# Discarted candidate: []
# Possible candidate: [{'blue washington': 1, 'robert rossen': 9}]
# lengthNecessary: 3.5
# [{'blue washington': 1, 'robert rossen': 9}]
# acceptance_diff 2
# ['robert rossen'] VS true_author: ['robert rossen']
# movie_id: 2813
# true director: Michael Tiddes
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.033499956130981445
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.001180887222290039
# Discarted candidate: [{'mike tiddes': 2}]
# Possible candidate: [{'michael tiddes': 11}]
# lengthNecessary: 3.55
# [{'michael tiddes': 11}]
# acceptance_diff 2
# ['michael tiddes'] VS true_author: ['michael tiddes']
# movie_id: 15123
# true director: Jon Bulette;Stone Roberts
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04086709022521973
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0012450218200683594
# Discarted candidate: []
# Possible candidate: [{'bulette jon': 3, 'f roberts stone': 1, 'roberts stone': 1}]
# lengthNecessary: 1.75
# [{'bulette jon': 3, 'f roberts stone': 1, 'roberts stone': 1}]
# acceptance_diff 2
# ['bulette jon', 'f roberts stone'] VS true_author: ['bulette jon', 'roberts stone']
# movie_id: 30280
# true director: Anthony Stabley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04506993293762207
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0012600421905517578
# Discarted candidate: []
# Possible candidate: [{'anthony stabley': 8}, {'anthony r stabley': 3}]
# lengthNecessary: 2.8499999999999996
# [{'anthony stabley': 8}, {'anthony r stabley': 3}]
# acceptance_diff 2
# ['anthony stabley'] VS true_author: ['anthony stabley']
# movie_id: 68652
# true director: Adam Kassen;Mark Kassen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0395660400390625
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0013270378112792969
# Discarted candidate: []
# Possible candidate: [{'kassen mark': 9}, {'adam kassen': 8}]
# lengthNecessary: 4.949999999999999
# [{'kassen mark': 9}, {'adam kassen': 8}]
# acceptance_diff 2
# ['kassen mark', 'adam kassen'] VS true_author: ['kassen mark', 'adam kassen']
# movie_id: 21609
# true director: Rowby Goren;Chuck Staley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04528689384460449
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009679794311523438
# Discarted candidate: []
# Possible candidate: [{'chuck staley': 3, 'goren rowby': 6}]
# lengthNecessary: 3.15
# [{'chuck staley': 3, 'goren rowby': 6}]
# acceptance_diff 2
# ['goren rowby'] VS true_author: ['chuck staley', 'goren rowby']
# movie_id: 37872
# true director: Michael Almereyda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03113698959350586
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.000982046127319336
# Discarted candidate: []
# Possible candidate: [{'almereyda michael': 5, 'campbell scott': 1}]
# lengthNecessary: 2.0999999999999996
# [{'almereyda michael': 5, 'campbell scott': 1}]
# acceptance_diff 2
# ['almereyda michael'] VS true_author: ['almereyda michael']
# movie_id: 45447
# true director: Fred C. Brannon;Thomas Carr
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04612469673156738
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010068416595458984
# Discarted candidate: []
# Possible candidate: [{'brannon c fred': 6, 'carr thomas': 3}]
# lengthNecessary: 3.15
# [{'brannon c fred': 6, 'carr thomas': 3}]
# acceptance_diff 2
# ['brannon c fred'] VS true_author: ['carr thomas', 'brannon c fred']
# movie_id: 24661
# true director: Matthew Celestre;Brett Celestre
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.027273178100585938
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009329319000244141
# Discarted candidate: []
# Possible candidate: [{'brett celestre': 1, 'brette celestre': 2, 'celestre matthew': 1}]
# lengthNecessary: 1.4
# [{'brett celestre': 1, 'brette celestre': 2, 'celestre matthew': 1}]
# acceptance_diff 2
# ['brett celestre', 'celestre matthew'] VS true_author: ['brett celestre', 'celestre matthew']
# movie_id: 3648
# true director: Nikolaj Arcel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.030297279357910156
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0016798973083496094
# Discarted candidate: [{'arcel nikaolaj': 2}]
# Possible candidate: [{'arcel nikolaj': 14}]
# lengthNecessary: 4.6
# [{'arcel nikolaj': 14}]
# acceptance_diff 2
# ['arcel nikolaj'] VS true_author: ['arcel nikolaj']
# movie_id: 13479
# true director: Ergin Orbey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0288999080657959
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.000993967056274414
# Discarted candidate: []
# Possible candidate: [{'engin orbey': 8, 'ergin orbey': 1}]
# lengthNecessary: 3.15
# [{'engin orbey': 8, 'ergin orbey': 1}]
# acceptance_diff 2
# ['engin orbey'] VS true_author: ['ergin orbey']
# movie_id: 18319
# true director: Baird Bryant;Johanna Demetrakas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04638195037841797
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.001207113265991211
# Discarted candidate: []
# Possible candidate: [{'baird bryant': 8}, {'demetrakas johanna': 5}]
# lengthNecessary: 3.55
# [{'baird bryant': 8}, {'demetrakas johanna': 5}]
# acceptance_diff 2
# ['baird bryant', 'demetrakas johanna'] VS true_author: ['baird bryant', 'demetrakas johanna']
# movie_id: 44223
# true director: Gene Kelly
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04169964790344238
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010149478912353516
# Discarted candidate: []
# Possible candidate: [{'freddie young': 1, 'gene kelly': 8}]
# lengthNecessary: 3.15
# [{'freddie young': 1, 'gene kelly': 8}]
# acceptance_diff 2
# ['gene kelly'] VS true_author: ['gene kelly']
# movie_id: 71075
# true director: David Twohy
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.043901920318603516
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0017271041870117188
# Discarted candidate: [{'david n twohy': 1}, {'david twohy': 1}]
# Possible candidate: [{'david twohy': 23}]
# lengthNecessary: 7.75
# [{'david twohy': 23}]
# acceptance_diff 2
# ['david twohy'] VS true_author: ['david twohy']
# movie_id: 80410
# true director: Paul Ragsdale
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05280900001525879
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010848045349121094
# Discarted candidate: []
# Possible candidate: [{'alba angelica de': 3, 'paul ragsdale': 6}]
# lengthNecessary: 3.15
# [{'alba angelica de': 3, 'paul ragsdale': 6}]
# acceptance_diff 2
# ['paul ragsdale'] VS true_author: ['paul ragsdale']
# movie_id: 71705
# true director: Allan Arkush
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05146527290344238
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0014452934265136719
# Discarted candidate: []
# Possible candidate: [{'allan arkush': 13}, {'dante joe': 6}]
# lengthNecessary: 5.6499999999999995
# [{'allan arkush': 13}, {'dante joe': 6}]
# acceptance_diff 2
# ['allan arkush', 'dante joe'] VS true_author: ['allan arkush']
# movie_id: 91114
# true director: Tian Zhuangzhuang
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.033128976821899414
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010459423065185547
# Discarted candidate: []
# Possible candidate: [{'pan peicheng': 3, 'tian zhuangzhuang': 3}]
# lengthNecessary: 2.0999999999999996
# [{'pan peicheng': 3, 'tian zhuangzhuang': 3}]
# acceptance_diff 2
# ['pan peicheng', 'tian zhuangzhuang'] VS true_author: ['tian zhuangzhuang']
# movie_id: 100574
# true director: Michael Hegner;Karsten Kiilerich
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.027189016342163086
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009908676147460938
# Discarted candidate: []
# Possible candidate: [{'hegner michael': 6, 'karsten kiilerich': 4}]
# lengthNecessary: 3.5
# [{'hegner michael': 6, 'karsten kiilerich': 4}]
# acceptance_diff 2
# ['hegner michael', 'karsten kiilerich'] VS true_author: ['hegner michael', 'karsten kiilerich']
# movie_id: 22475
# true director: Kevin King
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04542684555053711
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0018110275268554688
# Discarted candidate: []
# Possible candidate: [{'k king': 6, 'kevin king': 3}]
# lengthNecessary: 3.15
# [{'k king': 6, 'kevin king': 3}]
# acceptance_diff 2
# ['k king'] VS true_author: ['kevin king']
# movie_id: 57809
# true director: John Lamb
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03620123863220215
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009379386901855469
# Discarted candidate: []
# Possible candidate: [{'hill jack': 2, 'john lamb': 1}]
# lengthNecessary: 1.0499999999999998
# [{'hill jack': 2, 'john lamb': 1}]
# acceptance_diff 2
# ['hill jack', 'john lamb'] VS true_author: ['john lamb']
# movie_id: 97278
# true director: Norman Panama;Melvin Frank
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.041754722595214844
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010919570922851562
# Discarted candidate: []
# Possible candidate: [{'frank melvin': 4, 'norman panama': 3}]
# lengthNecessary: 2.4499999999999997
# [{'frank melvin': 4, 'norman panama': 3}]
# acceptance_diff 2
# ['frank melvin', 'norman panama'] VS true_author: ['norman panama', 'frank melvin']
# movie_id: 106242
# true director: Gionata Zarantonello
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.021444082260131836
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0005679130554199219
# Discarted candidate: []
# Possible candidate: [{'gionata zarantonello': 1, 'jonathan zarantonello': 1}]
# lengthNecessary: 0.7
# [{'gionata zarantonello': 1, 'jonathan zarantonello': 1}]
# acceptance_diff 2
# ['gionata zarantonello'] VS true_author: ['gionata zarantonello']
# movie_id: 81911
# true director: Kang Je-Gyu
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04900789260864258
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0014159679412841797
# Discarted candidate: [{'gyu je kang': 1}, {'je-gyu kang': 1}]
# Possible candidate: [{'je-gyu kang': 12, 'je-kyu kang': 7}]
# lengthNecessary: 6.35
# [{'je-gyu kang': 12, 'je-kyu kang': 7}]
# acceptance_diff 2
# ['je-gyu kang'] VS true_author: ['je-gyu kang']
# movie_id: 87781
# true director: Alistair Legrand
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.052206993103027344
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0018877983093261719
# Discarted candidate: [{'callaway ryan': 1}]
# Possible candidate: [{'alistair legrand': 16}]
# lengthNecessary: 4.949999999999999
# [{'alistair legrand': 16}]
# acceptance_diff 2
# ['alistair legrand'] VS true_author: ['alistair legrand']
# movie_id: 49079
# true director: Fernando Palacios
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04915308952331543
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.001070261001586914
# Discarted candidate: []
# Possible candidate: [{'fernando palacios': 2, 'j rafael salvia': 3}]
# lengthNecessary: 1.75
# [{'fernando palacios': 2, 'j rafael salvia': 3}]
# acceptance_diff 2
# ['fernando palacios', 'j rafael salvia'] VS true_author: ['fernando palacios']
# movie_id: 43271
# true director: R. Kiplin Pastor
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03642868995666504
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.001049041748046875
# Discarted candidate: []
# Possible candidate: [{'kip pastor': 3, 'kiplin pastor r': 1}]
# lengthNecessary: 1.4
# [{'kip pastor': 3, 'kiplin pastor r': 1}]
# acceptance_diff 2
# ['kip pastor', 'kiplin pastor r'] VS true_author: ['kiplin pastor r']
# movie_id: 43726
# true director: Quentin Tarantino
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06651496887207031
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 4
# Blocking time is: 0.002696990966796875
# Discarted candidate: [{'quentin tarantino': 2}, {'quentin tarantino': 1}]
# Possible candidate: [{'quentin tarantino': 24}, {'eli roth': 12}]
# lengthNecessary: 11.649999999999999
# [{'quentin tarantino': 24}, {'eli roth': 12}]
# acceptance_diff 2
# ['quentin tarantino', 'eli roth'] VS true_author: ['quentin tarantino']
# movie_id: 28418
# true director: Sharunas Bartas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0149078369140625
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0004858970642089844
# Discarted candidate: []
# Possible candidate: [{'bartas sar?nas': 1, 'bartas sharunas': 1}]
# lengthNecessary: 0.7
# [{'bartas sar?nas': 1, 'bartas sharunas': 1}]
# acceptance_diff 2
# ['bartas sar?nas'] VS true_author: ['bartas sharunas']
# movie_id: 111254
# true director: Luke Jaden;Cort Johns
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.053327083587646484
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010478496551513672
# Discarted candidate: []
# Possible candidate: [{'cort johns': 2, 'jaden luke': 4}]
# lengthNecessary: 2.0999999999999996
# [{'cort johns': 2, 'jaden luke': 4}]
# acceptance_diff 2
# ['cort johns', 'jaden luke'] VS true_author: ['cort johns', 'jaden luke']
# movie_id: 69205
# true director: Nancy Glass;Michele Loschiavo
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04028177261352539
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0011820793151855469
# Discarted candidate: []
# Possible candidate: [{'glass nancy': 2, 'loschiavo michele': 1}]
# lengthNecessary: 1.0499999999999998
# [{'glass nancy': 2, 'loschiavo michele': 1}]
# acceptance_diff 2
# ['glass nancy', 'loschiavo michele'] VS true_author: ['loschiavo michele', 'glass nancy']
# movie_id: 40048
# true director: Manuel Gonzalez Mauricio;Saul Barreto Ramos
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04962515830993652
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0012350082397460938
# Discarted candidate: []
# Possible candidate: [{'barreto ramos saul': 1, 'gonzalez manuel mauricio': 2}]
# lengthNecessary: 1.0499999999999998
# [{'barreto ramos saul': 1, 'gonzalez manuel mauricio': 2}]
# acceptance_diff 2
# ['barreto ramos saul', 'gonzalez manuel mauricio'] VS true_author: ['gonzalez manuel mauricio', 'barreto ramos saul']
# movie_id: 57896
# true director: Andrew V. McLaglen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03394198417663574
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009799003601074219
# Discarted candidate: []
# Possible candidate: [{'andrew mclaglen': 2, 'andrew mclaglen v': 6}]
# lengthNecessary: 2.8
# [{'andrew mclaglen': 2, 'andrew mclaglen v': 6}]
# acceptance_diff 2
# ['andrew mclaglen v'] VS true_author: ['andrew mclaglen v']
# movie_id: 32707
# true director: Paul Morrissey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03602194786071777
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010938644409179688
# Discarted candidate: []
# Possible candidate: [{'antonio margheriti': 2, 'morrissey paul': 6}]
# lengthNecessary: 2.8
# [{'antonio margheriti': 2, 'morrissey paul': 6}]
# acceptance_diff 2
# ['morrissey paul'] VS true_author: ['morrissey paul']
# movie_id: 80601
# true director: Frank Capra
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03742718696594238
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0012218952178955078
# Discarted candidate: []
# Possible candidate: [{'capra frank': 5, 'irvin willat': 3}]
# lengthNecessary: 2.8
# [{'capra frank': 5, 'irvin willat': 3}]
# acceptance_diff 2
# ['capra frank', 'irvin willat'] VS true_author: ['capra frank']
# movie_id: 109103
# true director: Dick Zondag;Ralph Zondag;Phil Nibbelink;Simon Wells
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08632302284240723
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 5
# Blocking time is: 0.0036759376525878906
# Discarted candidate: [{'nibbelink phil': 13}, {'dick zondag': 12}, {'simon wells': 12}, {'ralph zondag': 12}, {'nibbelink phil': 1}]
# Possible candidate: []
# lengthNecessary: 15.5
# []
# acceptance_diff 2
# [] VS true_author: ['dick zondag', 'simon wells', 'ralph zondag', 'nibbelink phil']
# movie_id: 76115
# true director: Adam Friedman;Iain Kennedy
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04926800727844238
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.001432180404663086
# Discarted candidate: []
# Possible candidate: [{'adam friedman': 7}, {'iain kennedy': 5}]
# lengthNecessary: 3.1999999999999993
# [{'adam friedman': 7}, {'iain kennedy': 5}]
# acceptance_diff 2
# ['adam friedman', 'iain kennedy'] VS true_author: ['iain kennedy', 'adam friedman']
# movie_id: 60263
# true director: Bill Guttentag;Dan Sturman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04065990447998047
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.001728057861328125
# Discarted candidate: [{'bill guttentag': 1}]
# Possible candidate: [{'bill guttentag': 13}, {'dan sturman': 9}]
# lengthNecessary: 7.049999999999999
# [{'bill guttentag': 13}, {'dan sturman': 9}]
# acceptance_diff 2
# ['bill guttentag', 'dan sturman'] VS true_author: ['bill guttentag', 'dan sturman']
# movie_id: 35119
# true director: Cynthia Wade;Cheryl Miller Houser
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07709622383117676
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.001245260238647461
# Discarted candidate: []
# Possible candidate: [{'cynthia wade': 6}, {'cheryl houser': 1, 'cheryl houser miller': 4}]
# lengthNecessary: 2.8499999999999996
# [{'cynthia wade': 6}, {'cheryl houser': 1, 'cheryl houser miller': 4}]
# acceptance_diff 2
# ['cynthia wade', 'cheryl houser miller'] VS true_author: ['cynthia wade', 'cheryl houser miller']
# movie_id: 97251
# true director: Michael Dudok De Wit
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06423521041870117
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0018188953399658203
# Discarted candidate: []
# Possible candidate: [{'de dudok michael wit': 3, 'dewit dudok michael': 1}]
# lengthNecessary: 1.4
# [{'de dudok michael wit': 3, 'dewit dudok michael': 1}]
# acceptance_diff 2
# ['de dudok michael wit'] VS true_author: ['de dudok michael wit']
# movie_id: 90003
# true director: Charles Chaplin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07462716102600098
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.002521991729736328
# Discarted candidate: []
# Possible candidate: [{'chaplin charles': 13}, {'chaplin charlie': 6}]
# lengthNecessary: 5.6499999999999995
# [{'chaplin charles': 13}, {'chaplin charlie': 6}]
# acceptance_diff 2
# ['chaplin charles'] VS true_author: ['chaplin charles']
# movie_id: 91535
# true director: J. A. Bayona
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07474303245544434
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.003503084182739258
# Discarted candidate: [{'antonio bayona juan': 2}]
# Possible candidate: [{'antonio bayona juan': 13}, {'a bayona j': 7}]
# lengthNecessary: 6.699999999999999
# [{'antonio bayona juan': 13}, {'a bayona j': 7}]
# acceptance_diff 2
# ['antonio bayona juan', 'a bayona j'] VS true_author: ['a bayona j']
# movie_id: 51346
# true director: William A. Seiter
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03825974464416504
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0011510848999023438
# Discarted candidate: []
# Possible candidate: [{'a seiter william': 2, 'seiter william': 1}]
# lengthNecessary: 1.0499999999999998
# [{'a seiter william': 2, 'seiter william': 1}]
# acceptance_diff 2
# ['a seiter william'] VS true_author: ['a seiter william']
# movie_id: 64713
# true director: Alan Mak;Felix Chong
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05764913558959961
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0013020038604736328
# Discarted candidate: []
# Possible candidate: [{'chong felix': 8}, {'alan mak': 5}]
# lengthNecessary: 3.55
# [{'chong felix': 8}, {'alan mak': 5}]
# acceptance_diff 2
# ['chong felix', 'alan mak'] VS true_author: ['alan mak', 'chong felix']
# movie_id: 87307
# true director: Florian Cossen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02844405174255371
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.000576019287109375
# Discarted candidate: []
# Possible candidate: [{'cossen florian': 1, 'cossen florian micoud': 1}]
# lengthNecessary: 0.7
# [{'cossen florian': 1, 'cossen florian micoud': 1}]
# acceptance_diff 2
# ['cossen florian', 'cossen florian micoud'] VS true_author: ['cossen florian']
# movie_id: 89712
# true director: Mauro Borrelli
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.031575679779052734
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010619163513183594
# Discarted candidate: []
# Possible candidate: [{'borrelli maura': 1, 'borrelli mauro': 2}]
# lengthNecessary: 1.0499999999999998
# [{'borrelli maura': 1, 'borrelli mauro': 2}]
# acceptance_diff 2
# ['borrelli maura'] VS true_author: ['borrelli mauro']
# movie_id: 11264
# true director: Rex Ingram
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05528998374938965
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0013909339904785156
# Discarted candidate: []
# Possible candidate: [{'alice terry': 1, 'ingram rex': 2}]
# lengthNecessary: 1.0499999999999998
# [{'alice terry': 1, 'ingram rex': 2}]
# acceptance_diff 2
# ['alice terry', 'ingram rex'] VS true_author: ['ingram rex']
# movie_id: 48608
# true director: John Stevenson;Mark Osborne
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.12077593803405762
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 6
# Blocking time is: 0.004499912261962891
# Discarted candidate: [{'john stevenson': 1}, {'mark osborne': 1}, {'john stevenson': 1}, {'mark osborne': 1}]
# Possible candidate: [{'mark osborne': 29}, {'john stevenson': 23}]
# lengthNecessary: 16.599999999999998
# [{'mark osborne': 29}, {'john stevenson': 23}]
# acceptance_diff 2
# ['mark osborne', 'john stevenson'] VS true_author: ['john stevenson', 'mark osborne']
# movie_id: 5451
# true director: Claudio Marques;Marilia Hughes
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.045629024505615234
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010709762573242188
# Discarted candidate: []
# Possible candidate: [{'claudio marques': 3, 'guerreiro hughes marilia': 2, 'hughes marilia': 1}]
# lengthNecessary: 2.0999999999999996
# [{'claudio marques': 3, 'guerreiro hughes marilia': 2, 'hughes marilia': 1}]
# acceptance_diff 2
# ['claudio marques', 'guerreiro hughes marilia', 'hughes marilia'] VS true_author: ['claudio marques', 'hughes marilia']
# movie_id: 29810
# true director: Herrmann Zschoche
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.051235198974609375
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0015110969543457031
# Discarted candidate: []
# Possible candidate: [{'herrmann zschoche': 8}, {'dressel eleonore': 4}]
# lengthNecessary: 3.1999999999999993
# [{'herrmann zschoche': 8}, {'dressel eleonore': 4}]
# acceptance_diff 2
# ['herrmann zschoche', 'dressel eleonore'] VS true_author: ['herrmann zschoche']
# movie_id: 78918
# true director: Marc Gracie;Tim Ferguson
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05316495895385742
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.001348733901977539
# Discarted candidate: []
# Possible candidate: [{'gracie marc': 6}, {'ferguson tim': 5}]
# lengthNecessary: 2.8499999999999996
# [{'gracie marc': 6}, {'ferguson tim': 5}]
# acceptance_diff 2
# ['gracie marc', 'ferguson tim'] VS true_author: ['gracie marc', 'ferguson tim']
# movie_id: 71440
# true director: Otto Preminger
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04881882667541504
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0016300678253173828
# ...
# Embedding time is: 0.037509918212890625
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0012269020080566406
# Discarted candidate: []
# Possible candidate: [{'l?a pool': 1, 'lea pool': 3}]
# lengthNecessary: 1.4
# [{'l?a pool': 1, 'lea pool': 3}]
# acceptance_diff 2
# ['l?a pool'] VS true_author: ['lea pool']
# movie_id: 69925
# true director: Heidi Maria Faisst
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04023599624633789
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010800361633300781
# Discarted candidate: []
# Possible candidate: [{'faissi heidi maria': 1, 'faisst heidi maria': 1}]
# lengthNecessary: 0.7
# [{'faissi heidi maria': 1, 'faisst heidi maria': 1}]
# acceptance_diff 2
# ['faissi heidi maria'] VS true_author: ['faisst heidi maria']
# movie_id: 47283
# true director: Carl Astrand;Mats Lindberg
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.056304931640625
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0013959407806396484
# Discarted candidate: []
# Possible candidate: [{'lindberg mats': 9}, {'astrand carl': 6}]
# lengthNecessary: 4.25
# [{'lindberg mats': 9}, {'astrand carl': 6}]
# acceptance_diff 2
# ['lindberg mats', 'astrand carl'] VS true_author: ['astrand carl', 'lindberg mats']
# movie_id: 40393
# true director: Ewing Scott
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03920602798461914
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.001377105712890625
# Discarted candidate: []
# Possible candidate: [{'ewing scott': 8}, {'george sherman': 3}]
# lengthNecessary: 2.8499999999999996
# [{'ewing scott': 8}, {'george sherman': 3}]
# acceptance_diff 2
# ['ewing scott', 'george sherman'] VS true_author: ['ewing scott']
# movie_id: 35829
# true director: Michael Paul Stephenson
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.042340993881225586
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.001605987548828125
# Discarted candidate: []
# Possible candidate: [{'michael paul stephenson': 6, 'michael stephenson': 2}]
# lengthNecessary: 2.8
# [{'michael paul stephenson': 6, 'michael stephenson': 2}]
# acceptance_diff 2
# ['michael paul stephenson'] VS true_author: ['michael paul stephenson']
# movie_id: 27116
# true director: Neil Marshall
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05206489562988281
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0020012855529785156
# Discarted candidate: [{'universal': 1}]
# Possible candidate: [{'marshall neil': 18}]
# lengthNecessary: 5.6499999999999995
# [{'marshall neil': 18}]
# acceptance_diff 2
# ['marshall neil'] VS true_author: ['marshall neil']
# movie_id: 49163
# true director: Vicente Aranda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.034178733825683594
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0012848377227783203
# Discarted candidate: []
# Possible candidate: [{'aranda vicente': 3, 'gomez raul': 2}]
# lengthNecessary: 1.75
# [{'aranda vicente': 3, 'gomez raul': 2}]
# acceptance_diff 2
# ['aranda vicente', 'gomez raul'] VS true_author: ['aranda vicente']
# movie_id: 64814
# true director: R. Balki
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03895401954650879
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010631084442138672
# Discarted candidate: []
# Possible candidate: [{'balki r': 4, 'ricky sandhu': 1}]
# lengthNecessary: 1.75
# [{'balki r': 4, 'ricky sandhu': 1}]
# acceptance_diff 2
# ['balki r'] VS true_author: ['balki r']
# movie_id: 87155
# true director: Jiri Svoboda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03289604187011719
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0013208389282226562
# Discarted candidate: []
# Possible candidate: [{'ji?i svoboda': 6, 'jiri svoboda': 1}]
# lengthNecessary: 2.4499999999999997
# [{'ji?i svoboda': 6, 'jiri svoboda': 1}]
# acceptance_diff 2
# ['ji?i svoboda'] VS true_author: ['jiri svoboda']
# movie_id: 19545
# true director: Charles Chu;Gavin Kelly
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03405189514160156
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0015919208526611328
# Discarted candidate: []
# Possible candidate: [{'charles chu': 1, 'gavin kelly': 2}]
# lengthNecessary: 1.0499999999999998
# [{'charles chu': 1, 'gavin kelly': 2}]
# acceptance_diff 2
# ['charles chu', 'gavin kelly'] VS true_author: ['charles chu', 'gavin kelly']
# movie_id: 46270
# true director: Seung-Hyeon Jin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03208017349243164
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0013241767883300781
# Discarted candidate: []
# Possible candidate: [{'hyeonh jin seung': 2, 'jin seung-hyeon': 2}]
# lengthNecessary: 1.4
# [{'hyeonh jin seung': 2, 'jin seung-hyeon': 2}]
# acceptance_diff 2
# ['hyeonh jin seung', 'jin seung-hyeon'] VS true_author: ['jin seung-hyeon']
# movie_id: 73371
# true director: Andrew Becker;Daniel Mehrer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02910900115966797
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0014660358428955078
# Discarted candidate: []
# Possible candidate: [{'andrew becker': 2, 'daniel mehrer': 1}]
# lengthNecessary: 1.0499999999999998
# [{'andrew becker': 2, 'daniel mehrer': 1}]
# acceptance_diff 2
# ['andrew becker', 'daniel mehrer'] VS true_author: ['daniel mehrer', 'andrew becker']
# movie_id: 61155
# true director: Chan-wook Park
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.033280134201049805
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0014791488647460938
# Discarted candidate: [{'chan-kyong park': 1, 'chan-wook park': 1}]
# Possible candidate: [{'chan-kyong park': 4, 'chan-wook park': 5}]
# lengthNecessary: 2.8499999999999996
# [{'chan-kyong park': 4, 'chan-wook park': 5}]
# acceptance_diff 2
# ['chan-kyong park', 'chan-wook park'] VS true_author: ['chan-wook park']
# movie_id: 111258
# true director: Michael Wadleigh
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07486796379089355
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 3
# Blocking time is: 0.0022368431091308594
# Discarted candidate: [{'d hancock john': 6}, {'hitzig rupert': 4}]
# Possible candidate: [{'michael wadleigh': 15}]
# lengthNecessary: 7.75
# [{'michael wadleigh': 15}]
# acceptance_diff 2
# ['michael wadleigh'] VS true_author: ['michael wadleigh']
# movie_id: 56502
# true director: Nagisa Oshima
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03637194633483887
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0014929771423339844
# Discarted candidate: []
# Possible candidate: [{'?shima nagisa': 2, 'nagisa oshima': 1}]
# lengthNecessary: 1.0499999999999998
# [{'?shima nagisa': 2, 'nagisa oshima': 1}]
# acceptance_diff 2
# ['?shima nagisa', 'nagisa oshima'] VS true_author: ['nagisa oshima']
# movie_id: 63743
# true director: Jeremy Frindel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0326080322265625
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010941028594970703
# Discarted candidate: []
# Possible candidate: [{'films substratum': 1, 'frindel jeremy': 7}]
# lengthNecessary: 2.8
# [{'films substratum': 1, 'frindel jeremy': 7}]
# acceptance_diff 2
# ['frindel jeremy'] VS true_author: ['frindel jeremy']
# movie_id: 105721
# true director: Georg Maas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.038713693618774414
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0010540485382080078
# Discarted candidate: []
# Possible candidate: [{'georg maas': 3, 'judith kaufmann': 2}]
# lengthNecessary: 1.75
# [{'georg maas': 3, 'judith kaufmann': 2}]
# acceptance_diff 2
# ['georg maas', 'judith kaufmann'] VS true_author: ['georg maas']
# movie_id: 88941
# true director: Jonah Bekhor;Zach Math
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.050267934799194336
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0014150142669677734
# Discarted candidate: []
# Possible candidate: [{'bekhor jonah': 10}, {'math zach': 9}]
# lengthNecessary: 5.6499999999999995
# [{'bekhor jonah': 10}, {'math zach': 9}]
# acceptance_diff 2
# ['bekhor jonah', 'math zach'] VS true_author: ['bekhor jonah', 'math zach']
# movie_id: 61767
# true director: Ryuhei Kitamura
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02616286277770996
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0011899471282958984
# Discarted candidate: []
# Possible candidate: [{'kitamura ry?hei': 2, 'kitamura ryuhei': 5}]
# lengthNecessary: 2.4499999999999997
# [{'kitamura ry?hei': 2, 'kitamura ryuhei': 5}]
# acceptance_diff 2
# ['kitamura ryuhei'] VS true_author: ['kitamura ryuhei']
# movie_id: 76373
# true director: Alice O'Fredericks;Jon Iversen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03275179862976074
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.00096893310546875
# Discarted candidate: []
# Possible candidate: [{"alice o'fredericks": 3, 'iversen jon': 2}]
# lengthNecessary: 1.75
# [{"alice o'fredericks": 3, 'iversen jon': 2}]
# acceptance_diff 2
# ["alice o'fredericks", 'iversen jon'] VS true_author: ['iversen jon', "alice o'fredericks"]
# movie_id: 38696
# true director: Sean Carr
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03398013114929199
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.001046895980834961
# Discarted candidate: []
# Possible candidate: [{'carr sean': 1, 'carrigan sean': 5}]
# lengthNecessary: 2.0999999999999996
# [{'carr sean': 1, 'carrigan sean': 5}]
# acceptance_diff 2
# ['carrigan sean'] VS true_author: ['carr sean']
# movie_id: 32680
# true director: Raj Nidimoru;Krishna DK
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0482029914855957
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0011172294616699219
# Discarted candidate: []
# Possible candidate: [{'d k krishna': 4, 'dk krishna': 1, 'nidimoru raj': 4}]
# lengthNecessary: 3.15
# [{'d k krishna': 4, 'dk krishna': 1, 'nidimoru raj': 4}]
# acceptance_diff 2
# ['d k krishna', 'nidimoru raj'] VS true_author: ['dk krishna', 'nidimoru raj']
# movie_id: 112475
# true director: Francis Ford Coppola
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06106996536254883
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.001435995101928711
# Discarted candidate: [{'coppola francis': 1}]
# Possible candidate: [{'coppola ford francis': 19}]
# lengthNecessary: 6.0
# [{'coppola ford francis': 19}]
# acceptance_diff 2
# ['coppola ford francis'] VS true_author: ['coppola ford francis']
# movie_id: 105251
# true director: Nic Hill;Scott Glosserman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03040790557861328
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0013737678527832031
# Discarted candidate: []
# Possible candidate: [{'glosserman scott': 2, 'hill nic': 1}]
# lengthNecessary: 1.0499999999999998
# [{'glosserman scott': 2, 'hill nic': 1}]
# acceptance_diff 2
# ['glosserman scott', 'hill nic'] VS true_author: ['hill nic', 'glosserman scott']
# movie_id: 58667
# true director: Chris R. Notarile;Kim Santiago
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04393601417541504
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0011730194091796875
# Discarted candidate: []
# Possible candidate: [{'kim santiago': 7}, {'chris notarile r': 4}]
# lengthNecessary: 2.8499999999999996
# [{'kim santiago': 7}, {'chris notarile r': 4}]
# acceptance_diff 2
# ['kim santiago', 'chris notarile r'] VS true_author: ['kim santiago', 'chris notarile r']
# movie_id: 87533
# true director: Chang Cheh;Pao Hsueh-Li
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0559539794921875
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 2
# Blocking time is: 0.0012440681457519531
# Discarted candidate: []
# Possible candidate: [{'chang cheh': 8}, {'hsueh li pao': 4, 'hsueh-li pao': 2}]
# lengthNecessary: 3.8999999999999995
# [{'chang cheh': 8}, {'hsueh li pao': 4, 'hsueh-li pao': 2}]
# acceptance_diff 2
# ['chang cheh', 'hsueh li pao'] VS true_author: ['chang cheh', 'hsueh-li pao']
# movie_id: 92814
# true director: Fritz Lang;Rene Sti
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.038401126861572266
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0011060237884521484
# Discarted candidate: []
# Possible candidate: [{'fritz lang': 6, 'rene sti': 2}]
# lengthNecessary: 2.8
# [{'fritz lang': 6, 'rene sti': 2}]
# acceptance_diff 2
# ['fritz lang'] VS true_author: ['fritz lang', 'rene sti']
# movie_id: 59689
# true director: Ines Paris;Daniela Fejerman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03632211685180664
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0011548995971679688
# Discarted candidate: []
# Possible candidate: [{'daniela fejerman': 4, 'ines paris': 2}]
# lengthNecessary: 2.0999999999999996
# [{'daniela fejerman': 4, 'ines paris': 2}]
# acceptance_diff 2
# ['daniela fejerman', 'ines paris'] VS true_author: ['ines paris', 'daniela fejerman']
# movie_id: 35985
# true director: Clay Tweel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05108904838562012
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0015082359313964844
# Discarted candidate: []
# Possible candidate: [{'clay j tweel': 2, 'clay tweel': 6}]
# lengthNecessary: 2.8
# [{'clay j tweel': 2, 'clay tweel': 6}]
# acceptance_diff 2
# ['clay tweel'] VS true_author: ['clay tweel']
# movie_id: 31151
# true director: Gaston Ravel;Tony Lekain
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.030360937118530273
# cluster_method: hierarchy
# num_clusters_rate: 0.1
# NUM_CLUSTERS 1
# Blocking time is: 0.0009419918060302734
# Discarted candidate: []
# Possible candidate: [{'gaston ravel': 1, 'lekain tony': 2}]
# lengthNecessary: 1.0499999999999998
# [{'gaston ravel': 1, 'lekain tony': 2}]
# acceptance_diff 2
# ['gaston ravel', 'lekain tony'] VS true_author: ['lekain tony', 'gaston ravel']
# Total time is: 20.162256956100464

# %% [markdown]
# # ALL Cases

# %%
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# precision is 0.4731404958677686
# recall is 0.5725
# f1Score is 0.5180995475113123
# (0.4731404958677686, 0.5725, 0.5180995475113123)

# %%
getEvaluation(finalDirectors, trueDirectors, 1) #0.3
# Out:
# precision is 0.49230769230769234
# recall is 0.56
# f1Score is 0.5239766081871345
# (0.49230769230769234, 0.56, 0.5239766081871345)

# %%
getEvaluation(finalDirectors, trueDirectors, 1) #0.35
# Out:
# precision is 0.5022727272727273
# recall is 0.5525
# f1Score is 0.5261904761904763
# (0.5022727272727273, 0.5525, 0.5261904761904763)

# %%
getEvaluation(finalDirectors, trueDirectors, 1) #Fix directors split
# Out:
# precision is 0.9272727272727272
# recall is 0.6891891891891891
# f1Score is 0.7906976744186047
# (0.9272727272727272, 0.6891891891891891, 0.7906976744186047)

# %% [markdown]
# # Add Multiple Winner from a block

# %%
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# precision is 0.8589041095890411
# recall is 1.0591216216216217
# f1Score is 0.9485627836611195
# (0.8589041095890411, 1.0591216216216217, 0.9485627836611195)

# %%
finalDirectors
# Out:
# [['chester e hal', 'cyril frankel', 'hamer robert'],
#  ['alexandre o philippe', 'alexandre philippe'],
#  ['bird brad'],
#  ['sherman vincent'],
#  ['clarke fraser heston'],
#  [],
#  ['godfrey ho', 'kim si-hyun'],
#  ['dave fleischer'],
#  ["d'urville martin"],
#  ['norton virgien', 'igor kovalyov'],
#  ['bezucha thomas'],
#  ['galinsky michael', 'hawley suki'],
#  ['chatrichalerm yukoi', 'chatrichalerm yukol'],
#  ['harvey parry', 'richard talmadge'],
#  ['hara keiichi'],
#  ['allegret yves', 'e portas rafael'],
#  ['cohen larry', 'tannen william'],
#  ['anant mahadevan', 'ananth mahadevan narayan'],
#  ['coen joel', 'coen ethan'],
#  ['dziga groupe vertov', 'godard jean-luc'],
#  ['adam small', 'peter stuart'],
#  ['caradog james', 'caradog james w'],
#  ['lord phil'],
#  ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande'],
#  ['albert magnoli', 'prince'],
#  ['andrzej bartkowiak'],
#  ['hugues martin', 'martin sandra'],
#  ['chomsky j marvin'],
#  ["o'haver tommy"],
#  ['dewey richard', 'marrinan timothy'],
#  ['a d pennebaker', 'chris hegedus'],
#  ['paolo taviani', 'taviani vittorio'],
#  ['johar karan'],
#  ['anlo sepulveda', 'collins paul'],
#  ['dudow slatan', 'groschopp richard', 'kurt maetzig'],
#  ['christian krones',
#   'florian weigensamer',
#   'muller olaf s',
#   'roland schrotthofer'],
#  ['robert rossen'],
#  ['michael tiddes'],
#  ['bulette jon', 'f roberts stone', 'roberts stone'],
#  ['anthony stabley'],
#  ['kassen mark', 'adam kassen'],
#  ['chuck staley', 'goren rowby'],
#  ['almereyda michael'],
#  ['brannon c fred', 'carr thomas'],
#  ['brett celestre', 'brette celestre', 'celestre matthew'],
#  ['arcel nikolaj'],
#  ['engin orbey'],
#  ['baird bryant', 'demetrakas johanna'],
#  ['gene kelly'],
#  ['david twohy'],
#  ['alba angelica de', 'paul ragsdale'],
#  ['allan arkush'],
#  ['pan peicheng', 'tian zhuangzhuang'],
#  ['hegner michael', 'karsten kiilerich'],
#  ['k king', 'kevin king'],
#  ['hill jack', 'john lamb'],
#  ['frank melvin', 'norman panama'],
#  ['gionata zarantonello', 'jonathan zarantonello'],
#  ['je-gyu kang'],
#  ['alistair legrand'],
#  ['fernando palacios', 'j rafael salvia'],
#  ['kip pastor', 'kiplin pastor r'],
#  ['quentin tarantino'],
#  ['bartas sar?nas', 'bartas sharunas'],
#  ['cort johns', 'jaden luke'],
#  ['glass nancy', 'loschiavo michele'],
#  ['barreto ramos saul', 'gonzalez manuel mauricio'],
#  ['andrew mclaglen v'],
#  ['morrissey paul'],
#  ['capra frank', 'irvin willat'],
#  [],
#  ['adam friedman', 'iain kennedy'],
#  ['bill guttentag', 'dan sturman'],
#  ['cynthia wade', 'cheryl houser', 'cheryl houser miller'],
#  ['de dudok michael wit', 'dewit dudok michael'],
#  ['chaplin charles'],
#  ['antonio bayona juan'],
#  ['a seiter william', 'seiter william'],
#  ['chong felix', 'alan mak'],
#  ['cossen florian', 'cossen florian micoud'],
#  ['borrelli maura', 'borrelli mauro'],
#  ['alice terry', 'ingram rex'],
#  ['mark osborne', 'john stevenson'],
#  ['claudio marques', 'guerreiro hughes marilia', 'hughes marilia'],
#  ['herrmann zschoche'],
#  ['gracie marc', 'ferguson tim'],
#  ['otto preminger'],
#  ['krayenb?hl sabine', 'krayenbuhl sabine', 'oelbaum zeva'],
#  ['arnfred morten', 'lars trier von'],
#  ['fastvold mona'],
#  ['jason rivers', 'jopia tony'],
#  ['singh tarsem'],
#  ['bryant david', 'richard stiles', 'sebastian smith'],
#  ['andrzej wajda', 'francois truffaut', 'marcel ophuls', 'renzo rossellini'],
#  ['hirschman ray', 'szarka william'],
#  ['eshom nelms', 'ian nelms'],
#  ['aaron bush k', 'roberts wally'],
#  ['spielberg steven'],
#  ['davis guggenheim'],
#  ['masha zur', 'yonathan zur'],
#  ['broomfield nick', 'dolezal rudi'],
#  ['anne-marie mieville', 'godard jean-luc'],
#  ['michael tiddes'],
#  ['bobby roe', 'jeff larson'],
#  ['cinzia th torrini', 'cinzia torrini'],
#  ['chang-wei gu', 'changwei gu'],
#  ['castellani renato', 'comencini luigi', 'franco rossi'],
#  ['chow thomas', 'kwan stanley'],
#  ['eric lewald', 'glenn morgan'],
#  ['guy reid'],
#  ['campopiano john', 'justin white'],
#  ['barry mahon', 'frank willard'],
#  ['beverly sebastian', 'ferd sebastian'],
#  ['betz jon', 'siegel taggart'],
#  ['anaise tara'],
#  ['cheng kang', 'shao-yung tung'],
#  ['d hogan w', 'david hogan'],
#  ['carlos jr ramos', 'honey lauren'],
#  ['gibson mel'],
#  ['burton tim', 'johnson michael'],
#  ['michael preece'],
#  ['cuaron jonas'],
#  ['cary fukunaga'],
#  ['frantisek pilat', 'otakar vavra'],
#  ['c miller steven'],
#  ['alexis ducord', 'arthur de pins'],
#  ['daniel petrie', 'sheldon sidney'],
#  ['arons rich', 'audu paden', 'dave marshall'],
#  ['a dupont e', 'andr dupont ewald', 'andre dupont ewald'],
#  ['denis hennelly henry', 'denis hennelly'],
#  ['hathaway henry', 'henry king', 'henry koster'],
#  ['burstein nanette', 'brett morgen'],
#  ['bartholomew craig strydom', 'daniels lee'],
#  ['bousman darren lynn'],
#  ['boivin patrick', 'olivier roberge'],
#  ['jordan metzger', 'kaley simpson'],
#  ['alexander barry brown', 'emilio estevez', 'glenn silber'],
#  ['buster keaton', 'charles lamont'],
#  ['createspace', 'jonze spike'],
#  ['adam rodgers', 'adam rogers'],
#  ['fukasaku kenta', 'fukasaku kinji'],
#  ['jared p scott', 'jared scott'],
#  ['rsumovi vuk', 'rsumovic vuk'],
#  ['elvey maurice', 'milton rosmer'],
#  ['daniel ingsten', 'jonas svensson'],
#  ['douglas gordon', 'richard wilson'],
#  ['emanuel goldman peter', 'emmanuel goldman peter'],
#  ['j lee thompson'],
#  ['george miller', 'george miller t'],
#  ['chabrol claude',
#   'douchet jean',
#   'eric rohmer',
#   'jean rouch',
#   'jean-daniel pollet'],
#  ['d foldes lawrence'],
#  ['stojanovi uros'],
#  ['dillon jonathan', 'dillon jonathan m'],
#  ['communications inc roads', 'hodge russell'],
#  ['andrew mclaglen', 'andrew mclaglen v'],
#  ['antal nimrod'],
#  ['gary michael schultz', 'gary schultz'],
#  ['corman roger'],
#  ['martin zandvliet'],
#  ['carl dreyer th', 'carl dreyer theodor'],
#  ['cheung sam', 'cheung sum'],
#  ['foster lewis r'],
#  ['basil dearden', 'hay will'],
#  ['isaac james'],
#  ['joseph m newman', 'joseph newman'],
#  ['heather m winters', 'heather winters'],
#  ['gallagher j michael'],
#  ['carvalho joao',
#   'carvalho tiago',
#   'francisco manuel sousa',
#   'ines lebreaud',
#   'katia rio'],
#  ['albert pereira-lazaro', 'emmanuel klotz'],
#  ['koji shiraishi',
#   'masayuki ochiai',
#   'nakamura yoshihiro',
#   'norio tsuruta',
#   'shimizu takashi'],
#  ['bernard deyries', 'kimio yabuki'],
#  ['gissberg jan', 'lasseby stig'],
#  ['christian de rezendes', "christian o'neill"],
#  ['christoph schaub', 'michael schindhelm'],
#  ['a dupont e', 'andre dupont ewald'],
#  ['caiozzi silvio', 'pablo perelman'],
#  ['jennifer prediger', 'jess weixler'],
#  ['lloyd stanton', 'paul toogood'],
#  ['bernard queysanne', 'georges perec'],
#  ['garc rodrigo', 'garcia rodrigo'],
#  ['charlotte zwerin', 'david maysles', 'albert maysles'],
#  ['ben knight', 'rummel travis'],
#  ['diego juan solanas'],
#  ['eng john', 'norton virgien'],
#  ['jugert rudolf'],
#  ['marco ristori', 'boni luca'],
#  ['armstrong michael'],
#  ['flying lotus'],
#  ['agnes varda',
#   'alain resnais',
#   'chris marker',
#   'ivens joris',
#   'klein william'],
#  ['adolphson edvin', 'sigurd wallen'],
#  ['fabrice ferrari', 'gilles perret'],
#  ['bob clampett', 'clampett robert'],
#  ['dardenne jean-pierre', 'dardenne luc'],
#  ['khalid mohamed', 'khalid mohammed'],
#  ['filho kleber mendon?a', 'filho kleber mendonca', 'timo zhalnin'],
#  ['f gutierrez javier'],
#  ['david paltenghi', 'montgomery tully'],
#  ['king vidor'],
#  ['minnelli vincente'],
#  ['bill l norton'],
#  ['glenn triggs', 'jeffrey roth'],
#  ['cayrol jean', 'claude durand'],
#  ['devaki singh', 'kenny luke'],
#  ['amber edwards', 'dave davidson'],
#  ['betts margaret'],
#  ['argott don', 'demian fenton'],
#  ['ji?i weiss', 'jiri weiss'],
#  ['otto preminger'],
#  ['andy de emmony', 'andy deemmony'],
#  ['a?ar friadegrik friadegriksson', 'fridrik fridriksson thor'],
#  ['bill couturi', 'bill couturie'],
#  ['bob carruthers', 'david mcwhinnie'],
#  ['john stockwell'],
#  ['roar uthaug'],
#  ['david leland', 'gary graver'],
#  ['francois ozon'],
#  ['de giulio santi', 'meschino neil'],
#  ['daisaku shirakawa', 'osamu tezuka', 'taiji yabushita'],
#  ['fred weintraub', 'kuhn tom'],
#  ['hunt jeremy', 'branit bruce'],
#  ['jennifer kent'],
#  ['simon wincer'],
#  ['carl dreyer th', 'carl dreyer theodor'],
#  ['blais matthew taylor', 'mack trevor'],
#  ['carnevale marcos', 'khosla raj'],
#  ['bostan elisabeta', 'codrescu nicolae'],
#  ['d rosenbaum scott', 'rosenbaum scott'],
#  ['galison peter', 'moss robb'],
#  ['ron satlof', 'ron satloff'],
#  ['a harold wayne', 'bosko mark steven'],
#  ['kate melville', 'kate melville miles'],
#  ['aleksandar petrovi', 'aleksandar petrovic'],
#  ['keven undergaro', 'kevin undergaro'],
#  ['chaplin charles', 'chaplin charlie'],
#  ['leroy mervyn'],
#  ['gallaga peque', 'lore reyes'],
#  ['h juran nathan', 'juran nathan'],
#  ['manskiy vitaliy', 'mansky vitaly'],
#  ['advani nikkhil', 'advani nikhil'],
#  ['brian yuzna', 'christophe gans', 'kaneko shusuke'],
#  ['brown clarence', 'maurice tourneur'],
#  ['brenda greene mitchell', 'brenda mitchell', 'douglas sam wainwright'],
#  ['anthony leondis'],
#  ['navot papushado', 'aharon keshales'],
#  ['ann guedes', 'eduardo guedes'],
#  ['bluth don'],
#  ['bj?rne larson', 'bjorne larson'],
#  ['f maxwell ronald'],
#  ['albacete alfonso', 'bardem miguel', 'david menkes'],
#  ['andrew lau', 'andrew lau wai-keung', 'lau wai-keung'],
#  ['vaclav vorli?ek'],
#  ['del roy ruth', 'liapis peter'],
#  ['not specifed', 'ritter tim'],
#  ['lord phil'],
#  ['prem raj', 'prem soni'],
#  ['hugo rodr?guez', 'hugo rodriguez'],
#  ['heidingsfelder markus', 'min tesch'],
#  ['crespo erick', 'crespo erick m', 'kiki melendez'],
#  ['french michael', 'miller scott'],
#  ['arye gross', 'gieras gregory'],
#  ["o'connor pat", 'oconnor pat'],
#  ['curt goetz', 'gillmann karl peter'],
#  ['gianni puccini', 'naschy paul'],
#  ['gerald thomas', 'ralph thomas'],
#  ['lekha singh', 'roger spottiswoode'],
#  ['anderson derek', 'kubicek victor'],
#  ['c fraser heston', 'clarke fraser heston'],
#  ['chlupacek matej', 'michal samir'],
#  ['jarkko laine t', 'kates naama'],
#  ['allen will'],
#  ['cohen rob'],
#  ['cresswell luke', 'mcnicholas steve'],
#  ['baxley craig r'],
#  ['jaa tony', 'panna rittikrai'],
#  ['carpenter stephen', 'jeffrey obrow'],
#  ['david nerlich', 'andrew traucki'],
#  ['arpa attila', 'arpa attila c'],
#  ['houston robert'],
#  ['erlingur thoroddsen', 'heldrich jacey'],
#  ['g?rard krawczyk', 'gerard krawczyk'],
#  ['dear william'],
#  ['carpenter john'],
#  ['joaqu?n pardav', 'joaquin pardave'],
#  ['david siegel', 'mcgehee scott'],
#  ['franco james', 'pamela romanowsky'],
#  ['dowdle erick john'],
#  ['hesser spencer terry', 'mazurek stephan'],
#  ['kabir khan'],
#  ['franco james', 'gus sant van'],
#  ['bigas luna', 'carles porta', 'lara sergi'],
#  ['benward luke', 'mark stouffer'],
#  ['g hunt jeffrey'],
#  ['chan wesley', 'philip wang'],
#  ['davide robert', 'purvis roberto'],
#  ['florian heinzen-ziob', 'georg heinzen'],
#  ['dionysius eric', 'eric mistler', 'levy-novion mariette'],
#  ['marshall neilan', 'mary pickford'],
#  ['devaney sean', 'eric weber'],
#  ['marshall rawson thurber'],
#  ['bernard campan', 'bourdon didier'],
#  ['charles vidor', 'huston john'],
#  ['akerblom gustaf', 'hannes holm'],
#  ['leroy mervyn'],
#  ['lipsky old?ich', 'lipsky oldrich'],
#  ['arthur qwak', 'guillaume ivernel'],
#  ['levin mark'],
#  ['paolo taviani', 'taviani vittorio'],
#  ['agel romi', 'holger wick'],
#  ['bestall cliff', 'bestall clifford', 'freeman morgan', 'lori mccreary'],
#  ['mora philippe'],
#  ['craig s zahler'],
#  ['a jack sunseri', 'deland nuse'],
#  ['bunuel luis'],
#  ['ching siu-tung', 'hark tsui'],
#  ['cavay fred', 'cavaye fred'],
#  ['anant mahadevan', 'ananth mahadevan narayan'],
#  ['hock jonathan', 'alistair christopher'],
#  ['casaril guy', 'chabrol claude'],
#  ['mate rudolph'],
#  ['dean fuller marcus'],
#  ['adrian powers', 'earl johan'],
#  ['english john', 'william witney'],
#  ['don taylor'],
#  ['alain delon', 'davis robin'],
#  ['asa faringer', 'hultberg ulf'],
#  ['adrien brody', 'ford kevin'],
#  ['delman jeffery'],
#  ['bradley young', 'erick vega', 'larry sands'],
#  ['filip remunda', 'klusak vit'],
#  ['acquisto luigi', 'bety reis'],
#  ['neri parenti', 'paolo villaggio'],
#  ['a?ric rohmer', 'eric rohmer'],
#  ['d harold schuster', 'harold schuster'],
#  ['guido manuli', 'maurizio nichetti'],
#  ['alfredo zacarias', 'conrad robert'],
#  ['daum menachem', 'oren rudavsky'],
#  ['mart?nez ra?l', 'martinez raul'],
#  ['andrew lau', 'andrew lau wai-keung', 'lau wai-keung'],
#  ['beno?t philippon', 'benoit philippon'],
#  ['ferrer jos', 'ferrer jose'],
#  ['barnz daniel'],
#  ['daniele huillet', 'jean-marie straub'],
#  ['darren grodsky'],
#  ['alexandre bustillo', 'julien maury'],
#  ['collins d lewis', 'keays vernon'],
#  ['charles vidor', 'cukor george'],
#  ['cavara paolo', 'franco prosperi', 'gualtiero jacopetti'],
#  ['jeff orlowski'],
#  ['pawe pawlikowski', 'pawel pawlikowski'],
#  ['pearry reginald teo'],
#  ['alexandre chartrand', 'gendron thierry'],
#  ['amateau rod'],
#  ['bulaji veljko'],
#  ['vasili zhuravlyov', 'vasily zhuravlyov'],
#  ['chatmon pete', 'rick zahn'],
#  ['francis jun posadas', 'francis posadas'],
#  ['beebe ford', 'ray taylor'],
#  ['andrei konchalovsky'],
#  ['giorgos lanthimos', 'lanthimos yorgos'],
#  ['estrada jose'],
#  ['francis girod', 'regis wargnier'],
#  ['gerard pires'],
#  ['karel zeman'],
#  ['english john'],
#  ['michael wright'],
#  ['christian weisenborn', 'erwin keusch'],
#  ['brodie higgs', 'daniil zinchenko'],
#  ['lambert susan', 'moore stefan'],
#  ['langen torin', 'jason tannis', 'kelly michael stewart', 'ramelan zachary'],
#  ["gavin o'connor"],
#  ['l?a pool', 'lea pool'],
#  ['faissi heidi maria', 'faisst heidi maria'],
#  ['lindberg mats', 'astrand carl'],
#  ['ewing scott'],
#  ['michael paul stephenson'],
#  ['marshall neil'],
#  ['aranda vicente', 'gomez raul'],
#  ['balki r', 'ricky sandhu'],
#  ['ji?i svoboda'],
#  ['charles chu', 'gavin kelly'],
#  ['hyeonh jin seung', 'jin seung-hyeon'],
#  ['andrew becker', 'daniel mehrer'],
#  ['chan-kyong park', 'chan-wook park'],
#  ['michael wadleigh'],
#  ['?shima nagisa', 'nagisa oshima'],
#  ['frindel jeremy'],
#  ['georg maas', 'judith kaufmann'],
#  ['bekhor jonah', 'math zach'],
#  ['kitamura ry?hei', 'kitamura ryuhei'],
#  ["alice o'fredericks", 'iversen jon'],
#  ['carrigan sean'],
#  ['d k krishna', 'dk krishna', 'nidimoru raj'],
#  ['coppola ford francis'],
#  ['glosserman scott', 'hill nic'],
#  ['kim santiago', 'chris notarile r'],
#  ['chang cheh', 'hsueh li pao', 'hsueh-li pao'],
#  ['fritz lang'],
#  ['daniela fejerman', 'ines paris'],
#  ['clay tweel'],
#  ['gaston ravel', 'lekain tony']]

# %%
trueDirectors
# Out:
# [['hamer robert'],
#  ['alexandre o philippe'],
#  ['bird brad'],
#  ['sherman vincent'],
#  ['c fraser heston'],
#  ['john landis', 'dante joe', 'george miller', 'spielberg steven'],
#  ['godfrey ho'],
#  ['dave fleischer'],
#  ["d'urville martin"],
#  ['norton virgien', 'igor kovalyov'],
#  ['bezucha thomas'],
#  ['hawley suki', 'galinsky michael'],
#  ['chatrichalerm yukol'],
#  ['richard talmadge', 'harvey parry'],
#  ['hara keiichi'],
#  ['allegret yves'],
#  ['cohen larry', 'tannen william'],
#  ['ananth mahadevan narayan'],
#  ['coen joel'],
#  ['godard jean-luc'],
#  ['adam small', 'peter stuart'],
#  ['caradog james w'],
#  ['christopher miller', 'lord phil'],
#  ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande'],
#  ['prince'],
#  ['andrzej bartkowiak'],
#  ['martin sandra', 'hugues martin'],
#  ['chomsky j marvin'],
#  ["o'haver tommy"],
#  ['marrinan timothy', 'dewey richard'],
#  ['chris hegedus', 'a d pennebaker'],
#  ['paolo taviani', 'taviani vittorio'],
#  ['johar karan'],
#  ['anlo sepulveda', 'collins paul'],
#  ['dudow slatan', 'kurt maetzig'],
#  ['christian krones',
#   'florian weigensamer',
#   'roland schrotthofer',
#   'muller olaf s'],
#  ['robert rossen'],
#  ['michael tiddes'],
#  ['roberts stone', 'bulette jon'],
#  ['anthony stabley'],
#  ['adam kassen', 'kassen mark'],
#  ['chuck staley', 'goren rowby'],
#  ['almereyda michael'],
#  ['brannon c fred', 'carr thomas'],
#  ['celestre matthew', 'brett celestre'],
#  ['arcel nikolaj'],
#  ['ergin orbey'],
#  ['demetrakas johanna', 'baird bryant'],
#  ['gene kelly'],
#  ['david twohy'],
#  ['paul ragsdale'],
#  ['allan arkush'],
#  ['tian zhuangzhuang'],
#  ['hegner michael', 'karsten kiilerich'],
#  ['kevin king'],
#  ['john lamb'],
#  ['frank melvin', 'norman panama'],
#  ['gionata zarantonello'],
#  ['je-gyu kang'],
#  ['alistair legrand'],
#  ['fernando palacios'],
#  ['kiplin pastor r'],
#  ['quentin tarantino'],
#  ['bartas sharunas'],
#  ['jaden luke', 'cort johns'],
#  ['loschiavo michele', 'glass nancy'],
#  ['barreto ramos saul', 'gonzalez manuel mauricio'],
#  ['andrew mclaglen v'],
#  ['morrissey paul'],
#  ['capra frank'],
#  ['nibbelink phil', 'ralph zondag', 'simon wells', 'dick zondag'],
#  ['iain kennedy', 'adam friedman'],
#  ['dan sturman', 'bill guttentag'],
#  ['cheryl houser miller', 'cynthia wade'],
#  ['de dudok michael wit'],
#  ['chaplin charles'],
#  ['a bayona j'],
#  ['a seiter william'],
#  ['chong felix', 'alan mak'],
#  ['cossen florian'],
#  ['borrelli mauro'],
#  ['ingram rex'],
#  ['mark osborne', 'john stevenson'],
#  ['claudio marques', 'hughes marilia'],
#  ['herrmann zschoche'],
#  ['gracie marc', 'ferguson tim'],
#  ['otto preminger'],
#  ['oelbaum zeva', 'krayenbuhl sabine'],
#  ['lars trier von'],
#  ['fastvold mona'],
#  ['jopia tony'],
#  ['singh tarsem'],
#  ['bryant david', 'sebastian smith', 'richard stiles'],
#  ['francois truffaut',
#   'andrzej wajda',
#   'ishihara shintaro',
#   'renzo rossellini',
#   'marcel ophuls'],
#  ['hirschman ray'],
#  ['ian nelms', 'eshom nelms'],
#  ['aaron bush k', 'roberts wally'],
#  ['spielberg steven'],
#  ['davis guggenheim'],
#  ['yonathan zur', 'masha zur'],
#  ['broomfield nick', 'dolezal rudi'],
#  ['anne-marie mieville', 'godard jean-luc'],
#  ['michael tiddes'],
#  ['bobby roe'],
#  ['cinzia th torrini'],
#  ['changwei gu'],
#  ['castellani renato', 'comencini luigi', 'franco rossi'],
#  ['kwan stanley'],
#  ['eric lewald', 'glenn morgan'],
#  ['guy reid'],
#  ['justin white', 'campopiano john'],
#  ['frank willard'],
#  ['beverly sebastian', 'ferd sebastian'],
#  ['betz jon', 'siegel taggart'],
#  ['anaise tara'],
#  ['cheng kang'],
#  ['d hogan w'],
#  ['carlos jr ramos', 'honey lauren'],
#  ['gibson mel'],
#  ['johnson mike', 'burton tim'],
#  ['michael preece'],
#  ['cuaron jonas'],
#  ['cary fukunaga joji'],
#  ['otakar vavra'],
#  ['c miller steven'],
#  ['arthur de pins', 'alexis ducord'],
#  ['daniel petrie'],
#  ['arons rich', 'audu paden', 'dave marshall'],
#  ['a dupont e'],
#  ['denis hennelly henry'],
#  ['jean negulesco',
#   'hawks howard',
#   'hathaway henry',
#   'henry king',
#   'henry koster'],
#  ['burstein nanette', 'brett morgen'],
#  ['daniels lee'],
#  ['bousman darren lynn'],
#  ['olivier roberge', 'boivin patrick'],
#  ['jordan metzger', 'kaley simpson'],
#  ['alexander barry brown', 'glenn silber'],
#  ['charles lamont'],
#  ['jonze spike'],
#  ['adam rodgers'],
#  ['fukasaku kinji', 'fukasaku kenta'],
#  ['jared p scott'],
#  ['rsumovic vuk'],
#  ['milton rosmer', 'elvey maurice'],
#  ['jonas svensson', 'daniel ingsten'],
#  ['douglas gordon'],
#  ['emanuel goldman peter'],
#  ['j lee thompson'],
#  ['george miller'],
#  ['jean rouch',
#   'jean-daniel pollet',
#   'chabrol claude',
#   'douchet jean',
#   'godard jean-luc',
#   'eric rohmer'],
#  ['d foldes lawrence'],
#  ['stojanovic uros'],
#  ['dillon jonathan m'],
#  ['hodge russell'],
#  ['andrew mclaglen v'],
#  ['antal nimrod'],
#  ['gary michael schultz'],
#  ['corman roger'],
#  ['martin zandvliet'],
#  ['carl dreyer theodor'],
#  ['cheung sum'],
#  ['foster lewis r'],
#  ['basil dearden', 'hay will'],
#  ['isaac jim'],
#  ['joseph m newman'],
#  ['heather winters'],
#  ['gallagher michael'],
#  ['carvalho joao',
#   'katia rio',
#   'francisco manuel sousa',
#   'ines lebreaud',
#   'carvalho tiago'],
#  ['albert pereira-lazaro', 'emmanuel klotz'],
#  ['masayuki ochiai',
#   'shimizu takashi',
#   'koji shiraishi',
#   'norio tsuruta',
#   'nakamura yoshihiro'],
#  ['bernard deyries', 'kimio yabuki'],
#  ['gissberg jan', 'lasseby stig'],
#  ["christian o'neill", 'christian de rezendes'],
#  ['christoph schaub', 'michael schindhelm'],
#  ['a dupont e'],
#  ['pablo perelman', 'caiozzi silvio'],
#  ['jennifer prediger', 'jess weixler'],
#  ['paul toogood', 'lloyd stanton'],
#  ['bernard queysanne', 'georges perec'],
#  ['garcia rodrigo'],
#  ['albert maysles', 'david maysles', 'charlotte zwerin'],
#  ['ben knight', 'rummel travis'],
#  ['juan solanas'],
#  ['norton virgien', 'eng john'],
#  ['jugert rudolf'],
#  ['boni luca', 'marco ristori'],
#  ['armstrong michael'],
#  ['steve'],
#  ['claude lelouch',
#   'klein william',
#   'chris marker',
#   'alain resnais',
#   'ivens joris',
#   'godard jean-luc'],
#  ['adolphson edvin'],
#  ['gilles perret', 'fabrice ferrari'],
#  ['clampett robert'],
#  ['dardenne luc', 'dardenne jean-pierre'],
#  ['khalid mohamed'],
#  ['filho kleber mendonca'],
#  ['f gutierrez javier'],
#  ['montgomery tully'],
#  ['king vidor'],
#  ['minnelli vincente'],
#  ['bill l norton'],
#  ['glenn triggs'],
#  ['cayrol jean', 'claude durand'],
#  ['devaki singh', 'kenny luke'],
#  ['amber edwards', 'dave davidson'],
#  ['betts maggie'],
#  ['demian fenton', 'argott don'],
#  ['jiri weiss'],
#  ['otto preminger'],
#  ['andy de emmony'],
#  ['fridrik fridriksson thor'],
#  ['bill couturie'],
#  ['bob carruthers', 'david mcwhinnie'],
#  ['john stockwell'],
#  ['roar uthaug'],
#  ['david leland'],
#  ['francois ozon'],
#  ['meschino neil', 'de giulio santi'],
#  ['taiji yabushita', 'osamu tezuka'],
#  ['fred weintraub', 'kuhn tom'],
#  ['branit bruce', 'hunt jeremy'],
#  ['jennifer kent'],
#  ['simon wincer'],
#  ['carl dreyer theodor'],
#  ['mack trevor'],
#  ['khosla raj'],
#  ['bostan elisabeta', 'codrescu nicolae'],
#  ['rosenbaum scott'],
#  ['galison peter', 'moss robb'],
#  ['ron satlof'],
#  ['bosko mark steven', 'a harold wayne'],
#  ['kate melville'],
#  ['aleksandar petrovic'],
#  ['keven undergaro'],
#  ['chaplin charles'],
#  ['leroy mervyn'],
#  ['lore reyes', 'gallaga peque'],
#  ['juran nathan'],
#  ['mansky vitaly'],
#  ['advani nikhil'],
#  ['christophe gans', 'kaneko shusuke', 'brian yuzna'],
#  ['maurice tourneur', 'brown clarence'],
#  ['douglas sam wainwright', 'brenda greene mitchell'],
#  ['leondis tony'],
#  ['aharon keshales', 'navot papushado'],
#  ['ann guedes', 'eduardo guedes'],
#  ['bluth don'],
#  ['bjorne larson'],
#  ['f maxwell ronald'],
#  ['david menkes', 'bardem miguel', 'albacete alfonso'],
#  ['andrew lau'],
#  ['vaclav vorlicek'],
#  ['del roy ruth'],
#  ['ritter tim'],
#  ['christopher miller', 'lord phil'],
#  ['prem raj'],
#  ['hugo rodriguez'],
#  ['heidingsfelder markus', 'min tesch'],
#  ['crespo erick m', 'kiki melendez'],
#  ['french michael'],
#  ['gieras gregory', 'arye gross'],
#  ["o'connor pat"],
#  ['curt goetz', 'gillmann karl peter'],
#  ['gianni puccini'],
#  ['gerald thomas'],
#  ['lekha singh', 'roger spottiswoode'],
#  ['anderson derek', 'kubicek victor'],
#  ['c fraser heston'],
#  ['chlupacek matej'],
#  ['kates naama'],
#  ['allen will'],
#  ['cohen rob'],
#  ['cresswell luke', 'mcnicholas steve'],
#  ['baxley craig r'],
#  ['jaa tony', 'panna rittikrai'],
#  ['carpenter stephen', 'jeffrey obrow'],
#  ['david nerlich', 'andrew traucki'],
#  ['arpa attila'],
#  ['kenji misumi', 'houston robert'],
#  ['erlingur thoroddsen'],
#  ['gerard krawczyk'],
#  ['dyke l thomas', 'dear william'],
#  ['carpenter john'],
#  ['joaquin pardave'],
#  ['david siegel', 'mcgehee scott'],
#  ['pamela romanowsky', 'franco james'],
#  ['dowdle erick john'],
#  ['hesser spencer terry'],
#  ['kabir khan'],
#  ['gus sant van', 'franco james'],
#  ['carles porta'],
#  ['mark stouffer'],
#  ['hunt jeffrey'],
#  ['philip wang', 'chan wesley'],
#  ['purvis roberto'],
#  ['florian heinzen-ziob', 'georg heinzen'],
#  ['eric mistler', 'dionysius eric'],
#  ['marshall neilan'],
#  ['eric weber'],
#  ['marshall rawson thurber'],
#  ['bernard campan', 'bourdon didier'],
#  ['charles vidor'],
#  ['akerblom gustaf'],
#  ['leroy mervyn'],
#  ['lipsky oldrich'],
#  ['guillaume ivernel', 'arthur qwak'],
#  ['levin mark'],
#  ['paolo taviani', 'taviani vittorio'],
#  ['holger wick', 'agel romi'],
#  ['bestall clifford'],
#  ['mora philippe'],
#  ['craig s zahler'],
#  ['a jack sunseri'],
#  ['bunuel luis'],
#  ['hark tsui'],
#  ['cavaye fred'],
#  ['ananth mahadevan narayan'],
#  ['hock jonathan'],
#  ['casaril guy'],
#  ['mate rudolph'],
#  ['dean fuller marcus'],
#  ['adrian powers', 'earl johan'],
#  ['william witney', 'english john'],
#  ['don taylor'],
#  ['alain delon'],
#  ['hultberg ulf'],
#  ['adrien brody', 'ford kevin'],
#  ['delman jeffrey'],
#  ['larry sands', 'erick vega', 'bradley young'],
#  ['filip remunda', 'klusak vit'],
#  ['bety reis', 'acquisto luigi'],
#  ['neri parenti', 'paolo villaggio'],
#  ['eric rohmer'],
#  ['harold schuster'],
#  ['guido manuli', 'maurizio nichetti'],
#  ['conrad robert', 'alfredo zacarias'],
#  ['oren rudavsky', 'daum menachem'],
#  ['martinez raul'],
#  ['alan mak', 'andrew lau'],
#  ['benoit philippon'],
#  ['ferrer jose'],
#  ['barnz daniel'],
#  ['daniele huillet', 'jean-marie straub'],
#  ['danny jacobs', 'darren grodsky'],
#  ['alexandre bustillo', 'julien maury'],
#  ['collins d lewis', 'keays vernon'],
#  ['charles vidor'],
#  ['cavara paolo', 'franco prosperi', 'gualtiero jacopetti'],
#  ['jeff orlowski'],
#  ['pawel pawlikowski'],
#  ['pearry teo'],
#  ['gendron thierry', 'alexandre chartrand'],
#  ['amateau rod'],
#  ['bulajic veljko'],
#  ['vasili zhuravlyov'],
#  ['chatmon pete'],
#  ['francis jun posadas'],
#  ['beebe ford', 'ray taylor'],
#  ['andrei konchalovsky'],
#  ['lanthimos yorgos'],
#  ['estrada jose'],
#  ['francis girod'],
#  ['gerard pires'],
#  ['karel zeman'],
#  ['william witney', 'english john'],
#  ['michael wright', 'j michael rix'],
#  ['christian weisenborn', 'erwin keusch'],
#  ['brodie higgs'],
#  ['lambert susan', 'moore stefan'],
#  ['langen torin', 'navin ramaswaran', 'ramelan zachary'],
#  ["gavin o'connor"],
#  ['lea pool'],
#  ['faisst heidi maria'],
#  ['lindberg mats', 'astrand carl'],
#  ['ewing scott'],
#  ['michael paul stephenson'],
#  ['marshall neil'],
#  ['aranda vicente'],
#  ['balki r'],
#  ['jiri svoboda'],
#  ['charles chu', 'gavin kelly'],
#  ['jin seung-hyeon'],
#  ['andrew becker', 'daniel mehrer'],
#  ['chan-wook park'],
#  ['michael wadleigh'],
#  ['nagisa oshima'],
#  ['frindel jeremy'],
#  ['georg maas'],
#  ['bekhor jonah', 'math zach'],
#  ['kitamura ryuhei'],
#  ["alice o'fredericks", 'iversen jon'],
#  ['carr sean'],
#  ['dk krishna', 'nidimoru raj'],
#  ['coppola ford francis'],
#  ['hill nic', 'glosserman scott'],
#  ['chris notarile r', 'kim santiago'],
#  ['hsueh-li pao', 'chang cheh'],
#  ['rene sti', 'fritz lang'],
#  ['daniela fejerman', 'ines paris'],
#  ['clay tweel'],
#  ['gaston ravel', 'lekain tony']]

# %%
_getTPFPFN(finalDirectors, trueDirectors)
# Out:
# (627, 103, -35)

# %% [markdown]
# # Add Multiple Winner and remove the similar one

# %%
# acceptance_diff 3
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# TP: 560, FP: 102, FN: 32
# precision is 0.8459214501510574
# recall is 0.9459459459459459
# f1Score is 0.8931419457735247
# (0.8459214501510574, 0.9459459459459459, 0.8931419457735247)

# %%
# acceptance_diff 2
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# precision is 0.8459214501510574
# recall is 0.9459459459459459
# f1Score is 0.8931419457735247
# (0.8459214501510574, 0.9459459459459459, 0.8931419457735247)

# %%
# acceptance_diff 1
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# TP: 503, FP: 73, FN: 89
# precision is 0.8732638888888888
# recall is 0.8496621621621622
# f1Score is 0.8613013698630135
# (0.8732638888888888, 0.8496621621621622, 0.8613013698630135)

# %%
# acceptance_diff 0
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# TP: 425, FP: 39, FN: 167
# precision is 0.915948275862069
# recall is 0.7179054054054054
# f1Score is 0.8049242424242425
# (0.915948275862069, 0.7179054054054054, 0.8049242424242425)

# %% [markdown]
# # Add block_weight

# %%
# block_weight 5
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# TP: 549, FP: 92, FN: 43
# precision is 0.8564742589703588
# recall is 0.9273648648648649
# f1Score is 0.8905109489051094
# (0.8564742589703588, 0.9273648648648649, 0.8905109489051094)

# %%
# block_weight 3
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# TP: 551, FP: 94, FN: 41
# precision is 0.8542635658914729
# recall is 0.9307432432432432
# f1Score is 0.8908649959579628
# (0.8542635658914729, 0.9307432432432432, 0.8908649959579628)

# %%
# block_weight 2
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# TP: 557, FP: 105, FN: 35
# precision is 0.8413897280966768
# recall is 0.9408783783783784
# f1Score is 0.8883572567783095
# (0.8413897280966768, 0.9408783783783784, 0.8883572567783095)

# %%
# block_weight 2 + fix only higher than 15
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# TP: 557, FP: 105, FN: 35
# precision is 0.8413897280966768
# recall is 0.9408783783783784
# f1Score is 0.8883572567783095
# (0.8413897280966768, 0.9408783783783784, 0.8883572567783095)

# %%
key_values = {
    'model_type':'bilstm',
    'char_level':False,
    'model_version': 2,
    'rnn_dim':1024,
    'verbose':1,
    'attributes_list': ['newDirector'],
    'embedding_type': 'inferSent',
    'dataset': 'clean_movie',
    'cluster_method': 'hierarchy',
    'num_clusters_rate': 0.05,
    'block_length_thresold': 0.35,
    'acceptance_diff':2,
    'block_weight': 2,
}

# %%
dataset_name, table_group_by_movie_id, list_movie_id, true_directors = load_dataset(key_values)
# Out:
# dataset: clean_movie
# Loading time is: 0.29227328300476074

# %%
start_time = time.time()
finalDirectors, trueDirectors = launchWithoutReductionFusionMovie(table_group_by_movie_id, list_movie_id, true_directors, key_values)
print("Total time is: {0}".format(time.time() - start_time))
# Out:
# movie_id: 73952
# true director: Robert Hamer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08913087844848633
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.005808830261230469
# Discarted candidate: []
# Possible candidate: [{'chester e hal': 2, 'cyril frankel': 1, 'hamer robert': 4}]
# lengthNecessary: 2.4499999999999997
# [{'chester e hal': 2, 'cyril frankel': 1, 'hamer robert': 4}]
# acceptance_diff 2
# ['chester e hal', 'hamer robert'] VS true_author: ['hamer robert']
# movie_id: 1655
# true director: Alexandre O. Philippe
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09842419624328613
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0013167858123779297
# Discarted candidate: []
# Possible candidate: [{'alexandre o philippe': 2, 'alexandre philippe': 1}]
# lengthNecessary: 1.0499999999999998
# [{'alexandre o philippe': 2, 'alexandre philippe': 1}]
# acceptance_diff 2
# ['alexandre o philippe'] VS true_author: ['alexandre o philippe']
# movie_id: 69693
# true director: Brad Bird
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.15221619606018066
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 2
# Blocking time is: 0.0032949447631835938
# Discarted candidate: [{'jan pinkava': 12}]
# Possible candidate: [{'bird brad': 28}]
# lengthNecessary: 13.0
# [{'bird brad': 28}]
# acceptance_diff 2
# ['bird brad'] VS true_author: ['bird brad']
# movie_id: 89575
# true director: Vincent Sherman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07974791526794434
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.004762887954711914
# Discarted candidate: []
# Possible candidate: [{'aldrich robert': 2, 'sherman vincent': 7}]
# lengthNecessary: 3.15
# [{'aldrich robert': 2, 'sherman vincent': 7}]
# acceptance_diff 2
# ['sherman vincent'] VS true_author: ['sherman vincent']
# movie_id: 5900
# true director: Fraser C. Heston
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0731194019317627
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0017507076263427734
# Discarted candidate: []
# Possible candidate: [{'c fraser heston': 2, 'clarke fraser heston': 7}]
# lengthNecessary: 3.15
# [{'c fraser heston': 2, 'clarke fraser heston': 7}]
# acceptance_diff 2
# ['clarke fraser heston'] VS true_author: ['c fraser heston']
# movie_id: 105551
# true director: John Landis;Steven Spielberg;Joe Dante;George Miller
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.26031994819641113
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 4
# Blocking time is: 0.007888078689575195
# Discarted candidate: [{'spielberg steven': 22}, {'john landis': 19}, {'george miller': 15}, {'dante joe': 15}]
# Possible candidate: []
# lengthNecessary: 22.849999999999998
# []
# acceptance_diff 2
# [] VS true_author: ['dante joe', 'george miller', 'spielberg steven', 'john landis']
# movie_id: 61521
# true director: Godfrey Ho
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05866813659667969
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0012538433074951172
# Discarted candidate: []
# Possible candidate: [{'godfrey ho': 3, 'kim si-hyun': 1}]
# lengthNecessary: 1.4
# [{'godfrey ho': 3, 'kim si-hyun': 1}]
# acceptance_diff 2
# ['godfrey ho', 'kim si-hyun'] VS true_author: ['godfrey ho']
# movie_id: 37376
# true director: Dave Fleischer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.17079591751098633
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0048809051513671875
# Discarted candidate: []
# Possible candidate: [{'bowsky willard': 1, 'dave fleischer': 13}]
# lengthNecessary: 4.8999999999999995
# [{'bowsky willard': 1, 'dave fleischer': 13}]
# acceptance_diff 2
# ['dave fleischer'] VS true_author: ['dave fleischer']
# movie_id: 26754
# true director: Martin D'Urville
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07582640647888184
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014488697052001953
# Discarted candidate: []
# Possible candidate: [{"d'urville martin": 11, 'durville martin': 2}]
# lengthNecessary: 4.55
# [{"d'urville martin": 11, 'durville martin': 2}]
# acceptance_diff 2
# ["d'urville martin"] VS true_author: ["d'urville martin"]
# movie_id: 97745
# true director: Norton Virgien;Igor Kovalyov
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07080984115600586
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 2
# Blocking time is: 0.003140687942504883
# Discarted candidate: []
# Possible candidate: [{'norton virgien': 16}, {'igor kovalyov': 15}]
# lengthNecessary: 9.85
# [{'norton virgien': 16}, {'igor kovalyov': 15}]
# acceptance_diff 2
# ['norton virgien', 'igor kovalyov'] VS true_author: ['norton virgien', 'igor kovalyov']
# movie_id: 58040
# true director: Thomas Bezucha
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04871773719787598
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 2
# Blocking time is: 0.002273082733154297
# Discarted candidate: [{'bezucha tom': 3}]
# Possible candidate: [{'bezucha thomas': 20}]
# lengthNecessary: 7.049999999999999
# [{'bezucha thomas': 20}]
# acceptance_diff 2
# ['bezucha thomas'] VS true_author: ['bezucha thomas']
# movie_id: 11447
# true director: Michael Galinsky;Suki Hawley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05894780158996582
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0015871524810791016
# Discarted candidate: []
# Possible candidate: [{'galinsky michael': 4, 'hawley suki': 6}]
# lengthNecessary: 3.5
# [{'galinsky michael': 4, 'hawley suki': 6}]
# acceptance_diff 2
# ['galinsky michael', 'hawley suki'] VS true_author: ['galinsky michael', 'hawley suki']
# movie_id: 92995
# true director: Chatrichalerm Yukol
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.022365093231201172
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0015327930450439453
# Discarted candidate: []
# Possible candidate: [{'chatrichalerm yukoi': 2, 'chatrichalerm yukol': 2}]
# lengthNecessary: 1.4
# [{'chatrichalerm yukoi': 2, 'chatrichalerm yukol': 2}]
# acceptance_diff 2
# ['chatrichalerm yukoi'] VS true_author: ['chatrichalerm yukol']
# movie_id: 45317
# true director: Richard Talmadge;Harvey Parry
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04071807861328125
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0019059181213378906
# Discarted candidate: []
# Possible candidate: [{'harvey parry': 3, 'richard talmadge': 1}]
# lengthNecessary: 1.4
# [{'harvey parry': 3, 'richard talmadge': 1}]
# acceptance_diff 2
# ['harvey parry', 'richard talmadge'] VS true_author: ['richard talmadge', 'harvey parry']
# movie_id: 57325
# true director: Keiichi Hara
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.055768728256225586
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 2
# Blocking time is: 0.0019466876983642578
# Discarted candidate: []
# Possible candidate: [{'michael sinterniklaas': 6, 'sheh stephanie': 6}, {'hara keiichi': 11}]
# lengthNecessary: 7.049999999999999
# [{'michael sinterniklaas': 6, 'sheh stephanie': 6}, {'hara keiichi': 11}]
# acceptance_diff 2
# ['michael sinterniklaas', 'sheh stephanie', 'hara keiichi'] VS true_author: ['hara keiichi']
# movie_id: 96819
# true director: Yves Allegret
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0401458740234375
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0008790493011474609
# Discarted candidate: []
# Possible candidate: [{'allegret yves': 2, 'e portas rafael': 1}]
# lengthNecessary: 1.0499999999999998
# [{'allegret yves': 2, 'e portas rafael': 1}]
# acceptance_diff 2
# ['allegret yves', 'e portas rafael'] VS true_author: ['allegret yves']
# movie_id: 24035
# true director: William Tannen;Larry Cohen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04811978340148926
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.001522064208984375
# Discarted candidate: []
# Possible candidate: [{'cohen larry': 6, 'tannen william': 4}]
# lengthNecessary: 3.5
# [{'cohen larry': 6, 'tannen william': 4}]
# acceptance_diff 2
# ['cohen larry', 'tannen william'] VS true_author: ['cohen larry', 'tannen william']
# movie_id: 5820
# true director: Ananth Narayan Mahadevan
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04761910438537598
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014841556549072266
# Discarted candidate: []
# Possible candidate: [{'anant mahadevan': 1, 'ananth mahadevan narayan': 3}]
# lengthNecessary: 1.4
# [{'anant mahadevan': 1, 'ananth mahadevan narayan': 3}]
# acceptance_diff 2
# ['anant mahadevan', 'ananth mahadevan narayan'] VS true_author: ['ananth mahadevan narayan']
# movie_id: 14372
# true director: Joel Coen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05925130844116211
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.002017974853515625
# Discarted candidate: []
# Possible candidate: [{'coen ethan': 7, 'coen joel': 13}]
# lengthNecessary: 7.0
# [{'coen ethan': 7, 'coen joel': 13}]
# acceptance_diff 2
# ['coen joel'] VS true_author: ['coen joel']
# movie_id: 2550
# true director: Jean-Luc Godard
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04901003837585449
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0013661384582519531
# Discarted candidate: []
# Possible candidate: [{'dziga groupe vertov': 1, 'godard jean-luc': 3}]
# lengthNecessary: 1.4
# [{'dziga groupe vertov': 1, 'godard jean-luc': 3}]
# acceptance_diff 2
# ['dziga groupe vertov', 'godard jean-luc'] VS true_author: ['godard jean-luc']
# movie_id: 8413
# true director: Adam Small;Peter Stuart
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05521106719970703
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0015969276428222656
# Discarted candidate: []
# Possible candidate: [{'adam small': 9, 'peter stuart': 7}]
# lengthNecessary: 5.6
# [{'adam small': 9, 'peter stuart': 7}]
# acceptance_diff 2
# ['adam small', 'peter stuart'] VS true_author: ['adam small', 'peter stuart']
# movie_id: 93760
# true director: Caradog W. James
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.027315855026245117
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.001386880874633789
# Discarted candidate: []
# Possible candidate: [{'caradog james': 3, 'caradog james w': 1}]
# lengthNecessary: 1.4
# [{'caradog james': 3, 'caradog james w': 1}]
# acceptance_diff 2
# ['caradog james'] VS true_author: ['caradog james w']
# movie_id: 93024
# true director: Phil Lord;Christopher Miller
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.10674881935119629
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 3
# Blocking time is: 0.004441976547241211
# Discarted candidate: [{'christopher miller': 15}, {'chris mckay': 2, 'chris miller': 8}]
# Possible candidate: [{'lord phil': 28}]
# lengthNecessary: 17.549999999999997
# [{'lord phil': 28}]
# acceptance_diff 2
# ['lord phil'] VS true_author: ['lord phil', 'christopher miller']
# movie_id: 63252
# true director: Gabriele Del Grande;Khaled Soliman Al Nassiry;Antonio Augugliaro
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.044682979583740234
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0015461444854736328
# Discarted candidate: []
# Possible candidate: [{'al khaled nassiry soliman': 1, 'antonio augugliaro': 2, 'del gabriele grande': 1}]
# lengthNecessary: 1.4
# [{'al khaled nassiry soliman': 1, 'antonio augugliaro': 2, 'del gabriele grande': 1}]
# acceptance_diff 2
# ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande'] VS true_author: ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande']
# movie_id: 76340
# true director: Prince
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.036962032318115234
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0015139579772949219
# Discarted candidate: []
# Possible candidate: [{'albert magnoli': 3, 'prince': 6}]
# lengthNecessary: 3.15
# [{'albert magnoli': 3, 'prince': 6}]
# acceptance_diff 2
# ['prince'] VS true_author: ['prince']
# movie_id: 21613
# true director: Andrzej Bartkowiak
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.041522979736328125
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0015668869018554688
# Discarted candidate: []
# Possible candidate: [{'andrzej bartkowiak': 19, 'andrzek bartkowiak': 1}]
# lengthNecessary: 7.0
# [{'andrzej bartkowiak': 19, 'andrzek bartkowiak': 1}]
# acceptance_diff 2
# ['andrzej bartkowiak'] VS true_author: ['andrzej bartkowiak']
# movie_id: 80167
# true director: Sandra Martin;Hugues Martin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.038999080657958984
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0013020038604736328
# Discarted candidate: []
# Possible candidate: [{'hugues martin': 4, 'martin sandra': 2}]
# lengthNecessary: 2.0999999999999996
# [{'hugues martin': 4, 'martin sandra': 2}]
# acceptance_diff 2
# ['hugues martin', 'martin sandra'] VS true_author: ['martin sandra', 'hugues martin']
# movie_id: 82271
# true director: Marvin J. Chomsky
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07287406921386719
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0016748905181884766
# Discarted candidate: []
# Possible candidate: [{'chomsky j marvin': 17, 'chomsky marvin': 1}]
# lengthNecessary: 6.3
# [{'chomsky j marvin': 17, 'chomsky marvin': 1}]
# acceptance_diff 2
# ['chomsky j marvin'] VS true_author: ['chomsky j marvin']
# movie_id: 7494
# true director: Tommy O'Haver
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.031172990798950195
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0010519027709960938
# Discarted candidate: []
# Possible candidate: [{"o'haver tommy": 7, 'ohaver tommy': 3}]
# lengthNecessary: 3.5
# [{"o'haver tommy": 7, 'ohaver tommy': 3}]
# acceptance_diff 2
# ["o'haver tommy"] VS true_author: ["o'haver tommy"]
# movie_id: 16640
# true director: Timothy Marrinan;Richard Dewey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.029143095016479492
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0008959770202636719
# Discarted candidate: []
# Possible candidate: [{'dewey richard': 1, 'marrinan timothy': 2}]
# lengthNecessary: 1.0499999999999998
# [{'dewey richard': 1, 'marrinan timothy': 2}]
# acceptance_diff 2
# ['dewey richard', 'marrinan timothy'] VS true_author: ['dewey richard', 'marrinan timothy']
# movie_id: 101119
# true director: Chris Hegedus;D. A. Pennebaker
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05537772178649902
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0013630390167236328
# Discarted candidate: []
# Possible candidate: [{'a d pennebaker': 9, 'chris hegedus': 7}]
# lengthNecessary: 5.6
# [{'a d pennebaker': 9, 'chris hegedus': 7}]
# acceptance_diff 2
# ['a d pennebaker', 'chris hegedus'] VS true_author: ['chris hegedus', 'a d pennebaker']
# movie_id: 17046
# true director: Paolo Taviani;Vittorio Taviani
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03085017204284668
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.001245260238647461
# Discarted candidate: []
# Possible candidate: [{'paolo taviani': 4, 'taviani vittorio': 2}]
# lengthNecessary: 2.0999999999999996
# [{'paolo taviani': 4, 'taviani vittorio': 2}]
# acceptance_diff 2
# ['paolo taviani', 'taviani vittorio'] VS true_author: ['paolo taviani', 'taviani vittorio']
# movie_id: 80539
# true director: Karan Johar
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.046829938888549805
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.001993894577026367
# Discarted candidate: []
# Possible candidate: [{'abhishek varman': 2, 'johar karan': 10}]
# lengthNecessary: 4.199999999999999
# [{'abhishek varman': 2, 'johar karan': 10}]
# acceptance_diff 2
# ['johar karan'] VS true_author: ['johar karan']
# movie_id: 111871
# true director: Anlo Sepulveda;Paul Collins
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.042498111724853516
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014767646789550781
# Discarted candidate: []
# Possible candidate: [{'anlo sepulveda': 3, 'collins paul': 2}]
# lengthNecessary: 1.75
# [{'anlo sepulveda': 3, 'collins paul': 2}]
# acceptance_diff 2
# ['anlo sepulveda', 'collins paul'] VS true_author: ['anlo sepulveda', 'collins paul']
# movie_id: 31082
# true director: Slatan Dudow;Kurt Maetzig
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.026960134506225586
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014190673828125
# Discarted candidate: []
# Possible candidate: [{'dudow slatan': 2, 'groschopp richard': 1, 'kurt maetzig': 1}]
# lengthNecessary: 1.4
# [{'dudow slatan': 2, 'groschopp richard': 1, 'kurt maetzig': 1}]
# acceptance_diff 2
# ['dudow slatan', 'groschopp richard', 'kurt maetzig'] VS true_author: ['dudow slatan', 'kurt maetzig']
# movie_id: 2672
# true director: Christian Krones;Olaf S. Muller;Roland Schrotthofer;Florian Weigensamer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04204392433166504
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0016491413116455078
# Discarted candidate: []
# Possible candidate: [{'christian krones': 1, 'florian weigensamer': 2, 'muller olaf s': 1, 'roland schrotthofer': 1}]
# lengthNecessary: 1.75
# [{'christian krones': 1, 'florian weigensamer': 2, 'muller olaf s': 1, 'roland schrotthofer': 1}]
# acceptance_diff 2
# ['christian krones', 'florian weigensamer', 'muller olaf s', 'roland schrotthofer'] VS true_author: ['muller olaf s', 'roland schrotthofer', 'florian weigensamer', 'christian krones']
# movie_id: 91427
# true director: Robert Rossen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03996896743774414
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0012979507446289062
# Discarted candidate: []
# Possible candidate: [{'blue washington': 1, 'robert rossen': 9}]
# lengthNecessary: 3.5
# [{'blue washington': 1, 'robert rossen': 9}]
# acceptance_diff 2
# ['robert rossen'] VS true_author: ['robert rossen']
# movie_id: 2813
# true director: Michael Tiddes
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03664994239807129
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.001432180404663086
# Discarted candidate: []
# Possible candidate: [{'michael tiddes': 11, 'mike tiddes': 2}]
# lengthNecessary: 4.55
# [{'michael tiddes': 11, 'mike tiddes': 2}]
# acceptance_diff 2
# ['michael tiddes'] VS true_author: ['michael tiddes']
# movie_id: 15123
# true director: Jon Bulette;Stone Roberts
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0416569709777832
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014438629150390625
# Discarted candidate: []
# Possible candidate: [{'bulette jon': 3, 'f roberts stone': 1, 'roberts stone': 1}]
# lengthNecessary: 1.75
# [{'bulette jon': 3, 'f roberts stone': 1, 'roberts stone': 1}]
# acceptance_diff 2
# ['bulette jon', 'f roberts stone'] VS true_author: ['bulette jon', 'roberts stone']
# movie_id: 30280
# true director: Anthony Stabley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03774404525756836
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0015311241149902344
# Discarted candidate: []
# Possible candidate: [{'anthony r stabley': 3, 'anthony stabley': 8}]
# lengthNecessary: 3.8499999999999996
# [{'anthony r stabley': 3, 'anthony stabley': 8}]
# acceptance_diff 2
# ['anthony stabley'] VS true_author: ['anthony stabley']
# movie_id: 68652
# true director: Adam Kassen;Mark Kassen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0369260311126709
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014939308166503906
# Discarted candidate: []
# Possible candidate: [{'adam kassen': 8, 'kassen mark': 9}]
# lengthNecessary: 5.949999999999999
# [{'adam kassen': 8, 'kassen mark': 9}]
# acceptance_diff 2
# ['adam kassen', 'kassen mark'] VS true_author: ['kassen mark', 'adam kassen']
# movie_id: 21609
# true director: Rowby Goren;Chuck Staley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0325617790222168
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0011649131774902344
# Discarted candidate: []
# Possible candidate: [{'chuck staley': 3, 'goren rowby': 6}]
# lengthNecessary: 3.15
# [{'chuck staley': 3, 'goren rowby': 6}]
# acceptance_diff 2
# ['goren rowby'] VS true_author: ['chuck staley', 'goren rowby']
# movie_id: 37872
# true director: Michael Almereyda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.027265071868896484
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0012149810791015625
# Discarted candidate: []
# Possible candidate: [{'almereyda michael': 5, 'campbell scott': 1}]
# lengthNecessary: 2.0999999999999996
# [{'almereyda michael': 5, 'campbell scott': 1}]
# acceptance_diff 2
# ['almereyda michael'] VS true_author: ['almereyda michael']
# movie_id: 45447
# true director: Fred C. Brannon;Thomas Carr
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.053928375244140625
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014538764953613281
# Discarted candidate: []
# Possible candidate: [{'brannon c fred': 6, 'carr thomas': 3}]
# lengthNecessary: 3.15
# [{'brannon c fred': 6, 'carr thomas': 3}]
# acceptance_diff 2
# ['brannon c fred'] VS true_author: ['carr thomas', 'brannon c fred']
# movie_id: 24661
# true director: Matthew Celestre;Brett Celestre
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.022530078887939453
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.001402139663696289
# Discarted candidate: []
# Possible candidate: [{'brett celestre': 1, 'brette celestre': 2, 'celestre matthew': 1}]
# lengthNecessary: 1.4
# [{'brett celestre': 1, 'brette celestre': 2, 'celestre matthew': 1}]
# acceptance_diff 2
# ['brett celestre', 'celestre matthew'] VS true_author: ['brett celestre', 'celestre matthew']
# movie_id: 3648
# true director: Nikolaj Arcel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02486109733581543
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0012769699096679688
# Discarted candidate: []
# Possible candidate: [{'arcel nikaolaj': 2, 'arcel nikolaj': 14}]
# lengthNecessary: 5.6
# [{'arcel nikaolaj': 2, 'arcel nikolaj': 14}]
# acceptance_diff 2
# ['arcel nikolaj'] VS true_author: ['arcel nikolaj']
# movie_id: 13479
# true director: Ergin Orbey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02688908576965332
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0013248920440673828
# Discarted candidate: []
# Possible candidate: [{'engin orbey': 8, 'ergin orbey': 1}]
# lengthNecessary: 3.15
# [{'engin orbey': 8, 'ergin orbey': 1}]
# acceptance_diff 2
# ['engin orbey'] VS true_author: ['ergin orbey']
# movie_id: 18319
# true director: Baird Bryant;Johanna Demetrakas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03940892219543457
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0012059211730957031
# Discarted candidate: []
# Possible candidate: [{'baird bryant': 8, 'demetrakas johanna': 5}]
# lengthNecessary: 4.55
# [{'baird bryant': 8, 'demetrakas johanna': 5}]
# acceptance_diff 2
# ['baird bryant'] VS true_author: ['baird bryant', 'demetrakas johanna']
# movie_id: 44223
# true director: Gene Kelly
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.044985055923461914
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.001132965087890625
# Discarted candidate: []
# Possible candidate: [{'freddie young': 1, 'gene kelly': 8}]
# lengthNecessary: 3.15
# [{'freddie young': 1, 'gene kelly': 8}]
# acceptance_diff 2
# ['gene kelly'] VS true_author: ['gene kelly']
# movie_id: 71075
# true director: David Twohy
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06831002235412598
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 2
# Blocking time is: 0.0018360614776611328
# Discarted candidate: [{'david n twohy': 1}]
# Possible candidate: [{'david twohy': 24}]
# lengthNecessary: 7.75
# [{'david twohy': 24}]
# acceptance_diff 2
# ['david twohy'] VS true_author: ['david twohy']
# movie_id: 80410
# true director: Paul Ragsdale
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.048398733139038086
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.001386880874633789
# Discarted candidate: []
# Possible candidate: [{'alba angelica de': 3, 'paul ragsdale': 6}]
# lengthNecessary: 3.15
# [{'alba angelica de': 3, 'paul ragsdale': 6}]
# acceptance_diff 2
# ['paul ragsdale'] VS true_author: ['paul ragsdale']
# movie_id: 71705
# true director: Allan Arkush
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04657316207885742
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0017211437225341797
# Discarted candidate: []
# Possible candidate: [{'allan arkush': 13, 'dante joe': 6}]
# lengthNecessary: 6.6499999999999995
# [{'allan arkush': 13, 'dante joe': 6}]
# acceptance_diff 2
# ['allan arkush'] VS true_author: ['allan arkush']
# movie_id: 91114
# true director: Tian Zhuangzhuang
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03223395347595215
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0010378360748291016
# Discarted candidate: []
# Possible candidate: [{'pan peicheng': 3, 'tian zhuangzhuang': 3}]
# lengthNecessary: 2.0999999999999996
# [{'pan peicheng': 3, 'tian zhuangzhuang': 3}]
# acceptance_diff 2
# ['pan peicheng', 'tian zhuangzhuang'] VS true_author: ['tian zhuangzhuang']
# movie_id: 100574
# true director: Michael Hegner;Karsten Kiilerich
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03400897979736328
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014700889587402344
# Discarted candidate: []
# Possible candidate: [{'hegner michael': 6, 'karsten kiilerich': 4}]
# lengthNecessary: 3.5
# [{'hegner michael': 6, 'karsten kiilerich': 4}]
# acceptance_diff 2
# ['hegner michael', 'karsten kiilerich'] VS true_author: ['hegner michael', 'karsten kiilerich']
# movie_id: 22475
# true director: Kevin King
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05183982849121094
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0010409355163574219
# Discarted candidate: []
# Possible candidate: [{'k king': 6, 'kevin king': 3}]
# lengthNecessary: 3.15
# [{'k king': 6, 'kevin king': 3}]
# acceptance_diff 2
# ['k king'] VS true_author: ['kevin king']
# movie_id: 57809
# true director: John Lamb
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.032645225524902344
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.001020193099975586
# Discarted candidate: []
# Possible candidate: [{'hill jack': 2, 'john lamb': 1}]
# lengthNecessary: 1.0499999999999998
# [{'hill jack': 2, 'john lamb': 1}]
# acceptance_diff 2
# ['hill jack', 'john lamb'] VS true_author: ['john lamb']
# movie_id: 97278
# true director: Norman Panama;Melvin Frank
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.036318063735961914
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0011708736419677734
# Discarted candidate: []
# Possible candidate: [{'frank melvin': 4, 'norman panama': 3}]
# lengthNecessary: 2.4499999999999997
# [{'frank melvin': 4, 'norman panama': 3}]
# acceptance_diff 2
# ['frank melvin', 'norman panama'] VS true_author: ['norman panama', 'frank melvin']
# movie_id: 106242
# true director: Gionata Zarantonello
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.018950700759887695
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0006978511810302734
# Discarted candidate: []
# Possible candidate: [{'gionata zarantonello': 1, 'jonathan zarantonello': 1}]
# lengthNecessary: 0.7
# [{'gionata zarantonello': 1, 'jonathan zarantonello': 1}]
# acceptance_diff 2
# ['gionata zarantonello'] VS true_author: ['gionata zarantonello']
# movie_id: 81911
# true director: Kang Je-Gyu
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04591727256774902
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 2
# Blocking time is: 0.0014100074768066406
# Discarted candidate: [{'gyu je kang': 1}]
# Possible candidate: [{'je-gyu kang': 13, 'je-kyu kang': 7}]
# lengthNecessary: 6.35
# [{'je-gyu kang': 13, 'je-kyu kang': 7}]
# acceptance_diff 2
# ['je-gyu kang'] VS true_author: ['je-gyu kang']
# movie_id: 87781
# true director: Alistair Legrand
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04589509963989258
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.001222848892211914
# Discarted candidate: []
# Possible candidate: [{'alistair legrand': 16, 'callaway ryan': 1}]
# lengthNecessary: 5.949999999999999
# [{'alistair legrand': 16, 'callaway ryan': 1}]
# acceptance_diff 2
# ['alistair legrand'] VS true_author: ['alistair legrand']
# movie_id: 49079
# true director: Fernando Palacios
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04602861404418945
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0017762184143066406
# Discarted candidate: []
# Possible candidate: [{'fernando palacios': 2, 'j rafael salvia': 3}]
# lengthNecessary: 1.75
# [{'fernando palacios': 2, 'j rafael salvia': 3}]
# acceptance_diff 2
# ['fernando palacios', 'j rafael salvia'] VS true_author: ['fernando palacios']
# movie_id: 43271
# true director: R. Kiplin Pastor
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03243899345397949
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0017199516296386719
# Discarted candidate: []
# Possible candidate: [{'kip pastor': 3, 'kiplin pastor r': 1}]
# lengthNecessary: 1.4
# [{'kip pastor': 3, 'kiplin pastor r': 1}]
# acceptance_diff 2
# ['kip pastor', 'kiplin pastor r'] VS true_author: ['kiplin pastor r']
# movie_id: 43726
# true director: Quentin Tarantino
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06473660469055176
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 2
# Blocking time is: 0.0025589466094970703
# Discarted candidate: [{'eli roth': 12}]
# Possible candidate: [{'quentin tarantino': 27}]
# lengthNecessary: 12.649999999999999
# [{'quentin tarantino': 27}]
# acceptance_diff 2
# ['quentin tarantino'] VS true_author: ['quentin tarantino']
# movie_id: 28418
# true director: Sharunas Bartas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.017528057098388672
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0009257793426513672
# Discarted candidate: []
# Possible candidate: [{'bartas sar?nas': 1, 'bartas sharunas': 1}]
# lengthNecessary: 0.7
# [{'bartas sar?nas': 1, 'bartas sharunas': 1}]
# acceptance_diff 2
# ['bartas sar?nas'] VS true_author: ['bartas sharunas']
# movie_id: 111254
# true director: Luke Jaden;Cort Johns
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03477311134338379
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0010039806365966797
# Discarted candidate: []
# Possible candidate: [{'cort johns': 2, 'jaden luke': 4}]
# lengthNecessary: 2.0999999999999996
# [{'cort johns': 2, 'jaden luke': 4}]
# acceptance_diff 2
# ['cort johns', 'jaden luke'] VS true_author: ['cort johns', 'jaden luke']
# movie_id: 69205
# true director: Nancy Glass;Michele Loschiavo
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03241896629333496
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0009291172027587891
# Discarted candidate: []
# Possible candidate: [{'glass nancy': 2, 'loschiavo michele': 1}]
# lengthNecessary: 1.0499999999999998
# [{'glass nancy': 2, 'loschiavo michele': 1}]
# acceptance_diff 2
# ['glass nancy', 'loschiavo michele'] VS true_author: ['loschiavo michele', 'glass nancy']
# movie_id: 40048
# true director: Manuel Gonzalez Mauricio;Saul Barreto Ramos
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.047361135482788086
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0012509822845458984
# Discarted candidate: []
# Possible candidate: [{'barreto ramos saul': 1, 'gonzalez manuel mauricio': 2}]
# lengthNecessary: 1.0499999999999998
# [{'barreto ramos saul': 1, 'gonzalez manuel mauricio': 2}]
# acceptance_diff 2
# ['barreto ramos saul', 'gonzalez manuel mauricio'] VS true_author: ['gonzalez manuel mauricio', 'barreto ramos saul']
# movie_id: 57896
# true director: Andrew V. McLaglen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.036557912826538086
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.00125885009765625
# Discarted candidate: []
# Possible candidate: [{'andrew mclaglen': 2, 'andrew mclaglen v': 6}]
# lengthNecessary: 2.8
# [{'andrew mclaglen': 2, 'andrew mclaglen v': 6}]
# acceptance_diff 2
# ['andrew mclaglen v'] VS true_author: ['andrew mclaglen v']
# movie_id: 32707
# true director: Paul Morrissey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03464984893798828
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.001461029052734375
# Discarted candidate: []
# Possible candidate: [{'antonio margheriti': 2, 'morrissey paul': 6}]
# lengthNecessary: 2.8
# [{'antonio margheriti': 2, 'morrissey paul': 6}]
# acceptance_diff 2
# ['morrissey paul'] VS true_author: ['morrissey paul']
# movie_id: 80601
# true director: Frank Capra
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03069472312927246
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0015780925750732422
# Discarted candidate: []
# Possible candidate: [{'capra frank': 5, 'irvin willat': 3}]
# lengthNecessary: 2.8
# [{'capra frank': 5, 'irvin willat': 3}]
# acceptance_diff 2
# ['capra frank', 'irvin willat'] VS true_author: ['capra frank']
# movie_id: 109103
# true director: Dick Zondag;Ralph Zondag;Phil Nibbelink;Simon Wells
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.10343074798583984
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 3
# Blocking time is: 0.003942251205444336
# Discarted candidate: [{'nibbelink phil': 14}, {'simon wells': 12}]
# Possible candidate: [{'dick zondag': 12, 'ralph zondag': 12}]
# lengthNecessary: 16.5
# [{'dick zondag': 12, 'ralph zondag': 12}]
# acceptance_diff 2
# ['dick zondag', 'ralph zondag'] VS true_author: ['dick zondag', 'simon wells', 'ralph zondag', 'nibbelink phil']
# movie_id: 76115
# true director: Adam Friedman;Iain Kennedy
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06166982650756836
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0016710758209228516
# Discarted candidate: []
# Possible candidate: [{'adam friedman': 7, 'iain kennedy': 5}]
# lengthNecessary: 4.199999999999999
# [{'adam friedman': 7, 'iain kennedy': 5}]
# acceptance_diff 2
# ['adam friedman', 'iain kennedy'] VS true_author: ['iain kennedy', 'adam friedman']
# movie_id: 60263
# true director: Bill Guttentag;Dan Sturman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1072089672088623
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 2
# Blocking time is: 0.0018396377563476562
# Discarted candidate: []
# Possible candidate: [{'bill guttentag': 14}, {'dan sturman': 9}]
# lengthNecessary: 7.049999999999999
# [{'bill guttentag': 14}, {'dan sturman': 9}]
# acceptance_diff 2
# ['bill guttentag', 'dan sturman'] VS true_author: ['bill guttentag', 'dan sturman']
# movie_id: 35119
# true director: Cynthia Wade;Cheryl Miller Houser
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09974884986877441
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0017342567443847656
# Discarted candidate: []
# Possible candidate: [{'cheryl houser': 1, 'cheryl houser miller': 4, 'cynthia wade': 6}]
# lengthNecessary: 3.8499999999999996
# [{'cheryl houser': 1, 'cheryl houser miller': 4, 'cynthia wade': 6}]
# acceptance_diff 2
# ['cheryl houser miller', 'cynthia wade'] VS true_author: ['cynthia wade', 'cheryl houser miller']
# movie_id: 97251
# true director: Michael Dudok De Wit
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07759404182434082
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0009949207305908203
# Discarted candidate: []
# Possible candidate: [{'de dudok michael wit': 3, 'dewit dudok michael': 1}]
# lengthNecessary: 1.4
# [{'de dudok michael wit': 3, 'dewit dudok michael': 1}]
# acceptance_diff 2
# ['de dudok michael wit'] VS true_author: ['de dudok michael wit']
# movie_id: 90003
# true director: Charles Chaplin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.10505795478820801
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0015759468078613281
# Discarted candidate: []
# Possible candidate: [{'chaplin charles': 13, 'chaplin charlie': 6}]
# lengthNecessary: 6.6499999999999995
# [{'chaplin charles': 13, 'chaplin charlie': 6}]
# acceptance_diff 2
# ['chaplin charles'] VS true_author: ['chaplin charles']
# movie_id: 91535
# true director: J. A. Bayona
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08727025985717773
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 2
# Blocking time is: 0.0022928714752197266
# Discarted candidate: []
# Possible candidate: [{'antonio bayona juan': 15}, {'a bayona j': 7}]
# lengthNecessary: 6.699999999999999
# [{'antonio bayona juan': 15}, {'a bayona j': 7}]
# acceptance_diff 2
# ['antonio bayona juan', 'a bayona j'] VS true_author: ['a bayona j']
# movie_id: 51346
# true director: William A. Seiter
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04641604423522949
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0031280517578125
# Discarted candidate: []
# Possible candidate: [{'a seiter william': 2, 'seiter william': 1}]
# lengthNecessary: 1.0499999999999998
# [{'a seiter william': 2, 'seiter william': 1}]
# acceptance_diff 2
# ['a seiter william'] VS true_author: ['a seiter william']
# movie_id: 64713
# true director: Alan Mak;Felix Chong
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04739522933959961
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0013110637664794922
# Discarted candidate: []
# Possible candidate: [{'alan mak': 5, 'chong felix': 8}]
# lengthNecessary: 4.55
# [{'alan mak': 5, 'chong felix': 8}]
# acceptance_diff 2
# ['chong felix'] VS true_author: ['alan mak', 'chong felix']
# movie_id: 87307
# true director: Florian Cossen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.024270057678222656
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0009219646453857422
# Discarted candidate: []
# Possible candidate: [{'cossen florian': 1, 'cossen florian micoud': 1}]
# lengthNecessary: 0.7
# [{'cossen florian': 1, 'cossen florian micoud': 1}]
# acceptance_diff 2
# ['cossen florian', 'cossen florian micoud'] VS true_author: ['cossen florian']
# movie_id: 89712
# true director: Mauro Borrelli
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.029865026473999023
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0011951923370361328
# Discarted candidate: []
# Possible candidate: [{'borrelli maura': 1, 'borrelli mauro': 2}]
# lengthNecessary: 1.0499999999999998
# [{'borrelli maura': 1, 'borrelli mauro': 2}]
# acceptance_diff 2
# ['borrelli maura'] VS true_author: ['borrelli mauro']
# movie_id: 11264
# true director: Rex Ingram
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04479503631591797
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0012819766998291016
# Discarted candidate: []
# Possible candidate: [{'alice terry': 1, 'ingram rex': 2}]
# lengthNecessary: 1.0499999999999998
# [{'alice terry': 1, 'ingram rex': 2}]
# acceptance_diff 2
# ['alice terry', 'ingram rex'] VS true_author: ['ingram rex']
# movie_id: 48608
# true director: John Stevenson;Mark Osborne
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.10713696479797363
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 3
# Blocking time is: 0.0050280094146728516
# Discarted candidate: [{'mark osborne': 1}]
# Possible candidate: [{'mark osborne': 30}, {'john stevenson': 25}]
# lengthNecessary: 18.599999999999998
# [{'mark osborne': 30}, {'john stevenson': 25}]
# acceptance_diff 2
# ['mark osborne', 'john stevenson'] VS true_author: ['john stevenson', 'mark osborne']
# movie_id: 5451
# true director: Claudio Marques;Marilia Hughes
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.040791988372802734
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0012569427490234375
# Discarted candidate: []
# Possible candidate: [{'claudio marques': 3, 'guerreiro hughes marilia': 2, 'hughes marilia': 1}]
# lengthNecessary: 2.0999999999999996
# [{'claudio marques': 3, 'guerreiro hughes marilia': 2, 'hughes marilia': 1}]
# acceptance_diff 2
# ['claudio marques', 'guerreiro hughes marilia', 'hughes marilia'] VS true_author: ['claudio marques', 'hughes marilia']
# movie_id: 29810
# true director: Herrmann Zschoche
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05924034118652344
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0025539398193359375
# Discarted candidate: []
# Possible candidate: [{'dressel eleonore': 4, 'herrmann zschoche': 8}]
# lengthNecessary: 4.199999999999999
# [{'dressel eleonore': 4, 'herrmann zschoche': 8}]
# acceptance_diff 2
# ['herrmann zschoche'] VS true_author: ['herrmann zschoche']
# movie_id: 78918
# true director: Marc Gracie;Tim Ferguson
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05097699165344238
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014090538024902344
# Discarted candidate: []
# Possible candidate: [{'ferguson tim': 5, 'gracie marc': 6}]
# lengthNecessary: 3.8499999999999996
# [{'ferguson tim': 5, 'gracie marc': 6}]
# acceptance_diff 2
# ['ferguson tim', 'gracie marc'] VS true_author: ['gracie marc', 'ferguson tim']
# movie_id: 71440
# true director: Otto Preminger
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04628133773803711
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0015788078308105469
# Discarted candidate: []
# Possible candidate: [{'jean negulesco': 3, 'otto preminger': 14}]
# lengthNecessary: 5.949999999999999
# [{'jean negulesco': 3, 'otto preminger': 14}]
# acceptance_diff 2
# ['otto preminger'] VS true_author: ['otto preminger']
# movie_id: 51150
# true director: Sabine Krayenbuhl;Zeva Oelbaum
# embedding_type: inferSent
# ...
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03825497627258301
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014300346374511719
# Discarted candidate: []
# Possible candidate: [{'l?a pool': 1, 'lea pool': 3}]
# lengthNecessary: 1.4
# [{'l?a pool': 1, 'lea pool': 3}]
# acceptance_diff 2
# ['l?a pool'] VS true_author: ['lea pool']
# movie_id: 69925
# true director: Heidi Maria Faisst
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0365602970123291
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0005908012390136719
# Discarted candidate: []
# Possible candidate: [{'faissi heidi maria': 1, 'faisst heidi maria': 1}]
# lengthNecessary: 0.7
# [{'faissi heidi maria': 1, 'faisst heidi maria': 1}]
# acceptance_diff 2
# ['faissi heidi maria'] VS true_author: ['faisst heidi maria']
# movie_id: 47283
# true director: Carl Astrand;Mats Lindberg
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04788923263549805
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014548301696777344
# Discarted candidate: []
# Possible candidate: [{'astrand carl': 6, 'lindberg mats': 9}]
# lengthNecessary: 5.25
# [{'astrand carl': 6, 'lindberg mats': 9}]
# acceptance_diff 2
# ['lindberg mats'] VS true_author: ['astrand carl', 'lindberg mats']
# movie_id: 40393
# true director: Ewing Scott
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04578375816345215
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0010099411010742188
# Discarted candidate: []
# Possible candidate: [{'ewing scott': 8, 'george sherman': 3}]
# lengthNecessary: 3.8499999999999996
# [{'ewing scott': 8, 'george sherman': 3}]
# acceptance_diff 2
# ['ewing scott'] VS true_author: ['ewing scott']
# movie_id: 35829
# true director: Michael Paul Stephenson
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04279971122741699
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0010128021240234375
# Discarted candidate: []
# Possible candidate: [{'michael paul stephenson': 6, 'michael stephenson': 2}]
# lengthNecessary: 2.8
# [{'michael paul stephenson': 6, 'michael stephenson': 2}]
# acceptance_diff 2
# ['michael paul stephenson'] VS true_author: ['michael paul stephenson']
# movie_id: 27116
# true director: Neil Marshall
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06385612487792969
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.001277923583984375
# Discarted candidate: []
# Possible candidate: [{'marshall neil': 18, 'universal': 1}]
# lengthNecessary: 6.6499999999999995
# [{'marshall neil': 18, 'universal': 1}]
# acceptance_diff 2
# ['marshall neil'] VS true_author: ['marshall neil']
# movie_id: 49163
# true director: Vicente Aranda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08705615997314453
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0016748905181884766
# Discarted candidate: []
# Possible candidate: [{'aranda vicente': 3, 'gomez raul': 2}]
# lengthNecessary: 1.75
# [{'aranda vicente': 3, 'gomez raul': 2}]
# acceptance_diff 2
# ['aranda vicente', 'gomez raul'] VS true_author: ['aranda vicente']
# movie_id: 64814
# true director: R. Balki
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08261609077453613
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0037550926208496094
# Discarted candidate: []
# Possible candidate: [{'balki r': 4, 'ricky sandhu': 1}]
# lengthNecessary: 1.75
# [{'balki r': 4, 'ricky sandhu': 1}]
# acceptance_diff 2
# ['balki r'] VS true_author: ['balki r']
# movie_id: 87155
# true director: Jiri Svoboda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0655369758605957
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0010418891906738281
# Discarted candidate: []
# Possible candidate: [{'ji?i svoboda': 6, 'jiri svoboda': 1}]
# lengthNecessary: 2.4499999999999997
# [{'ji?i svoboda': 6, 'jiri svoboda': 1}]
# acceptance_diff 2
# ['ji?i svoboda'] VS true_author: ['jiri svoboda']
# movie_id: 19545
# true director: Charles Chu;Gavin Kelly
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0734410285949707
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014102458953857422
# Discarted candidate: []
# Possible candidate: [{'charles chu': 1, 'gavin kelly': 2}]
# lengthNecessary: 1.0499999999999998
# [{'charles chu': 1, 'gavin kelly': 2}]
# acceptance_diff 2
# ['charles chu', 'gavin kelly'] VS true_author: ['charles chu', 'gavin kelly']
# movie_id: 46270
# true director: Seung-Hyeon Jin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06909489631652832
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014760494232177734
# Discarted candidate: []
# Possible candidate: [{'hyeonh jin seung': 2, 'jin seung-hyeon': 2}]
# lengthNecessary: 1.4
# [{'hyeonh jin seung': 2, 'jin seung-hyeon': 2}]
# acceptance_diff 2
# ['hyeonh jin seung', 'jin seung-hyeon'] VS true_author: ['jin seung-hyeon']
# movie_id: 73371
# true director: Andrew Becker;Daniel Mehrer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07188010215759277
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.002413034439086914
# Discarted candidate: []
# Possible candidate: [{'andrew becker': 2, 'daniel mehrer': 1}]
# lengthNecessary: 1.0499999999999998
# [{'andrew becker': 2, 'daniel mehrer': 1}]
# acceptance_diff 2
# ['andrew becker', 'daniel mehrer'] VS true_author: ['daniel mehrer', 'andrew becker']
# movie_id: 61155
# true director: Chan-wook Park
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07355117797851562
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0024251937866210938
# Discarted candidate: []
# Possible candidate: [{'chan-kyong park': 5, 'chan-wook park': 6}]
# lengthNecessary: 3.8499999999999996
# [{'chan-kyong park': 5, 'chan-wook park': 6}]
# acceptance_diff 2
# ['chan-kyong park', 'chan-wook park'] VS true_author: ['chan-wook park']
# movie_id: 111258
# true director: Michael Wadleigh
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1391289234161377
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 2
# Blocking time is: 0.0023801326751708984
# Discarted candidate: [{'d hancock john': 6}]
# Possible candidate: [{'hitzig rupert': 4, 'michael wadleigh': 15}]
# lengthNecessary: 7.75
# [{'hitzig rupert': 4, 'michael wadleigh': 15}]
# acceptance_diff 2
# ['michael wadleigh'] VS true_author: ['michael wadleigh']
# movie_id: 56502
# true director: Nagisa Oshima
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07317304611206055
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.006011962890625
# Discarted candidate: []
# Possible candidate: [{'?shima nagisa': 2, 'nagisa oshima': 1}]
# lengthNecessary: 1.0499999999999998
# [{'?shima nagisa': 2, 'nagisa oshima': 1}]
# acceptance_diff 2
# ['?shima nagisa', 'nagisa oshima'] VS true_author: ['nagisa oshima']
# movie_id: 63743
# true director: Jeremy Frindel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.12812018394470215
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.010354757308959961
# Discarted candidate: []
# Possible candidate: [{'films substratum': 1, 'frindel jeremy': 7}]
# lengthNecessary: 2.8
# [{'films substratum': 1, 'frindel jeremy': 7}]
# acceptance_diff 2
# ['frindel jeremy'] VS true_author: ['frindel jeremy']
# movie_id: 105721
# true director: Georg Maas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07670402526855469
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0017750263214111328
# Discarted candidate: []
# Possible candidate: [{'georg maas': 3, 'judith kaufmann': 2}]
# lengthNecessary: 1.75
# [{'georg maas': 3, 'judith kaufmann': 2}]
# acceptance_diff 2
# ['georg maas', 'judith kaufmann'] VS true_author: ['georg maas']
# movie_id: 88941
# true director: Jonah Bekhor;Zach Math
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09489297866821289
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0017788410186767578
# Discarted candidate: []
# Possible candidate: [{'bekhor jonah': 10, 'math zach': 9}]
# lengthNecessary: 6.6499999999999995
# [{'bekhor jonah': 10, 'math zach': 9}]
# acceptance_diff 2
# ['bekhor jonah', 'math zach'] VS true_author: ['bekhor jonah', 'math zach']
# movie_id: 61767
# true director: Ryuhei Kitamura
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.050495147705078125
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0017461776733398438
# Discarted candidate: []
# Possible candidate: [{'kitamura ry?hei': 2, 'kitamura ryuhei': 5}]
# lengthNecessary: 2.4499999999999997
# [{'kitamura ry?hei': 2, 'kitamura ryuhei': 5}]
# acceptance_diff 2
# ['kitamura ryuhei'] VS true_author: ['kitamura ryuhei']
# movie_id: 76373
# true director: Alice O'Fredericks;Jon Iversen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04138326644897461
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.004116058349609375
# Discarted candidate: []
# Possible candidate: [{"alice o'fredericks": 3, 'iversen jon': 2}]
# lengthNecessary: 1.75
# [{"alice o'fredericks": 3, 'iversen jon': 2}]
# acceptance_diff 2
# ["alice o'fredericks", 'iversen jon'] VS true_author: ['iversen jon', "alice o'fredericks"]
# movie_id: 38696
# true director: Sean Carr
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06452488899230957
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.002711057662963867
# Discarted candidate: []
# Possible candidate: [{'carr sean': 1, 'carrigan sean': 5}]
# lengthNecessary: 2.0999999999999996
# [{'carr sean': 1, 'carrigan sean': 5}]
# acceptance_diff 2
# ['carrigan sean'] VS true_author: ['carr sean']
# movie_id: 32680
# true director: Raj Nidimoru;Krishna DK
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08483695983886719
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0014300346374511719
# Discarted candidate: []
# Possible candidate: [{'d k krishna': 4, 'dk krishna': 1, 'nidimoru raj': 4}]
# lengthNecessary: 3.15
# [{'d k krishna': 4, 'dk krishna': 1, 'nidimoru raj': 4}]
# acceptance_diff 2
# ['d k krishna', 'nidimoru raj'] VS true_author: ['dk krishna', 'nidimoru raj']
# movie_id: 112475
# true director: Francis Ford Coppola
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1097407341003418
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0015287399291992188
# Discarted candidate: []
# Possible candidate: [{'coppola ford francis': 19, 'coppola francis': 1}]
# lengthNecessary: 7.0
# [{'coppola ford francis': 19, 'coppola francis': 1}]
# acceptance_diff 2
# ['coppola ford francis'] VS true_author: ['coppola ford francis']
# movie_id: 105251
# true director: Nic Hill;Scott Glosserman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05119800567626953
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.002067089080810547
# Discarted candidate: []
# Possible candidate: [{'glosserman scott': 2, 'hill nic': 1}]
# lengthNecessary: 1.0499999999999998
# [{'glosserman scott': 2, 'hill nic': 1}]
# acceptance_diff 2
# ['glosserman scott', 'hill nic'] VS true_author: ['hill nic', 'glosserman scott']
# movie_id: 58667
# true director: Chris R. Notarile;Kim Santiago
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0693051815032959
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.002765178680419922
# Discarted candidate: []
# Possible candidate: [{'chris notarile r': 4, 'kim santiago': 7}]
# lengthNecessary: 3.8499999999999996
# [{'chris notarile r': 4, 'kim santiago': 7}]
# acceptance_diff 2
# ['kim santiago'] VS true_author: ['kim santiago', 'chris notarile r']
# movie_id: 87533
# true director: Chang Cheh;Pao Hsueh-Li
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06588196754455566
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0013551712036132812
# Discarted candidate: []
# Possible candidate: [{'chang cheh': 8, 'hsueh li pao': 4, 'hsueh-li pao': 2}]
# lengthNecessary: 4.8999999999999995
# [{'chang cheh': 8, 'hsueh li pao': 4, 'hsueh-li pao': 2}]
# acceptance_diff 2
# ['chang cheh'] VS true_author: ['chang cheh', 'hsueh-li pao']
# movie_id: 92814
# true director: Fritz Lang;Rene Sti
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04813790321350098
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0015511512756347656
# Discarted candidate: []
# Possible candidate: [{'fritz lang': 6, 'rene sti': 2}]
# lengthNecessary: 2.8
# [{'fritz lang': 6, 'rene sti': 2}]
# acceptance_diff 2
# ['fritz lang'] VS true_author: ['fritz lang', 'rene sti']
# movie_id: 59689
# true director: Ines Paris;Daniela Fejerman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04074597358703613
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0012810230255126953
# Discarted candidate: []
# Possible candidate: [{'daniela fejerman': 4, 'ines paris': 2}]
# lengthNecessary: 2.0999999999999996
# [{'daniela fejerman': 4, 'ines paris': 2}]
# acceptance_diff 2
# ['daniela fejerman', 'ines paris'] VS true_author: ['ines paris', 'daniela fejerman']
# movie_id: 35985
# true director: Clay Tweel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05664801597595215
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0016028881072998047
# Discarted candidate: []
# Possible candidate: [{'clay j tweel': 2, 'clay tweel': 6}]
# lengthNecessary: 2.8
# [{'clay j tweel': 2, 'clay tweel': 6}]
# acceptance_diff 2
# ['clay tweel'] VS true_author: ['clay tweel']
# movie_id: 31151
# true director: Gaston Ravel;Tony Lekain
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03176593780517578
# cluster_method: hierarchy
# num_clusters_rate: 0.05
# NUM_CLUSTERS 1
# Blocking time is: 0.0012810230255126953
# Discarted candidate: []
# Possible candidate: [{'gaston ravel': 1, 'lekain tony': 2}]
# lengthNecessary: 1.0499999999999998
# [{'gaston ravel': 1, 'lekain tony': 2}]
# acceptance_diff 2
# ['gaston ravel', 'lekain tony'] VS true_author: ['lekain tony', 'gaston ravel']
# Total time is: 21.287713050842285

# %%
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# TP: 545, FP: 92, FN: 47
# precision is 0.8555729984301413
# recall is 0.9206081081081081
# f1Score is 0.886899918633035
# (0.8555729984301413, 0.9206081081081081, 0.886899918633035)

# %%
key_values = {
    'model_type':'bilstm',
    'char_level':False,
    'model_version': 2,
    'rnn_dim':1024,
    'verbose':1,
    'attributes_list': ['newDirector'],
    'embedding_type': 'inferSent',
    'dataset': 'clean_movie',
    'cluster_method': 'hierarchy',
    'num_clusters_rate': 0.01,
    'block_length_thresold': 0.35,
    'acceptance_diff':2,
    'block_weight': 5,
}

# %%
dataset_name, table_group_by_movie_id, list_movie_id, true_directors = load_dataset(key_values)
# Out:
# dataset: clean_movie
# Loading time is: 0.15001392364501953

# %%
start_time = time.time()
finalDirectors, trueDirectors = launchWithoutReductionFusionMovie(table_group_by_movie_id, list_movie_id, true_directors, key_values)
print("Total time is: {0}".format(time.time() - start_time))
# Out:
# movie_id: 73952
# true director: Robert Hamer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06668806076049805
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0020279884338378906
# Discarted candidate: []
# Possible candidate: [{'chester e hal': 2, 'cyril frankel': 1, 'hamer robert': 4}]
# lengthNecessary: 2.4499999999999997
# [{'chester e hal': 2, 'cyril frankel': 1, 'hamer robert': 4}]
# acceptance_diff 2
# ['chester e hal', 'hamer robert'] VS true_author: ['hamer robert']
# movie_id: 1655
# true director: Alexandre O. Philippe
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07591795921325684
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004094123840332031
# Discarted candidate: []
# Possible candidate: [{'alexandre o philippe': 2, 'alexandre philippe': 1}]
# lengthNecessary: 1.0499999999999998
# [{'alexandre o philippe': 2, 'alexandre philippe': 1}]
# acceptance_diff 2
# ['alexandre o philippe'] VS true_author: ['alexandre o philippe']
# movie_id: 69693
# true director: Brad Bird
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08682894706726074
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0027420520782470703
# Discarted candidate: []
# Possible candidate: [{'bird brad': 28, 'jan pinkava': 12}]
# lengthNecessary: 14.0
# [{'bird brad': 28, 'jan pinkava': 12}]
# acceptance_diff 2
# ['bird brad'] VS true_author: ['bird brad']
# movie_id: 89575
# true director: Vincent Sherman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.048217058181762695
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011630058288574219
# Discarted candidate: []
# Possible candidate: [{'aldrich robert': 2, 'sherman vincent': 7}]
# lengthNecessary: 3.15
# [{'aldrich robert': 2, 'sherman vincent': 7}]
# acceptance_diff 2
# ['sherman vincent'] VS true_author: ['sherman vincent']
# movie_id: 5900
# true director: Fraser C. Heston
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.049809932708740234
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015041828155517578
# Discarted candidate: []
# Possible candidate: [{'c fraser heston': 2, 'clarke fraser heston': 7}]
# lengthNecessary: 3.15
# [{'c fraser heston': 2, 'clarke fraser heston': 7}]
# acceptance_diff 2
# ['clarke fraser heston'] VS true_author: ['c fraser heston']
# movie_id: 105551
# true director: John Landis;Steven Spielberg;Joe Dante;George Miller
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.15582990646362305
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.006219148635864258
# Discarted candidate: []
# Possible candidate: [{'dante joe': 15, 'george miller': 15, 'john landis': 19, 'spielberg steven': 22}]
# lengthNecessary: 24.849999999999998
# [{'dante joe': 15, 'george miller': 15, 'john landis': 19, 'spielberg steven': 22}]
# acceptance_diff 2
# ['spielberg steven'] VS true_author: ['dante joe', 'george miller', 'spielberg steven', 'john landis']
# movie_id: 61521
# true director: Godfrey Ho
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.028438091278076172
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009469985961914062
# Discarted candidate: []
# Possible candidate: [{'godfrey ho': 3, 'kim si-hyun': 1}]
# lengthNecessary: 1.4
# [{'godfrey ho': 3, 'kim si-hyun': 1}]
# acceptance_diff 2
# ['godfrey ho', 'kim si-hyun'] VS true_author: ['godfrey ho']
# movie_id: 37376
# true director: Dave Fleischer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07553625106811523
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.003932952880859375
# Discarted candidate: []
# Possible candidate: [{'bowsky willard': 1, 'dave fleischer': 13}]
# lengthNecessary: 4.8999999999999995
# [{'bowsky willard': 1, 'dave fleischer': 13}]
# acceptance_diff 2
# ['dave fleischer'] VS true_author: ['dave fleischer']
# movie_id: 26754
# true director: Martin D'Urville
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.039566755294799805
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001558065414428711
# Discarted candidate: []
# Possible candidate: [{"d'urville martin": 11, 'durville martin': 2}]
# lengthNecessary: 4.55
# [{"d'urville martin": 11, 'durville martin': 2}]
# acceptance_diff 2
# ["d'urville martin"] VS true_author: ["d'urville martin"]
# movie_id: 97745
# true director: Norton Virgien;Igor Kovalyov
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.043337106704711914
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0024881362915039062
# Discarted candidate: []
# Possible candidate: [{'igor kovalyov': 15, 'norton virgien': 16}]
# lengthNecessary: 10.85
# [{'igor kovalyov': 15, 'norton virgien': 16}]
# acceptance_diff 2
# ['igor kovalyov', 'norton virgien'] VS true_author: ['norton virgien', 'igor kovalyov']
# movie_id: 58040
# true director: Thomas Bezucha
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04931521415710449
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0017461776733398438
# Discarted candidate: []
# Possible candidate: [{'bezucha thomas': 20, 'bezucha tom': 3}]
# lengthNecessary: 8.049999999999999
# [{'bezucha thomas': 20, 'bezucha tom': 3}]
# acceptance_diff 2
# ['bezucha thomas'] VS true_author: ['bezucha thomas']
# movie_id: 11447
# true director: Michael Galinsky;Suki Hawley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03508710861206055
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014870166778564453
# Discarted candidate: []
# Possible candidate: [{'galinsky michael': 4, 'hawley suki': 6}]
# lengthNecessary: 3.5
# [{'galinsky michael': 4, 'hawley suki': 6}]
# acceptance_diff 2
# ['galinsky michael', 'hawley suki'] VS true_author: ['galinsky michael', 'hawley suki']
# movie_id: 92995
# true director: Chatrichalerm Yukol
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02357196807861328
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001894235610961914
# Discarted candidate: []
# Possible candidate: [{'chatrichalerm yukoi': 2, 'chatrichalerm yukol': 2}]
# lengthNecessary: 1.4
# [{'chatrichalerm yukoi': 2, 'chatrichalerm yukol': 2}]
# acceptance_diff 2
# ['chatrichalerm yukoi'] VS true_author: ['chatrichalerm yukol']
# movie_id: 45317
# true director: Richard Talmadge;Harvey Parry
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03656506538391113
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012869834899902344
# Discarted candidate: []
# Possible candidate: [{'harvey parry': 3, 'richard talmadge': 1}]
# lengthNecessary: 1.4
# [{'harvey parry': 3, 'richard talmadge': 1}]
# acceptance_diff 2
# ['harvey parry', 'richard talmadge'] VS true_author: ['richard talmadge', 'harvey parry']
# movie_id: 57325
# true director: Keiichi Hara
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05232405662536621
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0020380020141601562
# Discarted candidate: []
# Possible candidate: [{'hara keiichi': 11, 'michael sinterniklaas': 6, 'sheh stephanie': 6}]
# lengthNecessary: 8.049999999999999
# [{'hara keiichi': 11, 'michael sinterniklaas': 6, 'sheh stephanie': 6}]
# acceptance_diff 2
# ['hara keiichi'] VS true_author: ['hara keiichi']
# movie_id: 96819
# true director: Yves Allegret
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05616593360900879
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001466989517211914
# Discarted candidate: []
# Possible candidate: [{'allegret yves': 2, 'e portas rafael': 1}]
# lengthNecessary: 1.0499999999999998
# [{'allegret yves': 2, 'e portas rafael': 1}]
# acceptance_diff 2
# ['allegret yves', 'e portas rafael'] VS true_author: ['allegret yves']
# movie_id: 24035
# true director: William Tannen;Larry Cohen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05695986747741699
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001851797103881836
# Discarted candidate: []
# Possible candidate: [{'cohen larry': 6, 'tannen william': 4}]
# lengthNecessary: 3.5
# [{'cohen larry': 6, 'tannen william': 4}]
# acceptance_diff 2
# ['cohen larry', 'tannen william'] VS true_author: ['cohen larry', 'tannen william']
# movie_id: 5820
# true director: Ananth Narayan Mahadevan
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04429292678833008
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014889240264892578
# Discarted candidate: []
# Possible candidate: [{'anant mahadevan': 1, 'ananth mahadevan narayan': 3}]
# lengthNecessary: 1.4
# [{'anant mahadevan': 1, 'ananth mahadevan narayan': 3}]
# acceptance_diff 2
# ['anant mahadevan', 'ananth mahadevan narayan'] VS true_author: ['ananth mahadevan narayan']
# movie_id: 14372
# true director: Joel Coen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05981707572937012
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004656076431274414
# Discarted candidate: []
# Possible candidate: [{'coen ethan': 7, 'coen joel': 13}]
# lengthNecessary: 7.0
# [{'coen ethan': 7, 'coen joel': 13}]
# acceptance_diff 2
# ['coen joel'] VS true_author: ['coen joel']
# movie_id: 2550
# true director: Jean-Luc Godard
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03559708595275879
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001332998275756836
# Discarted candidate: []
# Possible candidate: [{'dziga groupe vertov': 1, 'godard jean-luc': 3}]
# lengthNecessary: 1.4
# [{'dziga groupe vertov': 1, 'godard jean-luc': 3}]
# acceptance_diff 2
# ['dziga groupe vertov', 'godard jean-luc'] VS true_author: ['godard jean-luc']
# movie_id: 8413
# true director: Adam Small;Peter Stuart
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04070401191711426
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002002239227294922
# Discarted candidate: []
# Possible candidate: [{'adam small': 9, 'peter stuart': 7}]
# lengthNecessary: 5.6
# [{'adam small': 9, 'peter stuart': 7}]
# acceptance_diff 2
# ['adam small', 'peter stuart'] VS true_author: ['adam small', 'peter stuart']
# movie_id: 93760
# true director: Caradog W. James
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03354597091674805
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014109611511230469
# Discarted candidate: []
# Possible candidate: [{'caradog james': 3, 'caradog james w': 1}]
# lengthNecessary: 1.4
# [{'caradog james': 3, 'caradog james w': 1}]
# acceptance_diff 2
# ['caradog james'] VS true_author: ['caradog james w']
# movie_id: 93024
# true director: Phil Lord;Christopher Miller
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08259892463684082
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.005193233489990234
# Discarted candidate: []
# Possible candidate: [{'chris mckay': 2, 'chris miller': 8, 'christopher miller': 15, 'lord phil': 28}]
# lengthNecessary: 18.549999999999997
# [{'chris mckay': 2, 'chris miller': 8, 'christopher miller': 15, 'lord phil': 28}]
# acceptance_diff 2
# ['lord phil'] VS true_author: ['lord phil', 'christopher miller']
# movie_id: 63252
# true director: Gabriele Del Grande;Khaled Soliman Al Nassiry;Antonio Augugliaro
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.039621829986572266
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011970996856689453
# Discarted candidate: []
# Possible candidate: [{'al khaled nassiry soliman': 1, 'antonio augugliaro': 2, 'del gabriele grande': 1}]
# lengthNecessary: 1.4
# [{'al khaled nassiry soliman': 1, 'antonio augugliaro': 2, 'del gabriele grande': 1}]
# acceptance_diff 2
# ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande'] VS true_author: ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande']
# movie_id: 76340
# true director: Prince
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.026981115341186523
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.003475189208984375
# Discarted candidate: []
# Possible candidate: [{'albert magnoli': 3, 'prince': 6}]
# lengthNecessary: 3.15
# [{'albert magnoli': 3, 'prince': 6}]
# acceptance_diff 2
# ['prince'] VS true_author: ['prince']
# movie_id: 21613
# true director: Andrzej Bartkowiak
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04275393486022949
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001394033432006836
# Discarted candidate: []
# Possible candidate: [{'andrzej bartkowiak': 19, 'andrzek bartkowiak': 1}]
# lengthNecessary: 7.0
# [{'andrzej bartkowiak': 19, 'andrzek bartkowiak': 1}]
# acceptance_diff 2
# ['andrzej bartkowiak'] VS true_author: ['andrzej bartkowiak']
# movie_id: 80167
# true director: Sandra Martin;Hugues Martin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0328669548034668
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015337467193603516
# Discarted candidate: []
# Possible candidate: [{'hugues martin': 4, 'martin sandra': 2}]
# lengthNecessary: 2.0999999999999996
# [{'hugues martin': 4, 'martin sandra': 2}]
# acceptance_diff 2
# ['hugues martin', 'martin sandra'] VS true_author: ['martin sandra', 'hugues martin']
# movie_id: 82271
# true director: Marvin J. Chomsky
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.062032222747802734
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0018050670623779297
# Discarted candidate: []
# Possible candidate: [{'chomsky j marvin': 17, 'chomsky marvin': 1}]
# lengthNecessary: 6.3
# [{'chomsky j marvin': 17, 'chomsky marvin': 1}]
# acceptance_diff 2
# ['chomsky j marvin'] VS true_author: ['chomsky j marvin']
# movie_id: 7494
# true director: Tommy O'Haver
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03279995918273926
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013189315795898438
# Discarted candidate: []
# Possible candidate: [{"o'haver tommy": 7, 'ohaver tommy': 3}]
# lengthNecessary: 3.5
# [{"o'haver tommy": 7, 'ohaver tommy': 3}]
# acceptance_diff 2
# ["o'haver tommy"] VS true_author: ["o'haver tommy"]
# movie_id: 16640
# true director: Timothy Marrinan;Richard Dewey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.032279014587402344
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012547969818115234
# Discarted candidate: []
# Possible candidate: [{'dewey richard': 1, 'marrinan timothy': 2}]
# lengthNecessary: 1.0499999999999998
# [{'dewey richard': 1, 'marrinan timothy': 2}]
# acceptance_diff 2
# ['dewey richard', 'marrinan timothy'] VS true_author: ['dewey richard', 'marrinan timothy']
# movie_id: 101119
# true director: Chris Hegedus;D. A. Pennebaker
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04465484619140625
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012359619140625
# Discarted candidate: []
# Possible candidate: [{'a d pennebaker': 9, 'chris hegedus': 7}]
# lengthNecessary: 5.6
# [{'a d pennebaker': 9, 'chris hegedus': 7}]
# acceptance_diff 2
# ['a d pennebaker', 'chris hegedus'] VS true_author: ['chris hegedus', 'a d pennebaker']
# movie_id: 17046
# true director: Paolo Taviani;Vittorio Taviani
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02437615394592285
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009601116180419922
# Discarted candidate: []
# Possible candidate: [{'paolo taviani': 4, 'taviani vittorio': 2}]
# lengthNecessary: 2.0999999999999996
# [{'paolo taviani': 4, 'taviani vittorio': 2}]
# acceptance_diff 2
# ['paolo taviani', 'taviani vittorio'] VS true_author: ['paolo taviani', 'taviani vittorio']
# movie_id: 80539
# true director: Karan Johar
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03323197364807129
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010941028594970703
# Discarted candidate: []
# Possible candidate: [{'abhishek varman': 2, 'johar karan': 10}]
# lengthNecessary: 4.199999999999999
# [{'abhishek varman': 2, 'johar karan': 10}]
# acceptance_diff 2
# ['johar karan'] VS true_author: ['johar karan']
# movie_id: 111871
# true director: Anlo Sepulveda;Paul Collins
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06251168251037598
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011680126190185547
# Discarted candidate: []
# Possible candidate: [{'anlo sepulveda': 3, 'collins paul': 2}]
# lengthNecessary: 1.75
# [{'anlo sepulveda': 3, 'collins paul': 2}]
# acceptance_diff 2
# ['anlo sepulveda', 'collins paul'] VS true_author: ['anlo sepulveda', 'collins paul']
# movie_id: 31082
# true director: Slatan Dudow;Kurt Maetzig
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06076407432556152
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014710426330566406
# Discarted candidate: []
# Possible candidate: [{'dudow slatan': 2, 'groschopp richard': 1, 'kurt maetzig': 1}]
# lengthNecessary: 1.4
# [{'dudow slatan': 2, 'groschopp richard': 1, 'kurt maetzig': 1}]
# acceptance_diff 2
# ['dudow slatan', 'groschopp richard', 'kurt maetzig'] VS true_author: ['dudow slatan', 'kurt maetzig']
# movie_id: 2672
# true director: Christian Krones;Olaf S. Muller;Roland Schrotthofer;Florian Weigensamer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03891396522521973
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011713504791259766
# Discarted candidate: []
# Possible candidate: [{'christian krones': 1, 'florian weigensamer': 2, 'muller olaf s': 1, 'roland schrotthofer': 1}]
# lengthNecessary: 1.75
# [{'christian krones': 1, 'florian weigensamer': 2, 'muller olaf s': 1, 'roland schrotthofer': 1}]
# acceptance_diff 2
# ['christian krones', 'florian weigensamer', 'muller olaf s', 'roland schrotthofer'] VS true_author: ['muller olaf s', 'roland schrotthofer', 'florian weigensamer', 'christian krones']
# movie_id: 91427
# true director: Robert Rossen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03400707244873047
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009870529174804688
# Discarted candidate: []
# Possible candidate: [{'blue washington': 1, 'robert rossen': 9}]
# lengthNecessary: 3.5
# [{'blue washington': 1, 'robert rossen': 9}]
# acceptance_diff 2
# ['robert rossen'] VS true_author: ['robert rossen']
# movie_id: 2813
# true director: Michael Tiddes
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.029824018478393555
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011336803436279297
# Discarted candidate: []
# Possible candidate: [{'michael tiddes': 11, 'mike tiddes': 2}]
# lengthNecessary: 4.55
# [{'michael tiddes': 11, 'mike tiddes': 2}]
# acceptance_diff 2
# ['michael tiddes'] VS true_author: ['michael tiddes']
# movie_id: 15123
# true director: Jon Bulette;Stone Roberts
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03590798377990723
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013840198516845703
# Discarted candidate: []
# Possible candidate: [{'bulette jon': 3, 'f roberts stone': 1, 'roberts stone': 1}]
# lengthNecessary: 1.75
# [{'bulette jon': 3, 'f roberts stone': 1, 'roberts stone': 1}]
# acceptance_diff 2
# ['bulette jon', 'f roberts stone'] VS true_author: ['bulette jon', 'roberts stone']
# movie_id: 30280
# true director: Anthony Stabley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.043292999267578125
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010340213775634766
# Discarted candidate: []
# Possible candidate: [{'anthony r stabley': 3, 'anthony stabley': 8}]
# lengthNecessary: 3.8499999999999996
# [{'anthony r stabley': 3, 'anthony stabley': 8}]
# acceptance_diff 2
# ['anthony stabley'] VS true_author: ['anthony stabley']
# movie_id: 68652
# true director: Adam Kassen;Mark Kassen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.040624141693115234
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014142990112304688
# Discarted candidate: []
# Possible candidate: [{'adam kassen': 8, 'kassen mark': 9}]
# lengthNecessary: 5.949999999999999
# [{'adam kassen': 8, 'kassen mark': 9}]
# acceptance_diff 2
# ['adam kassen', 'kassen mark'] VS true_author: ['kassen mark', 'adam kassen']
# movie_id: 21609
# true director: Rowby Goren;Chuck Staley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03379416465759277
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010139942169189453
# Discarted candidate: []
# Possible candidate: [{'chuck staley': 3, 'goren rowby': 6}]
# lengthNecessary: 3.15
# [{'chuck staley': 3, 'goren rowby': 6}]
# acceptance_diff 2
# ['goren rowby'] VS true_author: ['chuck staley', 'goren rowby']
# movie_id: 37872
# true director: Michael Almereyda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.027493715286254883
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009739398956298828
# Discarted candidate: []
# Possible candidate: [{'almereyda michael': 5, 'campbell scott': 1}]
# lengthNecessary: 2.0999999999999996
# [{'almereyda michael': 5, 'campbell scott': 1}]
# acceptance_diff 2
# ['almereyda michael'] VS true_author: ['almereyda michael']
# movie_id: 45447
# true director: Fred C. Brannon;Thomas Carr
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.039361000061035156
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009930133819580078
# Discarted candidate: []
# Possible candidate: [{'brannon c fred': 6, 'carr thomas': 3}]
# lengthNecessary: 3.15
# [{'brannon c fred': 6, 'carr thomas': 3}]
# acceptance_diff 2
# ['brannon c fred'] VS true_author: ['carr thomas', 'brannon c fred']
# movie_id: 24661
# true director: Matthew Celestre;Brett Celestre
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03270411491394043
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011708736419677734
# Discarted candidate: []
# Possible candidate: [{'brett celestre': 1, 'brette celestre': 2, 'celestre matthew': 1}]
# lengthNecessary: 1.4
# [{'brett celestre': 1, 'brette celestre': 2, 'celestre matthew': 1}]
# acceptance_diff 2
# ['brett celestre', 'celestre matthew'] VS true_author: ['brett celestre', 'celestre matthew']
# movie_id: 3648
# true director: Nikolaj Arcel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02262091636657715
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012218952178955078
# Discarted candidate: []
# Possible candidate: [{'arcel nikaolaj': 2, 'arcel nikolaj': 14}]
# lengthNecessary: 5.6
# [{'arcel nikaolaj': 2, 'arcel nikolaj': 14}]
# acceptance_diff 2
# ['arcel nikolaj'] VS true_author: ['arcel nikolaj']
# movie_id: 13479
# true director: Ergin Orbey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02672100067138672
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010020732879638672
# Discarted candidate: []
# Possible candidate: [{'engin orbey': 8, 'ergin orbey': 1}]
# lengthNecessary: 3.15
# [{'engin orbey': 8, 'ergin orbey': 1}]
# acceptance_diff 2
# ['engin orbey'] VS true_author: ['ergin orbey']
# movie_id: 18319
# true director: Baird Bryant;Johanna Demetrakas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.047995805740356445
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001168966293334961
# Discarted candidate: []
# Possible candidate: [{'baird bryant': 8, 'demetrakas johanna': 5}]
# lengthNecessary: 4.55
# [{'baird bryant': 8, 'demetrakas johanna': 5}]
# acceptance_diff 2
# ['baird bryant'] VS true_author: ['baird bryant', 'demetrakas johanna']
# movie_id: 44223
# true director: Gene Kelly
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.036679983139038086
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010471343994140625
# Discarted candidate: []
# Possible candidate: [{'freddie young': 1, 'gene kelly': 8}]
# lengthNecessary: 3.15
# [{'freddie young': 1, 'gene kelly': 8}]
# acceptance_diff 2
# ['gene kelly'] VS true_author: ['gene kelly']
# movie_id: 71075
# true director: David Twohy
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05232834815979004
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0017650127410888672
# Discarted candidate: []
# Possible candidate: [{'david n twohy': 1, 'david twohy': 24}]
# lengthNecessary: 8.75
# [{'david n twohy': 1, 'david twohy': 24}]
# acceptance_diff 2
# ['david twohy'] VS true_author: ['david twohy']
# movie_id: 80410
# true director: Paul Ragsdale
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04377603530883789
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010690689086914062
# Discarted candidate: []
# Possible candidate: [{'alba angelica de': 3, 'paul ragsdale': 6}]
# lengthNecessary: 3.15
# [{'alba angelica de': 3, 'paul ragsdale': 6}]
# acceptance_diff 2
# ['paul ragsdale'] VS true_author: ['paul ragsdale']
# movie_id: 71705
# true director: Allan Arkush
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.043859004974365234
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013401508331298828
# Discarted candidate: []
# Possible candidate: [{'allan arkush': 13, 'dante joe': 6}]
# lengthNecessary: 6.6499999999999995
# [{'allan arkush': 13, 'dante joe': 6}]
# acceptance_diff 2
# ['allan arkush'] VS true_author: ['allan arkush']
# movie_id: 91114
# true director: Tian Zhuangzhuang
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0330507755279541
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001377105712890625
# Discarted candidate: []
# Possible candidate: [{'pan peicheng': 3, 'tian zhuangzhuang': 3}]
# lengthNecessary: 2.0999999999999996
# [{'pan peicheng': 3, 'tian zhuangzhuang': 3}]
# acceptance_diff 2
# ['pan peicheng', 'tian zhuangzhuang'] VS true_author: ['tian zhuangzhuang']
# movie_id: 100574
# true director: Michael Hegner;Karsten Kiilerich
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.028326034545898438
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010187625885009766
# Discarted candidate: []
# Possible candidate: [{'hegner michael': 6, 'karsten kiilerich': 4}]
# lengthNecessary: 3.5
# [{'hegner michael': 6, 'karsten kiilerich': 4}]
# acceptance_diff 2
# ['hegner michael', 'karsten kiilerich'] VS true_author: ['hegner michael', 'karsten kiilerich']
# movie_id: 22475
# true director: Kevin King
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03534197807312012
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010042190551757812
# Discarted candidate: []
# Possible candidate: [{'k king': 6, 'kevin king': 3}]
# lengthNecessary: 3.15
# [{'k king': 6, 'kevin king': 3}]
# acceptance_diff 2
# ['k king'] VS true_author: ['kevin king']
# movie_id: 57809
# true director: John Lamb
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0393369197845459
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009467601776123047
# Discarted candidate: []
# Possible candidate: [{'hill jack': 2, 'john lamb': 1}]
# lengthNecessary: 1.0499999999999998
# [{'hill jack': 2, 'john lamb': 1}]
# acceptance_diff 2
# ['hill jack', 'john lamb'] VS true_author: ['john lamb']
# movie_id: 97278
# true director: Norman Panama;Melvin Frank
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03484487533569336
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009510517120361328
# Discarted candidate: []
# Possible candidate: [{'frank melvin': 4, 'norman panama': 3}]
# lengthNecessary: 2.4499999999999997
# [{'frank melvin': 4, 'norman panama': 3}]
# acceptance_diff 2
# ['frank melvin', 'norman panama'] VS true_author: ['norman panama', 'frank melvin']
# movie_id: 106242
# true director: Gionata Zarantonello
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.018489837646484375
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001580953598022461
# Discarted candidate: []
# Possible candidate: [{'gionata zarantonello': 1, 'jonathan zarantonello': 1}]
# lengthNecessary: 0.7
# [{'gionata zarantonello': 1, 'jonathan zarantonello': 1}]
# acceptance_diff 2
# ['gionata zarantonello'] VS true_author: ['gionata zarantonello']
# movie_id: 81911
# true director: Kang Je-Gyu
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06435370445251465
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0022079944610595703
# Discarted candidate: []
# Possible candidate: [{'gyu je kang': 1, 'je-gyu kang': 13, 'je-kyu kang': 7}]
# lengthNecessary: 7.35
# [{'gyu je kang': 1, 'je-gyu kang': 13, 'je-kyu kang': 7}]
# acceptance_diff 2
# ['je-gyu kang'] VS true_author: ['je-gyu kang']
# movie_id: 87781
# true director: Alistair Legrand
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.043348073959350586
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012788772583007812
# Discarted candidate: []
# Possible candidate: [{'alistair legrand': 16, 'callaway ryan': 1}]
# lengthNecessary: 5.949999999999999
# [{'alistair legrand': 16, 'callaway ryan': 1}]
# acceptance_diff 2
# ['alistair legrand'] VS true_author: ['alistair legrand']
# movie_id: 49079
# true director: Fernando Palacios
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04860281944274902
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001210927963256836
# Discarted candidate: []
# Possible candidate: [{'fernando palacios': 2, 'j rafael salvia': 3}]
# lengthNecessary: 1.75
# [{'fernando palacios': 2, 'j rafael salvia': 3}]
# acceptance_diff 2
# ['fernando palacios', 'j rafael salvia'] VS true_author: ['fernando palacios']
# movie_id: 43271
# true director: R. Kiplin Pastor
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03155970573425293
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0008761882781982422
# Discarted candidate: []
# Possible candidate: [{'kip pastor': 3, 'kiplin pastor r': 1}]
# lengthNecessary: 1.4
# [{'kip pastor': 3, 'kiplin pastor r': 1}]
# acceptance_diff 2
# ['kip pastor', 'kiplin pastor r'] VS true_author: ['kiplin pastor r']
# movie_id: 43726
# true director: Quentin Tarantino
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06366491317749023
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.003734111785888672
# Discarted candidate: []
# Possible candidate: [{'eli roth': 12, 'quentin tarantino': 27}]
# lengthNecessary: 13.649999999999999
# [{'eli roth': 12, 'quentin tarantino': 27}]
# acceptance_diff 2
# ['quentin tarantino'] VS true_author: ['quentin tarantino']
# movie_id: 28418
# true director: Sharunas Bartas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.021841764450073242
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012617111206054688
# Discarted candidate: []
# Possible candidate: [{'bartas sar?nas': 1, 'bartas sharunas': 1}]
# lengthNecessary: 0.7
# [{'bartas sar?nas': 1, 'bartas sharunas': 1}]
# acceptance_diff 2
# ['bartas sar?nas'] VS true_author: ['bartas sharunas']
# movie_id: 111254
# true director: Luke Jaden;Cort Johns
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.032629966735839844
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015521049499511719
# Discarted candidate: []
# Possible candidate: [{'cort johns': 2, 'jaden luke': 4}]
# lengthNecessary: 2.0999999999999996
# [{'cort johns': 2, 'jaden luke': 4}]
# acceptance_diff 2
# ['cort johns', 'jaden luke'] VS true_author: ['cort johns', 'jaden luke']
# movie_id: 69205
# true director: Nancy Glass;Michele Loschiavo
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02913832664489746
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014069080352783203
# Discarted candidate: []
# Possible candidate: [{'glass nancy': 2, 'loschiavo michele': 1}]
# lengthNecessary: 1.0499999999999998
# [{'glass nancy': 2, 'loschiavo michele': 1}]
# acceptance_diff 2
# ['glass nancy', 'loschiavo michele'] VS true_author: ['loschiavo michele', 'glass nancy']
# movie_id: 40048
# true director: Manuel Gonzalez Mauricio;Saul Barreto Ramos
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04735898971557617
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001432180404663086
# Discarted candidate: []
# Possible candidate: [{'barreto ramos saul': 1, 'gonzalez manuel mauricio': 2}]
# lengthNecessary: 1.0499999999999998
# [{'barreto ramos saul': 1, 'gonzalez manuel mauricio': 2}]
# acceptance_diff 2
# ['barreto ramos saul', 'gonzalez manuel mauricio'] VS true_author: ['gonzalez manuel mauricio', 'barreto ramos saul']
# movie_id: 57896
# true director: Andrew V. McLaglen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.036238908767700195
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001377105712890625
# Discarted candidate: []
# Possible candidate: [{'andrew mclaglen': 2, 'andrew mclaglen v': 6}]
# lengthNecessary: 2.8
# [{'andrew mclaglen': 2, 'andrew mclaglen v': 6}]
# acceptance_diff 2
# ['andrew mclaglen v'] VS true_author: ['andrew mclaglen v']
# movie_id: 32707
# true director: Paul Morrissey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04892230033874512
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010068416595458984
# Discarted candidate: []
# Possible candidate: [{'antonio margheriti': 2, 'morrissey paul': 6}]
# lengthNecessary: 2.8
# [{'antonio margheriti': 2, 'morrissey paul': 6}]
# acceptance_diff 2
# ['morrissey paul'] VS true_author: ['morrissey paul']
# movie_id: 80601
# true director: Frank Capra
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.039681196212768555
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012021064758300781
# Discarted candidate: []
# Possible candidate: [{'capra frank': 5, 'irvin willat': 3}]
# lengthNecessary: 2.8
# [{'capra frank': 5, 'irvin willat': 3}]
# acceptance_diff 2
# ['capra frank', 'irvin willat'] VS true_author: ['capra frank']
# movie_id: 109103
# true director: Dick Zondag;Ralph Zondag;Phil Nibbelink;Simon Wells
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09873723983764648
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0036461353302001953
# Discarted candidate: []
# Possible candidate: [{'dick zondag': 12, 'nibbelink phil': 14, 'ralph zondag': 12, 'simon wells': 12}]
# lengthNecessary: 17.5
# [{'dick zondag': 12, 'nibbelink phil': 14, 'ralph zondag': 12, 'simon wells': 12}]
# acceptance_diff 2
# ['dick zondag', 'nibbelink phil', 'ralph zondag', 'simon wells'] VS true_author: ['dick zondag', 'simon wells', 'ralph zondag', 'nibbelink phil']
# movie_id: 76115
# true director: Adam Friedman;Iain Kennedy
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04566001892089844
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013580322265625
# Discarted candidate: []
# Possible candidate: [{'adam friedman': 7, 'iain kennedy': 5}]
# lengthNecessary: 4.199999999999999
# [{'adam friedman': 7, 'iain kennedy': 5}]
# acceptance_diff 2
# ['adam friedman', 'iain kennedy'] VS true_author: ['iain kennedy', 'adam friedman']
# movie_id: 60263
# true director: Bill Guttentag;Dan Sturman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05872321128845215
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0018918514251708984
# Discarted candidate: []
# Possible candidate: [{'bill guttentag': 14, 'dan sturman': 9}]
# lengthNecessary: 8.049999999999999
# [{'bill guttentag': 14, 'dan sturman': 9}]
# acceptance_diff 2
# ['bill guttentag'] VS true_author: ['bill guttentag', 'dan sturman']
# movie_id: 35119
# true director: Cynthia Wade;Cheryl Miller Houser
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05467629432678223
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013051033020019531
# Discarted candidate: []
# Possible candidate: [{'cheryl houser': 1, 'cheryl houser miller': 4, 'cynthia wade': 6}]
# lengthNecessary: 3.8499999999999996
# [{'cheryl houser': 1, 'cheryl houser miller': 4, 'cynthia wade': 6}]
# acceptance_diff 2
# ['cheryl houser miller', 'cynthia wade'] VS true_author: ['cynthia wade', 'cheryl houser miller']
# movie_id: 97251
# true director: Michael Dudok De Wit
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05227303504943848
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0027420520782470703
# Discarted candidate: []
# Possible candidate: [{'de dudok michael wit': 3, 'dewit dudok michael': 1}]
# lengthNecessary: 1.4
# [{'de dudok michael wit': 3, 'dewit dudok michael': 1}]
# acceptance_diff 2
# ['de dudok michael wit'] VS true_author: ['de dudok michael wit']
# movie_id: 90003
# true director: Charles Chaplin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05456113815307617
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013210773468017578
# Discarted candidate: []
# Possible candidate: [{'chaplin charles': 13, 'chaplin charlie': 6}]
# lengthNecessary: 6.6499999999999995
# [{'chaplin charles': 13, 'chaplin charlie': 6}]
# acceptance_diff 2
# ['chaplin charles'] VS true_author: ['chaplin charles']
# movie_id: 91535
# true director: J. A. Bayona
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.061531782150268555
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0017521381378173828
# Discarted candidate: []
# Possible candidate: [{'a bayona j': 7, 'antonio bayona juan': 15}]
# lengthNecessary: 7.699999999999999
# [{'a bayona j': 7, 'antonio bayona juan': 15}]
# acceptance_diff 2
# ['antonio bayona juan'] VS true_author: ['a bayona j']
# movie_id: 51346
# true director: William A. Seiter
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03431296348571777
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009601116180419922
# Discarted candidate: []
# Possible candidate: [{'a seiter william': 2, 'seiter william': 1}]
# lengthNecessary: 1.0499999999999998
# [{'a seiter william': 2, 'seiter william': 1}]
# acceptance_diff 2
# ['a seiter william'] VS true_author: ['a seiter william']
# movie_id: 64713
# true director: Alan Mak;Felix Chong
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04050588607788086
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015130043029785156
# Discarted candidate: []
# Possible candidate: [{'alan mak': 5, 'chong felix': 8}]
# lengthNecessary: 4.55
# [{'alan mak': 5, 'chong felix': 8}]
# acceptance_diff 2
# ['chong felix'] VS true_author: ['alan mak', 'chong felix']
# movie_id: 87307
# true director: Florian Cossen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.026304006576538086
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0005016326904296875
# Discarted candidate: []
# Possible candidate: [{'cossen florian': 1, 'cossen florian micoud': 1}]
# lengthNecessary: 0.7
# [{'cossen florian': 1, 'cossen florian micoud': 1}]
# acceptance_diff 2
# ['cossen florian', 'cossen florian micoud'] VS true_author: ['cossen florian']
# movie_id: 89712
# true director: Mauro Borrelli
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.023281097412109375
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0008971691131591797
# Discarted candidate: []
# Possible candidate: [{'borrelli maura': 1, 'borrelli mauro': 2}]
# lengthNecessary: 1.0499999999999998
# [{'borrelli maura': 1, 'borrelli mauro': 2}]
# acceptance_diff 2
# ['borrelli maura'] VS true_author: ['borrelli mauro']
# movie_id: 11264
# true director: Rex Ingram
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.030827999114990234
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009860992431640625
# Discarted candidate: []
# Possible candidate: [{'alice terry': 1, 'ingram rex': 2}]
# lengthNecessary: 1.0499999999999998
# [{'alice terry': 1, 'ingram rex': 2}]
# acceptance_diff 2
# ['alice terry', 'ingram rex'] VS true_author: ['ingram rex']
# movie_id: 48608
# true director: John Stevenson;Mark Osborne
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09455585479736328
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004189968109130859
# Discarted candidate: []
# Possible candidate: [{'john stevenson': 25, 'mark osborne': 31}]
# lengthNecessary: 19.599999999999998
# [{'john stevenson': 25, 'mark osborne': 31}]
# acceptance_diff 2
# ['mark osborne'] VS true_author: ['john stevenson', 'mark osborne']
# movie_id: 5451
# true director: Claudio Marques;Marilia Hughes
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03838205337524414
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012090206146240234
# Discarted candidate: []
# Possible candidate: [{'claudio marques': 3, 'guerreiro hughes marilia': 2, 'hughes marilia': 1}]
# lengthNecessary: 2.0999999999999996
# [{'claudio marques': 3, 'guerreiro hughes marilia': 2, 'hughes marilia': 1}]
# acceptance_diff 2
# ['claudio marques', 'guerreiro hughes marilia', 'hughes marilia'] VS true_author: ['claudio marques', 'hughes marilia']
# movie_id: 29810
# true director: Herrmann Zschoche
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03529691696166992
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016481876373291016
# Discarted candidate: []
# Possible candidate: [{'dressel eleonore': 4, 'herrmann zschoche': 8}]
# lengthNecessary: 4.199999999999999
# [{'dressel eleonore': 4, 'herrmann zschoche': 8}]
# acceptance_diff 2
# ['herrmann zschoche'] VS true_author: ['herrmann zschoche']
# movie_id: 78918
# true director: Marc Gracie;Tim Ferguson
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04648613929748535
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012171268463134766
# Discarted candidate: []
# Possible candidate: [{'ferguson tim': 5, 'gracie marc': 6}]
# lengthNecessary: 3.8499999999999996
# [{'ferguson tim': 5, 'gracie marc': 6}]
# acceptance_diff 2
# ['ferguson tim', 'gracie marc'] VS true_author: ['gracie marc', 'ferguson tim']
# movie_id: 71440
# true director: Otto Preminger
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03722691535949707
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0019221305847167969
# Discarted candidate: []
# Possible candidate: [{'jean negulesco': 3, 'otto preminger': 14}]
# lengthNecessary: 5.949999999999999
# ...
# char_level: False
# Embedding time is: 0.029564857482910156
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012531280517578125
# Discarted candidate: []
# Possible candidate: [{'l?a pool': 1, 'lea pool': 3}]
# lengthNecessary: 1.4
# [{'l?a pool': 1, 'lea pool': 3}]
# acceptance_diff 2
# ['l?a pool'] VS true_author: ['lea pool']
# movie_id: 69925
# true director: Heidi Maria Faisst
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02749800682067871
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010800361633300781
# Discarted candidate: []
# Possible candidate: [{'faissi heidi maria': 1, 'faisst heidi maria': 1}]
# lengthNecessary: 0.7
# [{'faissi heidi maria': 1, 'faisst heidi maria': 1}]
# acceptance_diff 2
# ['faissi heidi maria'] VS true_author: ['faisst heidi maria']
# movie_id: 47283
# true director: Carl Astrand;Mats Lindberg
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.039552927017211914
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001461029052734375
# Discarted candidate: []
# Possible candidate: [{'astrand carl': 6, 'lindberg mats': 9}]
# lengthNecessary: 5.25
# [{'astrand carl': 6, 'lindberg mats': 9}]
# acceptance_diff 2
# ['lindberg mats'] VS true_author: ['astrand carl', 'lindberg mats']
# movie_id: 40393
# true director: Ewing Scott
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03584599494934082
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012810230255126953
# Discarted candidate: []
# Possible candidate: [{'ewing scott': 8, 'george sherman': 3}]
# lengthNecessary: 3.8499999999999996
# [{'ewing scott': 8, 'george sherman': 3}]
# acceptance_diff 2
# ['ewing scott'] VS true_author: ['ewing scott']
# movie_id: 35829
# true director: Michael Paul Stephenson
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.052172183990478516
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015430450439453125
# Discarted candidate: []
# Possible candidate: [{'michael paul stephenson': 6, 'michael stephenson': 2}]
# lengthNecessary: 2.8
# [{'michael paul stephenson': 6, 'michael stephenson': 2}]
# acceptance_diff 2
# ['michael paul stephenson'] VS true_author: ['michael paul stephenson']
# movie_id: 27116
# true director: Neil Marshall
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04349803924560547
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016770362854003906
# Discarted candidate: []
# Possible candidate: [{'marshall neil': 18, 'universal': 1}]
# lengthNecessary: 6.6499999999999995
# [{'marshall neil': 18, 'universal': 1}]
# acceptance_diff 2
# ['marshall neil'] VS true_author: ['marshall neil']
# movie_id: 49163
# true director: Vicente Aranda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0298922061920166
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009706020355224609
# Discarted candidate: []
# Possible candidate: [{'aranda vicente': 3, 'gomez raul': 2}]
# lengthNecessary: 1.75
# [{'aranda vicente': 3, 'gomez raul': 2}]
# acceptance_diff 2
# ['aranda vicente', 'gomez raul'] VS true_author: ['aranda vicente']
# movie_id: 64814
# true director: R. Balki
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.024606943130493164
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0008988380432128906
# Discarted candidate: []
# Possible candidate: [{'balki r': 4, 'ricky sandhu': 1}]
# lengthNecessary: 1.75
# [{'balki r': 4, 'ricky sandhu': 1}]
# acceptance_diff 2
# ['balki r'] VS true_author: ['balki r']
# movie_id: 87155
# true director: Jiri Svoboda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.027536869049072266
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010218620300292969
# Discarted candidate: []
# Possible candidate: [{'ji?i svoboda': 6, 'jiri svoboda': 1}]
# lengthNecessary: 2.4499999999999997
# [{'ji?i svoboda': 6, 'jiri svoboda': 1}]
# acceptance_diff 2
# ['ji?i svoboda'] VS true_author: ['jiri svoboda']
# movie_id: 19545
# true director: Charles Chu;Gavin Kelly
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03730511665344238
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015251636505126953
# Discarted candidate: []
# Possible candidate: [{'charles chu': 1, 'gavin kelly': 2}]
# lengthNecessary: 1.0499999999999998
# [{'charles chu': 1, 'gavin kelly': 2}]
# acceptance_diff 2
# ['charles chu', 'gavin kelly'] VS true_author: ['charles chu', 'gavin kelly']
# movie_id: 46270
# true director: Seung-Hyeon Jin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.031745195388793945
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010266304016113281
# Discarted candidate: []
# Possible candidate: [{'hyeonh jin seung': 2, 'jin seung-hyeon': 2}]
# lengthNecessary: 1.4
# [{'hyeonh jin seung': 2, 'jin seung-hyeon': 2}]
# acceptance_diff 2
# ['hyeonh jin seung', 'jin seung-hyeon'] VS true_author: ['jin seung-hyeon']
# movie_id: 73371
# true director: Andrew Becker;Daniel Mehrer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02857184410095215
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011320114135742188
# Discarted candidate: []
# Possible candidate: [{'andrew becker': 2, 'daniel mehrer': 1}]
# lengthNecessary: 1.0499999999999998
# [{'andrew becker': 2, 'daniel mehrer': 1}]
# acceptance_diff 2
# ['andrew becker', 'daniel mehrer'] VS true_author: ['daniel mehrer', 'andrew becker']
# movie_id: 61155
# true director: Chan-wook Park
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.027199983596801758
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010287761688232422
# Discarted candidate: []
# Possible candidate: [{'chan-kyong park': 5, 'chan-wook park': 6}]
# lengthNecessary: 3.8499999999999996
# [{'chan-kyong park': 5, 'chan-wook park': 6}]
# acceptance_diff 2
# ['chan-kyong park', 'chan-wook park'] VS true_author: ['chan-wook park']
# movie_id: 111258
# true director: Michael Wadleigh
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.055890798568725586
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0018041133880615234
# Discarted candidate: []
# Possible candidate: [{'d hancock john': 6, 'hitzig rupert': 4, 'michael wadleigh': 15}]
# lengthNecessary: 8.75
# [{'d hancock john': 6, 'hitzig rupert': 4, 'michael wadleigh': 15}]
# acceptance_diff 2
# ['michael wadleigh'] VS true_author: ['michael wadleigh']
# movie_id: 56502
# true director: Nagisa Oshima
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.024466991424560547
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001184225082397461
# Discarted candidate: []
# Possible candidate: [{'?shima nagisa': 2, 'nagisa oshima': 1}]
# lengthNecessary: 1.0499999999999998
# [{'?shima nagisa': 2, 'nagisa oshima': 1}]
# acceptance_diff 2
# ['?shima nagisa', 'nagisa oshima'] VS true_author: ['nagisa oshima']
# movie_id: 63743
# true director: Jeremy Frindel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03558707237243652
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0018489360809326172
# Discarted candidate: []
# Possible candidate: [{'films substratum': 1, 'frindel jeremy': 7}]
# lengthNecessary: 2.8
# [{'films substratum': 1, 'frindel jeremy': 7}]
# acceptance_diff 2
# ['frindel jeremy'] VS true_author: ['frindel jeremy']
# movie_id: 105721
# true director: Georg Maas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03472161293029785
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010738372802734375
# Discarted candidate: []
# Possible candidate: [{'georg maas': 3, 'judith kaufmann': 2}]
# lengthNecessary: 1.75
# [{'georg maas': 3, 'judith kaufmann': 2}]
# acceptance_diff 2
# ['georg maas', 'judith kaufmann'] VS true_author: ['georg maas']
# movie_id: 88941
# true director: Jonah Bekhor;Zach Math
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04314303398132324
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0018770694732666016
# Discarted candidate: []
# Possible candidate: [{'bekhor jonah': 10, 'math zach': 9}]
# lengthNecessary: 6.6499999999999995
# [{'bekhor jonah': 10, 'math zach': 9}]
# acceptance_diff 2
# ['bekhor jonah', 'math zach'] VS true_author: ['bekhor jonah', 'math zach']
# movie_id: 61767
# true director: Ryuhei Kitamura
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.026658058166503906
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001068115234375
# Discarted candidate: []
# Possible candidate: [{'kitamura ry?hei': 2, 'kitamura ryuhei': 5}]
# lengthNecessary: 2.4499999999999997
# [{'kitamura ry?hei': 2, 'kitamura ryuhei': 5}]
# acceptance_diff 2
# ['kitamura ryuhei'] VS true_author: ['kitamura ryuhei']
# movie_id: 76373
# true director: Alice O'Fredericks;Jon Iversen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02302384376525879
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011639595031738281
# Discarted candidate: []
# Possible candidate: [{"alice o'fredericks": 3, 'iversen jon': 2}]
# lengthNecessary: 1.75
# [{"alice o'fredericks": 3, 'iversen jon': 2}]
# acceptance_diff 2
# ["alice o'fredericks", 'iversen jon'] VS true_author: ['iversen jon', "alice o'fredericks"]
# movie_id: 38696
# true director: Sean Carr
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03196597099304199
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013401508331298828
# Discarted candidate: []
# Possible candidate: [{'carr sean': 1, 'carrigan sean': 5}]
# lengthNecessary: 2.0999999999999996
# [{'carr sean': 1, 'carrigan sean': 5}]
# acceptance_diff 2
# ['carrigan sean'] VS true_author: ['carr sean']
# movie_id: 32680
# true director: Raj Nidimoru;Krishna DK
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05110001564025879
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016660690307617188
# Discarted candidate: []
# Possible candidate: [{'d k krishna': 4, 'dk krishna': 1, 'nidimoru raj': 4}]
# lengthNecessary: 3.15
# [{'d k krishna': 4, 'dk krishna': 1, 'nidimoru raj': 4}]
# acceptance_diff 2
# ['d k krishna', 'nidimoru raj'] VS true_author: ['dk krishna', 'nidimoru raj']
# movie_id: 112475
# true director: Francis Ford Coppola
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05689215660095215
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013949871063232422
# Discarted candidate: []
# Possible candidate: [{'coppola ford francis': 19, 'coppola francis': 1}]
# lengthNecessary: 7.0
# [{'coppola ford francis': 19, 'coppola francis': 1}]
# acceptance_diff 2
# ['coppola ford francis'] VS true_author: ['coppola ford francis']
# movie_id: 105251
# true director: Nic Hill;Scott Glosserman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.024610042572021484
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011589527130126953
# Discarted candidate: []
# Possible candidate: [{'glosserman scott': 2, 'hill nic': 1}]
# lengthNecessary: 1.0499999999999998
# [{'glosserman scott': 2, 'hill nic': 1}]
# acceptance_diff 2
# ['glosserman scott', 'hill nic'] VS true_author: ['hill nic', 'glosserman scott']
# movie_id: 58667
# true director: Chris R. Notarile;Kim Santiago
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03461408615112305
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009307861328125
# Discarted candidate: []
# Possible candidate: [{'chris notarile r': 4, 'kim santiago': 7}]
# lengthNecessary: 3.8499999999999996
# [{'chris notarile r': 4, 'kim santiago': 7}]
# acceptance_diff 2
# ['kim santiago'] VS true_author: ['kim santiago', 'chris notarile r']
# movie_id: 87533
# true director: Chang Cheh;Pao Hsueh-Li
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03531908988952637
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012958049774169922
# Discarted candidate: []
# Possible candidate: [{'chang cheh': 8, 'hsueh li pao': 4, 'hsueh-li pao': 2}]
# lengthNecessary: 4.8999999999999995
# [{'chang cheh': 8, 'hsueh li pao': 4, 'hsueh-li pao': 2}]
# acceptance_diff 2
# ['chang cheh'] VS true_author: ['chang cheh', 'hsueh-li pao']
# movie_id: 92814
# true director: Fritz Lang;Rene Sti
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03401017189025879
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012459754943847656
# Discarted candidate: []
# Possible candidate: [{'fritz lang': 6, 'rene sti': 2}]
# lengthNecessary: 2.8
# [{'fritz lang': 6, 'rene sti': 2}]
# acceptance_diff 2
# ['fritz lang'] VS true_author: ['fritz lang', 'rene sti']
# movie_id: 59689
# true director: Ines Paris;Daniela Fejerman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03795576095581055
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001168966293334961
# Discarted candidate: []
# Possible candidate: [{'daniela fejerman': 4, 'ines paris': 2}]
# lengthNecessary: 2.0999999999999996
# [{'daniela fejerman': 4, 'ines paris': 2}]
# acceptance_diff 2
# ['daniela fejerman', 'ines paris'] VS true_author: ['ines paris', 'daniela fejerman']
# movie_id: 35985
# true director: Clay Tweel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.042840003967285156
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.000997781753540039
# Discarted candidate: []
# Possible candidate: [{'clay j tweel': 2, 'clay tweel': 6}]
# lengthNecessary: 2.8
# [{'clay j tweel': 2, 'clay tweel': 6}]
# acceptance_diff 2
# ['clay tweel'] VS true_author: ['clay tweel']
# movie_id: 31151
# true director: Gaston Ravel;Tony Lekain
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.028015851974487305
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010113716125488281
# Discarted candidate: []
# Possible candidate: [{'gaston ravel': 1, 'lekain tony': 2}]
# lengthNecessary: 1.0499999999999998
# [{'gaston ravel': 1, 'lekain tony': 2}]
# acceptance_diff 2
# ['gaston ravel', 'lekain tony'] VS true_author: ['lekain tony', 'gaston ravel']
# Total time is: 19.774063110351562

# %%
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# TP: 543, FP: 85, FN: 49
# precision is 0.8646496815286624
# recall is 0.9172297297297297
# f1Score is 0.8901639344262294
# (0.8646496815286624, 0.9172297297297297, 0.8901639344262294)

# %%
key_values = {
    'model_type':'bilstm',
    'char_level':False,
    'model_version': 2,
    'rnn_dim':1024,
    'verbose':1,
    'attributes_list': ['newDirector'],
    'embedding_type': 'inferSent',
    'dataset': 'clean_movie',
    'cluster_method': 'hierarchy',
    'num_clusters_rate': 0.01,
    'block_length_thresold': 0.35,
    'acceptance_diff':5,
    'block_weight': 5,
}

# %%
dataset_name, table_group_by_movie_id, list_movie_id, true_directors = load_dataset(key_values)
# Out:
# dataset: clean_movie
# Loading time is: 0.14563894271850586

# %%
start_time = time.time()
finalDirectors, trueDirectors = launchWithoutReductionFusionMovie(table_group_by_movie_id, list_movie_id, true_directors, key_values)
print("Total time is: {0}".format(time.time() - start_time))
# Out:
# movie_id: 73952
# true director: Robert Hamer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07476401329040527
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010471343994140625
# Discarted candidate: []
# Possible candidate: [{'chester e hal': 2, 'cyril frankel': 1, 'hamer robert': 4}]
# lengthNecessary: 2.4499999999999997
# [{'chester e hal': 2, 'cyril frankel': 1, 'hamer robert': 4}]
# acceptance_diff 5
# ['chester e hal', 'cyril frankel', 'hamer robert'] VS true_author: ['hamer robert']
# movie_id: 1655
# true director: Alexandre O. Philippe
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.047369956970214844
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015077590942382812
# Discarted candidate: []
# Possible candidate: [{'alexandre o philippe': 2, 'alexandre philippe': 1}]
# lengthNecessary: 1.0499999999999998
# [{'alexandre o philippe': 2, 'alexandre philippe': 1}]
# acceptance_diff 5
# ['alexandre o philippe'] VS true_author: ['alexandre o philippe']
# movie_id: 69693
# true director: Brad Bird
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07612109184265137
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0028181076049804688
# Discarted candidate: []
# Possible candidate: [{'bird brad': 28, 'jan pinkava': 12}]
# lengthNecessary: 14.0
# [{'bird brad': 28, 'jan pinkava': 12}]
# acceptance_diff 5
# ['bird brad'] VS true_author: ['bird brad']
# movie_id: 89575
# true director: Vincent Sherman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04495573043823242
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013229846954345703
# Discarted candidate: []
# Possible candidate: [{'aldrich robert': 2, 'sherman vincent': 7}]
# lengthNecessary: 3.15
# [{'aldrich robert': 2, 'sherman vincent': 7}]
# acceptance_diff 5
# ['aldrich robert', 'sherman vincent'] VS true_author: ['sherman vincent']
# movie_id: 5900
# true director: Fraser C. Heston
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0461268424987793
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012822151184082031
# Discarted candidate: []
# Possible candidate: [{'c fraser heston': 2, 'clarke fraser heston': 7}]
# lengthNecessary: 3.15
# [{'c fraser heston': 2, 'clarke fraser heston': 7}]
# acceptance_diff 5
# ['c fraser heston'] VS true_author: ['c fraser heston']
# movie_id: 105551
# true director: John Landis;Steven Spielberg;Joe Dante;George Miller
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.13675689697265625
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.007464885711669922
# Discarted candidate: []
# Possible candidate: [{'dante joe': 15, 'george miller': 15, 'john landis': 19, 'spielberg steven': 22}]
# lengthNecessary: 24.849999999999998
# [{'dante joe': 15, 'george miller': 15, 'john landis': 19, 'spielberg steven': 22}]
# acceptance_diff 5
# ['john landis', 'spielberg steven'] VS true_author: ['dante joe', 'george miller', 'spielberg steven', 'john landis']
# movie_id: 61521
# true director: Godfrey Ho
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03783392906188965
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014278888702392578
# Discarted candidate: []
# Possible candidate: [{'godfrey ho': 3, 'kim si-hyun': 1}]
# lengthNecessary: 1.4
# [{'godfrey ho': 3, 'kim si-hyun': 1}]
# acceptance_diff 5
# ['godfrey ho', 'kim si-hyun'] VS true_author: ['godfrey ho']
# movie_id: 37376
# true director: Dave Fleischer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04884934425354004
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0034058094024658203
# Discarted candidate: []
# Possible candidate: [{'bowsky willard': 1, 'dave fleischer': 13}]
# lengthNecessary: 4.8999999999999995
# [{'bowsky willard': 1, 'dave fleischer': 13}]
# acceptance_diff 5
# ['dave fleischer'] VS true_author: ['dave fleischer']
# movie_id: 26754
# true director: Martin D'Urville
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0555729866027832
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014731884002685547
# Discarted candidate: []
# Possible candidate: [{"d'urville martin": 11, 'durville martin': 2}]
# lengthNecessary: 4.55
# [{"d'urville martin": 11, 'durville martin': 2}]
# acceptance_diff 5
# ["d'urville martin"] VS true_author: ["d'urville martin"]
# movie_id: 97745
# true director: Norton Virgien;Igor Kovalyov
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07378292083740234
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0031609535217285156
# Discarted candidate: []
# Possible candidate: [{'igor kovalyov': 15, 'norton virgien': 16}]
# lengthNecessary: 10.85
# [{'igor kovalyov': 15, 'norton virgien': 16}]
# acceptance_diff 5
# ['igor kovalyov', 'norton virgien'] VS true_author: ['norton virgien', 'igor kovalyov']
# movie_id: 58040
# true director: Thomas Bezucha
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08707189559936523
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001981973648071289
# Discarted candidate: []
# Possible candidate: [{'bezucha thomas': 20, 'bezucha tom': 3}]
# lengthNecessary: 8.049999999999999
# [{'bezucha thomas': 20, 'bezucha tom': 3}]
# acceptance_diff 5
# ['bezucha thomas'] VS true_author: ['bezucha thomas']
# movie_id: 11447
# true director: Michael Galinsky;Suki Hawley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0534520149230957
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011131763458251953
# Discarted candidate: []
# Possible candidate: [{'galinsky michael': 4, 'hawley suki': 6}]
# lengthNecessary: 3.5
# [{'galinsky michael': 4, 'hawley suki': 6}]
# acceptance_diff 5
# ['galinsky michael', 'hawley suki'] VS true_author: ['galinsky michael', 'hawley suki']
# movie_id: 92995
# true director: Chatrichalerm Yukol
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.022593021392822266
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.00185394287109375
# Discarted candidate: []
# Possible candidate: [{'chatrichalerm yukoi': 2, 'chatrichalerm yukol': 2}]
# lengthNecessary: 1.4
# [{'chatrichalerm yukoi': 2, 'chatrichalerm yukol': 2}]
# acceptance_diff 5
# ['chatrichalerm yukoi'] VS true_author: ['chatrichalerm yukol']
# movie_id: 45317
# true director: Richard Talmadge;Harvey Parry
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.050299882888793945
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002582073211669922
# Discarted candidate: []
# Possible candidate: [{'harvey parry': 3, 'richard talmadge': 1}]
# lengthNecessary: 1.4
# [{'harvey parry': 3, 'richard talmadge': 1}]
# acceptance_diff 5
# ['harvey parry', 'richard talmadge'] VS true_author: ['richard talmadge', 'harvey parry']
# movie_id: 57325
# true director: Keiichi Hara
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06515192985534668
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0020499229431152344
# Discarted candidate: []
# Possible candidate: [{'hara keiichi': 11, 'michael sinterniklaas': 6, 'sheh stephanie': 6}]
# lengthNecessary: 8.049999999999999
# [{'hara keiichi': 11, 'michael sinterniklaas': 6, 'sheh stephanie': 6}]
# acceptance_diff 5
# ['hara keiichi', 'michael sinterniklaas', 'sheh stephanie'] VS true_author: ['hara keiichi']
# movie_id: 96819
# true director: Yves Allegret
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03575587272644043
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0034601688385009766
# Discarted candidate: []
# Possible candidate: [{'allegret yves': 2, 'e portas rafael': 1}]
# lengthNecessary: 1.0499999999999998
# [{'allegret yves': 2, 'e portas rafael': 1}]
# acceptance_diff 5
# ['allegret yves', 'e portas rafael'] VS true_author: ['allegret yves']
# movie_id: 24035
# true director: William Tannen;Larry Cohen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09779191017150879
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011298656463623047
# Discarted candidate: []
# Possible candidate: [{'cohen larry': 6, 'tannen william': 4}]
# lengthNecessary: 3.5
# [{'cohen larry': 6, 'tannen william': 4}]
# acceptance_diff 5
# ['cohen larry', 'tannen william'] VS true_author: ['cohen larry', 'tannen william']
# movie_id: 5820
# true director: Ananth Narayan Mahadevan
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0565488338470459
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016949176788330078
# Discarted candidate: []
# Possible candidate: [{'anant mahadevan': 1, 'ananth mahadevan narayan': 3}]
# lengthNecessary: 1.4
# [{'anant mahadevan': 1, 'ananth mahadevan narayan': 3}]
# acceptance_diff 5
# ['anant mahadevan', 'ananth mahadevan narayan'] VS true_author: ['ananth mahadevan narayan']
# movie_id: 14372
# true director: Joel Coen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0646200180053711
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.00357818603515625
# Discarted candidate: []
# Possible candidate: [{'coen ethan': 7, 'coen joel': 13}]
# lengthNecessary: 7.0
# [{'coen ethan': 7, 'coen joel': 13}]
# acceptance_diff 5
# ['coen joel'] VS true_author: ['coen joel']
# movie_id: 2550
# true director: Jean-Luc Godard
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.040506839752197266
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009529590606689453
# Discarted candidate: []
# Possible candidate: [{'dziga groupe vertov': 1, 'godard jean-luc': 3}]
# lengthNecessary: 1.4
# [{'dziga groupe vertov': 1, 'godard jean-luc': 3}]
# acceptance_diff 5
# ['dziga groupe vertov', 'godard jean-luc'] VS true_author: ['godard jean-luc']
# movie_id: 8413
# true director: Adam Small;Peter Stuart
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.054717302322387695
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015869140625
# Discarted candidate: []
# Possible candidate: [{'adam small': 9, 'peter stuart': 7}]
# lengthNecessary: 5.6
# [{'adam small': 9, 'peter stuart': 7}]
# acceptance_diff 5
# ['adam small', 'peter stuart'] VS true_author: ['adam small', 'peter stuart']
# movie_id: 93760
# true director: Caradog W. James
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02706003189086914
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011010169982910156
# Discarted candidate: []
# Possible candidate: [{'caradog james': 3, 'caradog james w': 1}]
# lengthNecessary: 1.4
# [{'caradog james': 3, 'caradog james w': 1}]
# acceptance_diff 5
# ['caradog james'] VS true_author: ['caradog james w']
# movie_id: 93024
# true director: Phil Lord;Christopher Miller
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08887791633605957
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004309892654418945
# Discarted candidate: []
# Possible candidate: [{'chris mckay': 2, 'chris miller': 8, 'christopher miller': 15, 'lord phil': 28}]
# lengthNecessary: 18.549999999999997
# [{'chris mckay': 2, 'chris miller': 8, 'christopher miller': 15, 'lord phil': 28}]
# acceptance_diff 5
# ['lord phil'] VS true_author: ['lord phil', 'christopher miller']
# movie_id: 63252
# true director: Gabriele Del Grande;Khaled Soliman Al Nassiry;Antonio Augugliaro
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04550504684448242
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.000993967056274414
# Discarted candidate: []
# Possible candidate: [{'al khaled nassiry soliman': 1, 'antonio augugliaro': 2, 'del gabriele grande': 1}]
# lengthNecessary: 1.4
# [{'al khaled nassiry soliman': 1, 'antonio augugliaro': 2, 'del gabriele grande': 1}]
# acceptance_diff 5
# ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande'] VS true_author: ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande']
# movie_id: 76340
# true director: Prince
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06438398361206055
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012450218200683594
# Discarted candidate: []
# Possible candidate: [{'albert magnoli': 3, 'prince': 6}]
# lengthNecessary: 3.15
# [{'albert magnoli': 3, 'prince': 6}]
# acceptance_diff 5
# ['albert magnoli', 'prince'] VS true_author: ['prince']
# movie_id: 21613
# true director: Andrzej Bartkowiak
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.11297202110290527
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.003718137741088867
# Discarted candidate: []
# Possible candidate: [{'andrzej bartkowiak': 19, 'andrzek bartkowiak': 1}]
# lengthNecessary: 7.0
# [{'andrzej bartkowiak': 19, 'andrzek bartkowiak': 1}]
# acceptance_diff 5
# ['andrzej bartkowiak'] VS true_author: ['andrzej bartkowiak']
# movie_id: 80167
# true director: Sandra Martin;Hugues Martin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.12976503372192383
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.010357141494750977
# Discarted candidate: []
# Possible candidate: [{'hugues martin': 4, 'martin sandra': 2}]
# lengthNecessary: 2.0999999999999996
# [{'hugues martin': 4, 'martin sandra': 2}]
# acceptance_diff 5
# ['hugues martin', 'martin sandra'] VS true_author: ['martin sandra', 'hugues martin']
# movie_id: 82271
# true director: Marvin J. Chomsky
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.16519403457641602
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004528045654296875
# Discarted candidate: []
# Possible candidate: [{'chomsky j marvin': 17, 'chomsky marvin': 1}]
# lengthNecessary: 6.3
# [{'chomsky j marvin': 17, 'chomsky marvin': 1}]
# acceptance_diff 5
# ['chomsky j marvin'] VS true_author: ['chomsky j marvin']
# movie_id: 7494
# true director: Tommy O'Haver
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09777092933654785
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0026438236236572266
# Discarted candidate: []
# Possible candidate: [{"o'haver tommy": 7, 'ohaver tommy': 3}]
# lengthNecessary: 3.5
# [{"o'haver tommy": 7, 'ohaver tommy': 3}]
# acceptance_diff 5
# ["o'haver tommy"] VS true_author: ["o'haver tommy"]
# movie_id: 16640
# true director: Timothy Marrinan;Richard Dewey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.055384159088134766
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004470109939575195
# Discarted candidate: []
# Possible candidate: [{'dewey richard': 1, 'marrinan timothy': 2}]
# lengthNecessary: 1.0499999999999998
# [{'dewey richard': 1, 'marrinan timothy': 2}]
# acceptance_diff 5
# ['dewey richard', 'marrinan timothy'] VS true_author: ['dewey richard', 'marrinan timothy']
# movie_id: 101119
# true director: Chris Hegedus;D. A. Pennebaker
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09228897094726562
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004415035247802734
# Discarted candidate: []
# Possible candidate: [{'a d pennebaker': 9, 'chris hegedus': 7}]
# lengthNecessary: 5.6
# [{'a d pennebaker': 9, 'chris hegedus': 7}]
# acceptance_diff 5
# ['a d pennebaker', 'chris hegedus'] VS true_author: ['chris hegedus', 'a d pennebaker']
# movie_id: 17046
# true director: Paolo Taviani;Vittorio Taviani
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05399608612060547
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014967918395996094
# Discarted candidate: []
# Possible candidate: [{'paolo taviani': 4, 'taviani vittorio': 2}]
# lengthNecessary: 2.0999999999999996
# [{'paolo taviani': 4, 'taviani vittorio': 2}]
# acceptance_diff 5
# ['paolo taviani', 'taviani vittorio'] VS true_author: ['paolo taviani', 'taviani vittorio']
# movie_id: 80539
# true director: Karan Johar
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05810403823852539
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012531280517578125
# Discarted candidate: []
# Possible candidate: [{'abhishek varman': 2, 'johar karan': 10}]
# lengthNecessary: 4.199999999999999
# [{'abhishek varman': 2, 'johar karan': 10}]
# acceptance_diff 5
# ['johar karan'] VS true_author: ['johar karan']
# movie_id: 111871
# true director: Anlo Sepulveda;Paul Collins
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03990602493286133
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001753091812133789
# Discarted candidate: []
# Possible candidate: [{'anlo sepulveda': 3, 'collins paul': 2}]
# lengthNecessary: 1.75
# [{'anlo sepulveda': 3, 'collins paul': 2}]
# acceptance_diff 5
# ['anlo sepulveda', 'collins paul'] VS true_author: ['anlo sepulveda', 'collins paul']
# movie_id: 31082
# true director: Slatan Dudow;Kurt Maetzig
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05423998832702637
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0027430057525634766
# Discarted candidate: []
# Possible candidate: [{'dudow slatan': 2, 'groschopp richard': 1, 'kurt maetzig': 1}]
# lengthNecessary: 1.4
# [{'dudow slatan': 2, 'groschopp richard': 1, 'kurt maetzig': 1}]
# acceptance_diff 5
# ['dudow slatan', 'groschopp richard', 'kurt maetzig'] VS true_author: ['dudow slatan', 'kurt maetzig']
# movie_id: 2672
# true director: Christian Krones;Olaf S. Muller;Roland Schrotthofer;Florian Weigensamer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08611893653869629
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012249946594238281
# Discarted candidate: []
# Possible candidate: [{'christian krones': 1, 'florian weigensamer': 2, 'muller olaf s': 1, 'roland schrotthofer': 1}]
# lengthNecessary: 1.75
# [{'christian krones': 1, 'florian weigensamer': 2, 'muller olaf s': 1, 'roland schrotthofer': 1}]
# acceptance_diff 5
# ['christian krones', 'florian weigensamer', 'muller olaf s', 'roland schrotthofer'] VS true_author: ['muller olaf s', 'roland schrotthofer', 'florian weigensamer', 'christian krones']
# movie_id: 91427
# true director: Robert Rossen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07655215263366699
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013632774353027344
# Discarted candidate: []
# Possible candidate: [{'blue washington': 1, 'robert rossen': 9}]
# lengthNecessary: 3.5
# [{'blue washington': 1, 'robert rossen': 9}]
# acceptance_diff 5
# ['robert rossen'] VS true_author: ['robert rossen']
# movie_id: 2813
# true director: Michael Tiddes
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07039213180541992
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0029609203338623047
# Discarted candidate: []
# Possible candidate: [{'michael tiddes': 11, 'mike tiddes': 2}]
# lengthNecessary: 4.55
# [{'michael tiddes': 11, 'mike tiddes': 2}]
# acceptance_diff 5
# ['michael tiddes'] VS true_author: ['michael tiddes']
# movie_id: 15123
# true director: Jon Bulette;Stone Roberts
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03972506523132324
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0019960403442382812
# Discarted candidate: []
# Possible candidate: [{'bulette jon': 3, 'f roberts stone': 1, 'roberts stone': 1}]
# lengthNecessary: 1.75
# [{'bulette jon': 3, 'f roberts stone': 1, 'roberts stone': 1}]
# acceptance_diff 5
# ['bulette jon', 'f roberts stone'] VS true_author: ['bulette jon', 'roberts stone']
# movie_id: 30280
# true director: Anthony Stabley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05452394485473633
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012111663818359375
# Discarted candidate: []
# Possible candidate: [{'anthony r stabley': 3, 'anthony stabley': 8}]
# lengthNecessary: 3.8499999999999996
# [{'anthony r stabley': 3, 'anthony stabley': 8}]
# acceptance_diff 5
# ['anthony r stabley'] VS true_author: ['anthony stabley']
# movie_id: 68652
# true director: Adam Kassen;Mark Kassen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07253575325012207
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014200210571289062
# Discarted candidate: []
# Possible candidate: [{'adam kassen': 8, 'kassen mark': 9}]
# lengthNecessary: 5.949999999999999
# [{'adam kassen': 8, 'kassen mark': 9}]
# acceptance_diff 5
# ['adam kassen', 'kassen mark'] VS true_author: ['kassen mark', 'adam kassen']
# movie_id: 21609
# true director: Rowby Goren;Chuck Staley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07442688941955566
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012407302856445312
# Discarted candidate: []
# Possible candidate: [{'chuck staley': 3, 'goren rowby': 6}]
# lengthNecessary: 3.15
# [{'chuck staley': 3, 'goren rowby': 6}]
# acceptance_diff 5
# ['chuck staley', 'goren rowby'] VS true_author: ['chuck staley', 'goren rowby']
# movie_id: 37872
# true director: Michael Almereyda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06686210632324219
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002535104751586914
# Discarted candidate: []
# Possible candidate: [{'almereyda michael': 5, 'campbell scott': 1}]
# lengthNecessary: 2.0999999999999996
# [{'almereyda michael': 5, 'campbell scott': 1}]
# acceptance_diff 5
# ['almereyda michael', 'campbell scott'] VS true_author: ['almereyda michael']
# movie_id: 45447
# true director: Fred C. Brannon;Thomas Carr
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07574129104614258
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002418041229248047
# Discarted candidate: []
# Possible candidate: [{'brannon c fred': 6, 'carr thomas': 3}]
# lengthNecessary: 3.15
# [{'brannon c fred': 6, 'carr thomas': 3}]
# acceptance_diff 5
# ['brannon c fred', 'carr thomas'] VS true_author: ['carr thomas', 'brannon c fred']
# movie_id: 24661
# true director: Matthew Celestre;Brett Celestre
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04883694648742676
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015349388122558594
# Discarted candidate: []
# Possible candidate: [{'brett celestre': 1, 'brette celestre': 2, 'celestre matthew': 1}]
# lengthNecessary: 1.4
# [{'brett celestre': 1, 'brette celestre': 2, 'celestre matthew': 1}]
# acceptance_diff 5
# ['brett celestre', 'celestre matthew'] VS true_author: ['brett celestre', 'celestre matthew']
# movie_id: 3648
# true director: Nikolaj Arcel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04453468322753906
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014157295227050781
# Discarted candidate: []
# Possible candidate: [{'arcel nikaolaj': 2, 'arcel nikolaj': 14}]
# lengthNecessary: 5.6
# [{'arcel nikaolaj': 2, 'arcel nikolaj': 14}]
# acceptance_diff 5
# ['arcel nikolaj'] VS true_author: ['arcel nikolaj']
# movie_id: 13479
# true director: Ergin Orbey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.038008928298950195
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013399124145507812
# Discarted candidate: []
# Possible candidate: [{'engin orbey': 8, 'ergin orbey': 1}]
# lengthNecessary: 3.15
# [{'engin orbey': 8, 'ergin orbey': 1}]
# acceptance_diff 5
# ['engin orbey'] VS true_author: ['ergin orbey']
# movie_id: 18319
# true director: Baird Bryant;Johanna Demetrakas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05233287811279297
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016069412231445312
# Discarted candidate: []
# Possible candidate: [{'baird bryant': 8, 'demetrakas johanna': 5}]
# lengthNecessary: 4.55
# [{'baird bryant': 8, 'demetrakas johanna': 5}]
# acceptance_diff 5
# ['baird bryant', 'demetrakas johanna'] VS true_author: ['baird bryant', 'demetrakas johanna']
# movie_id: 44223
# true director: Gene Kelly
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0438380241394043
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016129016876220703
# Discarted candidate: []
# Possible candidate: [{'freddie young': 1, 'gene kelly': 8}]
# lengthNecessary: 3.15
# [{'freddie young': 1, 'gene kelly': 8}]
# acceptance_diff 5
# ['gene kelly'] VS true_author: ['gene kelly']
# movie_id: 71075
# true director: David Twohy
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06842589378356934
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0018188953399658203
# Discarted candidate: []
# Possible candidate: [{'david n twohy': 1, 'david twohy': 24}]
# lengthNecessary: 8.75
# [{'david n twohy': 1, 'david twohy': 24}]
# acceptance_diff 5
# ['david twohy'] VS true_author: ['david twohy']
# movie_id: 80410
# true director: Paul Ragsdale
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.050789833068847656
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002146005630493164
# Discarted candidate: []
# Possible candidate: [{'alba angelica de': 3, 'paul ragsdale': 6}]
# lengthNecessary: 3.15
# [{'alba angelica de': 3, 'paul ragsdale': 6}]
# acceptance_diff 5
# ['alba angelica de', 'paul ragsdale'] VS true_author: ['paul ragsdale']
# movie_id: 71705
# true director: Allan Arkush
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05204200744628906
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014412403106689453
# Discarted candidate: []
# Possible candidate: [{'allan arkush': 13, 'dante joe': 6}]
# lengthNecessary: 6.6499999999999995
# [{'allan arkush': 13, 'dante joe': 6}]
# acceptance_diff 5
# ['allan arkush'] VS true_author: ['allan arkush']
# movie_id: 91114
# true director: Tian Zhuangzhuang
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.030341148376464844
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009429454803466797
# Discarted candidate: []
# Possible candidate: [{'pan peicheng': 3, 'tian zhuangzhuang': 3}]
# lengthNecessary: 2.0999999999999996
# [{'pan peicheng': 3, 'tian zhuangzhuang': 3}]
# acceptance_diff 5
# ['pan peicheng', 'tian zhuangzhuang'] VS true_author: ['tian zhuangzhuang']
# movie_id: 100574
# true director: Michael Hegner;Karsten Kiilerich
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03284287452697754
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009877681732177734
# Discarted candidate: []
# Possible candidate: [{'hegner michael': 6, 'karsten kiilerich': 4}]
# lengthNecessary: 3.5
# [{'hegner michael': 6, 'karsten kiilerich': 4}]
# acceptance_diff 5
# ['hegner michael', 'karsten kiilerich'] VS true_author: ['hegner michael', 'karsten kiilerich']
# movie_id: 22475
# true director: Kevin King
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.048338890075683594
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0019321441650390625
# Discarted candidate: []
# Possible candidate: [{'k king': 6, 'kevin king': 3}]
# lengthNecessary: 3.15
# [{'k king': 6, 'kevin king': 3}]
# acceptance_diff 5
# ['k king', 'kevin king'] VS true_author: ['kevin king']
# movie_id: 57809
# true director: John Lamb
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04252004623413086
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0008780956268310547
# Discarted candidate: []
# Possible candidate: [{'hill jack': 2, 'john lamb': 1}]
# lengthNecessary: 1.0499999999999998
# [{'hill jack': 2, 'john lamb': 1}]
# acceptance_diff 5
# ['hill jack', 'john lamb'] VS true_author: ['john lamb']
# movie_id: 97278
# true director: Norman Panama;Melvin Frank
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04081892967224121
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0020599365234375
# Discarted candidate: []
# Possible candidate: [{'frank melvin': 4, 'norman panama': 3}]
# lengthNecessary: 2.4499999999999997
# [{'frank melvin': 4, 'norman panama': 3}]
# acceptance_diff 5
# ['frank melvin', 'norman panama'] VS true_author: ['norman panama', 'frank melvin']
# movie_id: 106242
# true director: Gionata Zarantonello
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.026978731155395508
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0008950233459472656
# Discarted candidate: []
# Possible candidate: [{'gionata zarantonello': 1, 'jonathan zarantonello': 1}]
# lengthNecessary: 0.7
# [{'gionata zarantonello': 1, 'jonathan zarantonello': 1}]
# acceptance_diff 5
# ['gionata zarantonello'] VS true_author: ['gionata zarantonello']
# movie_id: 81911
# true director: Kang Je-Gyu
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05745720863342285
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014641284942626953
# Discarted candidate: []
# Possible candidate: [{'gyu je kang': 1, 'je-gyu kang': 13, 'je-kyu kang': 7}]
# lengthNecessary: 7.35
# [{'gyu je kang': 1, 'je-gyu kang': 13, 'je-kyu kang': 7}]
# acceptance_diff 5
# ['je-gyu kang'] VS true_author: ['je-gyu kang']
# movie_id: 87781
# true director: Alistair Legrand
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06477212905883789
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012969970703125
# Discarted candidate: []
# Possible candidate: [{'alistair legrand': 16, 'callaway ryan': 1}]
# lengthNecessary: 5.949999999999999
# [{'alistair legrand': 16, 'callaway ryan': 1}]
# acceptance_diff 5
# ['alistair legrand'] VS true_author: ['alistair legrand']
# movie_id: 49079
# true director: Fernando Palacios
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05944991111755371
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009610652923583984
# Discarted candidate: []
# Possible candidate: [{'fernando palacios': 2, 'j rafael salvia': 3}]
# lengthNecessary: 1.75
# [{'fernando palacios': 2, 'j rafael salvia': 3}]
# acceptance_diff 5
# ['fernando palacios', 'j rafael salvia'] VS true_author: ['fernando palacios']
# movie_id: 43271
# true director: R. Kiplin Pastor
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.034139156341552734
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010690689086914062
# Discarted candidate: []
# Possible candidate: [{'kip pastor': 3, 'kiplin pastor r': 1}]
# lengthNecessary: 1.4
# [{'kip pastor': 3, 'kiplin pastor r': 1}]
# acceptance_diff 5
# ['kip pastor', 'kiplin pastor r'] VS true_author: ['kiplin pastor r']
# movie_id: 43726
# true director: Quentin Tarantino
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06858229637145996
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002584695816040039
# Discarted candidate: []
# Possible candidate: [{'eli roth': 12, 'quentin tarantino': 27}]
# lengthNecessary: 13.649999999999999
# [{'eli roth': 12, 'quentin tarantino': 27}]
# acceptance_diff 5
# ['quentin tarantino'] VS true_author: ['quentin tarantino']
# movie_id: 28418
# true director: Sharunas Bartas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.01589179039001465
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0007178783416748047
# Discarted candidate: []
# Possible candidate: [{'bartas sar?nas': 1, 'bartas sharunas': 1}]
# lengthNecessary: 0.7
# [{'bartas sar?nas': 1, 'bartas sharunas': 1}]
# acceptance_diff 5
# ['bartas sar?nas'] VS true_author: ['bartas sharunas']
# movie_id: 111254
# true director: Luke Jaden;Cort Johns
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05296516418457031
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015742778778076172
# Discarted candidate: []
# Possible candidate: [{'cort johns': 2, 'jaden luke': 4}]
# lengthNecessary: 2.0999999999999996
# [{'cort johns': 2, 'jaden luke': 4}]
# acceptance_diff 5
# ['cort johns', 'jaden luke'] VS true_author: ['cort johns', 'jaden luke']
# movie_id: 69205
# true director: Nancy Glass;Michele Loschiavo
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.050868988037109375
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001215219497680664
# Discarted candidate: []
# Possible candidate: [{'glass nancy': 2, 'loschiavo michele': 1}]
# lengthNecessary: 1.0499999999999998
# [{'glass nancy': 2, 'loschiavo michele': 1}]
# acceptance_diff 5
# ['glass nancy', 'loschiavo michele'] VS true_author: ['loschiavo michele', 'glass nancy']
# movie_id: 40048
# true director: Manuel Gonzalez Mauricio;Saul Barreto Ramos
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04860186576843262
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009300708770751953
# Discarted candidate: []
# Possible candidate: [{'barreto ramos saul': 1, 'gonzalez manuel mauricio': 2}]
# lengthNecessary: 1.0499999999999998
# [{'barreto ramos saul': 1, 'gonzalez manuel mauricio': 2}]
# acceptance_diff 5
# ['barreto ramos saul', 'gonzalez manuel mauricio'] VS true_author: ['gonzalez manuel mauricio', 'barreto ramos saul']
# movie_id: 57896
# true director: Andrew V. McLaglen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03785133361816406
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010569095611572266
# Discarted candidate: []
# Possible candidate: [{'andrew mclaglen': 2, 'andrew mclaglen v': 6}]
# lengthNecessary: 2.8
# [{'andrew mclaglen': 2, 'andrew mclaglen v': 6}]
# acceptance_diff 5
# ['andrew mclaglen'] VS true_author: ['andrew mclaglen v']
# movie_id: 32707
# true director: Paul Morrissey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03446078300476074
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013971328735351562
# Discarted candidate: []
# Possible candidate: [{'antonio margheriti': 2, 'morrissey paul': 6}]
# lengthNecessary: 2.8
# [{'antonio margheriti': 2, 'morrissey paul': 6}]
# acceptance_diff 5
# ['antonio margheriti', 'morrissey paul'] VS true_author: ['morrissey paul']
# movie_id: 80601
# true director: Frank Capra
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04395699501037598
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011241436004638672
# Discarted candidate: []
# Possible candidate: [{'capra frank': 5, 'irvin willat': 3}]
# lengthNecessary: 2.8
# [{'capra frank': 5, 'irvin willat': 3}]
# acceptance_diff 5
# ['capra frank', 'irvin willat'] VS true_author: ['capra frank']
# movie_id: 109103
# true director: Dick Zondag;Ralph Zondag;Phil Nibbelink;Simon Wells
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07761478424072266
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0035338401794433594
# Discarted candidate: []
# Possible candidate: [{'dick zondag': 12, 'nibbelink phil': 14, 'ralph zondag': 12, 'simon wells': 12}]
# lengthNecessary: 17.5
# [{'dick zondag': 12, 'nibbelink phil': 14, 'ralph zondag': 12, 'simon wells': 12}]
# acceptance_diff 5
# ['dick zondag', 'nibbelink phil', 'ralph zondag', 'simon wells'] VS true_author: ['dick zondag', 'simon wells', 'ralph zondag', 'nibbelink phil']
# movie_id: 76115
# true director: Adam Friedman;Iain Kennedy
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03846120834350586
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014271736145019531
# Discarted candidate: []
# Possible candidate: [{'adam friedman': 7, 'iain kennedy': 5}]
# lengthNecessary: 4.199999999999999
# [{'adam friedman': 7, 'iain kennedy': 5}]
# acceptance_diff 5
# ['adam friedman', 'iain kennedy'] VS true_author: ['iain kennedy', 'adam friedman']
# movie_id: 60263
# true director: Bill Guttentag;Dan Sturman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03537774085998535
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002047300338745117
# Discarted candidate: []
# Possible candidate: [{'bill guttentag': 14, 'dan sturman': 9}]
# lengthNecessary: 8.049999999999999
# [{'bill guttentag': 14, 'dan sturman': 9}]
# acceptance_diff 5
# ['bill guttentag', 'dan sturman'] VS true_author: ['bill guttentag', 'dan sturman']
# movie_id: 35119
# true director: Cynthia Wade;Cheryl Miller Houser
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04777789115905762
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002148151397705078
# Discarted candidate: []
# Possible candidate: [{'cheryl houser': 1, 'cheryl houser miller': 4, 'cynthia wade': 6}]
# lengthNecessary: 3.8499999999999996
# [{'cheryl houser': 1, 'cheryl houser miller': 4, 'cynthia wade': 6}]
# acceptance_diff 5
# ['cheryl houser', 'cheryl houser miller', 'cynthia wade'] VS true_author: ['cynthia wade', 'cheryl houser miller']
# movie_id: 97251
# true director: Michael Dudok De Wit
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.045719146728515625
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001194000244140625
# Discarted candidate: []
# Possible candidate: [{'de dudok michael wit': 3, 'dewit dudok michael': 1}]
# lengthNecessary: 1.4
# [{'de dudok michael wit': 3, 'dewit dudok michael': 1}]
# acceptance_diff 5
# ['de dudok michael wit'] VS true_author: ['de dudok michael wit']
# movie_id: 90003
# true director: Charles Chaplin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04645705223083496
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014569759368896484
# Discarted candidate: []
# Possible candidate: [{'chaplin charles': 13, 'chaplin charlie': 6}]
# lengthNecessary: 6.6499999999999995
# [{'chaplin charles': 13, 'chaplin charlie': 6}]
# acceptance_diff 5
# ['chaplin charles'] VS true_author: ['chaplin charles']
# movie_id: 91535
# true director: J. A. Bayona
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05432605743408203
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.00156402587890625
# Discarted candidate: []
# Possible candidate: [{'a bayona j': 7, 'antonio bayona juan': 15}]
# lengthNecessary: 7.699999999999999
# [{'a bayona j': 7, 'antonio bayona juan': 15}]
# acceptance_diff 5
# ['antonio bayona juan'] VS true_author: ['a bayona j']
# movie_id: 51346
# true director: William A. Seiter
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03118896484375
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009458065032958984
# Discarted candidate: []
# Possible candidate: [{'a seiter william': 2, 'seiter william': 1}]
# lengthNecessary: 1.0499999999999998
# [{'a seiter william': 2, 'seiter william': 1}]
# acceptance_diff 5
# ['a seiter william'] VS true_author: ['a seiter william']
# movie_id: 64713
# true director: Alan Mak;Felix Chong
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04950308799743652
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001432657241821289
# Discarted candidate: []
# Possible candidate: [{'alan mak': 5, 'chong felix': 8}]
# lengthNecessary: 4.55
# [{'alan mak': 5, 'chong felix': 8}]
# acceptance_diff 5
# ['alan mak', 'chong felix'] VS true_author: ['alan mak', 'chong felix']
# movie_id: 87307
# true director: Florian Cossen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.021664857864379883
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0006301403045654297
# Discarted candidate: []
# Possible candidate: [{'cossen florian': 1, 'cossen florian micoud': 1}]
# lengthNecessary: 0.7
# [{'cossen florian': 1, 'cossen florian micoud': 1}]
# acceptance_diff 5
# ['cossen florian', 'cossen florian micoud'] VS true_author: ['cossen florian']
# movie_id: 89712
# true director: Mauro Borrelli
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.023727893829345703
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001051187515258789
# Discarted candidate: []
# Possible candidate: [{'borrelli maura': 1, 'borrelli mauro': 2}]
# lengthNecessary: 1.0499999999999998
# [{'borrelli maura': 1, 'borrelli mauro': 2}]
# acceptance_diff 5
# ['borrelli maura'] VS true_author: ['borrelli mauro']
# movie_id: 11264
# true director: Rex Ingram
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03969287872314453
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001135110855102539
# Discarted candidate: []
# Possible candidate: [{'alice terry': 1, 'ingram rex': 2}]
# lengthNecessary: 1.0499999999999998
# [{'alice terry': 1, 'ingram rex': 2}]
# acceptance_diff 5
# ['alice terry', 'ingram rex'] VS true_author: ['ingram rex']
# movie_id: 48608
# true director: John Stevenson;Mark Osborne
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09047102928161621
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004374980926513672
# Discarted candidate: []
# Possible candidate: [{'john stevenson': 25, 'mark osborne': 31}]
# lengthNecessary: 19.599999999999998
# [{'john stevenson': 25, 'mark osborne': 31}]
# acceptance_diff 5
# ['mark osborne'] VS true_author: ['john stevenson', 'mark osborne']
# movie_id: 5451
# true director: Claudio Marques;Marilia Hughes
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04702425003051758
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010058879852294922
# Discarted candidate: []
# Possible candidate: [{'claudio marques': 3, 'guerreiro hughes marilia': 2, 'hughes marilia': 1}]
# lengthNecessary: 2.0999999999999996
# [{'claudio marques': 3, 'guerreiro hughes marilia': 2, 'hughes marilia': 1}]
# acceptance_diff 5
# ['claudio marques', 'guerreiro hughes marilia', 'hughes marilia'] VS true_author: ['claudio marques', 'hughes marilia']
# movie_id: 29810
# true director: Herrmann Zschoche
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.033094167709350586
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014917850494384766
# Discarted candidate: []
# Possible candidate: [{'dressel eleonore': 4, 'herrmann zschoche': 8}]
# lengthNecessary: 4.199999999999999
# [{'dressel eleonore': 4, 'herrmann zschoche': 8}]
# acceptance_diff 5
# ['dressel eleonore', 'herrmann zschoche'] VS true_author: ['herrmann zschoche']
# movie_id: 78918
# true director: Marc Gracie;Tim Ferguson
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03915905952453613
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001043081283569336
# Discarted candidate: []
# Possible candidate: [{'ferguson tim': 5, 'gracie marc': 6}]
# lengthNecessary: 3.8499999999999996
# [{'ferguson tim': 5, 'gracie marc': 6}]
# acceptance_diff 5
# ['ferguson tim', 'gracie marc'] VS true_author: ['gracie marc', 'ferguson tim']
# movie_id: 71440
# true director: Otto Preminger
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# ...
# NUM_CLUSTERS 1
# Blocking time is: 0.0015361309051513672
# Discarted candidate: []
# Possible candidate: [{'l?a pool': 1, 'lea pool': 3}]
# lengthNecessary: 1.4
# [{'l?a pool': 1, 'lea pool': 3}]
# acceptance_diff 5
# ['l?a pool'] VS true_author: ['lea pool']
# movie_id: 69925
# true director: Heidi Maria Faisst
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.050843238830566406
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001146078109741211
# Discarted candidate: []
# Possible candidate: [{'faissi heidi maria': 1, 'faisst heidi maria': 1}]
# lengthNecessary: 0.7
# [{'faissi heidi maria': 1, 'faisst heidi maria': 1}]
# acceptance_diff 5
# ['faissi heidi maria'] VS true_author: ['faisst heidi maria']
# movie_id: 47283
# true director: Carl Astrand;Mats Lindberg
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.059737205505371094
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013799667358398438
# Discarted candidate: []
# Possible candidate: [{'astrand carl': 6, 'lindberg mats': 9}]
# lengthNecessary: 5.25
# [{'astrand carl': 6, 'lindberg mats': 9}]
# acceptance_diff 5
# ['astrand carl', 'lindberg mats'] VS true_author: ['astrand carl', 'lindberg mats']
# movie_id: 40393
# true director: Ewing Scott
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.059416770935058594
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016810894012451172
# Discarted candidate: []
# Possible candidate: [{'ewing scott': 8, 'george sherman': 3}]
# lengthNecessary: 3.8499999999999996
# [{'ewing scott': 8, 'george sherman': 3}]
# acceptance_diff 5
# ['ewing scott', 'george sherman'] VS true_author: ['ewing scott']
# movie_id: 35829
# true director: Michael Paul Stephenson
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.13022708892822266
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0027053356170654297
# Discarted candidate: []
# Possible candidate: [{'michael paul stephenson': 6, 'michael stephenson': 2}]
# lengthNecessary: 2.8
# [{'michael paul stephenson': 6, 'michael stephenson': 2}]
# acceptance_diff 5
# ['michael paul stephenson'] VS true_author: ['michael paul stephenson']
# movie_id: 27116
# true director: Neil Marshall
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.10498595237731934
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004578113555908203
# Discarted candidate: []
# Possible candidate: [{'marshall neil': 18, 'universal': 1}]
# lengthNecessary: 6.6499999999999995
# [{'marshall neil': 18, 'universal': 1}]
# acceptance_diff 5
# ['marshall neil'] VS true_author: ['marshall neil']
# movie_id: 49163
# true director: Vicente Aranda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05253005027770996
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011861324310302734
# Discarted candidate: []
# Possible candidate: [{'aranda vicente': 3, 'gomez raul': 2}]
# lengthNecessary: 1.75
# [{'aranda vicente': 3, 'gomez raul': 2}]
# acceptance_diff 5
# ['aranda vicente', 'gomez raul'] VS true_author: ['aranda vicente']
# movie_id: 64814
# true director: R. Balki
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05231904983520508
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002170085906982422
# Discarted candidate: []
# Possible candidate: [{'balki r': 4, 'ricky sandhu': 1}]
# lengthNecessary: 1.75
# [{'balki r': 4, 'ricky sandhu': 1}]
# acceptance_diff 5
# ['balki r', 'ricky sandhu'] VS true_author: ['balki r']
# movie_id: 87155
# true director: Jiri Svoboda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04278826713562012
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0017802715301513672
# Discarted candidate: []
# Possible candidate: [{'ji?i svoboda': 6, 'jiri svoboda': 1}]
# lengthNecessary: 2.4499999999999997
# [{'ji?i svoboda': 6, 'jiri svoboda': 1}]
# acceptance_diff 5
# ['ji?i svoboda'] VS true_author: ['jiri svoboda']
# movie_id: 19545
# true director: Charles Chu;Gavin Kelly
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03203988075256348
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013949871063232422
# Discarted candidate: []
# Possible candidate: [{'charles chu': 1, 'gavin kelly': 2}]
# lengthNecessary: 1.0499999999999998
# [{'charles chu': 1, 'gavin kelly': 2}]
# acceptance_diff 5
# ['charles chu', 'gavin kelly'] VS true_author: ['charles chu', 'gavin kelly']
# movie_id: 46270
# true director: Seung-Hyeon Jin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.034399986267089844
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013539791107177734
# Discarted candidate: []
# Possible candidate: [{'hyeonh jin seung': 2, 'jin seung-hyeon': 2}]
# lengthNecessary: 1.4
# [{'hyeonh jin seung': 2, 'jin seung-hyeon': 2}]
# acceptance_diff 5
# ['hyeonh jin seung', 'jin seung-hyeon'] VS true_author: ['jin seung-hyeon']
# movie_id: 73371
# true director: Andrew Becker;Daniel Mehrer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.030469894409179688
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015759468078613281
# Discarted candidate: []
# Possible candidate: [{'andrew becker': 2, 'daniel mehrer': 1}]
# lengthNecessary: 1.0499999999999998
# [{'andrew becker': 2, 'daniel mehrer': 1}]
# acceptance_diff 5
# ['andrew becker', 'daniel mehrer'] VS true_author: ['daniel mehrer', 'andrew becker']
# movie_id: 61155
# true director: Chan-wook Park
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03299093246459961
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016219615936279297
# Discarted candidate: []
# Possible candidate: [{'chan-kyong park': 5, 'chan-wook park': 6}]
# lengthNecessary: 3.8499999999999996
# [{'chan-kyong park': 5, 'chan-wook park': 6}]
# acceptance_diff 5
# ['chan-kyong park', 'chan-wook park'] VS true_author: ['chan-wook park']
# movie_id: 111258
# true director: Michael Wadleigh
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07373428344726562
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0020248889923095703
# Discarted candidate: []
# Possible candidate: [{'d hancock john': 6, 'hitzig rupert': 4, 'michael wadleigh': 15}]
# lengthNecessary: 8.75
# [{'d hancock john': 6, 'hitzig rupert': 4, 'michael wadleigh': 15}]
# acceptance_diff 5
# ['michael wadleigh'] VS true_author: ['michael wadleigh']
# movie_id: 56502
# true director: Nagisa Oshima
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02846693992614746
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011858940124511719
# Discarted candidate: []
# Possible candidate: [{'?shima nagisa': 2, 'nagisa oshima': 1}]
# lengthNecessary: 1.0499999999999998
# [{'?shima nagisa': 2, 'nagisa oshima': 1}]
# acceptance_diff 5
# ['?shima nagisa', 'nagisa oshima'] VS true_author: ['nagisa oshima']
# movie_id: 63743
# true director: Jeremy Frindel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03140878677368164
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015869140625
# Discarted candidate: []
# Possible candidate: [{'films substratum': 1, 'frindel jeremy': 7}]
# lengthNecessary: 2.8
# [{'films substratum': 1, 'frindel jeremy': 7}]
# acceptance_diff 5
# ['frindel jeremy'] VS true_author: ['frindel jeremy']
# movie_id: 105721
# true director: Georg Maas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03377890586853027
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009732246398925781
# Discarted candidate: []
# Possible candidate: [{'georg maas': 3, 'judith kaufmann': 2}]
# lengthNecessary: 1.75
# [{'georg maas': 3, 'judith kaufmann': 2}]
# acceptance_diff 5
# ['georg maas', 'judith kaufmann'] VS true_author: ['georg maas']
# movie_id: 88941
# true director: Jonah Bekhor;Zach Math
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0489962100982666
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014979839324951172
# Discarted candidate: []
# Possible candidate: [{'bekhor jonah': 10, 'math zach': 9}]
# lengthNecessary: 6.6499999999999995
# [{'bekhor jonah': 10, 'math zach': 9}]
# acceptance_diff 5
# ['bekhor jonah', 'math zach'] VS true_author: ['bekhor jonah', 'math zach']
# movie_id: 61767
# true director: Ryuhei Kitamura
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02983999252319336
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001055002212524414
# Discarted candidate: []
# Possible candidate: [{'kitamura ry?hei': 2, 'kitamura ryuhei': 5}]
# lengthNecessary: 2.4499999999999997
# [{'kitamura ry?hei': 2, 'kitamura ryuhei': 5}]
# acceptance_diff 5
# ['kitamura ry?hei'] VS true_author: ['kitamura ryuhei']
# movie_id: 76373
# true director: Alice O'Fredericks;Jon Iversen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.036071062088012695
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016391277313232422
# Discarted candidate: []
# Possible candidate: [{"alice o'fredericks": 3, 'iversen jon': 2}]
# lengthNecessary: 1.75
# [{"alice o'fredericks": 3, 'iversen jon': 2}]
# acceptance_diff 5
# ["alice o'fredericks", 'iversen jon'] VS true_author: ['iversen jon', "alice o'fredericks"]
# movie_id: 38696
# true director: Sean Carr
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.047618865966796875
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0023300647735595703
# Discarted candidate: []
# Possible candidate: [{'carr sean': 1, 'carrigan sean': 5}]
# lengthNecessary: 2.0999999999999996
# [{'carr sean': 1, 'carrigan sean': 5}]
# acceptance_diff 5
# ['carr sean'] VS true_author: ['carr sean']
# movie_id: 32680
# true director: Raj Nidimoru;Krishna DK
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.057044029235839844
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002961874008178711
# Discarted candidate: []
# Possible candidate: [{'d k krishna': 4, 'dk krishna': 1, 'nidimoru raj': 4}]
# lengthNecessary: 3.15
# [{'d k krishna': 4, 'dk krishna': 1, 'nidimoru raj': 4}]
# acceptance_diff 5
# ['d k krishna', 'nidimoru raj'] VS true_author: ['dk krishna', 'nidimoru raj']
# movie_id: 112475
# true director: Francis Ford Coppola
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08741092681884766
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016040802001953125
# Discarted candidate: []
# Possible candidate: [{'coppola ford francis': 19, 'coppola francis': 1}]
# lengthNecessary: 7.0
# [{'coppola ford francis': 19, 'coppola francis': 1}]
# acceptance_diff 5
# ['coppola ford francis'] VS true_author: ['coppola ford francis']
# movie_id: 105251
# true director: Nic Hill;Scott Glosserman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.039479970932006836
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011510848999023438
# Discarted candidate: []
# Possible candidate: [{'glosserman scott': 2, 'hill nic': 1}]
# lengthNecessary: 1.0499999999999998
# [{'glosserman scott': 2, 'hill nic': 1}]
# acceptance_diff 5
# ['glosserman scott', 'hill nic'] VS true_author: ['hill nic', 'glosserman scott']
# movie_id: 58667
# true director: Chris R. Notarile;Kim Santiago
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04328608512878418
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011529922485351562
# Discarted candidate: []
# Possible candidate: [{'chris notarile r': 4, 'kim santiago': 7}]
# lengthNecessary: 3.8499999999999996
# [{'chris notarile r': 4, 'kim santiago': 7}]
# acceptance_diff 5
# ['chris notarile r', 'kim santiago'] VS true_author: ['kim santiago', 'chris notarile r']
# movie_id: 87533
# true director: Chang Cheh;Pao Hsueh-Li
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04230499267578125
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0017061233520507812
# Discarted candidate: []
# Possible candidate: [{'chang cheh': 8, 'hsueh li pao': 4, 'hsueh-li pao': 2}]
# lengthNecessary: 4.8999999999999995
# [{'chang cheh': 8, 'hsueh li pao': 4, 'hsueh-li pao': 2}]
# acceptance_diff 5
# ['chang cheh', 'hsueh li pao'] VS true_author: ['chang cheh', 'hsueh-li pao']
# movie_id: 92814
# true director: Fritz Lang;Rene Sti
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.034940242767333984
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.00121307373046875
# Discarted candidate: []
# Possible candidate: [{'fritz lang': 6, 'rene sti': 2}]
# lengthNecessary: 2.8
# [{'fritz lang': 6, 'rene sti': 2}]
# acceptance_diff 5
# ['fritz lang', 'rene sti'] VS true_author: ['fritz lang', 'rene sti']
# movie_id: 59689
# true director: Ines Paris;Daniela Fejerman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.040992021560668945
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013689994812011719
# Discarted candidate: []
# Possible candidate: [{'daniela fejerman': 4, 'ines paris': 2}]
# lengthNecessary: 2.0999999999999996
# [{'daniela fejerman': 4, 'ines paris': 2}]
# acceptance_diff 5
# ['daniela fejerman', 'ines paris'] VS true_author: ['ines paris', 'daniela fejerman']
# movie_id: 35985
# true director: Clay Tweel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05188298225402832
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015490055084228516
# Discarted candidate: []
# Possible candidate: [{'clay j tweel': 2, 'clay tweel': 6}]
# lengthNecessary: 2.8
# [{'clay j tweel': 2, 'clay tweel': 6}]
# acceptance_diff 5
# ['clay j tweel'] VS true_author: ['clay tweel']
# movie_id: 31151
# true director: Gaston Ravel;Tony Lekain
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.028890132904052734
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012669563293457031
# Discarted candidate: []
# Possible candidate: [{'gaston ravel': 1, 'lekain tony': 2}]
# lengthNecessary: 1.0499999999999998
# [{'gaston ravel': 1, 'lekain tony': 2}]
# acceptance_diff 5
# ['gaston ravel', 'lekain tony'] VS true_author: ['lekain tony', 'gaston ravel']
# Total time is: 20.549777269363403

# %%
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# TP: 578, FP: 119, FN: 14
# precision is 0.8292682926829268
# recall is 0.9763513513513513
# f1Score is 0.8968192397207138
# (0.8292682926829268, 0.9763513513513513, 0.8968192397207138)

# %%
key_values = {
    'model_type':'bilstm',
    'char_level':False,
    'model_version': 2,
    'rnn_dim':1024,
    'verbose':1,
    'attributes_list': ['newDirector'],
    'embedding_type': 'inferSent',
    'dataset': 'clean_movie',
    'cluster_method': 'hierarchy',
    'num_clusters_rate': 0.01,
    'block_length_thresold': 0.35,
    'acceptance_diff':4,
    'block_weight': 5,
}

# %%
dataset_name, table_group_by_movie_id, list_movie_id, true_directors = load_dataset(key_values)
# Out:
# dataset: clean_movie
# Loading time is: 0.1672508716583252

# %%
start_time = time.time()
finalDirectors, trueDirectors = launchWithoutReductionFusionMovie(table_group_by_movie_id, list_movie_id, true_directors, key_values)
print("Total time is: {0}".format(time.time() - start_time))
# Out:
# movie_id: 73952
# true director: Robert Hamer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09439802169799805
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009961128234863281
# Discarted candidate: []
# Possible candidate: [{'chester e hal': 2, 'cyril frankel': 1, 'hamer robert': 4}]
# lengthNecessary: 2.4499999999999997
# [{'chester e hal': 2, 'cyril frankel': 1, 'hamer robert': 4}]
# acceptance_diff 4
# ['chester e hal', 'cyril frankel', 'hamer robert'] VS true_author: ['hamer robert']
# movie_id: 1655
# true director: Alexandre O. Philippe
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04845905303955078
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001750946044921875
# Discarted candidate: []
# Possible candidate: [{'alexandre o philippe': 2, 'alexandre philippe': 1}]
# lengthNecessary: 1.0499999999999998
# [{'alexandre o philippe': 2, 'alexandre philippe': 1}]
# acceptance_diff 4
# ['alexandre o philippe'] VS true_author: ['alexandre o philippe']
# movie_id: 69693
# true director: Brad Bird
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09082317352294922
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0030536651611328125
# Discarted candidate: []
# Possible candidate: [{'bird brad': 28, 'jan pinkava': 12}]
# lengthNecessary: 14.0
# [{'bird brad': 28, 'jan pinkava': 12}]
# acceptance_diff 4
# ['bird brad'] VS true_author: ['bird brad']
# movie_id: 89575
# true director: Vincent Sherman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.043953895568847656
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011336803436279297
# Discarted candidate: []
# Possible candidate: [{'aldrich robert': 2, 'sherman vincent': 7}]
# lengthNecessary: 3.15
# [{'aldrich robert': 2, 'sherman vincent': 7}]
# acceptance_diff 4
# ['sherman vincent'] VS true_author: ['sherman vincent']
# movie_id: 5900
# true director: Fraser C. Heston
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04465794563293457
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001409769058227539
# Discarted candidate: []
# Possible candidate: [{'c fraser heston': 2, 'clarke fraser heston': 7}]
# lengthNecessary: 3.15
# [{'c fraser heston': 2, 'clarke fraser heston': 7}]
# acceptance_diff 4
# ['clarke fraser heston'] VS true_author: ['c fraser heston']
# movie_id: 105551
# true director: John Landis;Steven Spielberg;Joe Dante;George Miller
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.13661694526672363
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0073223114013671875
# Discarted candidate: []
# Possible candidate: [{'dante joe': 15, 'george miller': 15, 'john landis': 19, 'spielberg steven': 22}]
# lengthNecessary: 24.849999999999998
# [{'dante joe': 15, 'george miller': 15, 'john landis': 19, 'spielberg steven': 22}]
# acceptance_diff 4
# ['john landis', 'spielberg steven'] VS true_author: ['dante joe', 'george miller', 'spielberg steven', 'john landis']
# movie_id: 61521
# true director: Godfrey Ho
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.056208133697509766
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0017018318176269531
# Discarted candidate: []
# Possible candidate: [{'godfrey ho': 3, 'kim si-hyun': 1}]
# lengthNecessary: 1.4
# [{'godfrey ho': 3, 'kim si-hyun': 1}]
# acceptance_diff 4
# ['godfrey ho', 'kim si-hyun'] VS true_author: ['godfrey ho']
# movie_id: 37376
# true director: Dave Fleischer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07181620597839355
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001444101333618164
# Discarted candidate: []
# Possible candidate: [{'bowsky willard': 1, 'dave fleischer': 13}]
# lengthNecessary: 4.8999999999999995
# [{'bowsky willard': 1, 'dave fleischer': 13}]
# acceptance_diff 4
# ['dave fleischer'] VS true_author: ['dave fleischer']
# movie_id: 26754
# true director: Martin D'Urville
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04785799980163574
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.003576993942260742
# Discarted candidate: []
# Possible candidate: [{"d'urville martin": 11, 'durville martin': 2}]
# lengthNecessary: 4.55
# [{"d'urville martin": 11, 'durville martin': 2}]
# acceptance_diff 4
# ["d'urville martin"] VS true_author: ["d'urville martin"]
# movie_id: 97745
# true director: Norton Virgien;Igor Kovalyov
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1209859848022461
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.005277872085571289
# Discarted candidate: []
# Possible candidate: [{'igor kovalyov': 15, 'norton virgien': 16}]
# lengthNecessary: 10.85
# [{'igor kovalyov': 15, 'norton virgien': 16}]
# acceptance_diff 4
# ['igor kovalyov', 'norton virgien'] VS true_author: ['norton virgien', 'igor kovalyov']
# movie_id: 58040
# true director: Thomas Bezucha
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05044102668762207
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015611648559570312
# Discarted candidate: []
# Possible candidate: [{'bezucha thomas': 20, 'bezucha tom': 3}]
# lengthNecessary: 8.049999999999999
# [{'bezucha thomas': 20, 'bezucha tom': 3}]
# acceptance_diff 4
# ['bezucha thomas'] VS true_author: ['bezucha thomas']
# movie_id: 11447
# true director: Michael Galinsky;Suki Hawley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05366110801696777
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013620853424072266
# Discarted candidate: []
# Possible candidate: [{'galinsky michael': 4, 'hawley suki': 6}]
# lengthNecessary: 3.5
# [{'galinsky michael': 4, 'hawley suki': 6}]
# acceptance_diff 4
# ['galinsky michael', 'hawley suki'] VS true_author: ['galinsky michael', 'hawley suki']
# movie_id: 92995
# true director: Chatrichalerm Yukol
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02113795280456543
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0024640560150146484
# Discarted candidate: []
# Possible candidate: [{'chatrichalerm yukoi': 2, 'chatrichalerm yukol': 2}]
# lengthNecessary: 1.4
# [{'chatrichalerm yukoi': 2, 'chatrichalerm yukol': 2}]
# acceptance_diff 4
# ['chatrichalerm yukoi'] VS true_author: ['chatrichalerm yukol']
# movie_id: 45317
# true director: Richard Talmadge;Harvey Parry
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03461289405822754
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009701251983642578
# Discarted candidate: []
# Possible candidate: [{'harvey parry': 3, 'richard talmadge': 1}]
# lengthNecessary: 1.4
# [{'harvey parry': 3, 'richard talmadge': 1}]
# acceptance_diff 4
# ['harvey parry', 'richard talmadge'] VS true_author: ['richard talmadge', 'harvey parry']
# movie_id: 57325
# true director: Keiichi Hara
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06206321716308594
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0026700496673583984
# Discarted candidate: []
# Possible candidate: [{'hara keiichi': 11, 'michael sinterniklaas': 6, 'sheh stephanie': 6}]
# lengthNecessary: 8.049999999999999
# [{'hara keiichi': 11, 'michael sinterniklaas': 6, 'sheh stephanie': 6}]
# acceptance_diff 4
# ['hara keiichi'] VS true_author: ['hara keiichi']
# movie_id: 96819
# true director: Yves Allegret
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06765007972717285
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011799335479736328
# Discarted candidate: []
# Possible candidate: [{'allegret yves': 2, 'e portas rafael': 1}]
# lengthNecessary: 1.0499999999999998
# [{'allegret yves': 2, 'e portas rafael': 1}]
# acceptance_diff 4
# ['allegret yves', 'e portas rafael'] VS true_author: ['allegret yves']
# movie_id: 24035
# true director: William Tannen;Larry Cohen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05853009223937988
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001767873764038086
# Discarted candidate: []
# Possible candidate: [{'cohen larry': 6, 'tannen william': 4}]
# lengthNecessary: 3.5
# [{'cohen larry': 6, 'tannen william': 4}]
# acceptance_diff 4
# ['cohen larry', 'tannen william'] VS true_author: ['cohen larry', 'tannen william']
# movie_id: 5820
# true director: Ananth Narayan Mahadevan
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04114794731140137
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014650821685791016
# Discarted candidate: []
# Possible candidate: [{'anant mahadevan': 1, 'ananth mahadevan narayan': 3}]
# lengthNecessary: 1.4
# [{'anant mahadevan': 1, 'ananth mahadevan narayan': 3}]
# acceptance_diff 4
# ['anant mahadevan', 'ananth mahadevan narayan'] VS true_author: ['ananth mahadevan narayan']
# movie_id: 14372
# true director: Joel Coen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.055190086364746094
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001767873764038086
# Discarted candidate: []
# Possible candidate: [{'coen ethan': 7, 'coen joel': 13}]
# lengthNecessary: 7.0
# [{'coen ethan': 7, 'coen joel': 13}]
# acceptance_diff 4
# ['coen joel'] VS true_author: ['coen joel']
# movie_id: 2550
# true director: Jean-Luc Godard
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03051590919494629
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002009153366088867
# Discarted candidate: []
# Possible candidate: [{'dziga groupe vertov': 1, 'godard jean-luc': 3}]
# lengthNecessary: 1.4
# [{'dziga groupe vertov': 1, 'godard jean-luc': 3}]
# acceptance_diff 4
# ['dziga groupe vertov', 'godard jean-luc'] VS true_author: ['godard jean-luc']
# movie_id: 8413
# true director: Adam Small;Peter Stuart
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05913877487182617
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012280941009521484
# Discarted candidate: []
# Possible candidate: [{'adam small': 9, 'peter stuart': 7}]
# lengthNecessary: 5.6
# [{'adam small': 9, 'peter stuart': 7}]
# acceptance_diff 4
# ['adam small', 'peter stuart'] VS true_author: ['adam small', 'peter stuart']
# movie_id: 93760
# true director: Caradog W. James
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03031134605407715
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.00090789794921875
# Discarted candidate: []
# Possible candidate: [{'caradog james': 3, 'caradog james w': 1}]
# lengthNecessary: 1.4
# [{'caradog james': 3, 'caradog james w': 1}]
# acceptance_diff 4
# ['caradog james'] VS true_author: ['caradog james w']
# movie_id: 93024
# true director: Phil Lord;Christopher Miller
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09304189682006836
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004434823989868164
# Discarted candidate: []
# Possible candidate: [{'chris mckay': 2, 'chris miller': 8, 'christopher miller': 15, 'lord phil': 28}]
# lengthNecessary: 18.549999999999997
# [{'chris mckay': 2, 'chris miller': 8, 'christopher miller': 15, 'lord phil': 28}]
# acceptance_diff 4
# ['lord phil'] VS true_author: ['lord phil', 'christopher miller']
# movie_id: 63252
# true director: Gabriele Del Grande;Khaled Soliman Al Nassiry;Antonio Augugliaro
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05573868751525879
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013151168823242188
# Discarted candidate: []
# Possible candidate: [{'al khaled nassiry soliman': 1, 'antonio augugliaro': 2, 'del gabriele grande': 1}]
# lengthNecessary: 1.4
# [{'al khaled nassiry soliman': 1, 'antonio augugliaro': 2, 'del gabriele grande': 1}]
# acceptance_diff 4
# ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande'] VS true_author: ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande']
# movie_id: 76340
# true director: Prince
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.037069082260131836
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012202262878417969
# Discarted candidate: []
# Possible candidate: [{'albert magnoli': 3, 'prince': 6}]
# lengthNecessary: 3.15
# [{'albert magnoli': 3, 'prince': 6}]
# acceptance_diff 4
# ['albert magnoli', 'prince'] VS true_author: ['prince']
# movie_id: 21613
# true director: Andrzej Bartkowiak
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03906393051147461
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001977205276489258
# Discarted candidate: []
# Possible candidate: [{'andrzej bartkowiak': 19, 'andrzek bartkowiak': 1}]
# lengthNecessary: 7.0
# [{'andrzej bartkowiak': 19, 'andrzek bartkowiak': 1}]
# acceptance_diff 4
# ['andrzej bartkowiak'] VS true_author: ['andrzej bartkowiak']
# movie_id: 80167
# true director: Sandra Martin;Hugues Martin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03301095962524414
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010223388671875
# Discarted candidate: []
# Possible candidate: [{'hugues martin': 4, 'martin sandra': 2}]
# lengthNecessary: 2.0999999999999996
# [{'hugues martin': 4, 'martin sandra': 2}]
# acceptance_diff 4
# ['hugues martin', 'martin sandra'] VS true_author: ['martin sandra', 'hugues martin']
# movie_id: 82271
# true director: Marvin J. Chomsky
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.056989192962646484
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016908645629882812
# Discarted candidate: []
# Possible candidate: [{'chomsky j marvin': 17, 'chomsky marvin': 1}]
# lengthNecessary: 6.3
# [{'chomsky j marvin': 17, 'chomsky marvin': 1}]
# acceptance_diff 4
# ['chomsky j marvin'] VS true_author: ['chomsky j marvin']
# movie_id: 7494
# true director: Tommy O'Haver
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08430695533752441
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0017333030700683594
# Discarted candidate: []
# Possible candidate: [{"o'haver tommy": 7, 'ohaver tommy': 3}]
# lengthNecessary: 3.5
# [{"o'haver tommy": 7, 'ohaver tommy': 3}]
# acceptance_diff 4
# ["o'haver tommy"] VS true_author: ["o'haver tommy"]
# movie_id: 16640
# true director: Timothy Marrinan;Richard Dewey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06275391578674316
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0022459030151367188
# Discarted candidate: []
# Possible candidate: [{'dewey richard': 1, 'marrinan timothy': 2}]
# lengthNecessary: 1.0499999999999998
# [{'dewey richard': 1, 'marrinan timothy': 2}]
# acceptance_diff 4
# ['dewey richard', 'marrinan timothy'] VS true_author: ['dewey richard', 'marrinan timothy']
# movie_id: 101119
# true director: Chris Hegedus;D. A. Pennebaker
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1138303279876709
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0017571449279785156
# Discarted candidate: []
# Possible candidate: [{'a d pennebaker': 9, 'chris hegedus': 7}]
# lengthNecessary: 5.6
# [{'a d pennebaker': 9, 'chris hegedus': 7}]
# acceptance_diff 4
# ['a d pennebaker', 'chris hegedus'] VS true_author: ['chris hegedus', 'a d pennebaker']
# movie_id: 17046
# true director: Paolo Taviani;Vittorio Taviani
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03634190559387207
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001177072525024414
# Discarted candidate: []
# Possible candidate: [{'paolo taviani': 4, 'taviani vittorio': 2}]
# lengthNecessary: 2.0999999999999996
# [{'paolo taviani': 4, 'taviani vittorio': 2}]
# acceptance_diff 4
# ['paolo taviani', 'taviani vittorio'] VS true_author: ['paolo taviani', 'taviani vittorio']
# movie_id: 80539
# true director: Karan Johar
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.11031079292297363
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0026879310607910156
# Discarted candidate: []
# Possible candidate: [{'abhishek varman': 2, 'johar karan': 10}]
# lengthNecessary: 4.199999999999999
# [{'abhishek varman': 2, 'johar karan': 10}]
# acceptance_diff 4
# ['johar karan'] VS true_author: ['johar karan']
# movie_id: 111871
# true director: Anlo Sepulveda;Paul Collins
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08395123481750488
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009989738464355469
# Discarted candidate: []
# Possible candidate: [{'anlo sepulveda': 3, 'collins paul': 2}]
# lengthNecessary: 1.75
# [{'anlo sepulveda': 3, 'collins paul': 2}]
# acceptance_diff 4
# ['anlo sepulveda', 'collins paul'] VS true_author: ['anlo sepulveda', 'collins paul']
# movie_id: 31082
# true director: Slatan Dudow;Kurt Maetzig
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05221295356750488
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.011870861053466797
# Discarted candidate: []
# Possible candidate: [{'dudow slatan': 2, 'groschopp richard': 1, 'kurt maetzig': 1}]
# lengthNecessary: 1.4
# [{'dudow slatan': 2, 'groschopp richard': 1, 'kurt maetzig': 1}]
# acceptance_diff 4
# ['dudow slatan', 'groschopp richard', 'kurt maetzig'] VS true_author: ['dudow slatan', 'kurt maetzig']
# movie_id: 2672
# true director: Christian Krones;Olaf S. Muller;Roland Schrotthofer;Florian Weigensamer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06722593307495117
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0021190643310546875
# Discarted candidate: []
# Possible candidate: [{'christian krones': 1, 'florian weigensamer': 2, 'muller olaf s': 1, 'roland schrotthofer': 1}]
# lengthNecessary: 1.75
# [{'christian krones': 1, 'florian weigensamer': 2, 'muller olaf s': 1, 'roland schrotthofer': 1}]
# acceptance_diff 4
# ['christian krones', 'florian weigensamer', 'muller olaf s', 'roland schrotthofer'] VS true_author: ['muller olaf s', 'roland schrotthofer', 'florian weigensamer', 'christian krones']
# movie_id: 91427
# true director: Robert Rossen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.039685964584350586
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001058816909790039
# Discarted candidate: []
# Possible candidate: [{'blue washington': 1, 'robert rossen': 9}]
# lengthNecessary: 3.5
# [{'blue washington': 1, 'robert rossen': 9}]
# acceptance_diff 4
# ['robert rossen'] VS true_author: ['robert rossen']
# movie_id: 2813
# true director: Michael Tiddes
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0436398983001709
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014090538024902344
# Discarted candidate: []
# Possible candidate: [{'michael tiddes': 11, 'mike tiddes': 2}]
# lengthNecessary: 4.55
# [{'michael tiddes': 11, 'mike tiddes': 2}]
# acceptance_diff 4
# ['michael tiddes'] VS true_author: ['michael tiddes']
# movie_id: 15123
# true director: Jon Bulette;Stone Roberts
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.040524959564208984
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012431144714355469
# Discarted candidate: []
# Possible candidate: [{'bulette jon': 3, 'f roberts stone': 1, 'roberts stone': 1}]
# lengthNecessary: 1.75
# [{'bulette jon': 3, 'f roberts stone': 1, 'roberts stone': 1}]
# acceptance_diff 4
# ['bulette jon', 'f roberts stone'] VS true_author: ['bulette jon', 'roberts stone']
# movie_id: 30280
# true director: Anthony Stabley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.053788185119628906
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0017900466918945312
# Discarted candidate: []
# Possible candidate: [{'anthony r stabley': 3, 'anthony stabley': 8}]
# lengthNecessary: 3.8499999999999996
# [{'anthony r stabley': 3, 'anthony stabley': 8}]
# acceptance_diff 4
# ['anthony stabley'] VS true_author: ['anthony stabley']
# movie_id: 68652
# true director: Adam Kassen;Mark Kassen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0818178653717041
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012710094451904297
# Discarted candidate: []
# Possible candidate: [{'adam kassen': 8, 'kassen mark': 9}]
# lengthNecessary: 5.949999999999999
# [{'adam kassen': 8, 'kassen mark': 9}]
# acceptance_diff 4
# ['adam kassen', 'kassen mark'] VS true_author: ['kassen mark', 'adam kassen']
# movie_id: 21609
# true director: Rowby Goren;Chuck Staley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06822419166564941
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001477956771850586
# Discarted candidate: []
# Possible candidate: [{'chuck staley': 3, 'goren rowby': 6}]
# lengthNecessary: 3.15
# [{'chuck staley': 3, 'goren rowby': 6}]
# acceptance_diff 4
# ['chuck staley', 'goren rowby'] VS true_author: ['chuck staley', 'goren rowby']
# movie_id: 37872
# true director: Michael Almereyda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05172109603881836
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.003993034362792969
# Discarted candidate: []
# Possible candidate: [{'almereyda michael': 5, 'campbell scott': 1}]
# lengthNecessary: 2.0999999999999996
# [{'almereyda michael': 5, 'campbell scott': 1}]
# acceptance_diff 4
# ['almereyda michael', 'campbell scott'] VS true_author: ['almereyda michael']
# movie_id: 45447
# true director: Fred C. Brannon;Thomas Carr
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08627891540527344
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.009795665740966797
# Discarted candidate: []
# Possible candidate: [{'brannon c fred': 6, 'carr thomas': 3}]
# lengthNecessary: 3.15
# [{'brannon c fred': 6, 'carr thomas': 3}]
# acceptance_diff 4
# ['brannon c fred', 'carr thomas'] VS true_author: ['carr thomas', 'brannon c fred']
# movie_id: 24661
# true director: Matthew Celestre;Brett Celestre
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.055992841720581055
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001402139663696289
# Discarted candidate: []
# Possible candidate: [{'brett celestre': 1, 'brette celestre': 2, 'celestre matthew': 1}]
# lengthNecessary: 1.4
# [{'brett celestre': 1, 'brette celestre': 2, 'celestre matthew': 1}]
# acceptance_diff 4
# ['brett celestre', 'celestre matthew'] VS true_author: ['brett celestre', 'celestre matthew']
# movie_id: 3648
# true director: Nikolaj Arcel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05307912826538086
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0019540786743164062
# Discarted candidate: []
# Possible candidate: [{'arcel nikaolaj': 2, 'arcel nikolaj': 14}]
# lengthNecessary: 5.6
# [{'arcel nikaolaj': 2, 'arcel nikolaj': 14}]
# acceptance_diff 4
# ['arcel nikolaj'] VS true_author: ['arcel nikolaj']
# movie_id: 13479
# true director: Ergin Orbey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06532979011535645
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001405954360961914
# Discarted candidate: []
# Possible candidate: [{'engin orbey': 8, 'ergin orbey': 1}]
# lengthNecessary: 3.15
# [{'engin orbey': 8, 'ergin orbey': 1}]
# acceptance_diff 4
# ['engin orbey'] VS true_author: ['ergin orbey']
# movie_id: 18319
# true director: Baird Bryant;Johanna Demetrakas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05864119529724121
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016908645629882812
# Discarted candidate: []
# Possible candidate: [{'baird bryant': 8, 'demetrakas johanna': 5}]
# lengthNecessary: 4.55
# [{'baird bryant': 8, 'demetrakas johanna': 5}]
# acceptance_diff 4
# ['baird bryant', 'demetrakas johanna'] VS true_author: ['baird bryant', 'demetrakas johanna']
# movie_id: 44223
# true director: Gene Kelly
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05067610740661621
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016469955444335938
# Discarted candidate: []
# Possible candidate: [{'freddie young': 1, 'gene kelly': 8}]
# lengthNecessary: 3.15
# [{'freddie young': 1, 'gene kelly': 8}]
# acceptance_diff 4
# ['gene kelly'] VS true_author: ['gene kelly']
# movie_id: 71075
# true director: David Twohy
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0750892162322998
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002680063247680664
# Discarted candidate: []
# Possible candidate: [{'david n twohy': 1, 'david twohy': 24}]
# lengthNecessary: 8.75
# [{'david n twohy': 1, 'david twohy': 24}]
# acceptance_diff 4
# ['david twohy'] VS true_author: ['david twohy']
# movie_id: 80410
# true director: Paul Ragsdale
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.11283373832702637
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015039443969726562
# Discarted candidate: []
# Possible candidate: [{'alba angelica de': 3, 'paul ragsdale': 6}]
# lengthNecessary: 3.15
# [{'alba angelica de': 3, 'paul ragsdale': 6}]
# acceptance_diff 4
# ['alba angelica de', 'paul ragsdale'] VS true_author: ['paul ragsdale']
# movie_id: 71705
# true director: Allan Arkush
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.11724495887756348
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015759468078613281
# Discarted candidate: []
# Possible candidate: [{'allan arkush': 13, 'dante joe': 6}]
# lengthNecessary: 6.6499999999999995
# [{'allan arkush': 13, 'dante joe': 6}]
# acceptance_diff 4
# ['allan arkush'] VS true_author: ['allan arkush']
# movie_id: 91114
# true director: Tian Zhuangzhuang
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.060292959213256836
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.000881195068359375
# Discarted candidate: []
# Possible candidate: [{'pan peicheng': 3, 'tian zhuangzhuang': 3}]
# lengthNecessary: 2.0999999999999996
# [{'pan peicheng': 3, 'tian zhuangzhuang': 3}]
# acceptance_diff 4
# ['pan peicheng', 'tian zhuangzhuang'] VS true_author: ['tian zhuangzhuang']
# movie_id: 100574
# true director: Michael Hegner;Karsten Kiilerich
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07071733474731445
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001146078109741211
# Discarted candidate: []
# Possible candidate: [{'hegner michael': 6, 'karsten kiilerich': 4}]
# lengthNecessary: 3.5
# [{'hegner michael': 6, 'karsten kiilerich': 4}]
# acceptance_diff 4
# ['hegner michael', 'karsten kiilerich'] VS true_author: ['hegner michael', 'karsten kiilerich']
# movie_id: 22475
# true director: Kevin King
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07060599327087402
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013179779052734375
# Discarted candidate: []
# Possible candidate: [{'k king': 6, 'kevin king': 3}]
# lengthNecessary: 3.15
# [{'k king': 6, 'kevin king': 3}]
# acceptance_diff 4
# ['k king', 'kevin king'] VS true_author: ['kevin king']
# movie_id: 57809
# true director: John Lamb
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06232404708862305
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0007200241088867188
# Discarted candidate: []
# Possible candidate: [{'hill jack': 2, 'john lamb': 1}]
# lengthNecessary: 1.0499999999999998
# [{'hill jack': 2, 'john lamb': 1}]
# acceptance_diff 4
# ['hill jack', 'john lamb'] VS true_author: ['john lamb']
# movie_id: 97278
# true director: Norman Panama;Melvin Frank
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07286810874938965
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.003340005874633789
# Discarted candidate: []
# Possible candidate: [{'frank melvin': 4, 'norman panama': 3}]
# lengthNecessary: 2.4499999999999997
# [{'frank melvin': 4, 'norman panama': 3}]
# acceptance_diff 4
# ['frank melvin', 'norman panama'] VS true_author: ['norman panama', 'frank melvin']
# movie_id: 106242
# true director: Gionata Zarantonello
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.036347150802612305
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0005819797515869141
# Discarted candidate: []
# Possible candidate: [{'gionata zarantonello': 1, 'jonathan zarantonello': 1}]
# lengthNecessary: 0.7
# [{'gionata zarantonello': 1, 'jonathan zarantonello': 1}]
# acceptance_diff 4
# ['gionata zarantonello'] VS true_author: ['gionata zarantonello']
# movie_id: 81911
# true director: Kang Je-Gyu
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07860302925109863
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0018072128295898438
# Discarted candidate: []
# Possible candidate: [{'gyu je kang': 1, 'je-gyu kang': 13, 'je-kyu kang': 7}]
# lengthNecessary: 7.35
# [{'gyu je kang': 1, 'je-gyu kang': 13, 'je-kyu kang': 7}]
# acceptance_diff 4
# ['je-gyu kang'] VS true_author: ['je-gyu kang']
# movie_id: 87781
# true director: Alistair Legrand
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0836331844329834
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0026807785034179688
# Discarted candidate: []
# Possible candidate: [{'alistair legrand': 16, 'callaway ryan': 1}]
# lengthNecessary: 5.949999999999999
# [{'alistair legrand': 16, 'callaway ryan': 1}]
# acceptance_diff 4
# ['alistair legrand'] VS true_author: ['alistair legrand']
# movie_id: 49079
# true director: Fernando Palacios
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08326911926269531
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013017654418945312
# Discarted candidate: []
# Possible candidate: [{'fernando palacios': 2, 'j rafael salvia': 3}]
# lengthNecessary: 1.75
# [{'fernando palacios': 2, 'j rafael salvia': 3}]
# acceptance_diff 4
# ['fernando palacios', 'j rafael salvia'] VS true_author: ['fernando palacios']
# movie_id: 43271
# true director: R. Kiplin Pastor
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06371521949768066
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.00506901741027832
# Discarted candidate: []
# Possible candidate: [{'kip pastor': 3, 'kiplin pastor r': 1}]
# lengthNecessary: 1.4
# [{'kip pastor': 3, 'kiplin pastor r': 1}]
# acceptance_diff 4
# ['kip pastor', 'kiplin pastor r'] VS true_author: ['kiplin pastor r']
# movie_id: 43726
# true director: Quentin Tarantino
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09779715538024902
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0030829906463623047
# Discarted candidate: []
# Possible candidate: [{'eli roth': 12, 'quentin tarantino': 27}]
# lengthNecessary: 13.649999999999999
# [{'eli roth': 12, 'quentin tarantino': 27}]
# acceptance_diff 4
# ['quentin tarantino'] VS true_author: ['quentin tarantino']
# movie_id: 28418
# true director: Sharunas Bartas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.01803874969482422
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009160041809082031
# Discarted candidate: []
# Possible candidate: [{'bartas sar?nas': 1, 'bartas sharunas': 1}]
# lengthNecessary: 0.7
# [{'bartas sar?nas': 1, 'bartas sharunas': 1}]
# acceptance_diff 4
# ['bartas sar?nas'] VS true_author: ['bartas sharunas']
# movie_id: 111254
# true director: Luke Jaden;Cort Johns
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04645705223083496
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016970634460449219
# Discarted candidate: []
# Possible candidate: [{'cort johns': 2, 'jaden luke': 4}]
# lengthNecessary: 2.0999999999999996
# [{'cort johns': 2, 'jaden luke': 4}]
# acceptance_diff 4
# ['cort johns', 'jaden luke'] VS true_author: ['cort johns', 'jaden luke']
# movie_id: 69205
# true director: Nancy Glass;Michele Loschiavo
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04908299446105957
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013401508331298828
# Discarted candidate: []
# Possible candidate: [{'glass nancy': 2, 'loschiavo michele': 1}]
# lengthNecessary: 1.0499999999999998
# [{'glass nancy': 2, 'loschiavo michele': 1}]
# acceptance_diff 4
# ['glass nancy', 'loschiavo michele'] VS true_author: ['loschiavo michele', 'glass nancy']
# movie_id: 40048
# true director: Manuel Gonzalez Mauricio;Saul Barreto Ramos
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0491938591003418
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013871192932128906
# Discarted candidate: []
# Possible candidate: [{'barreto ramos saul': 1, 'gonzalez manuel mauricio': 2}]
# lengthNecessary: 1.0499999999999998
# [{'barreto ramos saul': 1, 'gonzalez manuel mauricio': 2}]
# acceptance_diff 4
# ['barreto ramos saul', 'gonzalez manuel mauricio'] VS true_author: ['gonzalez manuel mauricio', 'barreto ramos saul']
# movie_id: 57896
# true director: Andrew V. McLaglen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.043112993240356445
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011310577392578125
# Discarted candidate: []
# Possible candidate: [{'andrew mclaglen': 2, 'andrew mclaglen v': 6}]
# lengthNecessary: 2.8
# [{'andrew mclaglen': 2, 'andrew mclaglen v': 6}]
# acceptance_diff 4
# ['andrew mclaglen'] VS true_author: ['andrew mclaglen v']
# movie_id: 32707
# true director: Paul Morrissey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.042440176010131836
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0017290115356445312
# Discarted candidate: []
# Possible candidate: [{'antonio margheriti': 2, 'morrissey paul': 6}]
# lengthNecessary: 2.8
# [{'antonio margheriti': 2, 'morrissey paul': 6}]
# acceptance_diff 4
# ['antonio margheriti', 'morrissey paul'] VS true_author: ['morrissey paul']
# movie_id: 80601
# true director: Frank Capra
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04081082344055176
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010952949523925781
# Discarted candidate: []
# Possible candidate: [{'capra frank': 5, 'irvin willat': 3}]
# lengthNecessary: 2.8
# [{'capra frank': 5, 'irvin willat': 3}]
# acceptance_diff 4
# ['capra frank', 'irvin willat'] VS true_author: ['capra frank']
# movie_id: 109103
# true director: Dick Zondag;Ralph Zondag;Phil Nibbelink;Simon Wells
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.10344481468200684
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004266023635864258
# Discarted candidate: []
# Possible candidate: [{'dick zondag': 12, 'nibbelink phil': 14, 'ralph zondag': 12, 'simon wells': 12}]
# lengthNecessary: 17.5
# [{'dick zondag': 12, 'nibbelink phil': 14, 'ralph zondag': 12, 'simon wells': 12}]
# acceptance_diff 4
# ['dick zondag', 'nibbelink phil', 'ralph zondag', 'simon wells'] VS true_author: ['dick zondag', 'simon wells', 'ralph zondag', 'nibbelink phil']
# movie_id: 76115
# true director: Adam Friedman;Iain Kennedy
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06017279624938965
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0017838478088378906
# Discarted candidate: []
# Possible candidate: [{'adam friedman': 7, 'iain kennedy': 5}]
# lengthNecessary: 4.199999999999999
# [{'adam friedman': 7, 'iain kennedy': 5}]
# acceptance_diff 4
# ['adam friedman', 'iain kennedy'] VS true_author: ['iain kennedy', 'adam friedman']
# movie_id: 60263
# true director: Bill Guttentag;Dan Sturman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05533194541931152
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.003934144973754883
# Discarted candidate: []
# Possible candidate: [{'bill guttentag': 14, 'dan sturman': 9}]
# lengthNecessary: 8.049999999999999
# [{'bill guttentag': 14, 'dan sturman': 9}]
# acceptance_diff 4
# ['bill guttentag'] VS true_author: ['bill guttentag', 'dan sturman']
# movie_id: 35119
# true director: Cynthia Wade;Cheryl Miller Houser
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05925726890563965
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015659332275390625
# Discarted candidate: []
# Possible candidate: [{'cheryl houser': 1, 'cheryl houser miller': 4, 'cynthia wade': 6}]
# lengthNecessary: 3.8499999999999996
# [{'cheryl houser': 1, 'cheryl houser miller': 4, 'cynthia wade': 6}]
# acceptance_diff 4
# ['cheryl houser miller', 'cynthia wade'] VS true_author: ['cynthia wade', 'cheryl houser miller']
# movie_id: 97251
# true director: Michael Dudok De Wit
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0599668025970459
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010077953338623047
# Discarted candidate: []
# Possible candidate: [{'de dudok michael wit': 3, 'dewit dudok michael': 1}]
# lengthNecessary: 1.4
# [{'de dudok michael wit': 3, 'dewit dudok michael': 1}]
# acceptance_diff 4
# ['de dudok michael wit'] VS true_author: ['de dudok michael wit']
# movie_id: 90003
# true director: Charles Chaplin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05936098098754883
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0025589466094970703
# Discarted candidate: []
# Possible candidate: [{'chaplin charles': 13, 'chaplin charlie': 6}]
# lengthNecessary: 6.6499999999999995
# [{'chaplin charles': 13, 'chaplin charlie': 6}]
# acceptance_diff 4
# ['chaplin charles'] VS true_author: ['chaplin charles']
# movie_id: 91535
# true director: J. A. Bayona
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07480216026306152
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0019190311431884766
# Discarted candidate: []
# Possible candidate: [{'a bayona j': 7, 'antonio bayona juan': 15}]
# lengthNecessary: 7.699999999999999
# [{'a bayona j': 7, 'antonio bayona juan': 15}]
# acceptance_diff 4
# ['antonio bayona juan'] VS true_author: ['a bayona j']
# movie_id: 51346
# true director: William A. Seiter
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03947806358337402
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013000965118408203
# Discarted candidate: []
# Possible candidate: [{'a seiter william': 2, 'seiter william': 1}]
# lengthNecessary: 1.0499999999999998
# [{'a seiter william': 2, 'seiter william': 1}]
# acceptance_diff 4
# ['a seiter william'] VS true_author: ['a seiter william']
# movie_id: 64713
# true director: Alan Mak;Felix Chong
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05386185646057129
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001157999038696289
# Discarted candidate: []
# Possible candidate: [{'alan mak': 5, 'chong felix': 8}]
# lengthNecessary: 4.55
# [{'alan mak': 5, 'chong felix': 8}]
# acceptance_diff 4
# ['alan mak', 'chong felix'] VS true_author: ['alan mak', 'chong felix']
# movie_id: 87307
# true director: Florian Cossen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.024306774139404297
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016210079193115234
# Discarted candidate: []
# Possible candidate: [{'cossen florian': 1, 'cossen florian micoud': 1}]
# lengthNecessary: 0.7
# [{'cossen florian': 1, 'cossen florian micoud': 1}]
# acceptance_diff 4
# ['cossen florian', 'cossen florian micoud'] VS true_author: ['cossen florian']
# movie_id: 89712
# true director: Mauro Borrelli
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02208995819091797
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0018091201782226562
# Discarted candidate: []
# Possible candidate: [{'borrelli maura': 1, 'borrelli mauro': 2}]
# lengthNecessary: 1.0499999999999998
# [{'borrelli maura': 1, 'borrelli mauro': 2}]
# acceptance_diff 4
# ['borrelli maura'] VS true_author: ['borrelli mauro']
# movie_id: 11264
# true director: Rex Ingram
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02806401252746582
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013420581817626953
# Discarted candidate: []
# Possible candidate: [{'alice terry': 1, 'ingram rex': 2}]
# lengthNecessary: 1.0499999999999998
# [{'alice terry': 1, 'ingram rex': 2}]
# acceptance_diff 4
# ['alice terry', 'ingram rex'] VS true_author: ['ingram rex']
# movie_id: 48608
# true director: John Stevenson;Mark Osborne
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0805208683013916
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004530906677246094
# Discarted candidate: []
# Possible candidate: [{'john stevenson': 25, 'mark osborne': 31}]
# lengthNecessary: 19.599999999999998
# [{'john stevenson': 25, 'mark osborne': 31}]
# acceptance_diff 4
# ['mark osborne'] VS true_author: ['john stevenson', 'mark osborne']
# movie_id: 5451
# true director: Claudio Marques;Marilia Hughes
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03885912895202637
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002487659454345703
# Discarted candidate: []
# Possible candidate: [{'claudio marques': 3, 'guerreiro hughes marilia': 2, 'hughes marilia': 1}]
# lengthNecessary: 2.0999999999999996
# [{'claudio marques': 3, 'guerreiro hughes marilia': 2, 'hughes marilia': 1}]
# acceptance_diff 4
# ['claudio marques', 'guerreiro hughes marilia', 'hughes marilia'] VS true_author: ['claudio marques', 'hughes marilia']
# movie_id: 29810
# true director: Herrmann Zschoche
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03184390068054199
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015721321105957031
# Discarted candidate: []
# Possible candidate: [{'dressel eleonore': 4, 'herrmann zschoche': 8}]
# lengthNecessary: 4.199999999999999
# [{'dressel eleonore': 4, 'herrmann zschoche': 8}]
# acceptance_diff 4
# ['dressel eleonore', 'herrmann zschoche'] VS true_author: ['herrmann zschoche']
# movie_id: 78918
# true director: Marc Gracie;Tim Ferguson
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.037126779556274414
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016541481018066406
# Discarted candidate: []
# Possible candidate: [{'ferguson tim': 5, 'gracie marc': 6}]
# lengthNecessary: 3.8499999999999996
# [{'ferguson tim': 5, 'gracie marc': 6}]
# acceptance_diff 4
# ['ferguson tim', 'gracie marc'] VS true_author: ['gracie marc', 'ferguson tim']
# movie_id: 71440
# true director: Otto Preminger
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0324709415435791
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# ...
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010101795196533203
# Discarted candidate: []
# Possible candidate: [{'l?a pool': 1, 'lea pool': 3}]
# lengthNecessary: 1.4
# [{'l?a pool': 1, 'lea pool': 3}]
# acceptance_diff 4
# ['l?a pool'] VS true_author: ['lea pool']
# movie_id: 69925
# true director: Heidi Maria Faisst
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03435993194580078
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0006520748138427734
# Discarted candidate: []
# Possible candidate: [{'faissi heidi maria': 1, 'faisst heidi maria': 1}]
# lengthNecessary: 0.7
# [{'faissi heidi maria': 1, 'faisst heidi maria': 1}]
# acceptance_diff 4
# ['faissi heidi maria'] VS true_author: ['faisst heidi maria']
# movie_id: 47283
# true director: Carl Astrand;Mats Lindberg
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04579305648803711
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012748241424560547
# Discarted candidate: []
# Possible candidate: [{'astrand carl': 6, 'lindberg mats': 9}]
# lengthNecessary: 5.25
# [{'astrand carl': 6, 'lindberg mats': 9}]
# acceptance_diff 4
# ['astrand carl', 'lindberg mats'] VS true_author: ['astrand carl', 'lindberg mats']
# movie_id: 40393
# true director: Ewing Scott
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03630208969116211
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009911060333251953
# Discarted candidate: []
# Possible candidate: [{'ewing scott': 8, 'george sherman': 3}]
# lengthNecessary: 3.8499999999999996
# [{'ewing scott': 8, 'george sherman': 3}]
# acceptance_diff 4
# ['ewing scott'] VS true_author: ['ewing scott']
# movie_id: 35829
# true director: Michael Paul Stephenson
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.039055824279785156
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009911060333251953
# Discarted candidate: []
# Possible candidate: [{'michael paul stephenson': 6, 'michael stephenson': 2}]
# lengthNecessary: 2.8
# [{'michael paul stephenson': 6, 'michael stephenson': 2}]
# acceptance_diff 4
# ['michael paul stephenson'] VS true_author: ['michael paul stephenson']
# movie_id: 27116
# true director: Neil Marshall
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04150509834289551
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013518333435058594
# Discarted candidate: []
# Possible candidate: [{'marshall neil': 18, 'universal': 1}]
# lengthNecessary: 6.6499999999999995
# [{'marshall neil': 18, 'universal': 1}]
# acceptance_diff 4
# ['marshall neil'] VS true_author: ['marshall neil']
# movie_id: 49163
# true director: Vicente Aranda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.032070159912109375
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013408660888671875
# Discarted candidate: []
# Possible candidate: [{'aranda vicente': 3, 'gomez raul': 2}]
# lengthNecessary: 1.75
# [{'aranda vicente': 3, 'gomez raul': 2}]
# acceptance_diff 4
# ['aranda vicente', 'gomez raul'] VS true_author: ['aranda vicente']
# movie_id: 64814
# true director: R. Balki
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03271889686584473
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009908676147460938
# Discarted candidate: []
# Possible candidate: [{'balki r': 4, 'ricky sandhu': 1}]
# lengthNecessary: 1.75
# [{'balki r': 4, 'ricky sandhu': 1}]
# acceptance_diff 4
# ['balki r', 'ricky sandhu'] VS true_author: ['balki r']
# movie_id: 87155
# true director: Jiri Svoboda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02814793586730957
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009999275207519531
# Discarted candidate: []
# Possible candidate: [{'ji?i svoboda': 6, 'jiri svoboda': 1}]
# lengthNecessary: 2.4499999999999997
# [{'ji?i svoboda': 6, 'jiri svoboda': 1}]
# acceptance_diff 4
# ['ji?i svoboda'] VS true_author: ['jiri svoboda']
# movie_id: 19545
# true director: Charles Chu;Gavin Kelly
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.030894041061401367
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0008361339569091797
# Discarted candidate: []
# Possible candidate: [{'charles chu': 1, 'gavin kelly': 2}]
# lengthNecessary: 1.0499999999999998
# [{'charles chu': 1, 'gavin kelly': 2}]
# acceptance_diff 4
# ['charles chu', 'gavin kelly'] VS true_author: ['charles chu', 'gavin kelly']
# movie_id: 46270
# true director: Seung-Hyeon Jin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.028625965118408203
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009388923645019531
# Discarted candidate: []
# Possible candidate: [{'hyeonh jin seung': 2, 'jin seung-hyeon': 2}]
# lengthNecessary: 1.4
# [{'hyeonh jin seung': 2, 'jin seung-hyeon': 2}]
# acceptance_diff 4
# ['hyeonh jin seung', 'jin seung-hyeon'] VS true_author: ['jin seung-hyeon']
# movie_id: 73371
# true director: Andrew Becker;Daniel Mehrer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.028264999389648438
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009329319000244141
# Discarted candidate: []
# Possible candidate: [{'andrew becker': 2, 'daniel mehrer': 1}]
# lengthNecessary: 1.0499999999999998
# [{'andrew becker': 2, 'daniel mehrer': 1}]
# acceptance_diff 4
# ['andrew becker', 'daniel mehrer'] VS true_author: ['daniel mehrer', 'andrew becker']
# movie_id: 61155
# true director: Chan-wook Park
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.032804012298583984
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009701251983642578
# Discarted candidate: []
# Possible candidate: [{'chan-kyong park': 5, 'chan-wook park': 6}]
# lengthNecessary: 3.8499999999999996
# [{'chan-kyong park': 5, 'chan-wook park': 6}]
# acceptance_diff 4
# ['chan-kyong park', 'chan-wook park'] VS true_author: ['chan-wook park']
# movie_id: 111258
# true director: Michael Wadleigh
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07235312461853027
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016100406646728516
# Discarted candidate: []
# Possible candidate: [{'d hancock john': 6, 'hitzig rupert': 4, 'michael wadleigh': 15}]
# lengthNecessary: 8.75
# [{'d hancock john': 6, 'hitzig rupert': 4, 'michael wadleigh': 15}]
# acceptance_diff 4
# ['michael wadleigh'] VS true_author: ['michael wadleigh']
# movie_id: 56502
# true director: Nagisa Oshima
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.027753829956054688
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0008280277252197266
# Discarted candidate: []
# Possible candidate: [{'?shima nagisa': 2, 'nagisa oshima': 1}]
# lengthNecessary: 1.0499999999999998
# [{'?shima nagisa': 2, 'nagisa oshima': 1}]
# acceptance_diff 4
# ['?shima nagisa', 'nagisa oshima'] VS true_author: ['nagisa oshima']
# movie_id: 63743
# true director: Jeremy Frindel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.027001142501831055
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010519027709960938
# Discarted candidate: []
# Possible candidate: [{'films substratum': 1, 'frindel jeremy': 7}]
# lengthNecessary: 2.8
# [{'films substratum': 1, 'frindel jeremy': 7}]
# acceptance_diff 4
# ['frindel jeremy'] VS true_author: ['frindel jeremy']
# movie_id: 105721
# true director: Georg Maas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03497600555419922
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009667873382568359
# Discarted candidate: []
# Possible candidate: [{'georg maas': 3, 'judith kaufmann': 2}]
# lengthNecessary: 1.75
# [{'georg maas': 3, 'judith kaufmann': 2}]
# acceptance_diff 4
# ['georg maas', 'judith kaufmann'] VS true_author: ['georg maas']
# movie_id: 88941
# true director: Jonah Bekhor;Zach Math
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04078984260559082
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013740062713623047
# Discarted candidate: []
# Possible candidate: [{'bekhor jonah': 10, 'math zach': 9}]
# lengthNecessary: 6.6499999999999995
# [{'bekhor jonah': 10, 'math zach': 9}]
# acceptance_diff 4
# ['bekhor jonah', 'math zach'] VS true_author: ['bekhor jonah', 'math zach']
# movie_id: 61767
# true director: Ryuhei Kitamura
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.023746013641357422
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009980201721191406
# Discarted candidate: []
# Possible candidate: [{'kitamura ry?hei': 2, 'kitamura ryuhei': 5}]
# lengthNecessary: 2.4499999999999997
# [{'kitamura ry?hei': 2, 'kitamura ryuhei': 5}]
# acceptance_diff 4
# ['kitamura ry?hei'] VS true_author: ['kitamura ryuhei']
# movie_id: 76373
# true director: Alice O'Fredericks;Jon Iversen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.025112152099609375
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009219646453857422
# Discarted candidate: []
# Possible candidate: [{"alice o'fredericks": 3, 'iversen jon': 2}]
# lengthNecessary: 1.75
# [{"alice o'fredericks": 3, 'iversen jon': 2}]
# acceptance_diff 4
# ["alice o'fredericks", 'iversen jon'] VS true_author: ['iversen jon', "alice o'fredericks"]
# movie_id: 38696
# true director: Sean Carr
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04111313819885254
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010251998901367188
# Discarted candidate: []
# Possible candidate: [{'carr sean': 1, 'carrigan sean': 5}]
# lengthNecessary: 2.0999999999999996
# [{'carr sean': 1, 'carrigan sean': 5}]
# acceptance_diff 4
# ['carr sean'] VS true_author: ['carr sean']
# movie_id: 32680
# true director: Raj Nidimoru;Krishna DK
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04250288009643555
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010030269622802734
# Discarted candidate: []
# Possible candidate: [{'d k krishna': 4, 'dk krishna': 1, 'nidimoru raj': 4}]
# lengthNecessary: 3.15
# [{'d k krishna': 4, 'dk krishna': 1, 'nidimoru raj': 4}]
# acceptance_diff 4
# ['d k krishna', 'nidimoru raj'] VS true_author: ['dk krishna', 'nidimoru raj']
# movie_id: 112475
# true director: Francis Ford Coppola
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0528109073638916
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013408660888671875
# Discarted candidate: []
# Possible candidate: [{'coppola ford francis': 19, 'coppola francis': 1}]
# lengthNecessary: 7.0
# [{'coppola ford francis': 19, 'coppola francis': 1}]
# acceptance_diff 4
# ['coppola ford francis'] VS true_author: ['coppola ford francis']
# movie_id: 105251
# true director: Nic Hill;Scott Glosserman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.023572921752929688
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009050369262695312
# Discarted candidate: []
# Possible candidate: [{'glosserman scott': 2, 'hill nic': 1}]
# lengthNecessary: 1.0499999999999998
# [{'glosserman scott': 2, 'hill nic': 1}]
# acceptance_diff 4
# ['glosserman scott', 'hill nic'] VS true_author: ['hill nic', 'glosserman scott']
# movie_id: 58667
# true director: Chris R. Notarile;Kim Santiago
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.036359310150146484
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.000982046127319336
# Discarted candidate: []
# Possible candidate: [{'chris notarile r': 4, 'kim santiago': 7}]
# lengthNecessary: 3.8499999999999996
# [{'chris notarile r': 4, 'kim santiago': 7}]
# acceptance_diff 4
# ['chris notarile r', 'kim santiago'] VS true_author: ['kim santiago', 'chris notarile r']
# movie_id: 87533
# true director: Chang Cheh;Pao Hsueh-Li
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04422926902770996
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001007080078125
# Discarted candidate: []
# Possible candidate: [{'chang cheh': 8, 'hsueh li pao': 4, 'hsueh-li pao': 2}]
# lengthNecessary: 4.8999999999999995
# [{'chang cheh': 8, 'hsueh li pao': 4, 'hsueh-li pao': 2}]
# acceptance_diff 4
# ['chang cheh', 'hsueh li pao'] VS true_author: ['chang cheh', 'hsueh-li pao']
# movie_id: 92814
# true director: Fritz Lang;Rene Sti
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04624676704406738
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009810924530029297
# Discarted candidate: []
# Possible candidate: [{'fritz lang': 6, 'rene sti': 2}]
# lengthNecessary: 2.8
# [{'fritz lang': 6, 'rene sti': 2}]
# acceptance_diff 4
# ['fritz lang', 'rene sti'] VS true_author: ['fritz lang', 'rene sti']
# movie_id: 59689
# true director: Ines Paris;Daniela Fejerman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.033184051513671875
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009706020355224609
# Discarted candidate: []
# Possible candidate: [{'daniela fejerman': 4, 'ines paris': 2}]
# lengthNecessary: 2.0999999999999996
# [{'daniela fejerman': 4, 'ines paris': 2}]
# acceptance_diff 4
# ['daniela fejerman', 'ines paris'] VS true_author: ['ines paris', 'daniela fejerman']
# movie_id: 35985
# true director: Clay Tweel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04061484336853027
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009789466857910156
# Discarted candidate: []
# Possible candidate: [{'clay j tweel': 2, 'clay tweel': 6}]
# lengthNecessary: 2.8
# [{'clay j tweel': 2, 'clay tweel': 6}]
# acceptance_diff 4
# ['clay j tweel'] VS true_author: ['clay tweel']
# movie_id: 31151
# true director: Gaston Ravel;Tony Lekain
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.024123191833496094
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.000985860824584961
# Discarted candidate: []
# Possible candidate: [{'gaston ravel': 1, 'lekain tony': 2}]
# lengthNecessary: 1.0499999999999998
# [{'gaston ravel': 1, 'lekain tony': 2}]
# acceptance_diff 4
# ['gaston ravel', 'lekain tony'] VS true_author: ['lekain tony', 'gaston ravel']
# Total time is: 19.09786105155945

# %%
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# TP: 574, FP: 111, FN: 18
# precision is 0.8379562043795621
# recall is 0.9695945945945946
# f1Score is 0.8989819890368052
# (0.8379562043795621, 0.9695945945945946, 0.8989819890368052)

# %%
key_values = {
    'model_type':'bilstm',
    'char_level':False,
    'model_version': 2,
    'rnn_dim':1024,
    'verbose':1,
    'attributes_list': ['newDirector'],
    'embedding_type': 'inferSent',
    'dataset': 'clean_movie',
    'cluster_method': 'hierarchy',
    'num_clusters_rate': 0.01,
    'block_length_thresold': 0.35,
    'acceptance_diff':3,
    'block_weight': 5,
}

# %%
dataset_name, table_group_by_movie_id, list_movie_id, true_directors = load_dataset(key_values)
# Out:
# dataset: clean_movie
# Loading time is: 0.19414305686950684

# %%
start_time = time.time()
finalDirectors, trueDirectors = launchWithoutReductionFusionMovie(table_group_by_movie_id, list_movie_id, true_directors, key_values)
print("Total time is: {0}".format(time.time() - start_time))
# Out:
# movie_id: 73952
# true director: Robert Hamer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.08547687530517578
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.00683903694152832
# Discarted candidate: []
# Possible candidate: [{'chester e hal': 2, 'cyril frankel': 1, 'hamer robert': 4}]
# lengthNecessary: 2.4499999999999997
# [{'chester e hal': 2, 'cyril frankel': 1, 'hamer robert': 4}]
# acceptance_diff 3
# ['chester e hal', 'cyril frankel', 'hamer robert'] VS true_author: ['hamer robert']
# movie_id: 1655
# true director: Alexandre O. Philippe
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04525899887084961
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0008950233459472656
# Discarted candidate: []
# Possible candidate: [{'alexandre o philippe': 2, 'alexandre philippe': 1}]
# lengthNecessary: 1.0499999999999998
# [{'alexandre o philippe': 2, 'alexandre philippe': 1}]
# acceptance_diff 3
# ['alexandre o philippe'] VS true_author: ['alexandre o philippe']
# movie_id: 69693
# true director: Brad Bird
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09119606018066406
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004333972930908203
# Discarted candidate: []
# Possible candidate: [{'bird brad': 28, 'jan pinkava': 12}]
# lengthNecessary: 14.0
# [{'bird brad': 28, 'jan pinkava': 12}]
# acceptance_diff 3
# ['bird brad'] VS true_author: ['bird brad']
# movie_id: 89575
# true director: Vincent Sherman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03911614418029785
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011131763458251953
# Discarted candidate: []
# Possible candidate: [{'aldrich robert': 2, 'sherman vincent': 7}]
# lengthNecessary: 3.15
# [{'aldrich robert': 2, 'sherman vincent': 7}]
# acceptance_diff 3
# ['sherman vincent'] VS true_author: ['sherman vincent']
# movie_id: 5900
# true director: Fraser C. Heston
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04335784912109375
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014410018920898438
# Discarted candidate: []
# Possible candidate: [{'c fraser heston': 2, 'clarke fraser heston': 7}]
# lengthNecessary: 3.15
# [{'c fraser heston': 2, 'clarke fraser heston': 7}]
# acceptance_diff 3
# ['clarke fraser heston'] VS true_author: ['c fraser heston']
# movie_id: 105551
# true director: John Landis;Steven Spielberg;Joe Dante;George Miller
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.15008306503295898
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.014706134796142578
# Discarted candidate: []
# Possible candidate: [{'dante joe': 15, 'george miller': 15, 'john landis': 19, 'spielberg steven': 22}]
# lengthNecessary: 24.849999999999998
# [{'dante joe': 15, 'george miller': 15, 'john landis': 19, 'spielberg steven': 22}]
# acceptance_diff 3
# ['john landis', 'spielberg steven'] VS true_author: ['dante joe', 'george miller', 'spielberg steven', 'john landis']
# movie_id: 61521
# true director: Godfrey Ho
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05388689041137695
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001550912857055664
# Discarted candidate: []
# Possible candidate: [{'godfrey ho': 3, 'kim si-hyun': 1}]
# lengthNecessary: 1.4
# [{'godfrey ho': 3, 'kim si-hyun': 1}]
# acceptance_diff 3
# ['godfrey ho', 'kim si-hyun'] VS true_author: ['godfrey ho']
# movie_id: 37376
# true director: Dave Fleischer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06986308097839355
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001264333724975586
# Discarted candidate: []
# Possible candidate: [{'bowsky willard': 1, 'dave fleischer': 13}]
# lengthNecessary: 4.8999999999999995
# [{'bowsky willard': 1, 'dave fleischer': 13}]
# acceptance_diff 3
# ['dave fleischer'] VS true_author: ['dave fleischer']
# movie_id: 26754
# true director: Martin D'Urville
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04628801345825195
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015339851379394531
# Discarted candidate: []
# Possible candidate: [{"d'urville martin": 11, 'durville martin': 2}]
# lengthNecessary: 4.55
# [{"d'urville martin": 11, 'durville martin': 2}]
# acceptance_diff 3
# ["d'urville martin"] VS true_author: ["d'urville martin"]
# movie_id: 97745
# true director: Norton Virgien;Igor Kovalyov
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.11118388175964355
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0024261474609375
# Discarted candidate: []
# Possible candidate: [{'igor kovalyov': 15, 'norton virgien': 16}]
# lengthNecessary: 10.85
# [{'igor kovalyov': 15, 'norton virgien': 16}]
# acceptance_diff 3
# ['igor kovalyov', 'norton virgien'] VS true_author: ['norton virgien', 'igor kovalyov']
# movie_id: 58040
# true director: Thomas Bezucha
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0517270565032959
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002380847930908203
# Discarted candidate: []
# Possible candidate: [{'bezucha thomas': 20, 'bezucha tom': 3}]
# lengthNecessary: 8.049999999999999
# [{'bezucha thomas': 20, 'bezucha tom': 3}]
# acceptance_diff 3
# ['bezucha thomas'] VS true_author: ['bezucha thomas']
# movie_id: 11447
# true director: Michael Galinsky;Suki Hawley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05444002151489258
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013141632080078125
# Discarted candidate: []
# Possible candidate: [{'galinsky michael': 4, 'hawley suki': 6}]
# lengthNecessary: 3.5
# [{'galinsky michael': 4, 'hawley suki': 6}]
# acceptance_diff 3
# ['galinsky michael', 'hawley suki'] VS true_author: ['galinsky michael', 'hawley suki']
# movie_id: 92995
# true director: Chatrichalerm Yukol
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02424001693725586
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015079975128173828
# Discarted candidate: []
# Possible candidate: [{'chatrichalerm yukoi': 2, 'chatrichalerm yukol': 2}]
# lengthNecessary: 1.4
# [{'chatrichalerm yukoi': 2, 'chatrichalerm yukol': 2}]
# acceptance_diff 3
# ['chatrichalerm yukoi'] VS true_author: ['chatrichalerm yukol']
# movie_id: 45317
# true director: Richard Talmadge;Harvey Parry
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03925299644470215
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0017311573028564453
# Discarted candidate: []
# Possible candidate: [{'harvey parry': 3, 'richard talmadge': 1}]
# lengthNecessary: 1.4
# [{'harvey parry': 3, 'richard talmadge': 1}]
# acceptance_diff 3
# ['harvey parry', 'richard talmadge'] VS true_author: ['richard talmadge', 'harvey parry']
# movie_id: 57325
# true director: Keiichi Hara
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07288384437561035
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002273082733154297
# Discarted candidate: []
# Possible candidate: [{'hara keiichi': 11, 'michael sinterniklaas': 6, 'sheh stephanie': 6}]
# lengthNecessary: 8.049999999999999
# [{'hara keiichi': 11, 'michael sinterniklaas': 6, 'sheh stephanie': 6}]
# acceptance_diff 3
# ['hara keiichi'] VS true_author: ['hara keiichi']
# movie_id: 96819
# true director: Yves Allegret
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07518482208251953
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0008068084716796875
# Discarted candidate: []
# Possible candidate: [{'allegret yves': 2, 'e portas rafael': 1}]
# lengthNecessary: 1.0499999999999998
# [{'allegret yves': 2, 'e portas rafael': 1}]
# acceptance_diff 3
# ['allegret yves', 'e portas rafael'] VS true_author: ['allegret yves']
# movie_id: 24035
# true director: William Tannen;Larry Cohen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.058032989501953125
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002110004425048828
# Discarted candidate: []
# Possible candidate: [{'cohen larry': 6, 'tannen william': 4}]
# lengthNecessary: 3.5
# [{'cohen larry': 6, 'tannen william': 4}]
# acceptance_diff 3
# ['cohen larry', 'tannen william'] VS true_author: ['cohen larry', 'tannen william']
# movie_id: 5820
# true director: Ananth Narayan Mahadevan
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.041452884674072266
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014121532440185547
# Discarted candidate: []
# Possible candidate: [{'anant mahadevan': 1, 'ananth mahadevan narayan': 3}]
# lengthNecessary: 1.4
# [{'anant mahadevan': 1, 'ananth mahadevan narayan': 3}]
# acceptance_diff 3
# ['anant mahadevan', 'ananth mahadevan narayan'] VS true_author: ['ananth mahadevan narayan']
# movie_id: 14372
# true director: Joel Coen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05309104919433594
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013458728790283203
# Discarted candidate: []
# Possible candidate: [{'coen ethan': 7, 'coen joel': 13}]
# lengthNecessary: 7.0
# [{'coen ethan': 7, 'coen joel': 13}]
# acceptance_diff 3
# ['coen joel'] VS true_author: ['coen joel']
# movie_id: 2550
# true director: Jean-Luc Godard
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.032553911209106445
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009691715240478516
# Discarted candidate: []
# Possible candidate: [{'dziga groupe vertov': 1, 'godard jean-luc': 3}]
# lengthNecessary: 1.4
# [{'dziga groupe vertov': 1, 'godard jean-luc': 3}]
# acceptance_diff 3
# ['dziga groupe vertov', 'godard jean-luc'] VS true_author: ['godard jean-luc']
# movie_id: 8413
# true director: Adam Small;Peter Stuart
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05400395393371582
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013241767883300781
# Discarted candidate: []
# Possible candidate: [{'adam small': 9, 'peter stuart': 7}]
# lengthNecessary: 5.6
# [{'adam small': 9, 'peter stuart': 7}]
# acceptance_diff 3
# ['adam small', 'peter stuart'] VS true_author: ['adam small', 'peter stuart']
# movie_id: 93760
# true director: Caradog W. James
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.028908729553222656
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001252889633178711
# Discarted candidate: []
# Possible candidate: [{'caradog james': 3, 'caradog james w': 1}]
# lengthNecessary: 1.4
# [{'caradog james': 3, 'caradog james w': 1}]
# acceptance_diff 3
# ['caradog james'] VS true_author: ['caradog james w']
# movie_id: 93024
# true director: Phil Lord;Christopher Miller
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1957859992980957
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.006439924240112305
# Discarted candidate: []
# Possible candidate: [{'chris mckay': 2, 'chris miller': 8, 'christopher miller': 15, 'lord phil': 28}]
# lengthNecessary: 18.549999999999997
# [{'chris mckay': 2, 'chris miller': 8, 'christopher miller': 15, 'lord phil': 28}]
# acceptance_diff 3
# ['lord phil'] VS true_author: ['lord phil', 'christopher miller']
# movie_id: 63252
# true director: Gabriele Del Grande;Khaled Soliman Al Nassiry;Antonio Augugliaro
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.10359692573547363
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0038721561431884766
# Discarted candidate: []
# Possible candidate: [{'al khaled nassiry soliman': 1, 'antonio augugliaro': 2, 'del gabriele grande': 1}]
# lengthNecessary: 1.4
# [{'al khaled nassiry soliman': 1, 'antonio augugliaro': 2, 'del gabriele grande': 1}]
# acceptance_diff 3
# ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande'] VS true_author: ['al khaled nassiry soliman', 'antonio augugliaro', 'del gabriele grande']
# movie_id: 76340
# true director: Prince
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.046840667724609375
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011911392211914062
# Discarted candidate: []
# Possible candidate: [{'albert magnoli': 3, 'prince': 6}]
# lengthNecessary: 3.15
# [{'albert magnoli': 3, 'prince': 6}]
# acceptance_diff 3
# ['albert magnoli', 'prince'] VS true_author: ['prince']
# movie_id: 21613
# true director: Andrzej Bartkowiak
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09572696685791016
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002216815948486328
# Discarted candidate: []
# Possible candidate: [{'andrzej bartkowiak': 19, 'andrzek bartkowiak': 1}]
# lengthNecessary: 7.0
# [{'andrzej bartkowiak': 19, 'andrzek bartkowiak': 1}]
# acceptance_diff 3
# ['andrzej bartkowiak'] VS true_author: ['andrzej bartkowiak']
# movie_id: 80167
# true director: Sandra Martin;Hugues Martin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07321906089782715
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0018868446350097656
# Discarted candidate: []
# Possible candidate: [{'hugues martin': 4, 'martin sandra': 2}]
# lengthNecessary: 2.0999999999999996
# [{'hugues martin': 4, 'martin sandra': 2}]
# acceptance_diff 3
# ['hugues martin', 'martin sandra'] VS true_author: ['martin sandra', 'hugues martin']
# movie_id: 82271
# true director: Marvin J. Chomsky
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.1087799072265625
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.005453824996948242
# Discarted candidate: []
# Possible candidate: [{'chomsky j marvin': 17, 'chomsky marvin': 1}]
# lengthNecessary: 6.3
# [{'chomsky j marvin': 17, 'chomsky marvin': 1}]
# acceptance_diff 3
# ['chomsky j marvin'] VS true_author: ['chomsky j marvin']
# movie_id: 7494
# true director: Tommy O'Haver
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07340598106384277
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013189315795898438
# Discarted candidate: []
# Possible candidate: [{"o'haver tommy": 7, 'ohaver tommy': 3}]
# lengthNecessary: 3.5
# [{"o'haver tommy": 7, 'ohaver tommy': 3}]
# acceptance_diff 3
# ["o'haver tommy"] VS true_author: ["o'haver tommy"]
# movie_id: 16640
# true director: Timothy Marrinan;Richard Dewey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.028866052627563477
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001069784164428711
# Discarted candidate: []
# Possible candidate: [{'dewey richard': 1, 'marrinan timothy': 2}]
# lengthNecessary: 1.0499999999999998
# [{'dewey richard': 1, 'marrinan timothy': 2}]
# acceptance_diff 3
# ['dewey richard', 'marrinan timothy'] VS true_author: ['dewey richard', 'marrinan timothy']
# movie_id: 101119
# true director: Chris Hegedus;D. A. Pennebaker
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04469776153564453
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012629032135009766
# Discarted candidate: []
# Possible candidate: [{'a d pennebaker': 9, 'chris hegedus': 7}]
# lengthNecessary: 5.6
# [{'a d pennebaker': 9, 'chris hegedus': 7}]
# acceptance_diff 3
# ['a d pennebaker', 'chris hegedus'] VS true_author: ['chris hegedus', 'a d pennebaker']
# movie_id: 17046
# true director: Paolo Taviani;Vittorio Taviani
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04141974449157715
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0026068687438964844
# Discarted candidate: []
# Possible candidate: [{'paolo taviani': 4, 'taviani vittorio': 2}]
# lengthNecessary: 2.0999999999999996
# [{'paolo taviani': 4, 'taviani vittorio': 2}]
# acceptance_diff 3
# ['paolo taviani', 'taviani vittorio'] VS true_author: ['paolo taviani', 'taviani vittorio']
# movie_id: 80539
# true director: Karan Johar
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.11144804954528809
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0018024444580078125
# Discarted candidate: []
# Possible candidate: [{'abhishek varman': 2, 'johar karan': 10}]
# lengthNecessary: 4.199999999999999
# [{'abhishek varman': 2, 'johar karan': 10}]
# acceptance_diff 3
# ['johar karan'] VS true_author: ['johar karan']
# movie_id: 111871
# true director: Anlo Sepulveda;Paul Collins
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06043815612792969
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001332998275756836
# Discarted candidate: []
# Possible candidate: [{'anlo sepulveda': 3, 'collins paul': 2}]
# lengthNecessary: 1.75
# [{'anlo sepulveda': 3, 'collins paul': 2}]
# acceptance_diff 3
# ['anlo sepulveda', 'collins paul'] VS true_author: ['anlo sepulveda', 'collins paul']
# movie_id: 31082
# true director: Slatan Dudow;Kurt Maetzig
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04698824882507324
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013077259063720703
# Discarted candidate: []
# Possible candidate: [{'dudow slatan': 2, 'groschopp richard': 1, 'kurt maetzig': 1}]
# lengthNecessary: 1.4
# [{'dudow slatan': 2, 'groschopp richard': 1, 'kurt maetzig': 1}]
# acceptance_diff 3
# ['dudow slatan', 'groschopp richard', 'kurt maetzig'] VS true_author: ['dudow slatan', 'kurt maetzig']
# movie_id: 2672
# true director: Christian Krones;Olaf S. Muller;Roland Schrotthofer;Florian Weigensamer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0669412612915039
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0021271705627441406
# Discarted candidate: []
# Possible candidate: [{'christian krones': 1, 'florian weigensamer': 2, 'muller olaf s': 1, 'roland schrotthofer': 1}]
# lengthNecessary: 1.75
# [{'christian krones': 1, 'florian weigensamer': 2, 'muller olaf s': 1, 'roland schrotthofer': 1}]
# acceptance_diff 3
# ['christian krones', 'florian weigensamer', 'muller olaf s', 'roland schrotthofer'] VS true_author: ['muller olaf s', 'roland schrotthofer', 'florian weigensamer', 'christian krones']
# movie_id: 91427
# true director: Robert Rossen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.07007002830505371
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011827945709228516
# Discarted candidate: []
# Possible candidate: [{'blue washington': 1, 'robert rossen': 9}]
# lengthNecessary: 3.5
# [{'blue washington': 1, 'robert rossen': 9}]
# acceptance_diff 3
# ['robert rossen'] VS true_author: ['robert rossen']
# movie_id: 2813
# true director: Michael Tiddes
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03610110282897949
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014638900756835938
# Discarted candidate: []
# Possible candidate: [{'michael tiddes': 11, 'mike tiddes': 2}]
# lengthNecessary: 4.55
# [{'michael tiddes': 11, 'mike tiddes': 2}]
# acceptance_diff 3
# ['michael tiddes'] VS true_author: ['michael tiddes']
# movie_id: 15123
# true director: Jon Bulette;Stone Roberts
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05043292045593262
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004021883010864258
# Discarted candidate: []
# Possible candidate: [{'bulette jon': 3, 'f roberts stone': 1, 'roberts stone': 1}]
# lengthNecessary: 1.75
# [{'bulette jon': 3, 'f roberts stone': 1, 'roberts stone': 1}]
# acceptance_diff 3
# ['bulette jon', 'f roberts stone'] VS true_author: ['bulette jon', 'roberts stone']
# movie_id: 30280
# true director: Anthony Stabley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.054778099060058594
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014069080352783203
# Discarted candidate: []
# Possible candidate: [{'anthony r stabley': 3, 'anthony stabley': 8}]
# lengthNecessary: 3.8499999999999996
# [{'anthony r stabley': 3, 'anthony stabley': 8}]
# acceptance_diff 3
# ['anthony stabley'] VS true_author: ['anthony stabley']
# movie_id: 68652
# true director: Adam Kassen;Mark Kassen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04170680046081543
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001708984375
# Discarted candidate: []
# Possible candidate: [{'adam kassen': 8, 'kassen mark': 9}]
# lengthNecessary: 5.949999999999999
# [{'adam kassen': 8, 'kassen mark': 9}]
# acceptance_diff 3
# ['adam kassen', 'kassen mark'] VS true_author: ['kassen mark', 'adam kassen']
# movie_id: 21609
# true director: Rowby Goren;Chuck Staley
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04589271545410156
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009839534759521484
# Discarted candidate: []
# Possible candidate: [{'chuck staley': 3, 'goren rowby': 6}]
# lengthNecessary: 3.15
# [{'chuck staley': 3, 'goren rowby': 6}]
# acceptance_diff 3
# ['chuck staley', 'goren rowby'] VS true_author: ['chuck staley', 'goren rowby']
# movie_id: 37872
# true director: Michael Almereyda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03292989730834961
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009791851043701172
# Discarted candidate: []
# Possible candidate: [{'almereyda michael': 5, 'campbell scott': 1}]
# lengthNecessary: 2.0999999999999996
# [{'almereyda michael': 5, 'campbell scott': 1}]
# acceptance_diff 3
# ['almereyda michael'] VS true_author: ['almereyda michael']
# movie_id: 45447
# true director: Fred C. Brannon;Thomas Carr
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06268882751464844
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001049041748046875
# Discarted candidate: []
# Possible candidate: [{'brannon c fred': 6, 'carr thomas': 3}]
# lengthNecessary: 3.15
# [{'brannon c fred': 6, 'carr thomas': 3}]
# acceptance_diff 3
# ['brannon c fred', 'carr thomas'] VS true_author: ['carr thomas', 'brannon c fred']
# movie_id: 24661
# true director: Matthew Celestre;Brett Celestre
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.025873184204101562
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009791851043701172
# Discarted candidate: []
# Possible candidate: [{'brett celestre': 1, 'brette celestre': 2, 'celestre matthew': 1}]
# lengthNecessary: 1.4
# [{'brett celestre': 1, 'brette celestre': 2, 'celestre matthew': 1}]
# acceptance_diff 3
# ['brett celestre', 'celestre matthew'] VS true_author: ['brett celestre', 'celestre matthew']
# movie_id: 3648
# true director: Nikolaj Arcel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.024204015731811523
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012218952178955078
# Discarted candidate: []
# Possible candidate: [{'arcel nikaolaj': 2, 'arcel nikolaj': 14}]
# lengthNecessary: 5.6
# [{'arcel nikaolaj': 2, 'arcel nikolaj': 14}]
# acceptance_diff 3
# ['arcel nikolaj'] VS true_author: ['arcel nikolaj']
# movie_id: 13479
# true director: Ergin Orbey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.028812170028686523
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009930133819580078
# Discarted candidate: []
# Possible candidate: [{'engin orbey': 8, 'ergin orbey': 1}]
# lengthNecessary: 3.15
# [{'engin orbey': 8, 'ergin orbey': 1}]
# acceptance_diff 3
# ['engin orbey'] VS true_author: ['ergin orbey']
# movie_id: 18319
# true director: Baird Bryant;Johanna Demetrakas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03994321823120117
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001134634017944336
# Discarted candidate: []
# Possible candidate: [{'baird bryant': 8, 'demetrakas johanna': 5}]
# lengthNecessary: 4.55
# [{'baird bryant': 8, 'demetrakas johanna': 5}]
# acceptance_diff 3
# ['baird bryant', 'demetrakas johanna'] VS true_author: ['baird bryant', 'demetrakas johanna']
# movie_id: 44223
# true director: Gene Kelly
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04929995536804199
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013990402221679688
# Discarted candidate: []
# Possible candidate: [{'freddie young': 1, 'gene kelly': 8}]
# lengthNecessary: 3.15
# [{'freddie young': 1, 'gene kelly': 8}]
# acceptance_diff 3
# ['gene kelly'] VS true_author: ['gene kelly']
# movie_id: 71075
# true director: David Twohy
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06923699378967285
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002228975296020508
# Discarted candidate: []
# Possible candidate: [{'david n twohy': 1, 'david twohy': 24}]
# lengthNecessary: 8.75
# [{'david n twohy': 1, 'david twohy': 24}]
# acceptance_diff 3
# ['david twohy'] VS true_author: ['david twohy']
# movie_id: 80410
# true director: Paul Ragsdale
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.06709122657775879
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012748241424560547
# Discarted candidate: []
# Possible candidate: [{'alba angelica de': 3, 'paul ragsdale': 6}]
# lengthNecessary: 3.15
# [{'alba angelica de': 3, 'paul ragsdale': 6}]
# acceptance_diff 3
# ['alba angelica de', 'paul ragsdale'] VS true_author: ['paul ragsdale']
# movie_id: 71705
# true director: Allan Arkush
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05905294418334961
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013592243194580078
# Discarted candidate: []
# Possible candidate: [{'allan arkush': 13, 'dante joe': 6}]
# lengthNecessary: 6.6499999999999995
# [{'allan arkush': 13, 'dante joe': 6}]
# acceptance_diff 3
# ['allan arkush'] VS true_author: ['allan arkush']
# movie_id: 91114
# true director: Tian Zhuangzhuang
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.034510135650634766
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012009143829345703
# Discarted candidate: []
# Possible candidate: [{'pan peicheng': 3, 'tian zhuangzhuang': 3}]
# lengthNecessary: 2.0999999999999996
# [{'pan peicheng': 3, 'tian zhuangzhuang': 3}]
# acceptance_diff 3
# ['pan peicheng', 'tian zhuangzhuang'] VS true_author: ['tian zhuangzhuang']
# movie_id: 100574
# true director: Michael Hegner;Karsten Kiilerich
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03311514854431152
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001127004623413086
# Discarted candidate: []
# Possible candidate: [{'hegner michael': 6, 'karsten kiilerich': 4}]
# lengthNecessary: 3.5
# [{'hegner michael': 6, 'karsten kiilerich': 4}]
# acceptance_diff 3
# ['hegner michael', 'karsten kiilerich'] VS true_author: ['hegner michael', 'karsten kiilerich']
# movie_id: 22475
# true director: Kevin King
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.051396846771240234
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010161399841308594
# Discarted candidate: []
# Possible candidate: [{'k king': 6, 'kevin king': 3}]
# lengthNecessary: 3.15
# [{'k king': 6, 'kevin king': 3}]
# acceptance_diff 3
# ['k king', 'kevin king'] VS true_author: ['kevin king']
# movie_id: 57809
# true director: John Lamb
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0462038516998291
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001146078109741211
# Discarted candidate: []
# Possible candidate: [{'hill jack': 2, 'john lamb': 1}]
# lengthNecessary: 1.0499999999999998
# [{'hill jack': 2, 'john lamb': 1}]
# acceptance_diff 3
# ['hill jack', 'john lamb'] VS true_author: ['john lamb']
# movie_id: 97278
# true director: Norman Panama;Melvin Frank
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05369281768798828
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013120174407958984
# Discarted candidate: []
# Possible candidate: [{'frank melvin': 4, 'norman panama': 3}]
# lengthNecessary: 2.4499999999999997
# [{'frank melvin': 4, 'norman panama': 3}]
# acceptance_diff 3
# ['frank melvin', 'norman panama'] VS true_author: ['norman panama', 'frank melvin']
# movie_id: 106242
# true director: Gionata Zarantonello
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.025188684463500977
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.00051116943359375
# Discarted candidate: []
# Possible candidate: [{'gionata zarantonello': 1, 'jonathan zarantonello': 1}]
# lengthNecessary: 0.7
# [{'gionata zarantonello': 1, 'jonathan zarantonello': 1}]
# acceptance_diff 3
# ['gionata zarantonello'] VS true_author: ['gionata zarantonello']
# movie_id: 81911
# true director: Kang Je-Gyu
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.055999040603637695
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015900135040283203
# Discarted candidate: []
# Possible candidate: [{'gyu je kang': 1, 'je-gyu kang': 13, 'je-kyu kang': 7}]
# lengthNecessary: 7.35
# [{'gyu je kang': 1, 'je-gyu kang': 13, 'je-kyu kang': 7}]
# acceptance_diff 3
# ['je-gyu kang'] VS true_author: ['je-gyu kang']
# movie_id: 87781
# true director: Alistair Legrand
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.047289133071899414
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013689994812011719
# Discarted candidate: []
# Possible candidate: [{'alistair legrand': 16, 'callaway ryan': 1}]
# lengthNecessary: 5.949999999999999
# [{'alistair legrand': 16, 'callaway ryan': 1}]
# acceptance_diff 3
# ['alistair legrand'] VS true_author: ['alistair legrand']
# movie_id: 49079
# true director: Fernando Palacios
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03797197341918945
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009851455688476562
# Discarted candidate: []
# Possible candidate: [{'fernando palacios': 2, 'j rafael salvia': 3}]
# lengthNecessary: 1.75
# [{'fernando palacios': 2, 'j rafael salvia': 3}]
# acceptance_diff 3
# ['fernando palacios', 'j rafael salvia'] VS true_author: ['fernando palacios']
# movie_id: 43271
# true director: R. Kiplin Pastor
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.032933712005615234
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010004043579101562
# Discarted candidate: []
# Possible candidate: [{'kip pastor': 3, 'kiplin pastor r': 1}]
# lengthNecessary: 1.4
# [{'kip pastor': 3, 'kiplin pastor r': 1}]
# acceptance_diff 3
# ['kip pastor', 'kiplin pastor r'] VS true_author: ['kiplin pastor r']
# movie_id: 43726
# true director: Quentin Tarantino
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0638117790222168
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.002546072006225586
# Discarted candidate: []
# Possible candidate: [{'eli roth': 12, 'quentin tarantino': 27}]
# lengthNecessary: 13.649999999999999
# [{'eli roth': 12, 'quentin tarantino': 27}]
# acceptance_diff 3
# ['quentin tarantino'] VS true_author: ['quentin tarantino']
# movie_id: 28418
# true director: Sharunas Bartas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.022413969039916992
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0007669925689697266
# Discarted candidate: []
# Possible candidate: [{'bartas sar?nas': 1, 'bartas sharunas': 1}]
# lengthNecessary: 0.7
# [{'bartas sar?nas': 1, 'bartas sharunas': 1}]
# acceptance_diff 3
# ['bartas sar?nas'] VS true_author: ['bartas sharunas']
# movie_id: 111254
# true director: Luke Jaden;Cort Johns
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0377500057220459
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010859966278076172
# Discarted candidate: []
# Possible candidate: [{'cort johns': 2, 'jaden luke': 4}]
# lengthNecessary: 2.0999999999999996
# [{'cort johns': 2, 'jaden luke': 4}]
# acceptance_diff 3
# ['cort johns', 'jaden luke'] VS true_author: ['cort johns', 'jaden luke']
# movie_id: 69205
# true director: Nancy Glass;Michele Loschiavo
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.030673980712890625
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009961128234863281
# Discarted candidate: []
# Possible candidate: [{'glass nancy': 2, 'loschiavo michele': 1}]
# lengthNecessary: 1.0499999999999998
# [{'glass nancy': 2, 'loschiavo michele': 1}]
# acceptance_diff 3
# ['glass nancy', 'loschiavo michele'] VS true_author: ['loschiavo michele', 'glass nancy']
# movie_id: 40048
# true director: Manuel Gonzalez Mauricio;Saul Barreto Ramos
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.035701751708984375
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009829998016357422
# Discarted candidate: []
# Possible candidate: [{'barreto ramos saul': 1, 'gonzalez manuel mauricio': 2}]
# lengthNecessary: 1.0499999999999998
# [{'barreto ramos saul': 1, 'gonzalez manuel mauricio': 2}]
# acceptance_diff 3
# ['barreto ramos saul', 'gonzalez manuel mauricio'] VS true_author: ['gonzalez manuel mauricio', 'barreto ramos saul']
# movie_id: 57896
# true director: Andrew V. McLaglen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03268599510192871
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010919570922851562
# Discarted candidate: []
# Possible candidate: [{'andrew mclaglen': 2, 'andrew mclaglen v': 6}]
# lengthNecessary: 2.8
# [{'andrew mclaglen': 2, 'andrew mclaglen v': 6}]
# acceptance_diff 3
# ['andrew mclaglen v'] VS true_author: ['andrew mclaglen v']
# movie_id: 32707
# true director: Paul Morrissey
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.035806894302368164
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014100074768066406
# Discarted candidate: []
# Possible candidate: [{'antonio margheriti': 2, 'morrissey paul': 6}]
# lengthNecessary: 2.8
# [{'antonio margheriti': 2, 'morrissey paul': 6}]
# acceptance_diff 3
# ['morrissey paul'] VS true_author: ['morrissey paul']
# movie_id: 80601
# true director: Frank Capra
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04885673522949219
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016870498657226562
# Discarted candidate: []
# Possible candidate: [{'capra frank': 5, 'irvin willat': 3}]
# lengthNecessary: 2.8
# [{'capra frank': 5, 'irvin willat': 3}]
# acceptance_diff 3
# ['capra frank', 'irvin willat'] VS true_author: ['capra frank']
# movie_id: 109103
# true director: Dick Zondag;Ralph Zondag;Phil Nibbelink;Simon Wells
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09589695930480957
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.005850076675415039
# Discarted candidate: []
# Possible candidate: [{'dick zondag': 12, 'nibbelink phil': 14, 'ralph zondag': 12, 'simon wells': 12}]
# lengthNecessary: 17.5
# [{'dick zondag': 12, 'nibbelink phil': 14, 'ralph zondag': 12, 'simon wells': 12}]
# acceptance_diff 3
# ['dick zondag', 'nibbelink phil', 'ralph zondag', 'simon wells'] VS true_author: ['dick zondag', 'simon wells', 'ralph zondag', 'nibbelink phil']
# movie_id: 76115
# true director: Adam Friedman;Iain Kennedy
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0403900146484375
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001268148422241211
# Discarted candidate: []
# Possible candidate: [{'adam friedman': 7, 'iain kennedy': 5}]
# lengthNecessary: 4.199999999999999
# [{'adam friedman': 7, 'iain kennedy': 5}]
# acceptance_diff 3
# ['adam friedman', 'iain kennedy'] VS true_author: ['iain kennedy', 'adam friedman']
# movie_id: 60263
# true director: Bill Guttentag;Dan Sturman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04781198501586914
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0021979808807373047
# Discarted candidate: []
# Possible candidate: [{'bill guttentag': 14, 'dan sturman': 9}]
# lengthNecessary: 8.049999999999999
# [{'bill guttentag': 14, 'dan sturman': 9}]
# acceptance_diff 3
# ['bill guttentag'] VS true_author: ['bill guttentag', 'dan sturman']
# movie_id: 35119
# true director: Cynthia Wade;Cheryl Miller Houser
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.056787967681884766
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012121200561523438
# Discarted candidate: []
# Possible candidate: [{'cheryl houser': 1, 'cheryl houser miller': 4, 'cynthia wade': 6}]
# lengthNecessary: 3.8499999999999996
# [{'cheryl houser': 1, 'cheryl houser miller': 4, 'cynthia wade': 6}]
# acceptance_diff 3
# ['cheryl houser miller', 'cynthia wade'] VS true_author: ['cynthia wade', 'cheryl houser miller']
# movie_id: 97251
# true director: Michael Dudok De Wit
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03831791877746582
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012280941009521484
# Discarted candidate: []
# Possible candidate: [{'de dudok michael wit': 3, 'dewit dudok michael': 1}]
# lengthNecessary: 1.4
# [{'de dudok michael wit': 3, 'dewit dudok michael': 1}]
# acceptance_diff 3
# ['de dudok michael wit'] VS true_author: ['de dudok michael wit']
# movie_id: 90003
# true director: Charles Chaplin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04162883758544922
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.00167083740234375
# Discarted candidate: []
# Possible candidate: [{'chaplin charles': 13, 'chaplin charlie': 6}]
# lengthNecessary: 6.6499999999999995
# [{'chaplin charles': 13, 'chaplin charlie': 6}]
# acceptance_diff 3
# ['chaplin charles'] VS true_author: ['chaplin charles']
# movie_id: 91535
# true director: J. A. Bayona
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.048995018005371094
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0030679702758789062
# Discarted candidate: []
# Possible candidate: [{'a bayona j': 7, 'antonio bayona juan': 15}]
# lengthNecessary: 7.699999999999999
# [{'a bayona j': 7, 'antonio bayona juan': 15}]
# acceptance_diff 3
# ['antonio bayona juan'] VS true_author: ['a bayona j']
# movie_id: 51346
# true director: William A. Seiter
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04111123085021973
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010690689086914062
# Discarted candidate: []
# Possible candidate: [{'a seiter william': 2, 'seiter william': 1}]
# lengthNecessary: 1.0499999999999998
# [{'a seiter william': 2, 'seiter william': 1}]
# acceptance_diff 3
# ['a seiter william'] VS true_author: ['a seiter william']
# movie_id: 64713
# true director: Alan Mak;Felix Chong
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04071187973022461
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014107227325439453
# Discarted candidate: []
# Possible candidate: [{'alan mak': 5, 'chong felix': 8}]
# lengthNecessary: 4.55
# [{'alan mak': 5, 'chong felix': 8}]
# acceptance_diff 3
# ['alan mak', 'chong felix'] VS true_author: ['alan mak', 'chong felix']
# movie_id: 87307
# true director: Florian Cossen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.021540164947509766
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001500844955444336
# Discarted candidate: []
# Possible candidate: [{'cossen florian': 1, 'cossen florian micoud': 1}]
# lengthNecessary: 0.7
# [{'cossen florian': 1, 'cossen florian micoud': 1}]
# acceptance_diff 3
# ['cossen florian', 'cossen florian micoud'] VS true_author: ['cossen florian']
# movie_id: 89712
# true director: Mauro Borrelli
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0226743221282959
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011110305786132812
# Discarted candidate: []
# Possible candidate: [{'borrelli maura': 1, 'borrelli mauro': 2}]
# lengthNecessary: 1.0499999999999998
# [{'borrelli maura': 1, 'borrelli mauro': 2}]
# acceptance_diff 3
# ['borrelli maura'] VS true_author: ['borrelli mauro']
# movie_id: 11264
# true director: Rex Ingram
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02927684783935547
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001458883285522461
# Discarted candidate: []
# Possible candidate: [{'alice terry': 1, 'ingram rex': 2}]
# lengthNecessary: 1.0499999999999998
# [{'alice terry': 1, 'ingram rex': 2}]
# acceptance_diff 3
# ['alice terry', 'ingram rex'] VS true_author: ['ingram rex']
# movie_id: 48608
# true director: John Stevenson;Mark Osborne
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.09925007820129395
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.004186868667602539
# Discarted candidate: []
# Possible candidate: [{'john stevenson': 25, 'mark osborne': 31}]
# lengthNecessary: 19.599999999999998
# [{'john stevenson': 25, 'mark osborne': 31}]
# acceptance_diff 3
# ['mark osborne'] VS true_author: ['john stevenson', 'mark osborne']
# movie_id: 5451
# true director: Claudio Marques;Marilia Hughes
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03131389617919922
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014269351959228516
# Discarted candidate: []
# Possible candidate: [{'claudio marques': 3, 'guerreiro hughes marilia': 2, 'hughes marilia': 1}]
# lengthNecessary: 2.0999999999999996
# [{'claudio marques': 3, 'guerreiro hughes marilia': 2, 'hughes marilia': 1}]
# acceptance_diff 3
# ['claudio marques', 'guerreiro hughes marilia', 'hughes marilia'] VS true_author: ['claudio marques', 'hughes marilia']
# movie_id: 29810
# true director: Herrmann Zschoche
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02859187126159668
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001132965087890625
# Discarted candidate: []
# Possible candidate: [{'dressel eleonore': 4, 'herrmann zschoche': 8}]
# lengthNecessary: 4.199999999999999
# [{'dressel eleonore': 4, 'herrmann zschoche': 8}]
# acceptance_diff 3
# ['herrmann zschoche'] VS true_author: ['herrmann zschoche']
# movie_id: 78918
# true director: Marc Gracie;Tim Ferguson
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03775310516357422
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0011320114135742188
# Discarted candidate: []
# Possible candidate: [{'ferguson tim': 5, 'gracie marc': 6}]
# lengthNecessary: 3.8499999999999996
# [{'ferguson tim': 5, 'gracie marc': 6}]
# acceptance_diff 3
# ['ferguson tim', 'gracie marc'] VS true_author: ['gracie marc', 'ferguson tim']
# movie_id: 71440
# true director: Otto Preminger
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.032724857330322266
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0025129318237304688
# Discarted candidate: []
# ...
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009641647338867188
# Discarted candidate: []
# Possible candidate: [{'l?a pool': 1, 'lea pool': 3}]
# lengthNecessary: 1.4
# [{'l?a pool': 1, 'lea pool': 3}]
# acceptance_diff 3
# ['l?a pool'] VS true_author: ['lea pool']
# movie_id: 69925
# true director: Heidi Maria Faisst
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02878427505493164
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0004911422729492188
# Discarted candidate: []
# Possible candidate: [{'faissi heidi maria': 1, 'faisst heidi maria': 1}]
# lengthNecessary: 0.7
# [{'faissi heidi maria': 1, 'faisst heidi maria': 1}]
# acceptance_diff 3
# ['faissi heidi maria'] VS true_author: ['faisst heidi maria']
# movie_id: 47283
# true director: Carl Astrand;Mats Lindberg
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.048502206802368164
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001155853271484375
# Discarted candidate: []
# Possible candidate: [{'astrand carl': 6, 'lindberg mats': 9}]
# lengthNecessary: 5.25
# [{'astrand carl': 6, 'lindberg mats': 9}]
# acceptance_diff 3
# ['astrand carl', 'lindberg mats'] VS true_author: ['astrand carl', 'lindberg mats']
# movie_id: 40393
# true director: Ewing Scott
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03969216346740723
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010499954223632812
# Discarted candidate: []
# Possible candidate: [{'ewing scott': 8, 'george sherman': 3}]
# lengthNecessary: 3.8499999999999996
# [{'ewing scott': 8, 'george sherman': 3}]
# acceptance_diff 3
# ['ewing scott'] VS true_author: ['ewing scott']
# movie_id: 35829
# true director: Michael Paul Stephenson
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04143786430358887
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009846687316894531
# Discarted candidate: []
# Possible candidate: [{'michael paul stephenson': 6, 'michael stephenson': 2}]
# lengthNecessary: 2.8
# [{'michael paul stephenson': 6, 'michael stephenson': 2}]
# acceptance_diff 3
# ['michael paul stephenson'] VS true_author: ['michael paul stephenson']
# movie_id: 27116
# true director: Neil Marshall
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.041870832443237305
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001336812973022461
# Discarted candidate: []
# Possible candidate: [{'marshall neil': 18, 'universal': 1}]
# lengthNecessary: 6.6499999999999995
# [{'marshall neil': 18, 'universal': 1}]
# acceptance_diff 3
# ['marshall neil'] VS true_author: ['marshall neil']
# movie_id: 49163
# true director: Vicente Aranda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02936410903930664
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013401508331298828
# Discarted candidate: []
# Possible candidate: [{'aranda vicente': 3, 'gomez raul': 2}]
# lengthNecessary: 1.75
# [{'aranda vicente': 3, 'gomez raul': 2}]
# acceptance_diff 3
# ['aranda vicente', 'gomez raul'] VS true_author: ['aranda vicente']
# movie_id: 64814
# true director: R. Balki
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.0323033332824707
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010039806365966797
# Discarted candidate: []
# Possible candidate: [{'balki r': 4, 'ricky sandhu': 1}]
# lengthNecessary: 1.75
# [{'balki r': 4, 'ricky sandhu': 1}]
# acceptance_diff 3
# ['balki r', 'ricky sandhu'] VS true_author: ['balki r']
# movie_id: 87155
# true director: Jiri Svoboda
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03953409194946289
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015399456024169922
# Discarted candidate: []
# Possible candidate: [{'ji?i svoboda': 6, 'jiri svoboda': 1}]
# lengthNecessary: 2.4499999999999997
# [{'ji?i svoboda': 6, 'jiri svoboda': 1}]
# acceptance_diff 3
# ['ji?i svoboda'] VS true_author: ['jiri svoboda']
# movie_id: 19545
# true director: Charles Chu;Gavin Kelly
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.034085988998413086
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010018348693847656
# Discarted candidate: []
# Possible candidate: [{'charles chu': 1, 'gavin kelly': 2}]
# lengthNecessary: 1.0499999999999998
# [{'charles chu': 1, 'gavin kelly': 2}]
# acceptance_diff 3
# ['charles chu', 'gavin kelly'] VS true_author: ['charles chu', 'gavin kelly']
# movie_id: 46270
# true director: Seung-Hyeon Jin
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03279590606689453
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009672641754150391
# Discarted candidate: []
# Possible candidate: [{'hyeonh jin seung': 2, 'jin seung-hyeon': 2}]
# lengthNecessary: 1.4
# [{'hyeonh jin seung': 2, 'jin seung-hyeon': 2}]
# acceptance_diff 3
# ['hyeonh jin seung', 'jin seung-hyeon'] VS true_author: ['jin seung-hyeon']
# movie_id: 73371
# true director: Andrew Becker;Daniel Mehrer
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.028885841369628906
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0009648799896240234
# Discarted candidate: []
# Possible candidate: [{'andrew becker': 2, 'daniel mehrer': 1}]
# lengthNecessary: 1.0499999999999998
# [{'andrew becker': 2, 'daniel mehrer': 1}]
# acceptance_diff 3
# ['andrew becker', 'daniel mehrer'] VS true_author: ['daniel mehrer', 'andrew becker']
# movie_id: 61155
# true director: Chan-wook Park
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.027462005615234375
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001226186752319336
# Discarted candidate: []
# Possible candidate: [{'chan-kyong park': 5, 'chan-wook park': 6}]
# lengthNecessary: 3.8499999999999996
# [{'chan-kyong park': 5, 'chan-wook park': 6}]
# acceptance_diff 3
# ['chan-kyong park', 'chan-wook park'] VS true_author: ['chan-wook park']
# movie_id: 111258
# true director: Michael Wadleigh
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05608868598937988
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0018439292907714844
# Discarted candidate: []
# Possible candidate: [{'d hancock john': 6, 'hitzig rupert': 4, 'michael wadleigh': 15}]
# lengthNecessary: 8.75
# [{'d hancock john': 6, 'hitzig rupert': 4, 'michael wadleigh': 15}]
# acceptance_diff 3
# ['michael wadleigh'] VS true_author: ['michael wadleigh']
# movie_id: 56502
# true director: Nagisa Oshima
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03331494331359863
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014388561248779297
# Discarted candidate: []
# Possible candidate: [{'?shima nagisa': 2, 'nagisa oshima': 1}]
# lengthNecessary: 1.0499999999999998
# [{'?shima nagisa': 2, 'nagisa oshima': 1}]
# acceptance_diff 3
# ['?shima nagisa', 'nagisa oshima'] VS true_author: ['nagisa oshima']
# movie_id: 63743
# true director: Jeremy Frindel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.029886960983276367
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010819435119628906
# Discarted candidate: []
# Possible candidate: [{'films substratum': 1, 'frindel jeremy': 7}]
# lengthNecessary: 2.8
# [{'films substratum': 1, 'frindel jeremy': 7}]
# acceptance_diff 3
# ['frindel jeremy'] VS true_author: ['frindel jeremy']
# movie_id: 105721
# true director: Georg Maas
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.031707048416137695
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001219034194946289
# Discarted candidate: []
# Possible candidate: [{'georg maas': 3, 'judith kaufmann': 2}]
# lengthNecessary: 1.75
# [{'georg maas': 3, 'judith kaufmann': 2}]
# acceptance_diff 3
# ['georg maas', 'judith kaufmann'] VS true_author: ['georg maas']
# movie_id: 88941
# true director: Jonah Bekhor;Zach Math
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04475712776184082
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016019344329833984
# Discarted candidate: []
# Possible candidate: [{'bekhor jonah': 10, 'math zach': 9}]
# lengthNecessary: 6.6499999999999995
# [{'bekhor jonah': 10, 'math zach': 9}]
# acceptance_diff 3
# ['bekhor jonah', 'math zach'] VS true_author: ['bekhor jonah', 'math zach']
# movie_id: 61767
# true director: Ryuhei Kitamura
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.02576589584350586
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001338958740234375
# Discarted candidate: []
# Possible candidate: [{'kitamura ry?hei': 2, 'kitamura ryuhei': 5}]
# lengthNecessary: 2.4499999999999997
# [{'kitamura ry?hei': 2, 'kitamura ryuhei': 5}]
# acceptance_diff 3
# ['kitamura ry?hei'] VS true_author: ['kitamura ryuhei']
# movie_id: 76373
# true director: Alice O'Fredericks;Jon Iversen
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.022968053817749023
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013580322265625
# Discarted candidate: []
# Possible candidate: [{"alice o'fredericks": 3, 'iversen jon': 2}]
# lengthNecessary: 1.75
# [{"alice o'fredericks": 3, 'iversen jon': 2}]
# acceptance_diff 3
# ["alice o'fredericks", 'iversen jon'] VS true_author: ['iversen jon', "alice o'fredericks"]
# movie_id: 38696
# true director: Sean Carr
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.029742956161499023
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014069080352783203
# Discarted candidate: []
# Possible candidate: [{'carr sean': 1, 'carrigan sean': 5}]
# lengthNecessary: 2.0999999999999996
# [{'carr sean': 1, 'carrigan sean': 5}]
# acceptance_diff 3
# ['carrigan sean'] VS true_author: ['carr sean']
# movie_id: 32680
# true director: Raj Nidimoru;Krishna DK
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.05814194679260254
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001322031021118164
# Discarted candidate: []
# Possible candidate: [{'d k krishna': 4, 'dk krishna': 1, 'nidimoru raj': 4}]
# lengthNecessary: 3.15
# [{'d k krishna': 4, 'dk krishna': 1, 'nidimoru raj': 4}]
# acceptance_diff 3
# ['d k krishna', 'nidimoru raj'] VS true_author: ['dk krishna', 'nidimoru raj']
# movie_id: 112475
# true director: Francis Ford Coppola
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.059700965881347656
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0014178752899169922
# Discarted candidate: []
# Possible candidate: [{'coppola ford francis': 19, 'coppola francis': 1}]
# lengthNecessary: 7.0
# [{'coppola ford francis': 19, 'coppola francis': 1}]
# acceptance_diff 3
# ['coppola ford francis'] VS true_author: ['coppola ford francis']
# movie_id: 105251
# true director: Nic Hill;Scott Glosserman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.025285959243774414
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0015716552734375
# Discarted candidate: []
# Possible candidate: [{'glosserman scott': 2, 'hill nic': 1}]
# lengthNecessary: 1.0499999999999998
# [{'glosserman scott': 2, 'hill nic': 1}]
# acceptance_diff 3
# ['glosserman scott', 'hill nic'] VS true_author: ['hill nic', 'glosserman scott']
# movie_id: 58667
# true director: Chris R. Notarile;Kim Santiago
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03698897361755371
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0013310909271240234
# Discarted candidate: []
# Possible candidate: [{'chris notarile r': 4, 'kim santiago': 7}]
# lengthNecessary: 3.8499999999999996
# [{'chris notarile r': 4, 'kim santiago': 7}]
# acceptance_diff 3
# ['chris notarile r', 'kim santiago'] VS true_author: ['kim santiago', 'chris notarile r']
# movie_id: 87533
# true director: Chang Cheh;Pao Hsueh-Li
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.04977703094482422
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016269683837890625
# Discarted candidate: []
# Possible candidate: [{'chang cheh': 8, 'hsueh li pao': 4, 'hsueh-li pao': 2}]
# lengthNecessary: 4.8999999999999995
# [{'chang cheh': 8, 'hsueh li pao': 4, 'hsueh-li pao': 2}]
# acceptance_diff 3
# ['chang cheh'] VS true_author: ['chang cheh', 'hsueh-li pao']
# movie_id: 92814
# true director: Fritz Lang;Rene Sti
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03580737113952637
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0010020732879638672
# Discarted candidate: []
# Possible candidate: [{'fritz lang': 6, 'rene sti': 2}]
# lengthNecessary: 2.8
# [{'fritz lang': 6, 'rene sti': 2}]
# acceptance_diff 3
# ['fritz lang'] VS true_author: ['fritz lang', 'rene sti']
# movie_id: 59689
# true director: Ines Paris;Daniela Fejerman
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03284311294555664
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0012688636779785156
# Discarted candidate: []
# Possible candidate: [{'daniela fejerman': 4, 'ines paris': 2}]
# lengthNecessary: 2.0999999999999996
# [{'daniela fejerman': 4, 'ines paris': 2}]
# acceptance_diff 3
# ['daniela fejerman', 'ines paris'] VS true_author: ['ines paris', 'daniela fejerman']
# movie_id: 35985
# true director: Clay Tweel
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.03900575637817383
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.001294851303100586
# Discarted candidate: []
# Possible candidate: [{'clay j tweel': 2, 'clay tweel': 6}]
# lengthNecessary: 2.8
# [{'clay j tweel': 2, 'clay tweel': 6}]
# acceptance_diff 3
# ['clay tweel'] VS true_author: ['clay tweel']
# movie_id: 31151
# true director: Gaston Ravel;Tony Lekain
# embedding_type: inferSent
# attributes_list: ['newDirector']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.023936033248901367
# cluster_method: hierarchy
# num_clusters_rate: 0.01
# NUM_CLUSTERS 1
# Blocking time is: 0.0016300678253173828
# Discarted candidate: []
# Possible candidate: [{'gaston ravel': 1, 'lekain tony': 2}]
# lengthNecessary: 1.0499999999999998
# [{'gaston ravel': 1, 'lekain tony': 2}]
# acceptance_diff 3
# ['gaston ravel', 'lekain tony'] VS true_author: ['lekain tony', 'gaston ravel']
# Total time is: 18.883283853530884

# %%
getEvaluation(finalDirectors, trueDirectors, 1)
# Out:
# TP: 568, FP: 98, FN: 24
# precision is 0.8528528528528528
# recall is 0.9594594594594594
# f1Score is 0.90302066772655
# (0.8528528528528528, 0.9594594594594594, 0.90302066772655)
