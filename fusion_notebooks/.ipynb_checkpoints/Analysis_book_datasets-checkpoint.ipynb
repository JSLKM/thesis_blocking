# %%
import os
import sys
import time
import numpy as np
import matplotlib.pyplot as plt

module_path = os.path.abspath(os.path.join('../fusion'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
path1 = '../fusion/source_datasets/book/book_detail_fiction_childrens_fiction_young_adult.txt'
data1 = pd.read_csv(path, sep="\t")
path2 = '../fusion/source_datasets/book/book_detail_fiction_crime_fiction_mysteries.txt'
data2 = pd.read_csv(path, sep="\t")
path3 = '../fusion/source_datasets/book/book_detail_fiction_fantasy_science_fiction.txt'
data3 = pd.read_csv(path, sep="\t")
path4 = '../fusion/source_datasets/book/book_detail_fiction_horror_books.txt'
data4 = pd.read_csv(path, sep="\t")
path5 = '../fusion/source_datasets/book/book_detail_fiction_literature.txt'
data5 = pd.read_csv(path, sep="\t")
path6 = '../fusion/source_datasets/book/book_detail_fiction_romance_books.txt'
data6 = pd.read_csv(path, sep="\t")
path7 = '../fusion/source_datasets/book/book_detail_nonfiction_arts_photography_books.txt'
data7 = pd.read_csv(path, sep="\t")
path8 = '../fusion/source_datasets/book/book_detail_nonfiction_biographies.txt'
data8 = pd.read_csv(path, sep="\t")
path9 = '../fusion/source_datasets/book/book_detail_nonfiction_business_economics.txt'
data9 = pd.read_csv(path, sep="\t")
path10 = '../fusion/source_datasets/book/book_detail_nonfiction_cookbooks_food_drink.txt'
data10 = pd.read_csv(path, sep="\t")
path11 = '../fusion/source_datasets/book/book_detail_nonfiction_craft_hobbies_home.txt'
data11 = pd.read_csv(path, sep="\t")
path12 = '../fusion/source_datasets/book/book_detail_nonfiction_history_books.txt'
data12 = pd.read_csv(path, sep="\t")
path13 = '../fusion/source_datasets/book/book_detail_nonfiction_reference_books.txt'
data13 = pd.read_csv(path, sep="\t")
path14 = '../fusion/source_datasets/book/book_detail_nonfiction_religion_spirituality_books.txt'
data14 = pd.read_csv(path, sep="\t")
path15 = '../fusion/source_datasets/book/book_detail_nonfiction_science_books.txt'
data15 = pd.read_csv(path, sep="\t")
path16 = '../fusion/source_datasets/book/book_detail_nonfiction_self_help_books.txt'
data16 = pd.read_csv(path, sep="\t")
path17 = '../fusion/source_datasets/book/book_detail_nonfiction_social_science.txt'
data17 = pd.read_csv(path, sep="\t")
path18 = '../fusion/source_datasets/book/book_detail_nonfiction_travel_books.txt'
data18 = pd.read_csv(path, sep="\t")

# %%
listData = []
listData.append(data1)
listData.append(data2)
listData.append(data3)
listData.append(data4)
listData.append(data5)
listData.append(data6)
listData.append(data7)
listData.append(data8)
listData.append(data9)
listData.append(data10)
listData.append(data11)
listData.append(data12)
listData.append(data13)
listData.append(data14)
listData.append(data15)
listData.append(data16)
listData.append(data17)
listData.append(data18)

# %%
for d in listData:
    print(d.shape)
# Out:
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)
# (12294, 21)

# %%
size = len(listData)
for i in range(1,18):
    data1 = data1.append(listData[i])
    print(data1.shape)
dataMerged = data1
# Out:
# (24588, 21)
# (36882, 21)
# (49176, 21)
# (61470, 21)
# (73764, 21)
# (86058, 21)
# (98352, 21)
# (110646, 21)
# (122940, 21)
# (135234, 21)
# (147528, 21)
# (159822, 21)
# (172116, 21)
# (184410, 21)
# (196704, 21)
# (208998, 21)
# (221292, 21)

# %%
12294 * 18
# Out:
# 221292

# %%
data1.shape
# Out:
# (221292, 21)

# %%
dataMerged.shape
# Out:
# (221292, 21)

# %%
dataMerged
# Out:
#           ISBN_10        ISBN_13  \
# 0      0001361589  9780001361584
# 1      0001361589  9780001361584
# 2      0001380451  9780001380455
# 3      0001380451  9780001380455
# 4      0001380451  9780001380455
# ...           ...            ...
# 12289  9750806190  9789750806193
# 12290  9793780118  9789793780115
# 12291  9810019513  9789810019518
# 12292  9888240676  9789888240678
# 12293  9995768925  9789995768928
#
#                                                    title  \
# 0                         Noddys Rainy Day Activity Book
# 1      Fun With Noddy Summer Activity Book. Noddy's T...
# 2                          Fun And Games With Paddington
# 3                          FUN AND GAMES WITH PADDINGTON
# 4                          Fun and Games with Paddington
# ...                                                  ...
# 12289  Grimm masallari. 2 volumes set. Translated by ...
# 12290                                              Saman
# 12291                                All Manner of Magic
# 12292                        Circles (Yonezu Board Book)
# 12293                      Bobbsey Twins on a Ranch, The
#
#                       authors                       big_cate  \
# 0                Blyton, Enid  childrens-fiction-young-adult
# 1                 Enid Blyton  childrens-fiction-young-adult
# 2               BOND, Michael  childrens-fiction-young-adult
# 3                Michael Bond  childrens-fiction-young-adult
# 4               Bond, Michael  childrens-fiction-young-adult
# ...                       ...                            ...
# 12289  JACOP & WILHELM GRIMM.  childrens-fiction-young-adult
# 12290              Utami, Ayu  childrens-fiction-young-adult
# 12291                Bowvayne  childrens-fiction-young-adult
# 12292           Yusuke Yonezu  childrens-fiction-young-adult
# 12293         Hope, Laura Lee  childrens-fiction-young-adult
#
#                     small_cate                              seller  \
# 0                  enid-blyton                          Brit Books
# 1                  enid-blyton                         Buybyebooks
# 2             childrens-series                  Better World Books
# 3             childrens-series  Black Stump Books And Collectables
# 4             childrens-series              Bookbarn International
# ...                        ...                                 ...
# 12289              fairy-tales               Khalkedon Books, IOBA
# 12290  general-childrens-books                     Manyhills Books
# 12291  general-childrens-books                     Manyhills Books
# 12292              board-books             Strand Book Store, ABAA
# 12293  general-childrens-books                    Cozy Book Cellar
#
#                         location  \
# 0      MiltonKeynes,UnitedKingdo
# 1           Honiton,UnitedKingdo
# 2            Mishawaka,IN,U.S.A.
# 3          Skipton,VIC,,Australi
# 4       Bristol,SOM,UnitedKingdo
# ...                          ...
# 12289            Istanbul,Turkey
# 12290     Traralgon,VIC,Australi
# 12291    Traralgon,VIC,Australia
# 12292          NewYork,NY,U.S.A.
# 12293       Bellingham,MA,U.S.A.
#
#                                              seller_link seller_date  ...  \
# 0                   brit-books-milton-keynes/54148132/sf  2009-09-11  ...
# 1                        buybyebooks-honiton/56688246/sf  2011-06-21  ...
# 2      better-world-books-mishawaka-in-u.s.a/51315977/sf  2006-08-03  ...
# 3      black-stump-books-and-collectables-skipton/946...  2001-08-22  ...
# 4                bookbarn-international-bristol/11757/sf  2005-01-28  ...
# ...                                                  ...         ...  ...
# 12289       khalkedon-books%2c-ioba-istanbul/55990143/sf  2012-03-02  ...
# 12290              manyhills-books-traralgon/51322352/sf  2006-08-08  ...
# 12291              manyhills-books-traralgon/51322352/sf  2006-08-08  ...
# 12292       strand-book-store%2c-abaa-new-york/500041/sf  2000-04-12  ...
# 12293     cozy-book-cellar-bellingham-ma-u.s.a/738943/sf  2001-02-23  ...
#
#                          publisher publish_date                 binding  \
# 0      HarperCollinsChildrensBooks         1999               Paperback
# 1              BBC Childrens Books         1996                P&#x2F;B
# 2                          Collins         1977                    None
# 3                  Collins, London         1977        Laminated Boards
# 4                          Collins         1977               Paperback
# ...                            ...          ...                     ...
# 12289                YKY, Istanbul         2003             Dust jacket
# 12290  Equinox Publishing, Jakarta         2005  Medium Trade Paperback
# 12291     Media Masters, Singapore         1990               Softcover
# 12292                   minedition         2015               Hardcover
# 12293         Grosset &amp; Dunlap         1935               Hardcover
#
#       book_condition      illustrator dust_jacket_condition  \
# 0         Used; Good             None                  None
# 1             As New       Uncredited             No Jacket
# 2               Good             None                  None
# 3          Very Good        Ivor Wood                  None
# 4         Used; Good             None                  None
# ...              ...              ...                   ...
# 12289      Very Good             None             Very Good
# 12290      Very Good             None                  None
# 12291      Very Good  Andrew Matthews                  None
# 12292            New             None                  None
# 12293           Good             None                  None
#
#                     signed         edition       price  \
# 0                     None            None  US$ 105.49
# 1                     None            None  US$ 139.91
# 2                     None             NaN    US$ 3.48
# 3                     None   First Edition   US$ 23.76
# 4                     None            None    US$ 3.56
# ...                    ...             ...         ...
# 12289                 None             NaN   US$ 63.24
# 12290  Signed by Author(s)  First Edition.   US$ 63.50
# 12291  Signed by Author(s)  First Edition.  US$ 138.90
# 12292                 None             NaN    US$ 8.95
# 12293                 None             NaN    US$ 1.98
#
#                                                     link
# 0      https://www.abebooks.com/servlet/BookDetailsPL...
# 1      https://www.abebooks.com/servlet/BookDetailsPL...
# 2      https://www.abebooks.com/servlet/BookDetailsPL...
# 3      https://www.abebooks.com/servlet/BookDetailsPL...
# 4      https://www.abebooks.com/servlet/BookDetailsPL...
# ...                                                  ...
# 12289  https://www.abebooks.com/servlet/BookDetailsPL...
# 12290  https://www.abebooks.com/servlet/BookDetailsPL...
# 12291  https://www.abebooks.com/servlet/BookDetailsPL...
# 12292  https://www.abebooks.com/servlet/BookDetailsPL...
# 12293  https://www.abebooks.com/servlet/BookDetailsPL...
#
# [221292 rows x 21 columns]

# %%
dataMerged.drop_duplicates(['ISBN_10', 'seller'], keep="first", inplace=True)

# %%
dataMerged.shape
# Out:
# (12294, 21)
