# %%
import os
import sys
import time
import numpy as np
import matplotlib.pyplot as plt
module_path = os.path.abspath(os.path.join('../../fusion'))
sys.path.append(module_path)

# %%
from preprocessing_datasets import load_dataset
from embedding_algorithms import sentence_embedding, set_embedding_model
from dimensionality_reduction_algorithms import dimension_reduction_algorithms
from cluster_algorithms import cluster_algorithm

from helper import load_by_index, get_author_candidate
from plot_tools import plotChart, plotCluster

# %%
key_values = {
    'model_type':'bilstm',
    'char_level':False,
    'model_version': 2,
    'rnn_dim':1024,
    'verbose':1,
    'attributes_list': ['authors','title','big_cate', 'small_cate'],
    'embedding_type': 'inferSent',
    'dataset': 'merged_book',
    'cluster_method': 'tsne',
    'dimension_reduction': 'pca',
    'num_components': 2,
    'cluster_method': 'hierarchy',
    'num_clusters': 10
}

# %% [markdown]
# # SETUP INFERSENT

# %%
set_embedding_model(key_values)
# Out:
# Vocab size : 2196017
# model_version: 2
# rnn_dim: 1024
# model_type: bilstm
# char_level: False
# Setup time is: 177.0161099433899

# %% [markdown]
# # LOAD

# %%
dataset_name, table_group_by_isbn, isbn_list, true_authors = load_dataset(key_values)
# Out:
# dataset: merged_book
# Loading time is: 20.882210969924927

# %% [markdown]
# # Analysis book-1

# %%
table_ISBN, list_authors, true_author = load_by_index(table_group_by_isbn, isbn_list, true_authors, 0)
# Out:
# ISBN: 0439136350
# true author: J. K. Rowling

# %%
table_ISBN['authors'].value_counts()
# Out:
# Rowling, J. K.                                                             38
# J.K. Rowling                                                               38
# Rowling, J.K.                                                              30
# J. K. Rowling                                                              10
# None                                                                        6
# J.K. Rowling; Mary GrandPr? [Illustrator]                                   6
# J.K. Rowling, Mary GrandPr                                                  4
# J K Rowling                                                                 3
# Rowling, J K                                                                3
# Rowling, J.K.,                                                              1
# Rowling, J.K., Illustrated by Grandpre, Mary                                1
# J.K. Rowling, (Illustrator) Mary GrandPre                                   1
# J.K. ROWLING                                                                1
# Rowling, P.J.                                                               1
# J. K. ROWLING                                                               1
# ROWLING, J. K.                                                              1
# J.K. Rowling; Illustrator-Mary GrandPr                                      1
# Rowling, J.K. & Mary GrandPr                                                1
# J.k. Rowling                                                                1
# J. K Rowling                                                                1
# Rowling, J.K.; J(oanne) "Jo" Rowling, OBE FRSL - Pen Name: J.K. Rowling     1
# ROWLING, J. K.: 3rd NOVEL of the HARRY POTTER Septet                        1
# J K Rowling, Mary GrandPre                                                  1
# J.K. ROWLING, MARY GRANDPR                                                  1
# Rowling, J.K. (Author)                                                      1
# Rowling, J. K                                                               1
# Rowling, J. K./ GrandPre, Mary (ILT)                                        1
# J.k.rowling                                                                 1
# J.K. Rowling, Mary GrandPr?                                                 1
# J.K. Rowling/ Mary GrandPr                                                  1
# Rowling, J K ( Joanne )(aka Robert Galbraith / Kennilworthy Whisp )         1
# ROWLING J.K.                                                                1
# ROWLING,J                                                                   1
# Rowling, J. K.:                                                             1
# Rowling,J.K.                                                                1
# J.k. Rowling,                                                               1
# Rowling, JK                                                                 1
# ROWLING,J.K.                                                                1
# Name: authors, dtype: int64

# %%
embeddings_tokens = sentence_embedding(table_ISBN, key_values)
# Out:
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 1.365661859512329

# %%
pca_embeddings = dimension_reduction_algorithms(embeddings_tokens, key_values)
plotChart(list_authors, pca_embeddings)
# Out:
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.09697604179382324
# rows: 167
# classes: 167

# %%
blocks = cluster_algorithm(pca_embeddings, key_values)
#plotCluster(blocks, list_authors, key_values['num_clusters'], pca_embeddings)
# Out:
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0025589466094970703

# %%
author_candidate = get_author_candidate(list_authors, blocks)
print("{0} VS true_author: {1}".format(author_candidate, true_author))
# Out:
# {'Rowling, J. K.': 32} VS true_author: J. K. Rowling

# %% [markdown]
# # Loop

# %%
for index in range(1,20):
    print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
    print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>book number {0}<<<<<<<<<<<<<<<<<<<<<<<<".format(index+1))
    table_ISBN, list_authors, true_author = load_by_index(table_group_by_isbn, isbn_list, true_authors, index)
    print("-------------------------------")
    print("tot cases of author's name: {0}".format(len(table_ISBN['authors'].value_counts())))
    print("-------------------------------")
    embeddings_tokens = sentence_embedding(table_ISBN, key_values)
    print("-------------------------------")
    pca_embeddings = dimension_reduction_algorithms(embeddings_tokens, key_values)
    plotChart(list_authors, pca_embeddings)
    print("-------------------------------")
    blocks = cluster_algorithm(pca_embeddings, key_values)
    #plotCluster(blocks, list_authors, key_values['num_clusters'], pca_embeddings)
    print("-------------------------------")
    author_candidate = get_author_candidate(list_authors, blocks)
    print("{0} VS true_author: {1}".format(author_candidate, true_author))
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0439784549
# true author: J. K. Rowling
# -------------------------------
# tot cases of author's name: 23
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.7003891468048096
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.007721900939941406
# rows: 156
# classes: 156
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.002000093460083008
# -------------------------------
# {'J. K. Rowling; Illustrator-Mary GrandPr': 1, 'ROWLING, J. K.': 1, 'Rowling, J. K.': 54} VS true_author: J. K. Rowling
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0385349947
# true author: Sheryl Sandberg, Nell Scovell
# -------------------------------
# tot cases of author's name: 18
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.6442811489105225
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.00803995132446289
# rows: 149
# classes: 149
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0020759105682373047
# -------------------------------
# {'Sandberg, Sheryl': 60, 'Sandberg, Sheryl, and Scovell, Nell': 1, 'Sandberg, Sheryl.': 1, 'Sandberg, Sheryl/ Scovell, Nell (CON)': 1, 'Sandberg, Sheryl:': 1, 'Sandberg, Sheryl; Scovell, Nell': 1, 'Sheryl Sandberg, Nell Scovell': 2} VS true_author: Sheryl Sandberg, Nell Scovell
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0787960756
# true author: Patrick Lencioni
# -------------------------------
# tot cases of author's name: 12
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.8128252029418945
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.008607149124145508
# rows: 149
# classes: 149
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0020651817321777344
# -------------------------------
# {'Lencioni, Patrick': 51} VS true_author: Patrick Lencioni
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0439813786
# true author: Brian Selznick
# -------------------------------
# tot cases of author's name: 11
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.9211976528167725
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.015172004699707031
# rows: 148
# classes: 148
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0012040138244628906
# -------------------------------
# {'SELZNICK, Brian': 1, 'Selznick, Brian': 78, 'Selznick,Brian': 2} VS true_author: Brian Selznick
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 067082982X
# true author: Stephen King
# -------------------------------
# tot cases of author's name: 10
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.4872770309448242
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.00709986686706543
# rows: 146
# classes: 146
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.002064943313598633
# -------------------------------
# {'King, Stephen': 71} VS true_author: Stephen King
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0060530928
# true author: Neil Gaiman
# -------------------------------
# tot cases of author's name: 24
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.7413229942321777
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.00830698013305664
# rows: 146
# classes: 146
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0019431114196777344
# -------------------------------
# {'Gaiman, Neil': 67, 'Gaiman, Neil (Author)': 1, 'Gaiman, Neil (SIGNED AND DATED)': 1, 'Gaiman, Neil/ McKean, Dave (ILT)': 3, 'Gaiman, Neil/ McKean, Dave (Illustrator)': 1, 'Gaiman, Neil; McKean, Dave': 1, 'Gaiman, Neil; McKean, Dave [Illustrator]': 5, 'None': 1} VS true_author: Neil Gaiman
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0439139597
# true author: J. K. Rowling
# -------------------------------
# tot cases of author's name: 25
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.6907601356506348
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.0075109004974365234
# rows: 146
# classes: 146
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0021250247955322266
# -------------------------------
# {'Rowling, J. K.': 25} VS true_author: J. K. Rowling
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0375502912
# true author: Laura Hillenbrand
# -------------------------------
# tot cases of author's name: 11
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.43044209480285645
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.007139921188354492
# rows: 145
# classes: 145
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0013730525970458984
# -------------------------------
# {'HILLENBRAND, Laura': 2, 'HILLENBRAND, Laura.': 1, 'Hillenbrand, Laura': 68, 'Hillenbrand,Laura': 1, 'LAURA HILLENBRAND': 1, 'None': 4} VS true_author: Laura Hillenbrand
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 159562015X
# true author: Tom Rath
# -------------------------------
# tot cases of author's name: 10
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.7423379421234131
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.007283210754394531
# rows: 144
# classes: 144
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0020751953125
# -------------------------------
# {'Rath, Tom': 41} VS true_author: Tom Rath
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0679412956
# true author: Anne Rice
# -------------------------------
# tot cases of author's name: 9
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.4851372241973877
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.007196903228759766
# rows: 144
# classes: 144
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0011200904846191406
# -------------------------------
# {'None': 3, 'Rice, Anne': 45, 'Rice, Anne (SIGNED)': 1, 'Rice, Professor Anne': 1} VS true_author: Anne Rice
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 1880418568
# true author: Stephen King
# -------------------------------
# tot cases of author's name: 24
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.7296581268310547
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.007997989654541016
# rows: 144
# classes: 144
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0017766952514648438
# -------------------------------
# {'King, Stephen': 26, 'King, Stephen; Wrightson, Bernie': 2, 'King, Stephen; Wrightson, Bernie [Illustrator]': 3, 'King,Stephen': 1, 'None': 2, 'Wrightson, Bernie (Illustrator)': 1} VS true_author: Stephen King
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0345303059
# true author: Arthur C. Clarke
# -------------------------------
# tot cases of author's name: 18
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.5608499050140381
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.007428169250488281
# rows: 143
# classes: 143
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0020160675048828125
# -------------------------------
# {'CLARKE, Arthur C.': 1, 'Clarke, Arthur': 1, 'Clarke, Arthur C': 2, 'Clarke, Arthur C.': 39, 'Clarke, Arthur Charles': 2} VS true_author: Arthur C. Clarke
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0679411674
# true author: Toni Morrison
# -------------------------------
# tot cases of author's name: 13
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.3494892120361328
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.006869792938232422
# rows: 143
# classes: 143
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0010862350463867188
# -------------------------------
# {'MORRISON, Toni': 1, 'Morrison, Toni': 82, 'Morrison, Toni (editor)': 1, 'TONI MORRISON': 1} VS true_author: Toni Morrison
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0316065781
# true author: Elizabeth Kostova
# -------------------------------
# tot cases of author's name: 8
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.5522313117980957
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.007440090179443359
# rows: 143
# classes: 143
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0022439956665039062
# -------------------------------
# {'Kostova, Elizabeth': 46, 'None': 1} VS true_author: Elizabeth Kostova
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0679879242
# true author: Philip Pullman
# -------------------------------
# tot cases of author's name: 15
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.6218271255493164
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.016994714736938477
# rows: 143
# classes: 143
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0017228126525878906
# -------------------------------
# {'Pilip Pullman': 1, 'Pullman, Bill': 1, 'Pullman, Philip': 35, 'Pullman, Philip.': 2, 'Pullman, Philip; Slattery, Joan (editor)': 1, 'Pullman, Phillip': 2} VS true_author: Philip Pullman
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0375401601
# true author: Anne Rice
# -------------------------------
# tot cases of author's name: 11
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.6082420349121094
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.006824016571044922
# rows: 143
# classes: 143
# -------------------------------
# cluster_method: hierarchy
# num_clusters: 10
# Blocking time is: 0.0017800331115722656
# -------------------------------
# {'Rice, Anne': 69} VS true_author: Anne Rice
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# ISBN: 0684811073
# true author: Stephen Ambrose
# -------------------------------
# tot cases of author's name: 17
# -------------------------------
# embedding_type: inferSent
# attributes_list: ['authors', 'title', 'big_cate', 'small_cate']
# model_type: bilstm
# char_level: False
# Embedding time is: 0.9696638584136963
# -------------------------------
# dimension_reduction: pca
# num_components: 2
# Dimension reduction time is: 0.0074689388275146484
# rows: 143
# classes: 143
