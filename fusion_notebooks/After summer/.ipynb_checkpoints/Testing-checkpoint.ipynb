# %%
import os
import sys
import time
import numpy as np
import matplotlib.pyplot as plt

module_path = os.path.abspath(os.path.join('../../fusion'))
sys.path.append(module_path)

# %%
from preprocessing_datasets import load_dataset
from embedding_algorithms import sentence_embedding, set_embedding_model
from helper import load_by_index
from plot_tools import plotChart, plotCluster
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-3db5812ea1c9> in <module>
#       1 from preprocessing_datasets import load_dataset
#       2 from embedding_algorithms import sentence_embedding, set_embedding_model
# ----> 3 import load_by_index
#       4 from plot_tools import plotChart, plotCluster
#
# ModuleNotFoundError: No module named 'load_by_index'

# %%
key_values = {
    'model_type':'bilstm',
    'char_level':False,
    'model_version': 2,
    'rnn_dim':1024,
    'verbose':1,
    'embedding_type': 'inferSent',
    'dataset': 'merged_book',
    'cluster_method': 'tsne',
}

# %% [markdown]
# # SETUP INFERSENT

# %%
set_embedding_model(key_values)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c2623be9a892> in <module>
# ----> 1 set_embedding_model(key_values)
#
# ~/Desktop/Thesis_Jin/thesis/fusion/embedding_algorithms/__init__.py in set_embedding_model(key_values)
#      24     start_time = time.time()
#      25     from .inferSent import set_RNN_embedding
# ---> 26     set_RNN_embedding(key_values)
#      27     if key_values['verbose'] > 0:
#      28         print('model_version: {0}'.format(key_values['model_version']))
#
# ~/Desktop/Thesis_Jin/thesis/fusion/embedding_algorithms/inferSent.py in set_RNN_embedding(key_values)
#      78         set_lstm_embedder_model(key_values)
#      79     elif key_values['model_type'] == 'bilstm':
# ---> 80         set_bi_lstm_embedder_model(key_values)
#      81
#      82 def RNN_embedding(table, attributes_list, model_type, char_level):
#
# ...

# %% [markdown]
# # LOAD

# %%
dataset_name, table_group_by_isbn, isbn_list, true_authors = load_dataset(key_values)
# Out:
# dataset: merged_book
# Loading time is: 13.824224948883057

# %%
table_group_by_isbn

# %% [markdown]
# # Analysis book-1

# %%
table_ISBN, list_authors, true_author = load_by_index(table_group_by_isbn, isbn_list, true_authors, 0)
# Out:
# ISBN: 0439136350

# %% [markdown]
# ### unique values

# %%
table_ISBN['authors'].value_counts()
# Out:
# Rowling, J. K.                                                             38
# J.K. Rowling                                                               38
# Rowling, J.K.                                                              30
# J. K. Rowling                                                              10
# J.K. Rowling; Mary GrandPr? [Illustrator]                                   6
# None                                                                        6
# J.K. Rowling, Mary GrandPr                                                  4
# Rowling, J K                                                                3
# J K Rowling                                                                 3
# Rowling, J K ( Joanne )(aka Robert Galbraith / Kennilworthy Whisp )         1
# J K Rowling, Mary GrandPre                                                  1
# J.K. Rowling; Illustrator-Mary GrandPr                                      1
# ...

# %% [markdown]
# ### a

# %%
attr_list = ['authors','title','big_cate', 'small_cate']

embeddings_tokens = sentence_embedding(table_ISBN, )
#def getEmbedding(table_ISBN, attr_list):
#    from embedding_algorithms.inferSent import RNN_embedding
#    start_time = time.time()
#    params['attr_list'] = attr_list
#    embeddings_tokens = RNN_embedding(table_ISBN, attr_list, model_type, char_level)
#    embeddings_tokens = np.array(embeddings_tokens)
#    print('Time load: {0}'.format(time.time() - start_time))
#    return embeddings_tokens

#embeddings_tokens = getEmbedding(table_ISBN, attr_list)
# Out:
# attrs: ['authors', 'title', 'big_cate', 'small_cate']
# Time load: 0.9446918964385986

# %%
from dimensionality_reduction_algorithms.pca import pca_dim_reduction
from sklearn.decomposition import PCA


pca_model = PCA(n_components=2, random_state=88)

pca_embeddings = pca_model.fit_transform(embeddings_tokens)


params['reduction'] = {
    'name': 'PCA',
    'num_components': 2,
    'verbose': 1,
}

# %%
plotChart(column, pca_embeddings)
# Out:
# rows: 167
# classes: 167

# %%
from sklearn.manifold import TSNE

tsne_model = TSNE(
        perplexity=10, 
        n_components=2, 
        method='barnes_hut',
        early_exaggeration=12,
        init='pca', 
        n_iter=2500, 
        random_state=23
    )


tsne_embeddings = tsne_model.fit_transform(embeddings_tokens)

params['reduction'] = {
    'name': 'TSNE',
    'num_components': 2,
    'early_exaggeration': 12,
    'verbose': 1,
    'perplexity': 10,
    'method': "barnes_hut"
}

# %%
plotChart(column, tsne_embeddings)
# Out:
# rows: 167
# classes: 167

# %%
from cluster_algorithms.hierarchy_cluster import hierarchy_cluster
num_clusters = 10
blocks = hierarchy_cluster(pca_embeddings, {'num_clusters': num_clusters})

params['blocking'] = {
    'name': 'hierarchy',
    'num_clusters': num_clusters
}
# Out:
# clustering with NUM_CLUSTERS = 10,

# %%
plotCluster(blocks, column, num_clusters,pca_embeddings)
# Out:
# num of classes: 10

# %%
for index in blocks:
    print("index: {0} - {1}".format(index, len(blocks[index])))
# Out:
# index: 6 - 32
# index: 7 - 3
# index: 4 - 27
# index: 2 - 23
# index: 5 - 30
# index: 9 - 13
# index: 0 - 20
# index: 3 - 9
# index: 8 - 4
# index: 1 - 6

# %%
chosenIndex = blocks[6]

# %%
candidates = np.take(column, chosenIndex)

# %%
unique, counts = np.unique(candidates, return_counts=True)
result = dict(zip(unique, counts))

# %%
result
# Out:
# {'Rowling, J. K.': 32}
