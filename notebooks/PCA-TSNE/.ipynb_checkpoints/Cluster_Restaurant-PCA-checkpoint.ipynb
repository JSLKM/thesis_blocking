# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Setup" data-toc-modified-id="Setup-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Setup</a></span></li><li><span><a href="#Import-dataset" data-toc-modified-id="Import-dataset-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import dataset</a></span></li><li><span><a href="#Sentence-embedding" data-toc-modified-id="Sentence-embedding-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Sentence embedding</a></span><ul class="toc-item"><li><span><a href="#Infersent" data-toc-modified-id="Infersent-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Infersent</a></span></li></ul></li><li><span><a href="#Dimensionality-reduction" data-toc-modified-id="Dimensionality-reduction-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Dimensionality reduction</a></span><ul class="toc-item"><li><span><a href="#PCA" data-toc-modified-id="PCA-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>PCA</a></span></li></ul></li><li><span><a href="#Blocking" data-toc-modified-id="Blocking-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Blocking</a></span></li><li><span><a href="#Evaluation" data-toc-modified-id="Evaluation-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Evaluation</a></span></li><li><span><a href="#Results" data-toc-modified-id="Results-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Results</a></span></li></ul></div>

# %% [markdown]
# # Setup

# %%
import os
import sys
import time
import numpy as np
import matplotlib.pyplot as plt

module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from preprocessing_datasets.preprocessing_utilities import get_labels_by

params = {}

# %% [markdown]
# # Import dataset

# %%
from preprocessing_datasets.preprocessing_restaurant import clean_restaurant
table, pairs = clean_restaurant()

# %%
table
# Out:
#                          citruname                       addr  \
# 0        arnie morton's of chicago   "435 s. la cienega blv."
# 1        arnie morton's of chicago  "435 s. la cienega blvd."
# 2               art's delicatessen      "12224 ventura blvd."
# 3                       art's deli      "12224 ventura blvd."
# 4                    hotel bel-air     "701 stone canyon rd."
# ..                             ...                        ...
# 859                        ti couz            "3108 16th st."
# 860                      trio cafe        "1870 fillmore st."
# 861                         tu lan              "8 sixth st."
# 862                vicolo pizzeria              "201 ivy st."
# 863  wa-ha-ka oaxaca mexican grill            "2141 polk st."
#
#                 city           phone           type
# 0      "los angeles"  "310/246-1501"     "american"
# 1      "los angeles"  "310-246-1501"  "steakhouses"
# 2      "studio city"  "818/762-1221"     "american"
# 3      "studio city"  "818-762-1221"        "delis"
# 4          "bel air"  "310/472-1211"  "californian"
# ..               ...             ...            ...
# 859  "san francisco"  "415-252-7373"       "french"
# 860  "san francisco"  "415-563-2248"     "american"
# 861  "san francisco"  "415-626-0927"   "vietnamese"
# 862  "san francisco"  "415-863-2382"        "pizza"
# 863  "san francisco"  "415-775-1055"      "mexican"
#
# [864 rows x 5 columns]

# %% [markdown]
# # Sentence embedding

# %% [markdown]
# ## Infersent

# %% [markdown]
# Setup model

# %%
from embedding_algorithms.inferSent import set_RNN_embedding
start = time.time()
model_type = "bilstm" 
char_level = False
model_version = 2
rnn_dim = 2048
verbose = 1
set_RNN_embedding(model_type, char_level, model_version, rnn_dim, verbose)
print("TIME: {0}".format(time.time() - start))

params['embedding'] = {
    'name': 'Infersent',
    'model_type': model_type,
    'char_level': char_level,
    'model_version': model_version,
    'rnn_dim': rnn_dim,
    'verbose': verbose
}
# Out:
# Vocab size : 2196017
# TIME: 201.8050627708435

# %% [markdown]
# Embedding

# %%
from embedding_algorithms.inferSent import RNN_embedding
attr_list = ['citruname']
params['attr_list'] = attr_list
embeddings_tokens = RNN_embedding(table, attr_list, model_type, char_level)
embeddings_tokens = np.array(embeddings_tokens)
# Out:
# attrs: ['citruname']

# %% [markdown]
# # Dimensionality reduction

# %% [markdown]
# ## PCA

# %%
from dimensionality_reduction_algorithms.pca import pca_dim_reduction

start = time.time()
pca_embeddings = pca_dim_reduction(
            embeddings_tokens, 
            num_components=2,
            verbose=1)

print("PCA: {0}".format(time.time() - start))

params['reduction'] = {
    'name': 'PCA',
    'num_components': 2,
    'verbose': 1,
}
# Out:
# starting dimension: 4096
# setting PCA with n_components: 2
# PCA: 0.1064751148223877

# %% [markdown]
# # Blocking

# %%
from cluster_algorithms.hierarchy_cluster import hierarchy_cluster
num_clusters = 56


start = time.time()
blocks = hierarchy_cluster(pca_embeddings, {'num_clusters': num_clusters})
print("BLOCKS: {0}".format(time.time() - start))
params['blocking'] = {
    'name': 'hierarchy',
    'num_clusters': num_clusters
}
# Out:
# clustering with NUM_CLUSTERS = 56,
# BLOCKS: 0.03544282913208008

# %% [markdown]
# # Evaluation

# %%
from evaluation import calc_index
calc_index(blocks,table,pairs)
print()
print(params['attr_list'])
print(params['embedding'])
print(params['reduction'])
print(params['blocking'])
# Out:
# (RR) Reduction ratio is: 0.9645079610317153
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8767152025777939
# (PQ) Pair quality - Precision is: 0.006801692865779928
# (FM) Fmeasure is: 0.013489208633093525
#
# ['citruname']
# {'name': 'Infersent', 'model_type': 'bilstm', 'char_level': False, 'model_version': 2, 'rnn_dim': 2048, 'verbose': 1}
# {'name': 'PCA', 'num_components': 2, 'verbose': 1}
# {'name': 'hierarchy', 'num_clusters': 56}

# %%
for i in range(1,300,5):
    num_clusters = int(i)
    blocks = hierarchy_cluster(pca_embeddings, {'num_clusters': num_clusters})
    calc_index(blocks,table,pairs)
# Out:
# clustering with NUM_CLUSTERS = 1,
# (RR) Reduction ratio is: 0.0
# (PC) Pair completeness is: 1.0
# (RM) Reference metric (Harmonic mean RR and PC) is: 0
# (PQ) Pair quality - Precision is: 0.0003004162911463027
# (FM) Fmeasure is: 0.0006006521366054572
# clustering with NUM_CLUSTERS = 6,
# (RR) Reduction ratio is: 0.8295888588472597
# (PC) Pair completeness is: 0.875
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8516895411157864
# (PQ) Pair quality - Precision is: 0.0015425297487880124
# (FM) Fmeasure is: 0.003079630444346679
# clustering with NUM_CLUSTERS = 11,
# (RR) Reduction ratio is: 0.9016351229560963
# (PC) Pair completeness is: 0.8571428571428571
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8788262238164458
# (PQ) Pair quality - Precision is: 0.002617801047120419
# (FM) Fmeasure is: 0.005219660722053067
# clustering with NUM_CLUSTERS = 16,
# (RR) Reduction ratio is: 0.9246303806703575
# (PC) Pair completeness is: 0.8392857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.879893405032419
# (PQ) Pair quality - Precision is: 0.0033453147798854052
# (FM) Fmeasure is: 0.006664067207826734
# clustering with NUM_CLUSTERS = 21,
# (RR) Reduction ratio is: 0.9338574524698511
# (PC) Pair completeness is: 0.8303571428571429
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8790712967942431
# (PQ) Pair quality - Precision is: 0.0037714424753639646
# (FM) Fmeasure is: 0.007508780428727141
# clustering with NUM_CLUSTERS = 26,
# (RR) Reduction ratio is: 0.9430121024848719
# (PC) Pair completeness is: 0.8303571428571429
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8831063662074817
# (PQ) Pair quality - Precision is: 0.00437729454956227
# (FM) Fmeasure is: 0.008708680588070042
# clustering with NUM_CLUSTERS = 31,
# (RR) Reduction ratio is: 0.9482506115617355
# (PC) Pair completeness is: 0.8303571428571429
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8853966441703754
# (PQ) Pair quality - Precision is: 0.0048204011817757735
# (FM) Fmeasure is: 0.009585158464313322
# clustering with NUM_CLUSTERS = 36,
# (RR) Reduction ratio is: 0.954350135187331
# (PC) Pair completeness is: 0.8125
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8777309058614566
# (PQ) Pair quality - Precision is: 0.005346965156589694
# (FM) Fmeasure is: 0.010624014943669371
# clustering with NUM_CLUSTERS = 41,
# (RR) Reduction ratio is: 0.9583011458735676
# (PC) Pair completeness is: 0.8125
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8793982123138585
# (PQ) Pair quality - Precision is: 0.00585359578026502
# (FM) Fmeasure is: 0.011623451270915826
# clustering with NUM_CLUSTERS = 46,
# (RR) Reduction ratio is: 0.9615976782112355
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.875510926428548
# (PQ) Pair quality - Precision is: 0.006286233149402808
# (FM) Fmeasure is: 0.012474876983851966
# clustering with NUM_CLUSTERS = 51,
# (RR) Reduction ratio is: 0.9631078065319085
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8761363133561392
# (PQ) Pair quality - Precision is: 0.0065435509669914205
# (FM) Fmeasure is: 0.012981393336218087
# clustering with NUM_CLUSTERS = 56,
# (RR) Reduction ratio is: 0.9645079610317153
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8767152025777939
# (PQ) Pair quality - Precision is: 0.006801692865779928
# (FM) Fmeasure is: 0.013489208633093525
# clustering with NUM_CLUSTERS = 61,
# (RR) Reduction ratio is: 0.965301918372602
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.877043054427295
# (PQ) Pair quality - Precision is: 0.006957328385899814
# (FM) Fmeasure is: 0.0137952176578786
# clustering with NUM_CLUSTERS = 66,
# (RR) Reduction ratio is: 0.9670105360284966
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8777476032357805
# (PQ) Pair quality - Precision is: 0.007317668103097813
# (FM) Fmeasure is: 0.0145032632342277
# clustering with NUM_CLUSTERS = 71,
# (RR) Reduction ratio is: 0.9680888159306468
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.878191532733805
# (PQ) Pair quality - Precision is: 0.007564932335882996
# (FM) Fmeasure is: 0.014988758431176618
# clustering with NUM_CLUSTERS = 76,
# (RR) Reduction ratio is: 0.9693441268615081
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8787076659262699
# (PQ) Pair quality - Precision is: 0.007874704698573803
# (FM) Fmeasure is: 0.015596568754873927
# clustering with NUM_CLUSTERS = 81,
# (RR) Reduction ratio is: 0.9702856100596541
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8790942864252916
# (PQ) Pair quality - Precision is: 0.008124210146235782
# (FM) Fmeasure is: 0.0160857908847185
# clustering with NUM_CLUSTERS = 86,
# (RR) Reduction ratio is: 0.9706423544053904
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8792406764564801
# (PQ) Pair quality - Precision is: 0.008222932846048425
# (FM) Fmeasure is: 0.016279280094058064
# clustering with NUM_CLUSTERS = 91,
# (RR) Reduction ratio is: 0.9716133427749882
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8796388234905578
# (PQ) Pair quality - Precision is: 0.008504204856845885
# (FM) Fmeasure is: 0.01683029453015428
# clustering with NUM_CLUSTERS = 96,
# (RR) Reduction ratio is: 0.9721417535728081
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.879855311711012
# (PQ) Pair quality - Precision is: 0.008665511265164644
# (FM) Fmeasure is: 0.017146123071061153
# clustering with NUM_CLUSTERS = 101,
# (RR) Reduction ratio is: 0.9726808935238831
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8800760628772646
# (PQ) Pair quality - Precision is: 0.008836524300441826
# (FM) Fmeasure is: 0.017480819656210546
# clustering with NUM_CLUSTERS = 106,
# (RR) Reduction ratio is: 0.9730912836358955
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8802440075417689
# (PQ) Pair quality - Precision is: 0.008971291866028708
# (FM) Fmeasure is: 0.017744479495268136
# clustering with NUM_CLUSTERS = 111,
# (RR) Reduction ratio is: 0.973568730955753
# (PC) Pair completeness is: 0.8035714285714286
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8804392965321669
# (PQ) Pair quality - Precision is: 0.009133346864217576
# (FM) Fmeasure is: 0.01806140878988561
# clustering with NUM_CLUSTERS = 116,
# (RR) Reduction ratio is: 0.9737538088494057
# (PC) Pair completeness is: 0.7946428571428571
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8751277625641224
# (PQ) Pair quality - Precision is: 0.009095554420030658
# (FM) Fmeasure is: 0.017985248054966152
# clustering with NUM_CLUSTERS = 121,
# (RR) Reduction ratio is: 0.9740890948886314
# (PC) Pair completeness is: 0.7946428571428571
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8752631404492447
# (PQ) Pair quality - Precision is: 0.009213250517598344
# (FM) Fmeasure is: 0.018215309046254603
# clustering with NUM_CLUSTERS = 126,
# (RR) Reduction ratio is: 0.974330500836874
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.869915810511603
# (PQ) Pair quality - Precision is: 0.009195402298850575
# (FM) Fmeasure is: 0.018178062383804997
# clustering with NUM_CLUSTERS = 131,
# (RR) Reduction ratio is: 0.9746738337410411
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.870052628302438
# (PQ) Pair quality - Precision is: 0.009320059309468333
# (FM) Fmeasure is: 0.01842160351685158
# clustering with NUM_CLUSTERS = 136,
# (RR) Reduction ratio is: 0.9748589116346937
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8701263595068024
# (PQ) Pair quality - Precision is: 0.00938866958284434
# (FM) Fmeasure is: 0.018555614127569845
# clustering with NUM_CLUSTERS = 141,
# (RR) Reduction ratio is: 0.9751512810608987
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8702428018571808
# (PQ) Pair quality - Precision is: 0.009499136442141624
# (FM) Fmeasure is: 0.01877133105802048
# clustering with NUM_CLUSTERS = 146,
# (RR) Reduction ratio is: 0.9754865671001245
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8703762890736249
# (PQ) Pair quality - Precision is: 0.009629062260641207
# (FM) Fmeasure is: 0.019024970273483946
# clustering with NUM_CLUSTERS = 151,
# (RR) Reduction ratio is: 0.9757118793184841
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8704659639337236
# (PQ) Pair quality - Precision is: 0.009718387631143015
# (FM) Fmeasure is: 0.019199301843569327
# clustering with NUM_CLUSTERS = 156,
# (RR) Reduction ratio is: 0.9759237800952749
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8705502800732942
# (PQ) Pair quality - Precision is: 0.00980392156862745
# (FM) Fmeasure is: 0.01936619718309859
# clustering with NUM_CLUSTERS = 161,
# (RR) Reduction ratio is: 0.9761276340071241
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8706313751930229
# (PQ) Pair quality - Precision is: 0.009887640449438202
# (FM) Fmeasure is: 0.01952951620062139
# clustering with NUM_CLUSTERS = 166,
# (RR) Reduction ratio is: 0.9763153941890906
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8707060514658391
# (PQ) Pair quality - Precision is: 0.009966024915062289
# (FM) Fmeasure is: 0.01968239767389846
# clustering with NUM_CLUSTERS = 171,
# (RR) Reduction ratio is: 0.9763985451268186
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8707391173022613
# (PQ) Pair quality - Precision is: 0.010001136492783272
# (FM) Fmeasure is: 0.019750869711592418
# clustering with NUM_CLUSTERS = 176,
# (RR) Reduction ratio is: 0.976586305308785
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8708137706162753
# (PQ) Pair quality - Precision is: 0.010081338068507275
# (FM) Fmeasure is: 0.019907250311050784
# clustering with NUM_CLUSTERS = 181,
# (RR) Reduction ratio is: 0.9766909145530235
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8708553562770553
# (PQ) Pair quality - Precision is: 0.010126582278481013
# (FM) Fmeasure is: 0.019995455578277664
# clustering with NUM_CLUSTERS = 186,
# (RR) Reduction ratio is: 0.9768303935453414
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.870910796146038
# (PQ) Pair quality - Precision is: 0.010187543412827044
# (FM) Fmeasure is: 0.020114285714285716
# clustering with NUM_CLUSTERS = 191,
# (RR) Reduction ratio is: 0.9769671902493455
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8709651613413735
# (PQ) Pair quality - Precision is: 0.01024804937696518
# (FM) Fmeasure is: 0.020232210598919415
# clustering with NUM_CLUSTERS = 196,
# (RR) Reduction ratio is: 0.9771495858546844
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8710376351436682
# (PQ) Pair quality - Precision is: 0.010329850921469656
# (FM) Fmeasure is: 0.020391611632487545
# clustering with NUM_CLUSTERS = 201,
# (RR) Reduction ratio is: 0.9773051585768852
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8710994391838421
# (PQ) Pair quality - Precision is: 0.010400661860300201
# (FM) Fmeasure is: 0.02052956957891053
# clustering with NUM_CLUSTERS = 206,
# (RR) Reduction ratio is: 0.9774607312990858
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8711612323175292
# (PQ) Pair quality - Precision is: 0.010472450315363561
# (FM) Fmeasure is: 0.020669406928948916
# clustering with NUM_CLUSTERS = 211,
# (RR) Reduction ratio is: 0.9775599759666967
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8712006463785288
# (PQ) Pair quality - Precision is: 0.010518766435572556
# (FM) Fmeasure is: 0.020759613116301014
# clustering with NUM_CLUSTERS = 216,
# (RR) Reduction ratio is: 0.977610939444659
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8712208843073678
# (PQ) Pair quality - Precision is: 0.010542709955672696
# (FM) Fmeasure is: 0.020806241872561766
# clustering with NUM_CLUSTERS = 221,
# (RR) Reduction ratio is: 0.9776458091927385
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8712347306372943
# (PQ) Pair quality - Precision is: 0.010559155267578594
# (FM) Fmeasure is: 0.020838266635093538
# clustering with NUM_CLUSTERS = 226,
# (RR) Reduction ratio is: 0.9777316424187803
# (PC) Pair completeness is: 0.7857142857142857
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.871268811578054
# (PQ) Pair quality - Precision is: 0.010599855456516502
# (FM) Fmeasure is: 0.020917518421678154
# clustering with NUM_CLUSTERS = 231,
# (RR) Reduction ratio is: 0.9778979442942363
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8658166381647175
# (PQ) Pair quality - Precision is: 0.010558252427184465
# (FM) Fmeasure is: 0.020833333333333336
# clustering with NUM_CLUSTERS = 236,
# (RR) Reduction ratio is: 0.9779784129436505
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8658481767049998
# (PQ) Pair quality - Precision is: 0.010596833130328867
# (FM) Fmeasure is: 0.02090843547224225
# clustering with NUM_CLUSTERS = 241,
# (RR) Reduction ratio is: 0.9781339856658513
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8659091430149776
# (PQ) Pair quality - Precision is: 0.010672227674190383
# (FM) Fmeasure is: 0.021055179090029044
# clustering with NUM_CLUSTERS = 246,
# (RR) Reduction ratio is: 0.9782251834685207
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8659448768611331
# (PQ) Pair quality - Precision is: 0.010716925351071693
# (FM) Fmeasure is: 0.021142162818955045
# clustering with NUM_CLUSTERS = 251,
# (RR) Reduction ratio is: 0.9782734646581692
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8659637932762311
# (PQ) Pair quality - Precision is: 0.01074074074074074
# (FM) Fmeasure is: 0.021188504627374573
# clustering with NUM_CLUSTERS = 256,
# (RR) Reduction ratio is: 0.9783619801725247
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8659984706676012
# (PQ) Pair quality - Precision is: 0.010784678319077723
# (FM) Fmeasure is: 0.021273994375840568
# clustering with NUM_CLUSTERS = 261,
# (RR) Reduction ratio is: 0.9784263550920561
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8660236883917776
# (PQ) Pair quality - Precision is: 0.01081685938082805
# (FM) Fmeasure is: 0.02133660331085224
# clustering with NUM_CLUSTERS = 266,
# (RR) Reduction ratio is: 0.9784934122999013
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8660499548875267
# (PQ) Pair quality - Precision is: 0.010850586181092543
# (FM) Fmeasure is: 0.021402214022140223
# clustering with NUM_CLUSTERS = 271,
# (RR) Reduction ratio is: 0.9785282820479808
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8660636126721946
# (PQ) Pair quality - Precision is: 0.010868207370393504
# (FM) Fmeasure is: 0.02143649131452507
# clustering with NUM_CLUSTERS = 276,
# (RR) Reduction ratio is: 0.9786409381571607
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8661077341143877
# (PQ) Pair quality - Precision is: 0.01092553057892754
# (FM) Fmeasure is: 0.021547987616099072
# clustering with NUM_CLUSTERS = 281,
# (RR) Reduction ratio is: 0.978718724518261
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8661381956147967
# (PQ) Pair quality - Precision is: 0.010965465086967482
# (FM) Fmeasure is: 0.02162565249813572
# clustering with NUM_CLUSTERS = 286,
# (RR) Reduction ratio is: 0.9787696879962233
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.866158151685891
# (PQ) Pair quality - Precision is: 0.010991787744788376
# (FM) Fmeasure is: 0.021676840662763174
# clustering with NUM_CLUSTERS = 291,
# (RR) Reduction ratio is: 0.9788206514741856
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8661781065983766
# (PQ) Pair quality - Precision is: 0.011018237082066869
# (FM) Fmeasure is: 0.021728271728271728
# clustering with NUM_CLUSTERS = 296,
# (RR) Reduction ratio is: 0.978871614952148
# (PC) Pair completeness is: 0.7767857142857143
# (RM) Reference metric (Harmonic mean RR and PC) is: 0.8661980603523537
# (PQ) Pair quality - Precision is: 0.01104481401548813
# (FM) Fmeasure is: 0.021779947427713105

# %% [markdown]
# # Results

# %%
# Restaurant
# RR PC alpha
# attrs: ['citruname']
list_hierarchy_tsne = [0.9790, 0.9464, 0.9624] # TSNE: 18.875, BLOCKS: 0.0285, n_cluster: 56 
list_hierarchy_pca = [0.9645, 0.8035, 0.8767] # PCA: 0.10647, BLOCKS: 0.035
