# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=((rect.get_x() + rect.get_width() / 2), height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    fontsize=12,
                    fontweight='bold',
                    ha='center', va='bottom')
        
def plot_chart(list_RR, list_PC, list_alpha, title, saveName):
    labels = ['Standard', 'Suffix', 'Sorted Neighbourhood', 'Q-gram', 'Canopy', 'Emb-Cluster']
    x = np.arange(len(labels))  # the label locations
    width = 0.2  # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(x - width*4/3, list_RR, width, label='RR - Reduction Ratio', color="#ff4040")
    rects2 = ax.bar(x, list_PC, width, label='PC - Pair Completeness', color="#3b63f5")
    rects3 = ax.bar(x + width*4/3, list_alpha, width, label='α - Alpha', color="#51fa3e")

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Results', fontsize=20, fontweight='bold')
    ax.set_title(title, fontsize=25, fontweight='bold')
    ax.set_xticks(x)
    ax.set_xticklabels(labels, fontsize=15, fontweight='bold')
    ax.legend(loc=3, prop={'size': 15})

    autolabel(rects1, ax)
    autolabel(rects2, ax)
    autolabel(rects3, ax)

    fig.tight_layout()
    fig.set_size_inches(18.5, 10.5)
    if saveName:
        fig.savefig(saveName, dpi=100)
    plt.show()

# %%
list_RR = [0.9848,0.99,0.9848,0.9848,0.9848,0.9859]
list_PC = [0.9464,0.875,0.9464,0.9464,0.9464,0.9464]
list_alpha = [0.9652,0.9289,0.9652,0.9652,0.9652,0.9657]
title = 'Datasets Restaurant'

plot_chart(list_RR, list_PC, list_alpha, title, 'blocking_restaurant')

# %%
list_RR = [0.9659,0.989,0.9659,0.9464,0.9659,0.9635]
list_PC = [0.7881,0.4441,0.7881,0.8322,0.7881,0.887]
list_alpha = [0.8679,0.6129,0.8679,0.8856,0.8679,0.9241]
title = 'Datasets Cora'

plot_chart(list_RR, list_PC, list_alpha, title, 'blocking_cora')

# %%
list_RR = [0.9829,0.9829,0.8976,0.9829,0.9829,0.9006]
list_PC = [0.7703,0.7703,0.8721,0.7703,0.7703,0.9622]
list_alpha = [0.8637,0.8637,0.8647,0.8637,0.8637,0.9304]
title = 'Datasets Census'

plot_chart(list_RR, list_PC, list_alpha, title, 'blocking_census')

# %%
list_RR = [0.9996,0.9964,0.9974,0.0,0.9959,0.999]
list_PC = [0.8826,0.9528,0.9834,0.0,0.9645,0.9820]
list_alpha = [0.9374,0.9741,0.9903,0.0,0.9799,0.9904]
title = 'Datasets DBMP-ACM'

plot_chart(list_RR, list_PC, list_alpha, title, 'blocking_DBMP_ACM')

# %%
list_RR = [0.9865,0.9979,0.9604,0.9865,0.9865,0.9277]
list_PC = [0.4661,0.1792,0.4308,0.4661,0.4661,0.8407]
list_alpha = [0.6331,0.3034,0.5947,0.6331,0.6331,0.8821]
title = 'Datasets AMZN-GP'

plot_chart(list_RR, list_PC, list_alpha, title, 'blocking_AMZN-GP')

# %%
list_RR = [0.9793,0.9935,0.9371,0.9424,0.9793,0.9217]
list_PC = [0.6272,0.4011,0.8386,0.8049,0.6272,0.9024]
list_alpha = [0.7646,0.5714,0.8851,0.8682,0.7646,0.9120]
title = 'Datasets ABT-BUY'

plot_chart(list_RR, list_PC, list_alpha, title, 'blocking_ABT-BUY')

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=((rect.get_x() + rect.get_width() / 2), height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    fontsize=12,
                    fontweight='bold',
                    ha='center', va='bottom')
        
def plot_chart_2(list_RR, list_PC, title, saveName):
    labels = ['Standard', 'Suffix', 'Sorted Neighbourhood', 'Q-gram', 'Canopy', 'Emb-Cluster']
    x = np.arange(len(labels))  # the label locations
    width = 0.2  # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(x - width, list_RR, width, label='RR - Reduction Ratio', color="#ff4040")
    rects2 = ax.bar(x + width, list_PC, width, label='PC - Pair Completeness', color="#3b63f5")
    # rects3 = ax.bar(x + width*4/3, list_alpha, width, label='α - Alpha')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Results', fontsize=20, fontweight='bold')
    ax.set_title(title, fontsize=25, fontweight='bold')
    ax.set_xticks(x)
    ax.set_xticklabels(labels, fontsize=15, fontweight='bold')
    ax.legend(loc=3,prop={'size': 15})

    autolabel(rects1, ax)
    autolabel(rects2, ax)

    fig.tight_layout()
    fig.set_size_inches(18.5, 10.5)
    if saveName:
        fig.savefig(saveName, dpi=100)
    plt.show()

# %%
list_RR = [0.99,1,0.96,0.99,0.99,0.92]
list_PC = [0.17,0.11,0.19,0.17,0.17,0.90]
title = 'Datasets ABT-BUY'
#standard-suffix-sortedN-qGram-Canopy-Clust
plot_chart_2(list_RR, list_PC, title, 'blocking_ABT-BUY_forcing')

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=((rect.get_x() + rect.get_width() / 2), height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    fontsize=12,
                    fontweight='bold',
                    ha='center', va='bottom')
        
def plot_chart_2(list_RR, list_PC, title, saveName):
    labels = ['Average', 'RNN']
    x = np.arange(len(labels))  # the label locations
    width = 0.2  # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(x - width, list_RR, width, label='RR - Reduction Ratio', color="#ff4040")
    rects2 = ax.bar(x + width, list_PC, width, label='PC - Pair Completeness', color="#3b63f5")
    # rects3 = ax.bar(x + width*4/3, list_alpha, width, label='α - Alpha')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_title(title, fontsize=15, fontweight='bold')
    ax.set_xticks(x)
    ax.set_xticklabels(labels, fontsize=15)
    # ax.legend(loc='lower center',bbox_to_anchor=(0.5, -0.5),prop={'size': 10})
    autolabel(rects1, ax)
    autolabel(rects2, ax)

    fig.tight_layout()
    #fig.set_size_inches(18.5, 10.5)
    if saveName:
        fig.savefig(saveName, dpi=100)
    plt.show()

# %%
list_RR = [0.94, 0.99] 
list_PC = [0.83, 0.95]
title = 'Dataset Restaurant '
#standard-suffix-sortedN-qGram-Canopy-Clust
plot_chart_2(list_RR, list_PC, title, 'averageVSrnn_restaurant')

# %%
list_RR = [0.72, 0.96] 
list_PC = [0.42, 0.89]
title = 'Dataset Cora '
#standard-suffix-sortedN-qGram-Canopy-Clust
plot_chart_2(list_RR, list_PC, title, 'averageVSrnn_cora')

# %%
list_RR = [0.89, 0.9] 
list_PC = [0.8, 0.96]
title = 'Dataset Census'
#standard-suffix-sortedN-qGram-Canopy-Clust
plot_chart_2(list_RR, list_PC, title, 'averageVSrnn_census')

# %%
list_RR = [1, 0.99] 
list_PC = [0.67, 0.99]
title = 'Dataset DBLP-ACM'
#standard-suffix-sortedN-qGram-Canopy-Clust
plot_chart_2(list_RR, list_PC, title, 'averageVSrnn_dblp-acm')

# %%
list_RR = [1, 0.93] 
list_PC = [0.12, 0.84]
title = 'Dataset AMZN-GP'
#standard-suffix-sortedN-qGram-Canopy-Clust
plot_chart_2(list_RR, list_PC, title, 'averageVSrnn_amzon-gp')

# %%
list_RR = [0.98, 0.93] 
list_PC = [0.25, 0.91]
title = 'Dataset ABT-BUY'
#standard-suffix-sortedN-qGram-Canopy-Clust
plot_chart_2(list_RR, list_PC, title, 'averageVSrnn_abt-buy')

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=((rect.get_x() + rect.get_width() / 2), height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    fontsize=12,
                    fontweight='bold',
                    ha='center', va='bottom')
        
def plot_chart_2(list_RR, list_PC, labels, title, saveName):
    x = np.arange(len(labels))  # the label locations
    width = 0.2  # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(x - width, list_RR, width, label='RR - Reduction Ratio', color="#ff4040")
    rects2 = ax.bar(x + width, list_PC, width, label='PC - Pair Completeness', color="#3b63f5")
    # rects3 = ax.bar(x + width*4/3, list_alpha, width, label='α - Alpha')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_title(title, fontsize=15, fontweight='bold')
    ax.set_xticks(x)
    ax.set_xticklabels(labels, fontsize=15)
    #ax.legend(loc='lower center',bbox_to_anchor=(0.5, -0.5),prop={'size': 10})
    autolabel(rects1, ax)
    autolabel(rects2, ax)

    fig.tight_layout()
    #fig.set_size_inches(18.5, 10.5)
    if saveName:
        fig.savefig(saveName, dpi=100)
    plt.show()

# %%
list_RR = [0.94, 0.99] 
list_PC = [0.89, 0.95]
title = 'Dataset Restaurant'
labels = ['uni-LSTM', 'bi-LSTM']
plot_chart_2(list_RR, list_PC, labels, title,'uni-bi-lstm_restaurant')

list_RR = [0.93, 0.96] 
list_PC = [0.47, 0.89]
title = 'Dataset Cora'
labels = ['uni-LSTM', 'bi-LSTM']
plot_chart_2(list_RR, list_PC, labels, title,'uni-bi-lstm_cora')

list_RR = [0.89, 0.9] 
list_PC = [0.8, 0.96]
title = 'Dataset Census'
labels = ['uni-LSTM', 'bi-LSTM']
plot_chart_2(list_RR, list_PC, labels, title,'uni-bi-lstm_census')

list_RR = [0.99, 0.99] 
list_PC = [0.73, 0.99]
title = 'Dataset DBLP-ACM'
labels = ['uni-LSTM', 'bi-LSTM']
plot_chart_2(list_RR, list_PC, labels, title,'uni-bi-lstm_dblp-acm')

list_RR = [0.99, 0.93] 
list_PC = [0.27, 0.84]
title = 'Dataset AMZN-GP'
labels = ['uni-LSTM', 'bi-LSTM']
plot_chart_2(list_RR, list_PC, labels, title,'uni-bi-lstm_amzn-gp')

list_RR = [0.98, 0.93] 
list_PC = [0.33, 0.91]
title = 'Dataset ABT-BUY'
labels = ['uni-LSTM', 'bi-LSTM']
plot_chart_2(list_RR, list_PC, labels, title,'uni-bi-lstm_abt-buy')

# %%
list_RR = [0.94, 0.99] 
list_PC = [0.98, 0.95]
title = 'Dataset Restaurant'
labels = ['fastText', 'GloVe']
plot_chart_2(list_RR, list_PC, labels, title,'fastText-Glove_restaurant')

list_RR = [0.92, 0.96] 
list_PC = [0.6, 0.89]
title = 'Dataset Cora'
plot_chart_2(list_RR, list_PC, labels, title,'fastText-Glove_cora')

list_RR = [0.89, 0.9] 
list_PC = [0.8, 0.96]
title = 'Dataset Census'
plot_chart_2(list_RR, list_PC, labels, title,'fastText-Glove_census')

list_RR = [0.99, 0.99] 
list_PC = [0.94, 0.99]
title = 'Dataset DBLP-ACM'
plot_chart_2(list_RR, list_PC, labels, title,'fastText-Glove_dblp-acm')

list_RR = [0.99, 0.93] 
list_PC = [0.4, 0.84]
title = 'Dataset AMZN-GP'
plot_chart_2(list_RR, list_PC, labels, title,'fastText-Glove_amzn-gp')

list_RR = [0.98, 0.93] 
list_PC = [0.53, 0.91]
title = 'Dataset ABT-BUY'
plot_chart_2(list_RR, list_PC, labels, title,'fastText-Glove_abt-buy')

# %%
list_RR = [0.96, 0.99] 
list_PC = [0.8, 0.95]
title = 'Dataset Restaurant'
labels = ['PCA', 't-SNE']
plot_chart_2(list_RR, list_PC, labels, title,'pca-tsne_restaurant')

list_RR = [0.67, 0.96] 
list_PC = [0.66, 0.89]
title = 'Dataset Cora'
plot_chart_2(list_RR, list_PC, labels, title,'pca-tsne_cora')

list_RR = [0.56, 0.9] 
list_PC = [0.82, 0.96]
title = 'Dataset Census'
plot_chart_2(list_RR, list_PC, labels, title,'pca-tsne_census')

list_RR = [0.87, 1] 
list_PC = [0.74, 0.98]
title = 'Dataset DBLP-ACM'
plot_chart_2(list_RR, list_PC, labels, title,'pca-tsne_dblp-acm')

list_RR = [0.63, 0.93] 
list_PC = [0.55, 0.84]
title = 'Dataset AMZN-GP'
plot_chart_2(list_RR, list_PC, labels, title,'pca-tsne_amzn-gp')

list_RR = [0.61, 0.92] 
list_PC = [0.6, 0.9]
title = 'Dataset ABT-BUY'
plot_chart_2(list_RR, list_PC, labels, title,'pca-tsne_abt-buy')

# %%
list_RR = [0.98, 0.99,0.99,0.98] 
list_PC = [0.95, 0.92,0.95,0.95]
title = 'Dataset Restaurant'
labels = ['H-Clust', 'K-Means', 'DBSCAN', 'Birch']
plot_chart_2(list_RR, list_PC, labels, title,'cluster_restaurant')

list_RR = [0.96, 0.95,0.96,0.96] 
list_PC = [0.89, 0.85,0.87,0.89]
title = 'Dataset Cora'
plot_chart_2(list_RR, list_PC, labels, title,'cluster_cora')

list_RR = [0.9, 0.92,0.91,0.9] 
list_PC = [0.96, 0.89,0.88,0.89]
title = 'Dataset Census'
plot_chart_2(list_RR, list_PC, labels, title,'cluster_census')

list_RR = [1,0,1,1] 
list_PC = [0.98,0,0.98,0.98]
title = 'Dataset DBLP-ACM'
plot_chart_2(list_RR, list_PC, labels, title,'cluster_dblp-acm')

list_RR = [0.93, 0.92,0.96,0.96] 
list_PC = [0.84, 0.75,0.73,0.76]
title = 'Dataset AMZN-GP'
plot_chart_2(list_RR, list_PC, labels, title,'cluster_amzn-gp')

list_RR = [0.91, 0.92,0.94,0.92] 
list_PC = [0.91, 0.87,0.85,0.9]
title = 'Dataset ABT-BUY'
plot_chart_2(list_RR, list_PC, labels, title,'cluster_abt-buy')

# %%
list_RR = [0.98, 0.97,0.99] 
list_PC = [0.93, 0.94,0.95]
title = 'Dataset Restaurant'
labels = ['300','1024','2048']
plot_chart_2(list_RR, list_PC, labels, title,'cell_restaurant')

list_RR = [0.96, 0.96,0.96] 
list_PC = [0.85, 0.86,0.89]
title = 'Dataset Cora'
plot_chart_2(list_RR, list_PC, labels, title,'cell_cora')

list_RR = [0.89, 0.89,0.9] 
list_PC = [0.94, 0.95,0.96]
title = 'Dataset Census'
plot_chart_2(list_RR, list_PC, labels, title,'cell_census')

list_RR = [0.98,0.98,0.99] 
list_PC = [0.99,0.99,0.99]
title = 'Dataset DBLP-ACM'
plot_chart_2(list_RR, list_PC, labels, title,'cell_dblp-acm')

list_RR = [0.92, 0.92,0.93] 
list_PC = [0.84, 0.83,0.84]
title = 'Dataset AMZN-GP'
plot_chart_2(list_RR, list_PC, labels, title,'cell_amzn-gp')

list_RR = [0.95, 0.95,0.93] 
list_PC = [0.88, 0.89,0.91]
title = 'Dataset ABT-BUY'
plot_chart_2(list_RR, list_PC, labels, title,'cell_abt-buy')

# %%
list_embedding = [0.9233, 0.7626, 0.8352]
list_clustering = [0.9635, 0.887, 0.9241]
title = 'Scores Cora'


plot_chart(list_embedding, list_clustering, title)

# %%
list_embedding = [0.8945, 0.9542, 0.9234]
list_clustering = [0.9006, 0.9622, 0.9304]
title = 'Scores Census'

plot_chart(list_embedding, list_clustering, title)

# %%
list_embedding = [0.9873, 0.9946, 0.9909]
list_clustering = [0.9990, 0.9775, 0.9881]
title = 'Scores DBLP_ACM'

plot_chart(list_embedding, list_clustering, title)

# %%
list_embedding = [0.9436, 0.7885, 0.8591]
list_clustering = [0.9277, 0.8407, 0.8821]
title = 'Scores AMAZON-GP'

plot_chart(list_embedding, list_clustering, title)

# %%
list_embedding = [0.9343, 0.9088, 0.9213]
list_clustering = [0.9078, 0.9134, 0.9106]
title = 'Scores ABT-BUY'

plot_chart(list_embedding, list_clustering, title)
