# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-and-setup-models" data-toc-modified-id="Import-and-setup-models-1">Import and setup models</a></span></li><li><span><a href="#Embedding-all-attributes" data-toc-modified-id="Embedding-all-attributes-2">Embedding all attributes</a></span></li><li><span><a href="#Embedding-few-attributes" data-toc-modified-id="Embedding-few-attributes-3">Embedding few attributes</a></span></li><li><span><a href="#Trying-output-single" data-toc-modified-id="Trying-output-single-4">Trying output single</a></span></li></ul></div>

# %% [markdown]
# # Import and setup models

# %%
import os
import sys
import time
import numpy as np
import matplotlib.pyplot as plt

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from embedding_algorithms.inferSent import set_RNN_embedding, tuple_inferSent_embedding, RNN_embedding
from dimensionality_reduction_algorithms.tsne import tsne_dim_reduction
from preprocessing_datasets import load_dataset

# %%
dataset_name, table, pairs = load_dataset({'dataset':'cora', 'cluster_method': 'hierarchy', 'verbose': 1, 'embedding_type': 'infersent'})
# Out:
# #####################################################################
# CURRENT dataset:        cora
# CURRENT cluster_method: hierarchy
# CURRENT embedding_type: infersent
# #####################################################################

# %%
start = time.time()
set_RNN_embedding("bilstm", False, 2, 2048, 1)
print("TIME: {0}".format(time.time() - start))
# Out:
# Vocab size : 2196017
# TIME: 176.29808592796326

# %%
from preprocessing_datasets.preprocessing_utilities import get_labels_by
labels = get_labels_by('../source_datasets/cora/cora.csv', 'class')

# %%
import random
def random_color(n):
    r = int(random.random() * 256)
    g = int(random.random() * 256)
    b = int(random.random() * 256)
    step = 256 / n
    r += step
    g += step
    b += step
    r = int(r) % 256
    g = int(g) % 256
    b = int(b) % 256
    return r,g,b

def rgb2hex(r,g,b):
    return "#{:02x}{:02x}{:02x}".format(r,g,b)

# %%
dic = {}
count = 5

chosen_labels = []
remove_index = []
colors = {}
init_color = 1

for i in range(len(labels)):
    if labels[i] not in dic.keys():
        dic[labels[i]] = 1
        r, g, b = random_color(init_color)
        colors[labels[i]] = rgb2hex(r,g,b)
        init_color = init_color + 1
    elif dic[labels[i]] < count:
        dic[labels[i]] = dic[labels[i]] + 1
    else: 
        remove_index.append(i)
        continue
    chosen_labels.append(labels[i])
 
    
table = table.drop(remove_index)

# %% [markdown]
# # Embedding all attributes

# %%
embeddings_tokens = RNN_embedding(table, [], "bilstm", False)
embeddings_tokens = np.array(embeddings_tokens)
# Out:
# all attributes used

# %%
tsne_embeddings = tsne_dim_reduction(
    embeddings_tokens, 
    num_components=2,
    early_exaggeration=12,
    verbose=1,
    perplexity=40,
    method="barnes_hut")
# Out:
# starting dimension: 4096
# setting TSNE with n_components: 2 & perplexity: 40

# %%
x = []
y = []
for emb in tsne_embeddings:
    x.append(emb[0])
    y.append(emb[1])

print("rows: {0}".format(len(x)))
print("classes: {0}".format(len(colors)))

plt.figure(figsize=(13, 13)) 
for i in range(len(x)):
    plt.scatter(x[i],y[i], c=colors[chosen_labels[i]])
    # plt.annotate(i,
    #         xy=(x[i], y[i]),
    #         xytext=(5, 2),
    #         textcoords='offset points',
    #         ha='right',
    #         va='bottom')
plt.show()
# Out:
# rows: 420
# classes: 112

# %%
num_clusters = 10
blocks = hierarchy_cluster(tsne_embeddings, {'num_clusters': num_clusters})
x_blocks = []
y_blocks = []
for emb in tsne_embeddings:
    x_blocks.append(emb[0])
    y_blocks.append(emb[1])
plt.figure(figsize=(13, 13)) 

for i in range(num_clusters):
    colorInit = 1 + i
    r, g, b = random_color(colorInit)
    selected_color = rgb2hex(r,g,b)
    block = blocks[i]
    for e in block:
        plt.scatter(x[e],y[e], c=selected_color)
        #plt.annotate(colors[chosen_labels[e]],
        #             xy=(x[e], y[e]),
        #             xytext=(5, 2),
        #             textcoords='offset points',
        #             ha='right',
        #             va='bottom')

plt.show()
# Out:
# clustering with NUM_CLUSTERS = 10,

# %% [markdown]
# # Embedding few attributes

# %%
embeddings_tokens = RNN_embedding(table, ['author', 'title'], "bilstm", False)
embeddings_tokens = np.array(embeddings_tokens)
# Out:
# attrs: ['author', 'title']

# %%
tsne_embeddings = tsne_dim_reduction(
    embeddings_tokens, 
    num_components=2,
    verbose=1,
    perplexity=40,
    method="barnes_hut")
# Out:
# starting dimension: 4096
# setting TSNE with n_components: 2 & perplexity: 40

# %%
x = []
y = []
for emb in tsne_embeddings:
    x.append(emb[0])
    y.append(emb[1])

print("rows: {0}".format(len(x)))
print("classes: {0}".format(len(colors)))
# Out:
# rows: 420
# classes: 112

# %%
plt.figure(figsize=(13, 13)) 
for i in range(len(x)):
    plt.scatter(x[i],y[i], c=colors[chosen_labels[i]])
    # plt.annotate(i,
    #         xy=(x[i], y[i]),
    #         xytext=(5, 2),
    #         textcoords='offset points',
    #         ha='right',
    #         va='bottom')
plt.show()

# %%
num_clusters = 10
blocks = hierarchy_cluster(tsne_embeddings, {'num_clusters': num_clusters})
# Out:
# clustering with NUM_CLUSTERS = 10,

# %%
x_blocks = []
y_blocks = []
for emb in tsne_embeddings:
    x_blocks.append(emb[0])
    y_blocks.append(emb[1])

# %%
plt.figure(figsize=(13, 13)) 

for i in range(num_clusters):
    colorInit = 1 + i
    r, g, b = random_color(colorInit)
    selected_color = rgb2hex(r,g,b)
    block = blocks[i]
    for e in block:
        plt.scatter(x[e],y[e], c=selected_color)
        #plt.annotate(colors[chosen_labels[e]],
        #             xy=(x[e], y[e]),
        #             xytext=(5, 2),
        #             textcoords='offset points',
        #             ha='right',
        #             va='bottom')

plt.show()

# %% [markdown]
# # Trying output single

# %%
embeddings_tokens = RNN_embedding(table, ['author', 'title'], "bilstm", False)
embeddings_tokens = np.array(embeddings_tokens)

tsne_embeddings = tsne_dim_reduction(
    embeddings_tokens, 
    num_components=2,
    early_exaggeration=12,
    verbose=1,
    perplexity=40,
    method="barnes_hut")
# Out:
# attrs: ['author', 'title']
# starting dimension: 4096
# setting TSNE with n_components: 2 & perplexity: 40

# %%
x = []
y = []
for emb in tsne_embeddings:
    x.append(emb[0])
    y.append(emb[1])

print("rows: {0}".format(len(x)))
print("classes: {0}".format(len(colors)))
# Out:
# rows: 420
# classes: 112

# %%
colors.keys()
# Out:
# dict_keys(["'auer1995a'", "'blum1993'", "'blum1994'", "'cesa'", "'cohen1998'", "'dietterich1996'", "'drucker1992'", "'druker1992'", "'ehrenfeucht1988'", "'ehrenfeucht1989'", "'feder1995'", "'freund0000a'", "'freund1995a'", "'freund1992a'", "'freund1992b'", "'freund1992c'", "'freund1993a'", "'freund1993b'", "'freund1993c'", "'freund1995b'", "'freund1995c'", "'freund1995d'", "'freund1995e'", "'freund1995f'", "'freund1996a'", "'freund1996b'", "'freund1996c'", "'freund1996d'", "'freund1996e'", "'freund1997a'", "'freund1997b'", "'freund1997c'", "'freund1997d'", "'goldman1989'", "'goldman1993a'", "'goldman1990a'", "'goldman1990c'", "'goldman1991'", "'goldman1993'", "'goldman1995'", "'haussler1988'", "'haussler1991'", "'haussler1994a'", "'haussler1991p'", "'haussler1992'", "'haussler1994'", "'haussler1996'", "'helmbold1995'", "'helmbold1995a'", "'helmbold1996'", "'helmbold1996a'", "'helmbold1997'", "'helmbold1997c'", "'kautz1993'", "'kautz1995'", "'kearns1987'", "'kearns1987b'", "'kearns1988'", "'kearns1988b'", "'kearns1989'", "'kearns1989a'", "'kearns1990'", "'kearns1990b'", "'kearns1990c'", "'kearns1992a'", "'kearns1992c'", "'kearns1993a'", "'kearns1993b'", "'kearns1993c'", "'kearns1994a'", "'kearns1994b'", "'kearns1994c'", "'kearns1994cryp'", "'kearns1994d'", "'kearns1994e'", "'kearns1994f'", "'kearns1995b'", "'kearns1996a'", "'kearns1996b'", "'kearns1997a'", "'kearns1997b'", "'kearns1998'", "'kearns1999a'", "'kearns1999b'", "'lewis1996'", "'littlestone'", "'rivest1987'", "'rivest1987d'", "'rivest1989'", "'rivest1992'", "'rivest1993'", "'rivest1994'", "'schapire'", "'schapire1988'", "'schapire1989'", "'schapire1990'", "'schapire1990e'", "'schapire1991'", "'schapire1991l'", "'schapire1992'", "'schapire1993'", "'schapire1994'", "'schapire1995'", "'schapire1996'", "'schapire1996p'", "'schapire1997'", "'bauer1992'", "'schapire1997u'", "'schapire1997um'", "'schapire1998'", "'schapire1998mm'", "'singer'"])

# %%
key = "'blum1993'"
print(key)
x_points = []
y_points = []
for i in range(len(x)):
    if chosen_labels[i] == key:
        x_points.append(x[i])
        y_points.append(y[i])
plt.figure(figsize=(13, 13)) 
plt.scatter(x_points,y_points, c=colors[chosen_labels[i]])

plt.show()
# Out:
# 'blum1993'

# %%
plt.figure(figsize=(2, 2)) 
plt.scatter([1,2,3],[2,3,4], c="red")
plt.show()
